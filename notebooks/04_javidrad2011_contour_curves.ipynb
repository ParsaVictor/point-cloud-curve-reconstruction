# %% [markdown]
# # Imports and index definitions# Imports and index definitions# Imports and index definitions# Imports and index definitions# Imports and index definitions# Imports and index definitions# Imports and index definitions# Imports and index definitions# Imports and index definitions# Imports and index definitions# Imports and index definitions# Imports and index definitions# Imports and index definitions# Imports and index definitions# Imports and index definitions# Imports and index definitions# Imports and index definitions# Imports and index definitions# Imports and index definitions# Imports and index definitions# Imports and index definitions# Imports and index definitions# Imports and index definitions# Imports and index definitions# Imports and index definitions# Imports and index definitions# Imports and index definitions# Imports and index definitions# Imports and index definitions# Imports and index definitions# Imports and index definitions# Imports and index definitions# Imports and index definitions# Imports and index definitions# Imports and index definitions# Imports and index definitions# Imports and index definitions

# %%
import os, time, json
import os, time, json
import os, time, json
import os, time, json
import os, time, json
import os, time, json
import os, time, json
import os, time, json
import os, time, json
import os, time, json
import os, time, json
import os, time, json
import os, time, json
import os, time, json
import os, time, json
import os, time, json
import os, time, json
import os, time, json
import os, time, json
import os, time, json
import os, time, json
import os, time, json
import os, time, json
import os, time, json
import os, time, json
import os, time, json
import os, time, json
import os, time, json
import os, time, json
import os, time, json
import os, time, json
import os, time, json
import os, time, json
import os, time, json
import os, time, json
import os, time, json
import os, time, json
import numpy as np
import numpy as np
import numpy as np
import numpy as np
import numpy as np
import numpy as np
import numpy as np
import numpy as np
import numpy as np
import numpy as np
import numpy as np
import numpy as np
import numpy as np
import numpy as np
import numpy as np
import numpy as np
import numpy as np
import numpy as np
import numpy as np
import numpy as np
import numpy as np
import numpy as np
import numpy as np
import numpy as np
import numpy as np
import numpy as np
import numpy as np
import numpy as np
import numpy as np
import numpy as np
import numpy as np
import numpy as np
import numpy as np
import numpy as np
import numpy as np
import numpy as np
import numpy as np
import pandas as pd
import pandas as pd
import pandas as pd
import pandas as pd
import pandas as pd
import pandas as pd
import pandas as pd
import pandas as pd
import pandas as pd
import pandas as pd
import pandas as pd
import pandas as pd
import pandas as pd
import pandas as pd
import pandas as pd
import pandas as pd
import pandas as pd
import pandas as pd
import pandas as pd
import pandas as pd
import pandas as pd
import pandas as pd
import pandas as pd
import pandas as pd
import pandas as pd
import pandas as pd
import pandas as pd
import pandas as pd
import pandas as pd
import pandas as pd
import pandas as pd
import pandas as pd
import pandas as pd
import pandas as pd
import pandas as pd
import pandas as pd
import pandas as pd
from numpy.linalg import svd
from numpy.linalg import svd
from numpy.linalg import svd
from numpy.linalg import svd
from numpy.linalg import svd
from numpy.linalg import svd
from numpy.linalg import svd
from numpy.linalg import svd
from numpy.linalg import svd
from numpy.linalg import svd
from numpy.linalg import svd
from numpy.linalg import svd
from numpy.linalg import svd
from numpy.linalg import svd
from numpy.linalg import svd
from numpy.linalg import svd
from numpy.linalg import svd
from numpy.linalg import svd
from numpy.linalg import svd
from numpy.linalg import svd
from numpy.linalg import svd
from numpy.linalg import svd
from numpy.linalg import svd
from numpy.linalg import svd
from numpy.linalg import svd
from numpy.linalg import svd
from numpy.linalg import svd
from numpy.linalg import svd
from numpy.linalg import svd
from numpy.linalg import svd
from numpy.linalg import svd
from numpy.linalg import svd
from numpy.linalg import svd
from numpy.linalg import svd
from numpy.linalg import svd
from numpy.linalg import svd
from numpy.linalg import svd
from sklearn.neighbors import NearestNeighbors, KDTree
from sklearn.neighbors import NearestNeighbors, KDTree
from sklearn.neighbors import NearestNeighbors, KDTree
from sklearn.neighbors import NearestNeighbors, KDTree
from sklearn.neighbors import NearestNeighbors, KDTree
from sklearn.neighbors import NearestNeighbors, KDTree
from sklearn.neighbors import NearestNeighbors, KDTree
from sklearn.neighbors import NearestNeighbors, KDTree
from sklearn.neighbors import NearestNeighbors, KDTree
from sklearn.neighbors import NearestNeighbors, KDTree
from sklearn.neighbors import NearestNeighbors, KDTree
from sklearn.neighbors import NearestNeighbors, KDTree
from sklearn.neighbors import NearestNeighbors, KDTree
from sklearn.neighbors import NearestNeighbors, KDTree
from sklearn.neighbors import NearestNeighbors, KDTree
from sklearn.neighbors import NearestNeighbors, KDTree
from sklearn.neighbors import NearestNeighbors, KDTree
from sklearn.neighbors import NearestNeighbors, KDTree
from sklearn.neighbors import NearestNeighbors, KDTree
from sklearn.neighbors import NearestNeighbors, KDTree
from sklearn.neighbors import NearestNeighbors, KDTree
from sklearn.neighbors import NearestNeighbors, KDTree
from sklearn.neighbors import NearestNeighbors, KDTree
from sklearn.neighbors import NearestNeighbors, KDTree
from sklearn.neighbors import NearestNeighbors, KDTree
from sklearn.neighbors import NearestNeighbors, KDTree
from sklearn.neighbors import NearestNeighbors, KDTree
from sklearn.neighbors import NearestNeighbors, KDTree
from sklearn.neighbors import NearestNeighbors, KDTree
from sklearn.neighbors import NearestNeighbors, KDTree
from sklearn.neighbors import NearestNeighbors, KDTree
from sklearn.neighbors import NearestNeighbors, KDTree
from sklearn.neighbors import NearestNeighbors, KDTree
from sklearn.neighbors import NearestNeighbors, KDTree
from sklearn.neighbors import NearestNeighbors, KDTree
from sklearn.neighbors import NearestNeighbors, KDTree
from sklearn.neighbors import NearestNeighbors, KDTree
from sklearn.cluster import DBSCAN
from sklearn.cluster import DBSCAN
from sklearn.cluster import DBSCAN
from sklearn.cluster import DBSCAN
from sklearn.cluster import DBSCAN
from sklearn.cluster import DBSCAN
from sklearn.cluster import DBSCAN
from sklearn.cluster import DBSCAN
from sklearn.cluster import DBSCAN
from sklearn.cluster import DBSCAN
from sklearn.cluster import DBSCAN
from sklearn.cluster import DBSCAN
from sklearn.cluster import DBSCAN
from sklearn.cluster import DBSCAN
from sklearn.cluster import DBSCAN
from sklearn.cluster import DBSCAN
from sklearn.cluster import DBSCAN
from sklearn.cluster import DBSCAN
from sklearn.cluster import DBSCAN
from sklearn.cluster import DBSCAN
from sklearn.cluster import DBSCAN
from sklearn.cluster import DBSCAN
from sklearn.cluster import DBSCAN
from sklearn.cluster import DBSCAN
from sklearn.cluster import DBSCAN
from sklearn.cluster import DBSCAN
from sklearn.cluster import DBSCAN
from sklearn.cluster import DBSCAN
from sklearn.cluster import DBSCAN
from sklearn.cluster import DBSCAN
from sklearn.cluster import DBSCAN
from sklearn.cluster import DBSCAN
from sklearn.cluster import DBSCAN
from sklearn.cluster import DBSCAN
from sklearn.cluster import DBSCAN
from sklearn.cluster import DBSCAN
from sklearn.cluster import DBSCAN
from scipy.interpolate import splprep, splev
from scipy.interpolate import splprep, splev
from scipy.interpolate import splprep, splev
from scipy.interpolate import splprep, splev
from scipy.interpolate import splprep, splev
from scipy.interpolate import splprep, splev
from scipy.interpolate import splprep, splev
from scipy.interpolate import splprep, splev
from scipy.interpolate import splprep, splev
from scipy.interpolate import splprep, splev
from scipy.interpolate import splprep, splev
from scipy.interpolate import splprep, splev
from scipy.interpolate import splprep, splev
from scipy.interpolate import splprep, splev
from scipy.interpolate import splprep, splev
from scipy.interpolate import splprep, splev
from scipy.interpolate import splprep, splev
from scipy.interpolate import splprep, splev
from scipy.interpolate import splprep, splev
from scipy.interpolate import splprep, splev
from scipy.interpolate import splprep, splev
from scipy.interpolate import splprep, splev
from scipy.interpolate import splprep, splev
from scipy.interpolate import splprep, splev
from scipy.interpolate import splprep, splev
from scipy.interpolate import splprep, splev
from scipy.interpolate import splprep, splev
from scipy.interpolate import splprep, splev
from scipy.interpolate import splprep, splev
from scipy.interpolate import splprep, splev
from scipy.interpolate import splprep, splev
from scipy.interpolate import splprep, splev
from scipy.interpolate import splprep, splev
from scipy.interpolate import splprep, splev
from scipy.interpolate import splprep, splev
from scipy.interpolate import splprep, splev
from scipy.interpolate import splprep, splev
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from mpl_toolkits.mplot3d import Axes3D
from mpl_toolkits.mplot3d import Axes3D
from mpl_toolkits.mplot3d import Axes3D
from mpl_toolkits.mplot3d import Axes3D
from mpl_toolkits.mplot3d import Axes3D
from mpl_toolkits.mplot3d import Axes3D
from mpl_toolkits.mplot3d import Axes3D
from mpl_toolkits.mplot3d import Axes3D
from mpl_toolkits.mplot3d import Axes3D
from mpl_toolkits.mplot3d import Axes3D
from mpl_toolkits.mplot3d import Axes3D
from mpl_toolkits.mplot3d import Axes3D
from mpl_toolkits.mplot3d import Axes3D
from mpl_toolkits.mplot3d import Axes3D
from mpl_toolkits.mplot3d import Axes3D
from mpl_toolkits.mplot3d import Axes3D
from mpl_toolkits.mplot3d import Axes3D
from mpl_toolkits.mplot3d import Axes3D
from mpl_toolkits.mplot3d import Axes3D
from mpl_toolkits.mplot3d import Axes3D
from mpl_toolkits.mplot3d import Axes3D
from mpl_toolkits.mplot3d import Axes3D
from mpl_toolkits.mplot3d import Axes3D
from mpl_toolkits.mplot3d import Axes3D
from mpl_toolkits.mplot3d import Axes3D
from mpl_toolkits.mplot3d import Axes3D
from mpl_toolkits.mplot3d import Axes3D
from mpl_toolkits.mplot3d import Axes3D
from mpl_toolkits.mplot3d import Axes3D
from mpl_toolkits.mplot3d import Axes3D
from mpl_toolkits.mplot3d import Axes3D
from mpl_toolkits.mplot3d import Axes3D
from mpl_toolkits.mplot3d import Axes3D
from mpl_toolkits.mplot3d import Axes3D
from mpl_toolkits.mplot3d import Axes3D
from mpl_toolkits.mplot3d import Axes3D





































INPUT_CSV = "6.csv"           # input CSV (first three columns X,Y,Z)
INPUT_CSV = "6.csv"           # input CSV (first three columns X,Y,Z)
INPUT_CSV = "6.csv"           # input CSV (first three columns X,Y,Z)
INPUT_CSV = "6.csv"           # input CSV (first three columns X,Y,Z)
INPUT_CSV = "6.csv"           # input CSV (first three columns X,Y,Z)
INPUT_CSV = "6.csv"           # input CSV (first three columns X,Y,Z)
INPUT_CSV = "6.csv"           # input CSV (first three columns X,Y,Z)
INPUT_CSV = "6.csv"           # input CSV (first three columns X,Y,Z)
INPUT_CSV = "6.csv"           # input CSV (first three columns X,Y,Z)
INPUT_CSV = "6.csv"           # input CSV (first three columns X,Y,Z)
INPUT_CSV = "6.csv"           # input CSV (first three columns X,Y,Z)
INPUT_CSV = "6.csv"           # input CSV (first three columns X,Y,Z)
INPUT_CSV = "6.csv"           # input CSV (first three columns X,Y,Z)
INPUT_CSV = "6.csv"           # input CSV (first three columns X,Y,Z)
INPUT_CSV = "6.csv"           # input CSV (first three columns X,Y,Z)
INPUT_CSV = "6.csv"           # input CSV (first three columns X,Y,Z)
INPUT_CSV = "6.csv"           # input CSV (first three columns X,Y,Z)
INPUT_CSV = "6.csv"           # input CSV (first three columns X,Y,Z)
INPUT_CSV = "6.csv"           # input CSV (first three columns X,Y,Z)
INPUT_CSV = "6.csv"           # input CSV (first three columns X,Y,Z)
INPUT_CSV = "6.csv"           # input CSV (first three columns X,Y,Z)
INPUT_CSV = "6.csv"           # input CSV (first three columns X,Y,Z)
INPUT_CSV = "6.csv"           # input CSV (first three columns X,Y,Z)
INPUT_CSV = "6.csv"           # input CSV (first three columns X,Y,Z)
INPUT_CSV = "6.csv"           # input CSV (first three columns X,Y,Z)
INPUT_CSV = "6.csv"           # input CSV (first three columns X,Y,Z)
INPUT_CSV = "6.csv"           # input CSV (first three columns X,Y,Z)
INPUT_CSV = "6.csv"           # input CSV (first three columns X,Y,Z)
INPUT_CSV = "6.csv"           # input CSV (first three columns X,Y,Z)
INPUT_CSV = "6.csv"           # input CSV (first three columns X,Y,Z)
INPUT_CSV = "6.csv"           # input CSV (first three columns X,Y,Z)
INPUT_CSV = "6.csv"           # input CSV (first three columns X,Y,Z)
INPUT_CSV = "6.csv"           # input CSV (first three columns X,Y,Z)
INPUT_CSV = "6.csv"           # input CSV (first three columns X,Y,Z)
INPUT_CSV = "6.csv"           # input CSV (first three columns X,Y,Z)
INPUT_CSV = "6.csv"           # input CSV (first three columns X,Y,Z)
INPUT_CSV = "6.csv"           # input CSV (first three columns X,Y,Z)
OUTDIR = "results_clean"      # output directory
OUTDIR = "results_clean"      # output directory
OUTDIR = "results_clean"      # output directory
OUTDIR = "results_clean"      # output directory
OUTDIR = "results_clean"      # output directory
OUTDIR = "results_clean"      # output directory
OUTDIR = "results_clean"      # output directory
OUTDIR = "results_clean"      # output directory
OUTDIR = "results_clean"      # output directory
OUTDIR = "results_clean"      # output directory
OUTDIR = "results_clean"      # output directory
OUTDIR = "results_clean"      # output directory
OUTDIR = "results_clean"      # output directory
OUTDIR = "results_clean"      # output directory
OUTDIR = "results_clean"      # output directory
OUTDIR = "results_clean"      # output directory
OUTDIR = "results_clean"      # output directory
OUTDIR = "results_clean"      # output directory
OUTDIR = "results_clean"      # output directory
OUTDIR = "results_clean"      # output directory
OUTDIR = "results_clean"      # output directory
OUTDIR = "results_clean"      # output directory
OUTDIR = "results_clean"      # output directory
OUTDIR = "results_clean"      # output directory
OUTDIR = "results_clean"      # output directory
OUTDIR = "results_clean"      # output directory
OUTDIR = "results_clean"      # output directory
OUTDIR = "results_clean"      # output directory
OUTDIR = "results_clean"      # output directory
OUTDIR = "results_clean"      # output directory
OUTDIR = "results_clean"      # output directory
OUTDIR = "results_clean"      # output directory
OUTDIR = "results_clean"      # output directory
OUTDIR = "results_clean"      # output directory
OUTDIR = "results_clean"      # output directory
OUTDIR = "results_clean"      # output directory
OUTDIR = "results_clean"      # output directory
OUTFILE = "6_cleaned_only_removed.csv"  # output: retained points only (no coordinates modified)
OUTFILE = "6_cleaned_only_removed.csv"  # output: retained points only (no coordinates modified)
OUTFILE = "6_cleaned_only_removed.csv"  # output: retained points only (no coordinates modified)
OUTFILE = "6_cleaned_only_removed.csv"  # output: retained points only (no coordinates modified)
OUTFILE = "6_cleaned_only_removed.csv"  # output: retained points only (no coordinates modified)
OUTFILE = "6_cleaned_only_removed.csv"  # output: retained points only (no coordinates modified)
OUTFILE = "6_cleaned_only_removed.csv"  # output: retained points only (no coordinates modified)
OUTFILE = "6_cleaned_only_removed.csv"  # output: retained points only (no coordinates modified)
OUTFILE = "6_cleaned_only_removed.csv"  # output: retained points only (no coordinates modified)
OUTFILE = "6_cleaned_only_removed.csv"  # output: retained points only (no coordinates modified)
OUTFILE = "6_cleaned_only_removed.csv"  # output: retained points only (no coordinates modified)
OUTFILE = "6_cleaned_only_removed.csv"  # output: retained points only (no coordinates modified)
OUTFILE = "6_cleaned_only_removed.csv"  # output: retained points only (no coordinates modified)
OUTFILE = "6_cleaned_only_removed.csv"  # output: retained points only (no coordinates modified)
OUTFILE = "6_cleaned_only_removed.csv"  # output: retained points only (no coordinates modified)
OUTFILE = "6_cleaned_only_removed.csv"  # output: retained points only (no coordinates modified)
OUTFILE = "6_cleaned_only_removed.csv"  # output: retained points only (no coordinates modified)
OUTFILE = "6_cleaned_only_removed.csv"  # output: retained points only (no coordinates modified)
OUTFILE = "6_cleaned_only_removed.csv"  # output: retained points only (no coordinates modified)
OUTFILE = "6_cleaned_only_removed.csv"  # output: retained points only (no coordinates modified)
OUTFILE = "6_cleaned_only_removed.csv"  # output: retained points only (no coordinates modified)
OUTFILE = "6_cleaned_only_removed.csv"  # output: retained points only (no coordinates modified)
OUTFILE = "6_cleaned_only_removed.csv"  # output: retained points only (no coordinates modified)
OUTFILE = "6_cleaned_only_removed.csv"  # output: retained points only (no coordinates modified)
OUTFILE = "6_cleaned_only_removed.csv"  # output: retained points only (no coordinates modified)
OUTFILE = "6_cleaned_only_removed.csv"  # output: retained points only (no coordinates modified)
OUTFILE = "6_cleaned_only_removed.csv"  # output: retained points only (no coordinates modified)
OUTFILE = "6_cleaned_only_removed.csv"  # output: retained points only (no coordinates modified)
OUTFILE = "6_cleaned_only_removed.csv"  # output: retained points only (no coordinates modified)
OUTFILE = "6_cleaned_only_removed.csv"  # output: retained points only (no coordinates modified)
OUTFILE = "6_cleaned_only_removed.csv"  # output: retained points only (no coordinates modified)
OUTFILE = "6_cleaned_only_removed.csv"  # output: retained points only (no coordinates modified)
OUTFILE = "6_cleaned_only_removed.csv"  # output: retained points only (no coordinates modified)
OUTFILE = "6_cleaned_only_removed.csv"  # output: retained points only (no coordinates modified)
OUTFILE = "6_cleaned_only_removed.csv"  # output: retained points only (no coordinates modified)
OUTFILE = "6_cleaned_only_removed.csv"  # output: retained points only (no coordinates modified)
OUTFILE = "6_cleaned_only_removed.csv"  # output: retained points only (no coordinates modified)
SUMMARY_JSON = "clean_summary.json"
SUMMARY_JSON = "clean_summary.json"
SUMMARY_JSON = "clean_summary.json"
SUMMARY_JSON = "clean_summary.json"
SUMMARY_JSON = "clean_summary.json"
SUMMARY_JSON = "clean_summary.json"
SUMMARY_JSON = "clean_summary.json"
SUMMARY_JSON = "clean_summary.json"
SUMMARY_JSON = "clean_summary.json"
SUMMARY_JSON = "clean_summary.json"
SUMMARY_JSON = "clean_summary.json"
SUMMARY_JSON = "clean_summary.json"
SUMMARY_JSON = "clean_summary.json"
SUMMARY_JSON = "clean_summary.json"
SUMMARY_JSON = "clean_summary.json"
SUMMARY_JSON = "clean_summary.json"
SUMMARY_JSON = "clean_summary.json"
SUMMARY_JSON = "clean_summary.json"
SUMMARY_JSON = "clean_summary.json"
SUMMARY_JSON = "clean_summary.json"
SUMMARY_JSON = "clean_summary.json"
SUMMARY_JSON = "clean_summary.json"
SUMMARY_JSON = "clean_summary.json"
SUMMARY_JSON = "clean_summary.json"
SUMMARY_JSON = "clean_summary.json"
SUMMARY_JSON = "clean_summary.json"
SUMMARY_JSON = "clean_summary.json"
SUMMARY_JSON = "clean_summary.json"
SUMMARY_JSON = "clean_summary.json"
SUMMARY_JSON = "clean_summary.json"
SUMMARY_JSON = "clean_summary.json"
SUMMARY_JSON = "clean_summary.json"
SUMMARY_JSON = "clean_summary.json"
SUMMARY_JSON = "clean_summary.json"
SUMMARY_JSON = "clean_summary.json"
SUMMARY_JSON = "clean_summary.json"
SUMMARY_JSON = "clean_summary.json"





































# Outlier removal control (main knobs)
# Outlier removal control (main knobs)
# Outlier removal control (main knobs)
# Outlier removal control (main knobs)
# Outlier removal control (main knobs)
# Outlier removal control (main knobs)
# Outlier removal control (main knobs)
# Outlier removal control (main knobs)
# Outlier removal control (main knobs)
# Outlier removal control (main knobs)
# Outlier removal control (main knobs)
# Outlier removal control (main knobs)
# Outlier removal control (main knobs)
# Outlier removal control (main knobs)
# Outlier removal control (main knobs)
# Outlier removal control (main knobs)
# Outlier removal control (main knobs)
# Outlier removal control (main knobs)
# Outlier removal control (main knobs)
# Outlier removal control (main knobs)
# Outlier removal control (main knobs)
# Outlier removal control (main knobs)
# Outlier removal control (main knobs)
# Outlier removal control (main knobs)
# Outlier removal control (main knobs)
# Outlier removal control (main knobs)
# Outlier removal control (main knobs)
# Outlier removal control (main knobs)
# Outlier removal control (main knobs)
# Outlier removal control (main knobs)
# Outlier removal control (main knobs)
# Outlier removal control (main knobs)
# Outlier removal control (main knobs)
# Outlier removal control (main knobs)
# Outlier removal control (main knobs)
# Outlier removal control (main knobs)
# Outlier removal control (main knobs)
DIST_FACTOR_TO_CURVE = 0.8    # threshold: remove point if distance-to-curve > DIST_FACTOR * local_band_width
DIST_FACTOR_TO_CURVE = 0.8    # threshold: remove point if distance-to-curve > DIST_FACTOR * local_band_width
DIST_FACTOR_TO_CURVE = 0.8    # threshold: remove point if distance-to-curve > DIST_FACTOR * local_band_width
DIST_FACTOR_TO_CURVE = 0.8    # threshold: remove point if distance-to-curve > DIST_FACTOR * local_band_width
DIST_FACTOR_TO_CURVE = 0.8    # threshold: remove point if distance-to-curve > DIST_FACTOR * local_band_width
DIST_FACTOR_TO_CURVE = 0.8    # threshold: remove point if distance-to-curve > DIST_FACTOR * local_band_width
DIST_FACTOR_TO_CURVE = 0.8    # threshold: remove point if distance-to-curve > DIST_FACTOR * local_band_width
DIST_FACTOR_TO_CURVE = 0.8    # threshold: remove point if distance-to-curve > DIST_FACTOR * local_band_width
DIST_FACTOR_TO_CURVE = 0.8    # threshold: remove point if distance-to-curve > DIST_FACTOR * local_band_width
DIST_FACTOR_TO_CURVE = 0.8    # threshold: remove point if distance-to-curve > DIST_FACTOR * local_band_width
DIST_FACTOR_TO_CURVE = 0.8    # threshold: remove point if distance-to-curve > DIST_FACTOR * local_band_width
DIST_FACTOR_TO_CURVE = 0.8    # threshold: remove point if distance-to-curve > DIST_FACTOR * local_band_width
DIST_FACTOR_TO_CURVE = 0.8    # threshold: remove point if distance-to-curve > DIST_FACTOR * local_band_width
DIST_FACTOR_TO_CURVE = 0.8    # threshold: remove point if distance-to-curve > DIST_FACTOR * local_band_width
DIST_FACTOR_TO_CURVE = 0.8    # threshold: remove point if distance-to-curve > DIST_FACTOR * local_band_width
DIST_FACTOR_TO_CURVE = 0.8    # threshold: remove point if distance-to-curve > DIST_FACTOR * local_band_width
DIST_FACTOR_TO_CURVE = 0.8    # threshold: remove point if distance-to-curve > DIST_FACTOR * local_band_width
DIST_FACTOR_TO_CURVE = 0.8    # threshold: remove point if distance-to-curve > DIST_FACTOR * local_band_width
DIST_FACTOR_TO_CURVE = 0.8    # threshold: remove point if distance-to-curve > DIST_FACTOR * local_band_width
DIST_FACTOR_TO_CURVE = 0.8    # threshold: remove point if distance-to-curve > DIST_FACTOR * local_band_width
DIST_FACTOR_TO_CURVE = 0.8    # threshold: remove point if distance-to-curve > DIST_FACTOR * local_band_width
DIST_FACTOR_TO_CURVE = 0.8    # threshold: remove point if distance-to-curve > DIST_FACTOR * local_band_width
DIST_FACTOR_TO_CURVE = 0.8    # threshold: remove point if distance-to-curve > DIST_FACTOR * local_band_width
DIST_FACTOR_TO_CURVE = 0.8    # threshold: remove point if distance-to-curve > DIST_FACTOR * local_band_width
DIST_FACTOR_TO_CURVE = 0.8    # threshold: remove point if distance-to-curve > DIST_FACTOR * local_band_width
DIST_FACTOR_TO_CURVE = 0.8    # threshold: remove point if distance-to-curve > DIST_FACTOR * local_band_width
DIST_FACTOR_TO_CURVE = 0.8    # threshold: remove point if distance-to-curve > DIST_FACTOR * local_band_width
DIST_FACTOR_TO_CURVE = 0.8    # threshold: remove point if distance-to-curve > DIST_FACTOR * local_band_width
DIST_FACTOR_TO_CURVE = 0.8    # threshold: remove point if distance-to-curve > DIST_FACTOR * local_band_width
DIST_FACTOR_TO_CURVE = 0.8    # threshold: remove point if distance-to-curve > DIST_FACTOR * local_band_width
DIST_FACTOR_TO_CURVE = 0.8    # threshold: remove point if distance-to-curve > DIST_FACTOR * local_band_width
DIST_FACTOR_TO_CURVE = 0.8    # threshold: remove point if distance-to-curve > DIST_FACTOR * local_band_width
DIST_FACTOR_TO_CURVE = 0.8    # threshold: remove point if distance-to-curve > DIST_FACTOR * local_band_width
DIST_FACTOR_TO_CURVE = 0.8    # threshold: remove point if distance-to-curve > DIST_FACTOR * local_band_width
DIST_FACTOR_TO_CURVE = 0.8    # threshold: remove point if distance-to-curve > DIST_FACTOR * local_band_width
DIST_FACTOR_TO_CURVE = 0.8    # threshold: remove point if distance-to-curve > DIST_FACTOR * local_band_width
DIST_FACTOR_TO_CURVE = 0.8    # threshold: remove point if distance-to-curve > DIST_FACTOR * local_band_width
CIRCLE_RADIUS_FACTOR = 1.0   # for control point detection (per paper) — larger => smoother
CIRCLE_RADIUS_FACTOR = 1.0   # for control point detection (per paper) — larger => smoother
CIRCLE_RADIUS_FACTOR = 1.0   # for control point detection (per paper) — larger => smoother
CIRCLE_RADIUS_FACTOR = 1.0   # for control point detection (per paper) — larger => smoother
CIRCLE_RADIUS_FACTOR = 1.0   # for control point detection (per paper) — larger => smoother
CIRCLE_RADIUS_FACTOR = 1.0   # for control point detection (per paper) — larger => smoother
CIRCLE_RADIUS_FACTOR = 1.0   # for control point detection (per paper) — larger => smoother
CIRCLE_RADIUS_FACTOR = 1.0   # for control point detection (per paper) — larger => smoother
CIRCLE_RADIUS_FACTOR = 1.0   # for control point detection (per paper) — larger => smoother
CIRCLE_RADIUS_FACTOR = 1.0   # for control point detection (per paper) — larger => smoother
CIRCLE_RADIUS_FACTOR = 1.0   # for control point detection (per paper) — larger => smoother
CIRCLE_RADIUS_FACTOR = 1.0   # for control point detection (per paper) — larger => smoother
CIRCLE_RADIUS_FACTOR = 1.0   # for control point detection (per paper) — larger => smoother
CIRCLE_RADIUS_FACTOR = 1.0   # for control point detection (per paper) — larger => smoother
CIRCLE_RADIUS_FACTOR = 1.0   # for control point detection (per paper) — larger => smoother
CIRCLE_RADIUS_FACTOR = 1.0   # for control point detection (per paper) — larger => smoother
CIRCLE_RADIUS_FACTOR = 1.0   # for control point detection (per paper) — larger => smoother
CIRCLE_RADIUS_FACTOR = 1.0   # for control point detection (per paper) — larger => smoother
CIRCLE_RADIUS_FACTOR = 1.0   # for control point detection (per paper) — larger => smoother
CIRCLE_RADIUS_FACTOR = 1.0   # for control point detection (per paper) — larger => smoother
CIRCLE_RADIUS_FACTOR = 1.0   # for control point detection (per paper) — larger => smoother
CIRCLE_RADIUS_FACTOR = 1.0   # for control point detection (per paper) — larger => smoother
CIRCLE_RADIUS_FACTOR = 1.0   # for control point detection (per paper) — larger => smoother
CIRCLE_RADIUS_FACTOR = 1.0   # for control point detection (per paper) — larger => smoother
CIRCLE_RADIUS_FACTOR = 1.0   # for control point detection (per paper) — larger => smoother
CIRCLE_RADIUS_FACTOR = 1.0   # for control point detection (per paper) — larger => smoother
CIRCLE_RADIUS_FACTOR = 1.0   # for control point detection (per paper) — larger => smoother
CIRCLE_RADIUS_FACTOR = 1.0   # for control point detection (per paper) — larger => smoother
CIRCLE_RADIUS_FACTOR = 1.0   # for control point detection (per paper) — larger => smoother
CIRCLE_RADIUS_FACTOR = 1.0   # for control point detection (per paper) — larger => smoother
CIRCLE_RADIUS_FACTOR = 1.0   # for control point detection (per paper) — larger => smoother
CIRCLE_RADIUS_FACTOR = 1.0   # for control point detection (per paper) — larger => smoother
CIRCLE_RADIUS_FACTOR = 1.0   # for control point detection (per paper) — larger => smoother
CIRCLE_RADIUS_FACTOR = 1.0   # for control point detection (per paper) — larger => smoother
CIRCLE_RADIUS_FACTOR = 1.0   # for control point detection (per paper) — larger => smoother
CIRCLE_RADIUS_FACTOR = 1.0   # for control point detection (per paper) — larger => smoother
CIRCLE_RADIUS_FACTOR = 1.0   # for control point detection (per paper) — larger => smoother
MIN_POINTS_IN_CIRCLE = 5      # if fewer than this many points fall in the circle, skip that circle
MIN_POINTS_IN_CIRCLE = 5      # if fewer than this many points fall in the circle, skip that circle
MIN_POINTS_IN_CIRCLE = 5      # if fewer than this many points fall in the circle, skip that circle
MIN_POINTS_IN_CIRCLE = 5      # if fewer than this many points fall in the circle, skip that circle
MIN_POINTS_IN_CIRCLE = 5      # if fewer than this many points fall in the circle, skip that circle
MIN_POINTS_IN_CIRCLE = 5      # if fewer than this many points fall in the circle, skip that circle
MIN_POINTS_IN_CIRCLE = 5      # if fewer than this many points fall in the circle, skip that circle
MIN_POINTS_IN_CIRCLE = 5      # if fewer than this many points fall in the circle, skip that circle
MIN_POINTS_IN_CIRCLE = 5      # if fewer than this many points fall in the circle, skip that circle
MIN_POINTS_IN_CIRCLE = 5      # if fewer than this many points fall in the circle, skip that circle
MIN_POINTS_IN_CIRCLE = 5      # if fewer than this many points fall in the circle, skip that circle
MIN_POINTS_IN_CIRCLE = 5      # if fewer than this many points fall in the circle, skip that circle
MIN_POINTS_IN_CIRCLE = 5      # if fewer than this many points fall in the circle, skip that circle
MIN_POINTS_IN_CIRCLE = 5      # if fewer than this many points fall in the circle, skip that circle
MIN_POINTS_IN_CIRCLE = 5      # if fewer than this many points fall in the circle, skip that circle
MIN_POINTS_IN_CIRCLE = 5      # if fewer than this many points fall in the circle, skip that circle
MIN_POINTS_IN_CIRCLE = 5      # if fewer than this many points fall in the circle, skip that circle
MIN_POINTS_IN_CIRCLE = 5      # if fewer than this many points fall in the circle, skip that circle
MIN_POINTS_IN_CIRCLE = 5      # if fewer than this many points fall in the circle, skip that circle
MIN_POINTS_IN_CIRCLE = 5      # if fewer than this many points fall in the circle, skip that circle
MIN_POINTS_IN_CIRCLE = 5      # if fewer than this many points fall in the circle, skip that circle
MIN_POINTS_IN_CIRCLE = 5      # if fewer than this many points fall in the circle, skip that circle
MIN_POINTS_IN_CIRCLE = 5      # if fewer than this many points fall in the circle, skip that circle
MIN_POINTS_IN_CIRCLE = 5      # if fewer than this many points fall in the circle, skip that circle
MIN_POINTS_IN_CIRCLE = 5      # if fewer than this many points fall in the circle, skip that circle
MIN_POINTS_IN_CIRCLE = 5      # if fewer than this many points fall in the circle, skip that circle
MIN_POINTS_IN_CIRCLE = 5      # if fewer than this many points fall in the circle, skip that circle
MIN_POINTS_IN_CIRCLE = 5      # if fewer than this many points fall in the circle, skip that circle
MIN_POINTS_IN_CIRCLE = 5      # if fewer than this many points fall in the circle, skip that circle
MIN_POINTS_IN_CIRCLE = 5      # if fewer than this many points fall in the circle, skip that circle
MIN_POINTS_IN_CIRCLE = 5      # if fewer than this many points fall in the circle, skip that circle
MIN_POINTS_IN_CIRCLE = 5      # if fewer than this many points fall in the circle, skip that circle
MIN_POINTS_IN_CIRCLE = 5      # if fewer than this many points fall in the circle, skip that circle
MIN_POINTS_IN_CIRCLE = 5      # if fewer than this many points fall in the circle, skip that circle
MIN_POINTS_IN_CIRCLE = 5      # if fewer than this many points fall in the circle, skip that circle
MIN_POINTS_IN_CIRCLE = 5      # if fewer than this many points fall in the circle, skip that circle
MIN_POINTS_IN_CIRCLE = 5      # if fewer than this many points fall in the circle, skip that circle





































# Remove small clusters at the end (DBSCAN)
# Remove small clusters at the end (DBSCAN)
# Remove small clusters at the end (DBSCAN)
# Remove small clusters at the end (DBSCAN)
# Remove small clusters at the end (DBSCAN)
# Remove small clusters at the end (DBSCAN)
# Remove small clusters at the end (DBSCAN)
# Remove small clusters at the end (DBSCAN)
# Remove small clusters at the end (DBSCAN)
# Remove small clusters at the end (DBSCAN)
# Remove small clusters at the end (DBSCAN)
# Remove small clusters at the end (DBSCAN)
# Remove small clusters at the end (DBSCAN)
# Remove small clusters at the end (DBSCAN)
# Remove small clusters at the end (DBSCAN)
# Remove small clusters at the end (DBSCAN)
# Remove small clusters at the end (DBSCAN)
# Remove small clusters at the end (DBSCAN)
# Remove small clusters at the end (DBSCAN)
# Remove small clusters at the end (DBSCAN)
# Remove small clusters at the end (DBSCAN)
# Remove small clusters at the end (DBSCAN)
# Remove small clusters at the end (DBSCAN)
# Remove small clusters at the end (DBSCAN)
# Remove small clusters at the end (DBSCAN)
# Remove small clusters at the end (DBSCAN)
# Remove small clusters at the end (DBSCAN)
# Remove small clusters at the end (DBSCAN)
# Remove small clusters at the end (DBSCAN)
# Remove small clusters at the end (DBSCAN)
# Remove small clusters at the end (DBSCAN)
# Remove small clusters at the end (DBSCAN)
# Remove small clusters at the end (DBSCAN)
# Remove small clusters at the end (DBSCAN)
# Remove small clusters at the end (DBSCAN)
# Remove small clusters at the end (DBSCAN)
# Remove small clusters at the end (DBSCAN)
DBSCAN_EPS_FACTOR = 1.0       # eps = factor * median_nn_of_all_points
DBSCAN_EPS_FACTOR = 1.0       # eps = factor * median_nn_of_all_points
DBSCAN_EPS_FACTOR = 1.0       # eps = factor * median_nn_of_all_points
DBSCAN_EPS_FACTOR = 1.0       # eps = factor * median_nn_of_all_points
DBSCAN_EPS_FACTOR = 1.0       # eps = factor * median_nn_of_all_points
DBSCAN_EPS_FACTOR = 1.0       # eps = factor * median_nn_of_all_points
DBSCAN_EPS_FACTOR = 1.0       # eps = factor * median_nn_of_all_points
DBSCAN_EPS_FACTOR = 1.0       # eps = factor * median_nn_of_all_points
DBSCAN_EPS_FACTOR = 1.0       # eps = factor * median_nn_of_all_points
DBSCAN_EPS_FACTOR = 1.0       # eps = factor * median_nn_of_all_points
DBSCAN_EPS_FACTOR = 1.0       # eps = factor * median_nn_of_all_points
DBSCAN_EPS_FACTOR = 1.0       # eps = factor * median_nn_of_all_points
DBSCAN_EPS_FACTOR = 1.0       # eps = factor * median_nn_of_all_points
DBSCAN_EPS_FACTOR = 1.0       # eps = factor * median_nn_of_all_points
DBSCAN_EPS_FACTOR = 1.0       # eps = factor * median_nn_of_all_points
DBSCAN_EPS_FACTOR = 1.0       # eps = factor * median_nn_of_all_points
DBSCAN_EPS_FACTOR = 1.0       # eps = factor * median_nn_of_all_points
DBSCAN_EPS_FACTOR = 1.0       # eps = factor * median_nn_of_all_points
DBSCAN_EPS_FACTOR = 1.0       # eps = factor * median_nn_of_all_points
DBSCAN_EPS_FACTOR = 1.0       # eps = factor * median_nn_of_all_points
DBSCAN_EPS_FACTOR = 1.0       # eps = factor * median_nn_of_all_points
DBSCAN_EPS_FACTOR = 1.0       # eps = factor * median_nn_of_all_points
DBSCAN_EPS_FACTOR = 1.0       # eps = factor * median_nn_of_all_points
DBSCAN_EPS_FACTOR = 1.0       # eps = factor * median_nn_of_all_points
DBSCAN_EPS_FACTOR = 1.0       # eps = factor * median_nn_of_all_points
DBSCAN_EPS_FACTOR = 1.0       # eps = factor * median_nn_of_all_points
DBSCAN_EPS_FACTOR = 1.0       # eps = factor * median_nn_of_all_points
DBSCAN_EPS_FACTOR = 1.0       # eps = factor * median_nn_of_all_points
DBSCAN_EPS_FACTOR = 1.0       # eps = factor * median_nn_of_all_points
DBSCAN_EPS_FACTOR = 1.0       # eps = factor * median_nn_of_all_points
DBSCAN_EPS_FACTOR = 1.0       # eps = factor * median_nn_of_all_points
DBSCAN_EPS_FACTOR = 1.0       # eps = factor * median_nn_of_all_points
DBSCAN_EPS_FACTOR = 1.0       # eps = factor * median_nn_of_all_points
DBSCAN_EPS_FACTOR = 1.0       # eps = factor * median_nn_of_all_points
DBSCAN_EPS_FACTOR = 1.0       # eps = factor * median_nn_of_all_points
DBSCAN_EPS_FACTOR = 1.0       # eps = factor * median_nn_of_all_points
DBSCAN_EPS_FACTOR = 1.0       # eps = factor * median_nn_of_all_points
DBSCAN_MIN_SAMPLES = 5        # min samples for a valid cluster
DBSCAN_MIN_SAMPLES = 5        # min samples for a valid cluster
DBSCAN_MIN_SAMPLES = 5        # min samples for a valid cluster
DBSCAN_MIN_SAMPLES = 5        # min samples for a valid cluster
DBSCAN_MIN_SAMPLES = 5        # min samples for a valid cluster
DBSCAN_MIN_SAMPLES = 5        # min samples for a valid cluster
DBSCAN_MIN_SAMPLES = 5        # min samples for a valid cluster
DBSCAN_MIN_SAMPLES = 5        # min samples for a valid cluster
DBSCAN_MIN_SAMPLES = 5        # min samples for a valid cluster
DBSCAN_MIN_SAMPLES = 5        # min samples for a valid cluster
DBSCAN_MIN_SAMPLES = 5        # min samples for a valid cluster
DBSCAN_MIN_SAMPLES = 5        # min samples for a valid cluster
DBSCAN_MIN_SAMPLES = 5        # min samples for a valid cluster
DBSCAN_MIN_SAMPLES = 5        # min samples for a valid cluster
DBSCAN_MIN_SAMPLES = 5        # min samples for a valid cluster
DBSCAN_MIN_SAMPLES = 5        # min samples for a valid cluster
DBSCAN_MIN_SAMPLES = 5        # min samples for a valid cluster
DBSCAN_MIN_SAMPLES = 5        # min samples for a valid cluster
DBSCAN_MIN_SAMPLES = 5        # min samples for a valid cluster
DBSCAN_MIN_SAMPLES = 5        # min samples for a valid cluster
DBSCAN_MIN_SAMPLES = 5        # min samples for a valid cluster
DBSCAN_MIN_SAMPLES = 5        # min samples for a valid cluster
DBSCAN_MIN_SAMPLES = 5        # min samples for a valid cluster
DBSCAN_MIN_SAMPLES = 5        # min samples for a valid cluster
DBSCAN_MIN_SAMPLES = 5        # min samples for a valid cluster
DBSCAN_MIN_SAMPLES = 5        # min samples for a valid cluster
DBSCAN_MIN_SAMPLES = 5        # min samples for a valid cluster
DBSCAN_MIN_SAMPLES = 5        # min samples for a valid cluster
DBSCAN_MIN_SAMPLES = 5        # min samples for a valid cluster
DBSCAN_MIN_SAMPLES = 5        # min samples for a valid cluster
DBSCAN_MIN_SAMPLES = 5        # min samples for a valid cluster
DBSCAN_MIN_SAMPLES = 5        # min samples for a valid cluster
DBSCAN_MIN_SAMPLES = 5        # min samples for a valid cluster
DBSCAN_MIN_SAMPLES = 5        # min samples for a valid cluster
DBSCAN_MIN_SAMPLES = 5        # min samples for a valid cluster
DBSCAN_MIN_SAMPLES = 5        # min samples for a valid cluster
DBSCAN_MIN_SAMPLES = 5        # min samples for a valid cluster
MIN_CLUSTER_SIZE = 12          # if cluster is smaller than this => remove (stricter => increase value)
MIN_CLUSTER_SIZE = 12          # if cluster is smaller than this => remove (stricter => increase value)
MIN_CLUSTER_SIZE = 12          # if cluster is smaller than this => remove (stricter => increase value)
MIN_CLUSTER_SIZE = 12          # if cluster is smaller than this => remove (stricter => increase value)
MIN_CLUSTER_SIZE = 12          # if cluster is smaller than this => remove (stricter => increase value)
MIN_CLUSTER_SIZE = 12          # if cluster is smaller than this => remove (stricter => increase value)
MIN_CLUSTER_SIZE = 12          # if cluster is smaller than this => remove (stricter => increase value)
MIN_CLUSTER_SIZE = 12          # if cluster is smaller than this => remove (stricter => increase value)
MIN_CLUSTER_SIZE = 12          # if cluster is smaller than this => remove (stricter => increase value)
MIN_CLUSTER_SIZE = 12          # if cluster is smaller than this => remove (stricter => increase value)
MIN_CLUSTER_SIZE = 12          # if cluster is smaller than this => remove (stricter => increase value)
MIN_CLUSTER_SIZE = 12          # if cluster is smaller than this => remove (stricter => increase value)
MIN_CLUSTER_SIZE = 12          # if cluster is smaller than this => remove (stricter => increase value)
MIN_CLUSTER_SIZE = 12          # if cluster is smaller than this => remove (stricter => increase value)
MIN_CLUSTER_SIZE = 12          # if cluster is smaller than this => remove (stricter => increase value)
MIN_CLUSTER_SIZE = 12          # if cluster is smaller than this => remove (stricter => increase value)
MIN_CLUSTER_SIZE = 12          # if cluster is smaller than this => remove (stricter => increase value)
MIN_CLUSTER_SIZE = 12          # if cluster is smaller than this => remove (stricter => increase value)
MIN_CLUSTER_SIZE = 12          # if cluster is smaller than this => remove (stricter => increase value)
MIN_CLUSTER_SIZE = 12          # if cluster is smaller than this => remove (stricter => increase value)
MIN_CLUSTER_SIZE = 12          # if cluster is smaller than this => remove (stricter => increase value)
MIN_CLUSTER_SIZE = 12          # if cluster is smaller than this => remove (stricter => increase value)
MIN_CLUSTER_SIZE = 12          # if cluster is smaller than this => remove (stricter => increase value)
MIN_CLUSTER_SIZE = 12          # if cluster is smaller than this => remove (stricter => increase value)
MIN_CLUSTER_SIZE = 12          # if cluster is smaller than this => remove (stricter => increase value)
MIN_CLUSTER_SIZE = 12          # if cluster is smaller than this => remove (stricter => increase value)
MIN_CLUSTER_SIZE = 12          # if cluster is smaller than this => remove (stricter => increase value)
MIN_CLUSTER_SIZE = 12          # if cluster is smaller than this => remove (stricter => increase value)
MIN_CLUSTER_SIZE = 12          # if cluster is smaller than this => remove (stricter => increase value)
MIN_CLUSTER_SIZE = 12          # if cluster is smaller than this => remove (stricter => increase value)
MIN_CLUSTER_SIZE = 12          # if cluster is smaller than this => remove (stricter => increase value)
MIN_CLUSTER_SIZE = 12          # if cluster is smaller than this => remove (stricter => increase value)
MIN_CLUSTER_SIZE = 12          # if cluster is smaller than this => remove (stricter => increase value)
MIN_CLUSTER_SIZE = 12          # if cluster is smaller than this => remove (stricter => increase value)
MIN_CLUSTER_SIZE = 12          # if cluster is smaller than this => remove (stricter => increase value)
MIN_CLUSTER_SIZE = 12          # if cluster is smaller than this => remove (stricter => increase value)
MIN_CLUSTER_SIZE = 12          # if cluster is smaller than this => remove (stricter => increase value)





































# Adaptive slicing
# Adaptive slicing
# Adaptive slicing
# Adaptive slicing
# Adaptive slicing
# Adaptive slicing
# Adaptive slicing
# Adaptive slicing
# Adaptive slicing
# Adaptive slicing
# Adaptive slicing
# Adaptive slicing
# Adaptive slicing
# Adaptive slicing
# Adaptive slicing
# Adaptive slicing
# Adaptive slicing
# Adaptive slicing
# Adaptive slicing
# Adaptive slicing
# Adaptive slicing
# Adaptive slicing
# Adaptive slicing
# Adaptive slicing
# Adaptive slicing
# Adaptive slicing
# Adaptive slicing
# Adaptive slicing
# Adaptive slicing
# Adaptive slicing
# Adaptive slicing
# Adaptive slicing
# Adaptive slicing
# Adaptive slicing
# Adaptive slicing
# Adaptive slicing
# Adaptive slicing
BUILD_AXIS = 2                # slicing axis: 0=x 1=y 2=z
BUILD_AXIS = 2                # slicing axis: 0=x 1=y 2=z
BUILD_AXIS = 2                # slicing axis: 0=x 1=y 2=z
BUILD_AXIS = 2                # slicing axis: 0=x 1=y 2=z
BUILD_AXIS = 2                # slicing axis: 0=x 1=y 2=z
BUILD_AXIS = 2                # slicing axis: 0=x 1=y 2=z
BUILD_AXIS = 2                # slicing axis: 0=x 1=y 2=z
BUILD_AXIS = 2                # slicing axis: 0=x 1=y 2=z
BUILD_AXIS = 2                # slicing axis: 0=x 1=y 2=z
BUILD_AXIS = 2                # slicing axis: 0=x 1=y 2=z
BUILD_AXIS = 2                # slicing axis: 0=x 1=y 2=z
BUILD_AXIS = 2                # slicing axis: 0=x 1=y 2=z
BUILD_AXIS = 2                # slicing axis: 0=x 1=y 2=z
BUILD_AXIS = 2                # slicing axis: 0=x 1=y 2=z
BUILD_AXIS = 2                # slicing axis: 0=x 1=y 2=z
BUILD_AXIS = 2                # slicing axis: 0=x 1=y 2=z
BUILD_AXIS = 2                # slicing axis: 0=x 1=y 2=z
BUILD_AXIS = 2                # slicing axis: 0=x 1=y 2=z
BUILD_AXIS = 2                # slicing axis: 0=x 1=y 2=z
BUILD_AXIS = 2                # slicing axis: 0=x 1=y 2=z
BUILD_AXIS = 2                # slicing axis: 0=x 1=y 2=z
BUILD_AXIS = 2                # slicing axis: 0=x 1=y 2=z
BUILD_AXIS = 2                # slicing axis: 0=x 1=y 2=z
BUILD_AXIS = 2                # slicing axis: 0=x 1=y 2=z
BUILD_AXIS = 2                # slicing axis: 0=x 1=y 2=z
BUILD_AXIS = 2                # slicing axis: 0=x 1=y 2=z
BUILD_AXIS = 2                # slicing axis: 0=x 1=y 2=z
BUILD_AXIS = 2                # slicing axis: 0=x 1=y 2=z
BUILD_AXIS = 2                # slicing axis: 0=x 1=y 2=z
BUILD_AXIS = 2                # slicing axis: 0=x 1=y 2=z
BUILD_AXIS = 2                # slicing axis: 0=x 1=y 2=z
BUILD_AXIS = 2                # slicing axis: 0=x 1=y 2=z
BUILD_AXIS = 2                # slicing axis: 0=x 1=y 2=z
BUILD_AXIS = 2                # slicing axis: 0=x 1=y 2=z
BUILD_AXIS = 2                # slicing axis: 0=x 1=y 2=z
BUILD_AXIS = 2                # slicing axis: 0=x 1=y 2=z
BUILD_AXIS = 2                # slicing axis: 0=x 1=y 2=z
INITIAL_LAYER_THICKNESS = 0.3        # very thin slices
INITIAL_LAYER_THICKNESS = 0.3        # very thin slices
INITIAL_LAYER_THICKNESS = 0.3        # very thin slices
INITIAL_LAYER_THICKNESS = 0.3        # very thin slices
INITIAL_LAYER_THICKNESS = 0.3        # very thin slices
INITIAL_LAYER_THICKNESS = 0.3        # very thin slices
INITIAL_LAYER_THICKNESS = 0.3        # very thin slices
INITIAL_LAYER_THICKNESS = 0.3        # very thin slices
INITIAL_LAYER_THICKNESS = 0.3        # very thin slices
INITIAL_LAYER_THICKNESS = 0.3        # very thin slices
INITIAL_LAYER_THICKNESS = 0.3        # very thin slices
INITIAL_LAYER_THICKNESS = 0.3        # very thin slices
INITIAL_LAYER_THICKNESS = 0.3        # very thin slices
INITIAL_LAYER_THICKNESS = 0.3        # very thin slices
INITIAL_LAYER_THICKNESS = 0.3        # very thin slices
INITIAL_LAYER_THICKNESS = 0.3        # very thin slices
INITIAL_LAYER_THICKNESS = 0.3        # very thin slices
INITIAL_LAYER_THICKNESS = 0.3        # very thin slices
INITIAL_LAYER_THICKNESS = 0.3        # very thin slices
INITIAL_LAYER_THICKNESS = 0.3        # very thin slices
INITIAL_LAYER_THICKNESS = 0.3        # very thin slices
INITIAL_LAYER_THICKNESS = 0.3        # very thin slices
INITIAL_LAYER_THICKNESS = 0.3        # very thin slices
INITIAL_LAYER_THICKNESS = 0.3        # very thin slices
INITIAL_LAYER_THICKNESS = 0.3        # very thin slices
INITIAL_LAYER_THICKNESS = 0.3        # very thin slices
INITIAL_LAYER_THICKNESS = 0.3        # very thin slices
INITIAL_LAYER_THICKNESS = 0.3        # very thin slices
INITIAL_LAYER_THICKNESS = 0.3        # very thin slices
INITIAL_LAYER_THICKNESS = 0.3        # very thin slices
INITIAL_LAYER_THICKNESS = 0.3        # very thin slices
INITIAL_LAYER_THICKNESS = 0.3        # very thin slices
INITIAL_LAYER_THICKNESS = 0.3        # very thin slices
INITIAL_LAYER_THICKNESS = 0.3        # very thin slices
INITIAL_LAYER_THICKNESS = 0.3        # very thin slices
INITIAL_LAYER_THICKNESS = 0.3        # very thin slices
INITIAL_LAYER_THICKNESS = 0.3        # very thin slices
TMIN, TMAX = 0.05, 10.0
TMIN, TMAX = 0.05, 10.0
TMIN, TMAX = 0.05, 10.0
TMIN, TMAX = 0.05, 10.0
TMIN, TMAX = 0.05, 10.0
TMIN, TMAX = 0.05, 10.0
TMIN, TMAX = 0.05, 10.0
TMIN, TMAX = 0.05, 10.0
TMIN, TMAX = 0.05, 10.0
TMIN, TMAX = 0.05, 10.0
TMIN, TMAX = 0.05, 10.0
TMIN, TMAX = 0.05, 10.0
TMIN, TMAX = 0.05, 10.0
TMIN, TMAX = 0.05, 10.0
TMIN, TMAX = 0.05, 10.0
TMIN, TMAX = 0.05, 10.0
TMIN, TMAX = 0.05, 10.0
TMIN, TMAX = 0.05, 10.0
TMIN, TMAX = 0.05, 10.0
TMIN, TMAX = 0.05, 10.0
TMIN, TMAX = 0.05, 10.0
TMIN, TMAX = 0.05, 10.0
TMIN, TMAX = 0.05, 10.0
TMIN, TMAX = 0.05, 10.0
TMIN, TMAX = 0.05, 10.0
TMIN, TMAX = 0.05, 10.0
TMIN, TMAX = 0.05, 10.0
TMIN, TMAX = 0.05, 10.0
TMIN, TMAX = 0.05, 10.0
TMIN, TMAX = 0.05, 10.0
TMIN, TMAX = 0.05, 10.0
TMIN, TMAX = 0.05, 10.0
TMIN, TMAX = 0.05, 10.0
TMIN, TMAX = 0.05, 10.0
TMIN, TMAX = 0.05, 10.0
TMIN, TMAX = 0.05, 10.0
TMIN, TMAX = 0.05, 10.0
SHAPE_ERROR_TOL = 0.2                # very high precision
SHAPE_ERROR_TOL = 0.2                # very high precision
SHAPE_ERROR_TOL = 0.2                # very high precision
SHAPE_ERROR_TOL = 0.2                # very high precision
SHAPE_ERROR_TOL = 0.2                # very high precision
SHAPE_ERROR_TOL = 0.2                # very high precision
SHAPE_ERROR_TOL = 0.2                # very high precision
SHAPE_ERROR_TOL = 0.2                # very high precision
SHAPE_ERROR_TOL = 0.2                # very high precision
SHAPE_ERROR_TOL = 0.2                # very high precision
SHAPE_ERROR_TOL = 0.2                # very high precision
SHAPE_ERROR_TOL = 0.2                # very high precision
SHAPE_ERROR_TOL = 0.2                # very high precision
SHAPE_ERROR_TOL = 0.2                # very high precision
SHAPE_ERROR_TOL = 0.2                # very high precision
SHAPE_ERROR_TOL = 0.2                # very high precision
SHAPE_ERROR_TOL = 0.2                # very high precision
SHAPE_ERROR_TOL = 0.2                # very high precision
SHAPE_ERROR_TOL = 0.2                # very high precision
SHAPE_ERROR_TOL = 0.2                # very high precision
SHAPE_ERROR_TOL = 0.2                # very high precision
SHAPE_ERROR_TOL = 0.2                # very high precision
SHAPE_ERROR_TOL = 0.2                # very high precision
SHAPE_ERROR_TOL = 0.2                # very high precision
SHAPE_ERROR_TOL = 0.2                # very high precision
SHAPE_ERROR_TOL = 0.2                # very high precision
SHAPE_ERROR_TOL = 0.2                # very high precision
SHAPE_ERROR_TOL = 0.2                # very high precision
SHAPE_ERROR_TOL = 0.2                # very high precision
SHAPE_ERROR_TOL = 0.2                # very high precision
SHAPE_ERROR_TOL = 0.2                # very high precision
SHAPE_ERROR_TOL = 0.2                # very high precision
SHAPE_ERROR_TOL = 0.2                # very high precision
SHAPE_ERROR_TOL = 0.2                # very high precision
SHAPE_ERROR_TOL = 0.2                # very high precision
SHAPE_ERROR_TOL = 0.2                # very high precision
SHAPE_ERROR_TOL = 0.2                # very high precision
MAX_SLICE_ITERS = 12
MAX_SLICE_ITERS = 12
MAX_SLICE_ITERS = 12
MAX_SLICE_ITERS = 12
MAX_SLICE_ITERS = 12
MAX_SLICE_ITERS = 12
MAX_SLICE_ITERS = 12
MAX_SLICE_ITERS = 12
MAX_SLICE_ITERS = 12
MAX_SLICE_ITERS = 12
MAX_SLICE_ITERS = 12
MAX_SLICE_ITERS = 12
MAX_SLICE_ITERS = 12
MAX_SLICE_ITERS = 12
MAX_SLICE_ITERS = 12
MAX_SLICE_ITERS = 12
MAX_SLICE_ITERS = 12
MAX_SLICE_ITERS = 12
MAX_SLICE_ITERS = 12
MAX_SLICE_ITERS = 12
MAX_SLICE_ITERS = 12
MAX_SLICE_ITERS = 12
MAX_SLICE_ITERS = 12
MAX_SLICE_ITERS = 12
MAX_SLICE_ITERS = 12
MAX_SLICE_ITERS = 12
MAX_SLICE_ITERS = 12
MAX_SLICE_ITERS = 12
MAX_SLICE_ITERS = 12
MAX_SLICE_ITERS = 12
MAX_SLICE_ITERS = 12
MAX_SLICE_ITERS = 12
MAX_SLICE_ITERS = 12
MAX_SLICE_ITERS = 12
MAX_SLICE_ITERS = 12
MAX_SLICE_ITERS = 12
MAX_SLICE_ITERS = 12





































# speed / stability
# speed / stability
# speed / stability
# speed / stability
# speed / stability
# speed / stability
# speed / stability
# speed / stability
# speed / stability
# speed / stability
# speed / stability
# speed / stability
# speed / stability
# speed / stability
# speed / stability
# speed / stability
# speed / stability
# speed / stability
# speed / stability
# speed / stability
# speed / stability
# speed / stability
# speed / stability
# speed / stability
# speed / stability
# speed / stability
# speed / stability
# speed / stability
# speed / stability
# speed / stability
# speed / stability
# speed / stability
# speed / stability
# speed / stability
# speed / stability
# speed / stability
# speed / stability
SAMPLE_POINTS_FOR_INITIAL = 300   # max samples for initial B-spline fit (fewer => faster)
SAMPLE_POINTS_FOR_INITIAL = 300   # max samples for initial B-spline fit (fewer => faster)
SAMPLE_POINTS_FOR_INITIAL = 300   # max samples for initial B-spline fit (fewer => faster)
SAMPLE_POINTS_FOR_INITIAL = 300   # max samples for initial B-spline fit (fewer => faster)
SAMPLE_POINTS_FOR_INITIAL = 300   # max samples for initial B-spline fit (fewer => faster)
SAMPLE_POINTS_FOR_INITIAL = 300   # max samples for initial B-spline fit (fewer => faster)
SAMPLE_POINTS_FOR_INITIAL = 300   # max samples for initial B-spline fit (fewer => faster)
SAMPLE_POINTS_FOR_INITIAL = 300   # max samples for initial B-spline fit (fewer => faster)
SAMPLE_POINTS_FOR_INITIAL = 300   # max samples for initial B-spline fit (fewer => faster)
SAMPLE_POINTS_FOR_INITIAL = 300   # max samples for initial B-spline fit (fewer => faster)
SAMPLE_POINTS_FOR_INITIAL = 300   # max samples for initial B-spline fit (fewer => faster)
SAMPLE_POINTS_FOR_INITIAL = 300   # max samples for initial B-spline fit (fewer => faster)
SAMPLE_POINTS_FOR_INITIAL = 300   # max samples for initial B-spline fit (fewer => faster)
SAMPLE_POINTS_FOR_INITIAL = 300   # max samples for initial B-spline fit (fewer => faster)
SAMPLE_POINTS_FOR_INITIAL = 300   # max samples for initial B-spline fit (fewer => faster)
SAMPLE_POINTS_FOR_INITIAL = 300   # max samples for initial B-spline fit (fewer => faster)
SAMPLE_POINTS_FOR_INITIAL = 300   # max samples for initial B-spline fit (fewer => faster)
SAMPLE_POINTS_FOR_INITIAL = 300   # max samples for initial B-spline fit (fewer => faster)
SAMPLE_POINTS_FOR_INITIAL = 300   # max samples for initial B-spline fit (fewer => faster)
SAMPLE_POINTS_FOR_INITIAL = 300   # max samples for initial B-spline fit (fewer => faster)
SAMPLE_POINTS_FOR_INITIAL = 300   # max samples for initial B-spline fit (fewer => faster)
SAMPLE_POINTS_FOR_INITIAL = 300   # max samples for initial B-spline fit (fewer => faster)
SAMPLE_POINTS_FOR_INITIAL = 300   # max samples for initial B-spline fit (fewer => faster)
SAMPLE_POINTS_FOR_INITIAL = 300   # max samples for initial B-spline fit (fewer => faster)
SAMPLE_POINTS_FOR_INITIAL = 300   # max samples for initial B-spline fit (fewer => faster)
SAMPLE_POINTS_FOR_INITIAL = 300   # max samples for initial B-spline fit (fewer => faster)
SAMPLE_POINTS_FOR_INITIAL = 300   # max samples for initial B-spline fit (fewer => faster)
SAMPLE_POINTS_FOR_INITIAL = 300   # max samples for initial B-spline fit (fewer => faster)
SAMPLE_POINTS_FOR_INITIAL = 300   # max samples for initial B-spline fit (fewer => faster)
SAMPLE_POINTS_FOR_INITIAL = 300   # max samples for initial B-spline fit (fewer => faster)
SAMPLE_POINTS_FOR_INITIAL = 300   # max samples for initial B-spline fit (fewer => faster)
SAMPLE_POINTS_FOR_INITIAL = 300   # max samples for initial B-spline fit (fewer => faster)
SAMPLE_POINTS_FOR_INITIAL = 300   # max samples for initial B-spline fit (fewer => faster)
SAMPLE_POINTS_FOR_INITIAL = 300   # max samples for initial B-spline fit (fewer => faster)
SAMPLE_POINTS_FOR_INITIAL = 300   # max samples for initial B-spline fit (fewer => faster)
SAMPLE_POINTS_FOR_INITIAL = 300   # max samples for initial B-spline fit (fewer => faster)
SAMPLE_POINTS_FOR_INITIAL = 300   # max samples for initial B-spline fit (fewer => faster)
CURVE_SAMPLES = 400               # final curve samples for distance computation
CURVE_SAMPLES = 400               # final curve samples for distance computation
CURVE_SAMPLES = 400               # final curve samples for distance computation
CURVE_SAMPLES = 400               # final curve samples for distance computation
CURVE_SAMPLES = 400               # final curve samples for distance computation
CURVE_SAMPLES = 400               # final curve samples for distance computation
CURVE_SAMPLES = 400               # final curve samples for distance computation
CURVE_SAMPLES = 400               # final curve samples for distance computation
CURVE_SAMPLES = 400               # final curve samples for distance computation
CURVE_SAMPLES = 400               # final curve samples for distance computation
CURVE_SAMPLES = 400               # final curve samples for distance computation
CURVE_SAMPLES = 400               # final curve samples for distance computation
CURVE_SAMPLES = 400               # final curve samples for distance computation
CURVE_SAMPLES = 400               # final curve samples for distance computation
CURVE_SAMPLES = 400               # final curve samples for distance computation
CURVE_SAMPLES = 400               # final curve samples for distance computation
CURVE_SAMPLES = 400               # final curve samples for distance computation
CURVE_SAMPLES = 400               # final curve samples for distance computation
CURVE_SAMPLES = 400               # final curve samples for distance computation
CURVE_SAMPLES = 400               # final curve samples for distance computation
CURVE_SAMPLES = 400               # final curve samples for distance computation
CURVE_SAMPLES = 400               # final curve samples for distance computation
CURVE_SAMPLES = 400               # final curve samples for distance computation
CURVE_SAMPLES = 400               # final curve samples for distance computation
CURVE_SAMPLES = 400               # final curve samples for distance computation
CURVE_SAMPLES = 400               # final curve samples for distance computation
CURVE_SAMPLES = 400               # final curve samples for distance computation
CURVE_SAMPLES = 400               # final curve samples for distance computation
CURVE_SAMPLES = 400               # final curve samples for distance computation
CURVE_SAMPLES = 400               # final curve samples for distance computation
CURVE_SAMPLES = 400               # final curve samples for distance computation
CURVE_SAMPLES = 400               # final curve samples for distance computation
CURVE_SAMPLES = 400               # final curve samples for distance computation
CURVE_SAMPLES = 400               # final curve samples for distance computation
CURVE_SAMPLES = 400               # final curve samples for distance computation
CURVE_SAMPLES = 400               # final curve samples for distance computation
CURVE_SAMPLES = 400               # final curve samples for distance computation
VERBOSE = True
VERBOSE = True
VERBOSE = True
VERBOSE = True
VERBOSE = True
VERBOSE = True
VERBOSE = True
VERBOSE = True
VERBOSE = True
VERBOSE = True
VERBOSE = True
VERBOSE = True
VERBOSE = True
VERBOSE = True
VERBOSE = True
VERBOSE = True
VERBOSE = True
VERBOSE = True
VERBOSE = True
VERBOSE = True
VERBOSE = True
VERBOSE = True
VERBOSE = True
VERBOSE = True
VERBOSE = True
VERBOSE = True
VERBOSE = True
VERBOSE = True
VERBOSE = True
VERBOSE = True
VERBOSE = True
VERBOSE = True
VERBOSE = True
VERBOSE = True
VERBOSE = True
VERBOSE = True
VERBOSE = True

# %% [markdown]
# ## ---------- IO helper functions ----------
# ## ---------- IO helper functions ----------
# ## ---------- IO helper functions ----------
# ## ---------- IO helper functions ----------
# ## ---------- IO helper functions ----------
# ## ---------- IO helper functions ----------
# ## ---------- IO helper functions ----------
# ## ---------- IO helper functions ----------
# ## ---------- IO helper functions ----------
# ## ---------- IO helper functions ----------
# ## ---------- IO helper functions ----------
# ## ---------- IO helper functions ----------
# ## ---------- IO helper functions ----------
# ## ---------- IO helper functions ----------
# ## ---------- IO helper functions ----------
# ## ---------- IO helper functions ----------
# ## ---------- IO helper functions ----------
# ## ---------- IO helper functions ----------
# ## ---------- IO helper functions ----------
# ## ---------- IO helper functions ----------
# ## ---------- IO helper functions ----------
# ## ---------- IO helper functions ----------
# ## ---------- IO helper functions ----------
# ## ---------- IO helper functions ----------
# ## ---------- IO helper functions ----------
# ## ---------- IO helper functions ----------
# ## ---------- IO helper functions ----------
# ## ---------- IO helper functions ----------
# ## ---------- IO helper functions ----------
# ## ---------- IO helper functions ----------
# ## ---------- IO helper functions ----------
# ## ---------- IO helper functions ----------
# ## ---------- IO helper functions ----------
# ## ---------- IO helper functions ----------
# ## ---------- IO helper functions ----------
# ## ---------- IO helper functions ----------
# ## ---------- IO helper functions ----------

# %%
def load_csv_xyz(path):
def load_csv_xyz(path):
def load_csv_xyz(path):
def load_csv_xyz(path):
def load_csv_xyz(path):
def load_csv_xyz(path):
def load_csv_xyz(path):
def load_csv_xyz(path):
def load_csv_xyz(path):
def load_csv_xyz(path):
def load_csv_xyz(path):
def load_csv_xyz(path):
def load_csv_xyz(path):
def load_csv_xyz(path):
def load_csv_xyz(path):
def load_csv_xyz(path):
def load_csv_xyz(path):
def load_csv_xyz(path):
def load_csv_xyz(path):
def load_csv_xyz(path):
def load_csv_xyz(path):
def load_csv_xyz(path):
def load_csv_xyz(path):
def load_csv_xyz(path):
def load_csv_xyz(path):
def load_csv_xyz(path):
def load_csv_xyz(path):
def load_csv_xyz(path):
def load_csv_xyz(path):
def load_csv_xyz(path):
def load_csv_xyz(path):
def load_csv_xyz(path):
def load_csv_xyz(path):
def load_csv_xyz(path):
def load_csv_xyz(path):
def load_csv_xyz(path):
def load_csv_xyz(path):
    if not os.path.exists(path):
    if not os.path.exists(path):
    if not os.path.exists(path):
    if not os.path.exists(path):
    if not os.path.exists(path):
    if not os.path.exists(path):
    if not os.path.exists(path):
    if not os.path.exists(path):
    if not os.path.exists(path):
    if not os.path.exists(path):
    if not os.path.exists(path):
    if not os.path.exists(path):
    if not os.path.exists(path):
    if not os.path.exists(path):
    if not os.path.exists(path):
    if not os.path.exists(path):
    if not os.path.exists(path):
    if not os.path.exists(path):
    if not os.path.exists(path):
    if not os.path.exists(path):
    if not os.path.exists(path):
    if not os.path.exists(path):
    if not os.path.exists(path):
    if not os.path.exists(path):
    if not os.path.exists(path):
    if not os.path.exists(path):
    if not os.path.exists(path):
    if not os.path.exists(path):
    if not os.path.exists(path):
    if not os.path.exists(path):
    if not os.path.exists(path):
    if not os.path.exists(path):
    if not os.path.exists(path):
    if not os.path.exists(path):
    if not os.path.exists(path):
    if not os.path.exists(path):
    if not os.path.exists(path):
        raise FileNotFoundError(path)
        raise FileNotFoundError(path)
        raise FileNotFoundError(path)
        raise FileNotFoundError(path)
        raise FileNotFoundError(path)
        raise FileNotFoundError(path)
        raise FileNotFoundError(path)
        raise FileNotFoundError(path)
        raise FileNotFoundError(path)
        raise FileNotFoundError(path)
        raise FileNotFoundError(path)
        raise FileNotFoundError(path)
        raise FileNotFoundError(path)
        raise FileNotFoundError(path)
        raise FileNotFoundError(path)
        raise FileNotFoundError(path)
        raise FileNotFoundError(path)
        raise FileNotFoundError(path)
        raise FileNotFoundError(path)
        raise FileNotFoundError(path)
        raise FileNotFoundError(path)
        raise FileNotFoundError(path)
        raise FileNotFoundError(path)
        raise FileNotFoundError(path)
        raise FileNotFoundError(path)
        raise FileNotFoundError(path)
        raise FileNotFoundError(path)
        raise FileNotFoundError(path)
        raise FileNotFoundError(path)
        raise FileNotFoundError(path)
        raise FileNotFoundError(path)
        raise FileNotFoundError(path)
        raise FileNotFoundError(path)
        raise FileNotFoundError(path)
        raise FileNotFoundError(path)
        raise FileNotFoundError(path)
        raise FileNotFoundError(path)
    df = pd.read_csv(path, comment='#')
    df = pd.read_csv(path, comment='#')
    df = pd.read_csv(path, comment='#')
    df = pd.read_csv(path, comment='#')
    df = pd.read_csv(path, comment='#')
    df = pd.read_csv(path, comment='#')
    df = pd.read_csv(path, comment='#')
    df = pd.read_csv(path, comment='#')
    df = pd.read_csv(path, comment='#')
    df = pd.read_csv(path, comment='#')
    df = pd.read_csv(path, comment='#')
    df = pd.read_csv(path, comment='#')
    df = pd.read_csv(path, comment='#')
    df = pd.read_csv(path, comment='#')
    df = pd.read_csv(path, comment='#')
    df = pd.read_csv(path, comment='#')
    df = pd.read_csv(path, comment='#')
    df = pd.read_csv(path, comment='#')
    df = pd.read_csv(path, comment='#')
    df = pd.read_csv(path, comment='#')
    df = pd.read_csv(path, comment='#')
    df = pd.read_csv(path, comment='#')
    df = pd.read_csv(path, comment='#')
    df = pd.read_csv(path, comment='#')
    df = pd.read_csv(path, comment='#')
    df = pd.read_csv(path, comment='#')
    df = pd.read_csv(path, comment='#')
    df = pd.read_csv(path, comment='#')
    df = pd.read_csv(path, comment='#')
    df = pd.read_csv(path, comment='#')
    df = pd.read_csv(path, comment='#')
    df = pd.read_csv(path, comment='#')
    df = pd.read_csv(path, comment='#')
    df = pd.read_csv(path, comment='#')
    df = pd.read_csv(path, comment='#')
    df = pd.read_csv(path, comment='#')
    df = pd.read_csv(path, comment='#')
    cols = df.columns.tolist()
    cols = df.columns.tolist()
    cols = df.columns.tolist()
    cols = df.columns.tolist()
    cols = df.columns.tolist()
    cols = df.columns.tolist()
    cols = df.columns.tolist()
    cols = df.columns.tolist()
    cols = df.columns.tolist()
    cols = df.columns.tolist()
    cols = df.columns.tolist()
    cols = df.columns.tolist()
    cols = df.columns.tolist()
    cols = df.columns.tolist()
    cols = df.columns.tolist()
    cols = df.columns.tolist()
    cols = df.columns.tolist()
    cols = df.columns.tolist()
    cols = df.columns.tolist()
    cols = df.columns.tolist()
    cols = df.columns.tolist()
    cols = df.columns.tolist()
    cols = df.columns.tolist()
    cols = df.columns.tolist()
    cols = df.columns.tolist()
    cols = df.columns.tolist()
    cols = df.columns.tolist()
    cols = df.columns.tolist()
    cols = df.columns.tolist()
    cols = df.columns.tolist()
    cols = df.columns.tolist()
    cols = df.columns.tolist()
    cols = df.columns.tolist()
    cols = df.columns.tolist()
    cols = df.columns.tolist()
    cols = df.columns.tolist()
    cols = df.columns.tolist()
    if set(['X','Y','Z']).issubset(set(cols)):
    if set(['X','Y','Z']).issubset(set(cols)):
    if set(['X','Y','Z']).issubset(set(cols)):
    if set(['X','Y','Z']).issubset(set(cols)):
    if set(['X','Y','Z']).issubset(set(cols)):
    if set(['X','Y','Z']).issubset(set(cols)):
    if set(['X','Y','Z']).issubset(set(cols)):
    if set(['X','Y','Z']).issubset(set(cols)):
    if set(['X','Y','Z']).issubset(set(cols)):
    if set(['X','Y','Z']).issubset(set(cols)):
    if set(['X','Y','Z']).issubset(set(cols)):
    if set(['X','Y','Z']).issubset(set(cols)):
    if set(['X','Y','Z']).issubset(set(cols)):
    if set(['X','Y','Z']).issubset(set(cols)):
    if set(['X','Y','Z']).issubset(set(cols)):
    if set(['X','Y','Z']).issubset(set(cols)):
    if set(['X','Y','Z']).issubset(set(cols)):
    if set(['X','Y','Z']).issubset(set(cols)):
    if set(['X','Y','Z']).issubset(set(cols)):
    if set(['X','Y','Z']).issubset(set(cols)):
    if set(['X','Y','Z']).issubset(set(cols)):
    if set(['X','Y','Z']).issubset(set(cols)):
    if set(['X','Y','Z']).issubset(set(cols)):
    if set(['X','Y','Z']).issubset(set(cols)):
    if set(['X','Y','Z']).issubset(set(cols)):
    if set(['X','Y','Z']).issubset(set(cols)):
    if set(['X','Y','Z']).issubset(set(cols)):
    if set(['X','Y','Z']).issubset(set(cols)):
    if set(['X','Y','Z']).issubset(set(cols)):
    if set(['X','Y','Z']).issubset(set(cols)):
    if set(['X','Y','Z']).issubset(set(cols)):
    if set(['X','Y','Z']).issubset(set(cols)):
    if set(['X','Y','Z']).issubset(set(cols)):
    if set(['X','Y','Z']).issubset(set(cols)):
    if set(['X','Y','Z']).issubset(set(cols)):
    if set(['X','Y','Z']).issubset(set(cols)):
    if set(['X','Y','Z']).issubset(set(cols)):
        arr = df[['X','Y','Z']].values
        arr = df[['X','Y','Z']].values
        arr = df[['X','Y','Z']].values
        arr = df[['X','Y','Z']].values
        arr = df[['X','Y','Z']].values
        arr = df[['X','Y','Z']].values
        arr = df[['X','Y','Z']].values
        arr = df[['X','Y','Z']].values
        arr = df[['X','Y','Z']].values
        arr = df[['X','Y','Z']].values
        arr = df[['X','Y','Z']].values
        arr = df[['X','Y','Z']].values
        arr = df[['X','Y','Z']].values
        arr = df[['X','Y','Z']].values
        arr = df[['X','Y','Z']].values
        arr = df[['X','Y','Z']].values
        arr = df[['X','Y','Z']].values
        arr = df[['X','Y','Z']].values
        arr = df[['X','Y','Z']].values
        arr = df[['X','Y','Z']].values
        arr = df[['X','Y','Z']].values
        arr = df[['X','Y','Z']].values
        arr = df[['X','Y','Z']].values
        arr = df[['X','Y','Z']].values
        arr = df[['X','Y','Z']].values
        arr = df[['X','Y','Z']].values
        arr = df[['X','Y','Z']].values
        arr = df[['X','Y','Z']].values
        arr = df[['X','Y','Z']].values
        arr = df[['X','Y','Z']].values
        arr = df[['X','Y','Z']].values
        arr = df[['X','Y','Z']].values
        arr = df[['X','Y','Z']].values
        arr = df[['X','Y','Z']].values
        arr = df[['X','Y','Z']].values
        arr = df[['X','Y','Z']].values
        arr = df[['X','Y','Z']].values
    else:
    else:
    else:
    else:
    else:
    else:
    else:
    else:
    else:
    else:
    else:
    else:
    else:
    else:
    else:
    else:
    else:
    else:
    else:
    else:
    else:
    else:
    else:
    else:
    else:
    else:
    else:
    else:
    else:
    else:
    else:
    else:
    else:
    else:
    else:
    else:
    else:
        arr = df.iloc[:, :3].values
        arr = df.iloc[:, :3].values
        arr = df.iloc[:, :3].values
        arr = df.iloc[:, :3].values
        arr = df.iloc[:, :3].values
        arr = df.iloc[:, :3].values
        arr = df.iloc[:, :3].values
        arr = df.iloc[:, :3].values
        arr = df.iloc[:, :3].values
        arr = df.iloc[:, :3].values
        arr = df.iloc[:, :3].values
        arr = df.iloc[:, :3].values
        arr = df.iloc[:, :3].values
        arr = df.iloc[:, :3].values
        arr = df.iloc[:, :3].values
        arr = df.iloc[:, :3].values
        arr = df.iloc[:, :3].values
        arr = df.iloc[:, :3].values
        arr = df.iloc[:, :3].values
        arr = df.iloc[:, :3].values
        arr = df.iloc[:, :3].values
        arr = df.iloc[:, :3].values
        arr = df.iloc[:, :3].values
        arr = df.iloc[:, :3].values
        arr = df.iloc[:, :3].values
        arr = df.iloc[:, :3].values
        arr = df.iloc[:, :3].values
        arr = df.iloc[:, :3].values
        arr = df.iloc[:, :3].values
        arr = df.iloc[:, :3].values
        arr = df.iloc[:, :3].values
        arr = df.iloc[:, :3].values
        arr = df.iloc[:, :3].values
        arr = df.iloc[:, :3].values
        arr = df.iloc[:, :3].values
        arr = df.iloc[:, :3].values
        arr = df.iloc[:, :3].values
    return arr.astype(float), df
    return arr.astype(float), df
    return arr.astype(float), df
    return arr.astype(float), df
    return arr.astype(float), df
    return arr.astype(float), df
    return arr.astype(float), df
    return arr.astype(float), df
    return arr.astype(float), df
    return arr.astype(float), df
    return arr.astype(float), df
    return arr.astype(float), df
    return arr.astype(float), df
    return arr.astype(float), df
    return arr.astype(float), df
    return arr.astype(float), df
    return arr.astype(float), df
    return arr.astype(float), df
    return arr.astype(float), df
    return arr.astype(float), df
    return arr.astype(float), df
    return arr.astype(float), df
    return arr.astype(float), df
    return arr.astype(float), df
    return arr.astype(float), df
    return arr.astype(float), df
    return arr.astype(float), df
    return arr.astype(float), df
    return arr.astype(float), df
    return arr.astype(float), df
    return arr.astype(float), df
    return arr.astype(float), df
    return arr.astype(float), df
    return arr.astype(float), df
    return arr.astype(float), df
    return arr.astype(float), df
    return arr.astype(float), df





































def save_csv_xyz(path, pts, header="X,Y,Z"):
def save_csv_xyz(path, pts, header="X,Y,Z"):
def save_csv_xyz(path, pts, header="X,Y,Z"):
def save_csv_xyz(path, pts, header="X,Y,Z"):
def save_csv_xyz(path, pts, header="X,Y,Z"):
def save_csv_xyz(path, pts, header="X,Y,Z"):
def save_csv_xyz(path, pts, header="X,Y,Z"):
def save_csv_xyz(path, pts, header="X,Y,Z"):
def save_csv_xyz(path, pts, header="X,Y,Z"):
def save_csv_xyz(path, pts, header="X,Y,Z"):
def save_csv_xyz(path, pts, header="X,Y,Z"):
def save_csv_xyz(path, pts, header="X,Y,Z"):
def save_csv_xyz(path, pts, header="X,Y,Z"):
def save_csv_xyz(path, pts, header="X,Y,Z"):
def save_csv_xyz(path, pts, header="X,Y,Z"):
def save_csv_xyz(path, pts, header="X,Y,Z"):
def save_csv_xyz(path, pts, header="X,Y,Z"):
def save_csv_xyz(path, pts, header="X,Y,Z"):
def save_csv_xyz(path, pts, header="X,Y,Z"):
def save_csv_xyz(path, pts, header="X,Y,Z"):
def save_csv_xyz(path, pts, header="X,Y,Z"):
def save_csv_xyz(path, pts, header="X,Y,Z"):
def save_csv_xyz(path, pts, header="X,Y,Z"):
def save_csv_xyz(path, pts, header="X,Y,Z"):
def save_csv_xyz(path, pts, header="X,Y,Z"):
def save_csv_xyz(path, pts, header="X,Y,Z"):
def save_csv_xyz(path, pts, header="X,Y,Z"):
def save_csv_xyz(path, pts, header="X,Y,Z"):
def save_csv_xyz(path, pts, header="X,Y,Z"):
def save_csv_xyz(path, pts, header="X,Y,Z"):
def save_csv_xyz(path, pts, header="X,Y,Z"):
def save_csv_xyz(path, pts, header="X,Y,Z"):
def save_csv_xyz(path, pts, header="X,Y,Z"):
def save_csv_xyz(path, pts, header="X,Y,Z"):
def save_csv_xyz(path, pts, header="X,Y,Z"):
def save_csv_xyz(path, pts, header="X,Y,Z"):
def save_csv_xyz(path, pts, header="X,Y,Z"):
    os.makedirs(os.path.dirname(path) or ".", exist_ok=True)
    os.makedirs(os.path.dirname(path) or ".", exist_ok=True)
    os.makedirs(os.path.dirname(path) or ".", exist_ok=True)
    os.makedirs(os.path.dirname(path) or ".", exist_ok=True)
    os.makedirs(os.path.dirname(path) or ".", exist_ok=True)
    os.makedirs(os.path.dirname(path) or ".", exist_ok=True)
    os.makedirs(os.path.dirname(path) or ".", exist_ok=True)
    os.makedirs(os.path.dirname(path) or ".", exist_ok=True)
    os.makedirs(os.path.dirname(path) or ".", exist_ok=True)
    os.makedirs(os.path.dirname(path) or ".", exist_ok=True)
    os.makedirs(os.path.dirname(path) or ".", exist_ok=True)
    os.makedirs(os.path.dirname(path) or ".", exist_ok=True)
    os.makedirs(os.path.dirname(path) or ".", exist_ok=True)
    os.makedirs(os.path.dirname(path) or ".", exist_ok=True)
    os.makedirs(os.path.dirname(path) or ".", exist_ok=True)
    os.makedirs(os.path.dirname(path) or ".", exist_ok=True)
    os.makedirs(os.path.dirname(path) or ".", exist_ok=True)
    os.makedirs(os.path.dirname(path) or ".", exist_ok=True)
    os.makedirs(os.path.dirname(path) or ".", exist_ok=True)
    os.makedirs(os.path.dirname(path) or ".", exist_ok=True)
    os.makedirs(os.path.dirname(path) or ".", exist_ok=True)
    os.makedirs(os.path.dirname(path) or ".", exist_ok=True)
    os.makedirs(os.path.dirname(path) or ".", exist_ok=True)
    os.makedirs(os.path.dirname(path) or ".", exist_ok=True)
    os.makedirs(os.path.dirname(path) or ".", exist_ok=True)
    os.makedirs(os.path.dirname(path) or ".", exist_ok=True)
    os.makedirs(os.path.dirname(path) or ".", exist_ok=True)
    os.makedirs(os.path.dirname(path) or ".", exist_ok=True)
    os.makedirs(os.path.dirname(path) or ".", exist_ok=True)
    os.makedirs(os.path.dirname(path) or ".", exist_ok=True)
    os.makedirs(os.path.dirname(path) or ".", exist_ok=True)
    os.makedirs(os.path.dirname(path) or ".", exist_ok=True)
    os.makedirs(os.path.dirname(path) or ".", exist_ok=True)
    os.makedirs(os.path.dirname(path) or ".", exist_ok=True)
    os.makedirs(os.path.dirname(path) or ".", exist_ok=True)
    os.makedirs(os.path.dirname(path) or ".", exist_ok=True)
    os.makedirs(os.path.dirname(path) or ".", exist_ok=True)
    np.savetxt(path, pts, delimiter=",", header=header, comments='')    np.savetxt(path, pts, delimiter=",", header=header, comments='')    np.savetxt(path, pts, delimiter=",", header=header, comments='')    np.savetxt(path, pts, delimiter=",", header=header, comments='')    np.savetxt(path, pts, delimiter=",", header=header, comments='')    np.savetxt(path, pts, delimiter=",", header=header, comments='')    np.savetxt(path, pts, delimiter=",", header=header, comments='')    np.savetxt(path, pts, delimiter=",", header=header, comments='')    np.savetxt(path, pts, delimiter=",", header=header, comments='')    np.savetxt(path, pts, delimiter=",", header=header, comments='')    np.savetxt(path, pts, delimiter=",", header=header, comments='')    np.savetxt(path, pts, delimiter=",", header=header, comments='')    np.savetxt(path, pts, delimiter=",", header=header, comments='')    np.savetxt(path, pts, delimiter=",", header=header, comments='')    np.savetxt(path, pts, delimiter=",", header=header, comments='')    np.savetxt(path, pts, delimiter=",", header=header, comments='')    np.savetxt(path, pts, delimiter=",", header=header, comments='')    np.savetxt(path, pts, delimiter=",", header=header, comments='')    np.savetxt(path, pts, delimiter=",", header=header, comments='')    np.savetxt(path, pts, delimiter=",", header=header, comments='')    np.savetxt(path, pts, delimiter=",", header=header, comments='')    np.savetxt(path, pts, delimiter=",", header=header, comments='')    np.savetxt(path, pts, delimiter=",", header=header, comments='')    np.savetxt(path, pts, delimiter=",", header=header, comments='')    np.savetxt(path, pts, delimiter=",", header=header, comments='')    np.savetxt(path, pts, delimiter=",", header=header, comments='')    np.savetxt(path, pts, delimiter=",", header=header, comments='')    np.savetxt(path, pts, delimiter=",", header=header, comments='')    np.savetxt(path, pts, delimiter=",", header=header, comments='')    np.savetxt(path, pts, delimiter=",", header=header, comments='')    np.savetxt(path, pts, delimiter=",", header=header, comments='')    np.savetxt(path, pts, delimiter=",", header=header, comments='')    np.savetxt(path, pts, delimiter=",", header=header, comments='')    np.savetxt(path, pts, delimiter=",", header=header, comments='')    np.savetxt(path, pts, delimiter=",", header=header, comments='')    np.savetxt(path, pts, delimiter=",", header=header, comments='')    np.savetxt(path, pts, delimiter=",", header=header, comments='')

# %% [markdown]
# ## ---------- Projection and bandwidth calculation ----------
# ## ---------- Projection and bandwidth calculation ----------
# ## ---------- Projection and bandwidth calculation ----------
# ## ---------- Projection and bandwidth calculation ----------
# ## ---------- Projection and bandwidth calculation ----------
# ## ---------- Projection and bandwidth calculation ----------
# ## ---------- Projection and bandwidth calculation ----------
# ## ---------- Projection and bandwidth calculation ----------
# ## ---------- Projection and bandwidth calculation ----------
# ## ---------- Projection and bandwidth calculation ----------
# ## ---------- Projection and bandwidth calculation ----------
# ## ---------- Projection and bandwidth calculation ----------
# ## ---------- Projection and bandwidth calculation ----------
# ## ---------- Projection and bandwidth calculation ----------
# ## ---------- Projection and bandwidth calculation ----------
# ## ---------- Projection and bandwidth calculation ----------
# ## ---------- Projection and bandwidth calculation ----------
# ## ---------- Projection and bandwidth calculation ----------
# ## ---------- Projection and bandwidth calculation ----------
# ## ---------- Projection and bandwidth calculation ----------
# ## ---------- Projection and bandwidth calculation ----------
# ## ---------- Projection and bandwidth calculation ----------
# ## ---------- Projection and bandwidth calculation ----------
# ## ---------- Projection and bandwidth calculation ----------
# ## ---------- Projection and bandwidth calculation ----------
# ## ---------- Projection and bandwidth calculation ----------
# ## ---------- Projection and bandwidth calculation ----------
# ## ---------- Projection and bandwidth calculation ----------
# ## ---------- Projection and bandwidth calculation ----------
# ## ---------- Projection and bandwidth calculation ----------
# ## ---------- Projection and bandwidth calculation ----------
# ## ---------- Projection and bandwidth calculation ----------
# ## ---------- Projection and bandwidth calculation ----------
# ## ---------- Projection and bandwidth calculation ----------
# ## ---------- Projection and bandwidth calculation ----------
# ## ---------- Projection and bandwidth calculation ----------
# ## ---------- Projection and bandwidth calculation ----------

# %%
def project_to_plane(points, axis, plane_coord):
def project_to_plane(points, axis, plane_coord):
def project_to_plane(points, axis, plane_coord):
def project_to_plane(points, axis, plane_coord):
def project_to_plane(points, axis, plane_coord):
def project_to_plane(points, axis, plane_coord):
def project_to_plane(points, axis, plane_coord):
def project_to_plane(points, axis, plane_coord):
def project_to_plane(points, axis, plane_coord):
def project_to_plane(points, axis, plane_coord):
def project_to_plane(points, axis, plane_coord):
def project_to_plane(points, axis, plane_coord):
def project_to_plane(points, axis, plane_coord):
def project_to_plane(points, axis, plane_coord):
def project_to_plane(points, axis, plane_coord):
def project_to_plane(points, axis, plane_coord):
def project_to_plane(points, axis, plane_coord):
def project_to_plane(points, axis, plane_coord):
def project_to_plane(points, axis, plane_coord):
def project_to_plane(points, axis, plane_coord):
def project_to_plane(points, axis, plane_coord):
def project_to_plane(points, axis, plane_coord):
def project_to_plane(points, axis, plane_coord):
def project_to_plane(points, axis, plane_coord):
def project_to_plane(points, axis, plane_coord):
def project_to_plane(points, axis, plane_coord):
def project_to_plane(points, axis, plane_coord):
def project_to_plane(points, axis, plane_coord):
def project_to_plane(points, axis, plane_coord):
def project_to_plane(points, axis, plane_coord):
def project_to_plane(points, axis, plane_coord):
def project_to_plane(points, axis, plane_coord):
def project_to_plane(points, axis, plane_coord):
def project_to_plane(points, axis, plane_coord):
def project_to_plane(points, axis, plane_coord):
def project_to_plane(points, axis, plane_coord):
def project_to_plane(points, axis, plane_coord):
    pts = np.asarray(points, dtype=float)
    pts = np.asarray(points, dtype=float)
    pts = np.asarray(points, dtype=float)
    pts = np.asarray(points, dtype=float)
    pts = np.asarray(points, dtype=float)
    pts = np.asarray(points, dtype=float)
    pts = np.asarray(points, dtype=float)
    pts = np.asarray(points, dtype=float)
    pts = np.asarray(points, dtype=float)
    pts = np.asarray(points, dtype=float)
    pts = np.asarray(points, dtype=float)
    pts = np.asarray(points, dtype=float)
    pts = np.asarray(points, dtype=float)
    pts = np.asarray(points, dtype=float)
    pts = np.asarray(points, dtype=float)
    pts = np.asarray(points, dtype=float)
    pts = np.asarray(points, dtype=float)
    pts = np.asarray(points, dtype=float)
    pts = np.asarray(points, dtype=float)
    pts = np.asarray(points, dtype=float)
    pts = np.asarray(points, dtype=float)
    pts = np.asarray(points, dtype=float)
    pts = np.asarray(points, dtype=float)
    pts = np.asarray(points, dtype=float)
    pts = np.asarray(points, dtype=float)
    pts = np.asarray(points, dtype=float)
    pts = np.asarray(points, dtype=float)
    pts = np.asarray(points, dtype=float)
    pts = np.asarray(points, dtype=float)
    pts = np.asarray(points, dtype=float)
    pts = np.asarray(points, dtype=float)
    pts = np.asarray(points, dtype=float)
    pts = np.asarray(points, dtype=float)
    pts = np.asarray(points, dtype=float)
    pts = np.asarray(points, dtype=float)
    pts = np.asarray(points, dtype=float)
    pts = np.asarray(points, dtype=float)
    if pts.shape[0] == 0:
    if pts.shape[0] == 0:
    if pts.shape[0] == 0:
    if pts.shape[0] == 0:
    if pts.shape[0] == 0:
    if pts.shape[0] == 0:
    if pts.shape[0] == 0:
    if pts.shape[0] == 0:
    if pts.shape[0] == 0:
    if pts.shape[0] == 0:
    if pts.shape[0] == 0:
    if pts.shape[0] == 0:
    if pts.shape[0] == 0:
    if pts.shape[0] == 0:
    if pts.shape[0] == 0:
    if pts.shape[0] == 0:
    if pts.shape[0] == 0:
    if pts.shape[0] == 0:
    if pts.shape[0] == 0:
    if pts.shape[0] == 0:
    if pts.shape[0] == 0:
    if pts.shape[0] == 0:
    if pts.shape[0] == 0:
    if pts.shape[0] == 0:
    if pts.shape[0] == 0:
    if pts.shape[0] == 0:
    if pts.shape[0] == 0:
    if pts.shape[0] == 0:
    if pts.shape[0] == 0:
    if pts.shape[0] == 0:
    if pts.shape[0] == 0:
    if pts.shape[0] == 0:
    if pts.shape[0] == 0:
    if pts.shape[0] == 0:
    if pts.shape[0] == 0:
    if pts.shape[0] == 0:
    if pts.shape[0] == 0:
        return np.zeros((0,3)), np.zeros((0,2)), np.zeros(3), np.zeros(3), np.zeros(3)
        return np.zeros((0,3)), np.zeros((0,2)), np.zeros(3), np.zeros(3), np.zeros(3)
        return np.zeros((0,3)), np.zeros((0,2)), np.zeros(3), np.zeros(3), np.zeros(3)
        return np.zeros((0,3)), np.zeros((0,2)), np.zeros(3), np.zeros(3), np.zeros(3)
        return np.zeros((0,3)), np.zeros((0,2)), np.zeros(3), np.zeros(3), np.zeros(3)
        return np.zeros((0,3)), np.zeros((0,2)), np.zeros(3), np.zeros(3), np.zeros(3)
        return np.zeros((0,3)), np.zeros((0,2)), np.zeros(3), np.zeros(3), np.zeros(3)
        return np.zeros((0,3)), np.zeros((0,2)), np.zeros(3), np.zeros(3), np.zeros(3)
        return np.zeros((0,3)), np.zeros((0,2)), np.zeros(3), np.zeros(3), np.zeros(3)
        return np.zeros((0,3)), np.zeros((0,2)), np.zeros(3), np.zeros(3), np.zeros(3)
        return np.zeros((0,3)), np.zeros((0,2)), np.zeros(3), np.zeros(3), np.zeros(3)
        return np.zeros((0,3)), np.zeros((0,2)), np.zeros(3), np.zeros(3), np.zeros(3)
        return np.zeros((0,3)), np.zeros((0,2)), np.zeros(3), np.zeros(3), np.zeros(3)
        return np.zeros((0,3)), np.zeros((0,2)), np.zeros(3), np.zeros(3), np.zeros(3)
        return np.zeros((0,3)), np.zeros((0,2)), np.zeros(3), np.zeros(3), np.zeros(3)
        return np.zeros((0,3)), np.zeros((0,2)), np.zeros(3), np.zeros(3), np.zeros(3)
        return np.zeros((0,3)), np.zeros((0,2)), np.zeros(3), np.zeros(3), np.zeros(3)
        return np.zeros((0,3)), np.zeros((0,2)), np.zeros(3), np.zeros(3), np.zeros(3)
        return np.zeros((0,3)), np.zeros((0,2)), np.zeros(3), np.zeros(3), np.zeros(3)
        return np.zeros((0,3)), np.zeros((0,2)), np.zeros(3), np.zeros(3), np.zeros(3)
        return np.zeros((0,3)), np.zeros((0,2)), np.zeros(3), np.zeros(3), np.zeros(3)
        return np.zeros((0,3)), np.zeros((0,2)), np.zeros(3), np.zeros(3), np.zeros(3)
        return np.zeros((0,3)), np.zeros((0,2)), np.zeros(3), np.zeros(3), np.zeros(3)
        return np.zeros((0,3)), np.zeros((0,2)), np.zeros(3), np.zeros(3), np.zeros(3)
        return np.zeros((0,3)), np.zeros((0,2)), np.zeros(3), np.zeros(3), np.zeros(3)
        return np.zeros((0,3)), np.zeros((0,2)), np.zeros(3), np.zeros(3), np.zeros(3)
        return np.zeros((0,3)), np.zeros((0,2)), np.zeros(3), np.zeros(3), np.zeros(3)
        return np.zeros((0,3)), np.zeros((0,2)), np.zeros(3), np.zeros(3), np.zeros(3)
        return np.zeros((0,3)), np.zeros((0,2)), np.zeros(3), np.zeros(3), np.zeros(3)
        return np.zeros((0,3)), np.zeros((0,2)), np.zeros(3), np.zeros(3), np.zeros(3)
        return np.zeros((0,3)), np.zeros((0,2)), np.zeros(3), np.zeros(3), np.zeros(3)
        return np.zeros((0,3)), np.zeros((0,2)), np.zeros(3), np.zeros(3), np.zeros(3)
        return np.zeros((0,3)), np.zeros((0,2)), np.zeros(3), np.zeros(3), np.zeros(3)
        return np.zeros((0,3)), np.zeros((0,2)), np.zeros(3), np.zeros(3), np.zeros(3)
        return np.zeros((0,3)), np.zeros((0,2)), np.zeros(3), np.zeros(3), np.zeros(3)
        return np.zeros((0,3)), np.zeros((0,2)), np.zeros(3), np.zeros(3), np.zeros(3)
        return np.zeros((0,3)), np.zeros((0,2)), np.zeros(3), np.zeros(3), np.zeros(3)
    # axis_vec
    # axis_vec
    # axis_vec
    # axis_vec
    # axis_vec
    # axis_vec
    # axis_vec
    # axis_vec
    # axis_vec
    # axis_vec
    # axis_vec
    # axis_vec
    # axis_vec
    # axis_vec
    # axis_vec
    # axis_vec
    # axis_vec
    # axis_vec
    # axis_vec
    # axis_vec
    # axis_vec
    # axis_vec
    # axis_vec
    # axis_vec
    # axis_vec
    # axis_vec
    # axis_vec
    # axis_vec
    # axis_vec
    # axis_vec
    # axis_vec
    # axis_vec
    # axis_vec
    # axis_vec
    # axis_vec
    # axis_vec
    # axis_vec
    axis_vec = np.zeros(3); axis_vec[int(axis)] = 1.0
    axis_vec = np.zeros(3); axis_vec[int(axis)] = 1.0
    axis_vec = np.zeros(3); axis_vec[int(axis)] = 1.0
    axis_vec = np.zeros(3); axis_vec[int(axis)] = 1.0
    axis_vec = np.zeros(3); axis_vec[int(axis)] = 1.0
    axis_vec = np.zeros(3); axis_vec[int(axis)] = 1.0
    axis_vec = np.zeros(3); axis_vec[int(axis)] = 1.0
    axis_vec = np.zeros(3); axis_vec[int(axis)] = 1.0
    axis_vec = np.zeros(3); axis_vec[int(axis)] = 1.0
    axis_vec = np.zeros(3); axis_vec[int(axis)] = 1.0
    axis_vec = np.zeros(3); axis_vec[int(axis)] = 1.0
    axis_vec = np.zeros(3); axis_vec[int(axis)] = 1.0
    axis_vec = np.zeros(3); axis_vec[int(axis)] = 1.0
    axis_vec = np.zeros(3); axis_vec[int(axis)] = 1.0
    axis_vec = np.zeros(3); axis_vec[int(axis)] = 1.0
    axis_vec = np.zeros(3); axis_vec[int(axis)] = 1.0
    axis_vec = np.zeros(3); axis_vec[int(axis)] = 1.0
    axis_vec = np.zeros(3); axis_vec[int(axis)] = 1.0
    axis_vec = np.zeros(3); axis_vec[int(axis)] = 1.0
    axis_vec = np.zeros(3); axis_vec[int(axis)] = 1.0
    axis_vec = np.zeros(3); axis_vec[int(axis)] = 1.0
    axis_vec = np.zeros(3); axis_vec[int(axis)] = 1.0
    axis_vec = np.zeros(3); axis_vec[int(axis)] = 1.0
    axis_vec = np.zeros(3); axis_vec[int(axis)] = 1.0
    axis_vec = np.zeros(3); axis_vec[int(axis)] = 1.0
    axis_vec = np.zeros(3); axis_vec[int(axis)] = 1.0
    axis_vec = np.zeros(3); axis_vec[int(axis)] = 1.0
    axis_vec = np.zeros(3); axis_vec[int(axis)] = 1.0
    axis_vec = np.zeros(3); axis_vec[int(axis)] = 1.0
    axis_vec = np.zeros(3); axis_vec[int(axis)] = 1.0
    axis_vec = np.zeros(3); axis_vec[int(axis)] = 1.0
    axis_vec = np.zeros(3); axis_vec[int(axis)] = 1.0
    axis_vec = np.zeros(3); axis_vec[int(axis)] = 1.0
    axis_vec = np.zeros(3); axis_vec[int(axis)] = 1.0
    axis_vec = np.zeros(3); axis_vec[int(axis)] = 1.0
    axis_vec = np.zeros(3); axis_vec[int(axis)] = 1.0
    axis_vec = np.zeros(3); axis_vec[int(axis)] = 1.0
    # plane: origin at the selected axis value
    # plane: origin at the selected axis value
    # plane: origin at the selected axis value
    # plane: origin at the selected axis value
    # plane: origin at the selected axis value
    # plane: origin at the selected axis value
    # plane: origin at the selected axis value
    # plane: origin at the selected axis value
    # plane: origin at the selected axis value
    # plane: origin at the selected axis value
    # plane: origin at the selected axis value
    # plane: origin at the selected axis value
    # plane: origin at the selected axis value
    # plane: origin at the selected axis value
    # plane: origin at the selected axis value
    # plane: origin at the selected axis value
    # plane: origin at the selected axis value
    # plane: origin at the selected axis value
    # plane: origin at the selected axis value
    # plane: origin at the selected axis value
    # plane: origin at the selected axis value
    # plane: origin at the selected axis value
    # plane: origin at the selected axis value
    # plane: origin at the selected axis value
    # plane: origin at the selected axis value
    # plane: origin at the selected axis value
    # plane: origin at the selected axis value
    # plane: origin at the selected axis value
    # plane: origin at the selected axis value
    # plane: origin at the selected axis value
    # plane: origin at the selected axis value
    # plane: origin at the selected axis value
    # plane: origin at the selected axis value
    # plane: origin at the selected axis value
    # plane: origin at the selected axis value
    # plane: origin at the selected axis value
    # plane: origin at the selected axis value
    origin_world = np.array([0.0,0.0,0.0]); origin_world[int(axis)] = plane_coord
    origin_world = np.array([0.0,0.0,0.0]); origin_world[int(axis)] = plane_coord
    origin_world = np.array([0.0,0.0,0.0]); origin_world[int(axis)] = plane_coord
    origin_world = np.array([0.0,0.0,0.0]); origin_world[int(axis)] = plane_coord
    origin_world = np.array([0.0,0.0,0.0]); origin_world[int(axis)] = plane_coord
    origin_world = np.array([0.0,0.0,0.0]); origin_world[int(axis)] = plane_coord
    origin_world = np.array([0.0,0.0,0.0]); origin_world[int(axis)] = plane_coord
    origin_world = np.array([0.0,0.0,0.0]); origin_world[int(axis)] = plane_coord
    origin_world = np.array([0.0,0.0,0.0]); origin_world[int(axis)] = plane_coord
    origin_world = np.array([0.0,0.0,0.0]); origin_world[int(axis)] = plane_coord
    origin_world = np.array([0.0,0.0,0.0]); origin_world[int(axis)] = plane_coord
    origin_world = np.array([0.0,0.0,0.0]); origin_world[int(axis)] = plane_coord
    origin_world = np.array([0.0,0.0,0.0]); origin_world[int(axis)] = plane_coord
    origin_world = np.array([0.0,0.0,0.0]); origin_world[int(axis)] = plane_coord
    origin_world = np.array([0.0,0.0,0.0]); origin_world[int(axis)] = plane_coord
    origin_world = np.array([0.0,0.0,0.0]); origin_world[int(axis)] = plane_coord
    origin_world = np.array([0.0,0.0,0.0]); origin_world[int(axis)] = plane_coord
    origin_world = np.array([0.0,0.0,0.0]); origin_world[int(axis)] = plane_coord
    origin_world = np.array([0.0,0.0,0.0]); origin_world[int(axis)] = plane_coord
    origin_world = np.array([0.0,0.0,0.0]); origin_world[int(axis)] = plane_coord
    origin_world = np.array([0.0,0.0,0.0]); origin_world[int(axis)] = plane_coord
    origin_world = np.array([0.0,0.0,0.0]); origin_world[int(axis)] = plane_coord
    origin_world = np.array([0.0,0.0,0.0]); origin_world[int(axis)] = plane_coord
    origin_world = np.array([0.0,0.0,0.0]); origin_world[int(axis)] = plane_coord
    origin_world = np.array([0.0,0.0,0.0]); origin_world[int(axis)] = plane_coord
    origin_world = np.array([0.0,0.0,0.0]); origin_world[int(axis)] = plane_coord
    origin_world = np.array([0.0,0.0,0.0]); origin_world[int(axis)] = plane_coord
    origin_world = np.array([0.0,0.0,0.0]); origin_world[int(axis)] = plane_coord
    origin_world = np.array([0.0,0.0,0.0]); origin_world[int(axis)] = plane_coord
    origin_world = np.array([0.0,0.0,0.0]); origin_world[int(axis)] = plane_coord
    origin_world = np.array([0.0,0.0,0.0]); origin_world[int(axis)] = plane_coord
    origin_world = np.array([0.0,0.0,0.0]); origin_world[int(axis)] = plane_coord
    origin_world = np.array([0.0,0.0,0.0]); origin_world[int(axis)] = plane_coord
    origin_world = np.array([0.0,0.0,0.0]); origin_world[int(axis)] = plane_coord
    origin_world = np.array([0.0,0.0,0.0]); origin_world[int(axis)] = plane_coord
    origin_world = np.array([0.0,0.0,0.0]); origin_world[int(axis)] = plane_coord
    origin_world = np.array([0.0,0.0,0.0]); origin_world[int(axis)] = plane_coord
    # PCA (SVD) to find the plane basis vectors
    # PCA (SVD) to find the plane basis vectors
    # PCA (SVD) to find the plane basis vectors
    # PCA (SVD) to find the plane basis vectors
    # PCA (SVD) to find the plane basis vectors
    # PCA (SVD) to find the plane basis vectors
    # PCA (SVD) to find the plane basis vectors
    # PCA (SVD) to find the plane basis vectors
    # PCA (SVD) to find the plane basis vectors
    # PCA (SVD) to find the plane basis vectors
    # PCA (SVD) to find the plane basis vectors
    # PCA (SVD) to find the plane basis vectors
    # PCA (SVD) to find the plane basis vectors
    # PCA (SVD) to find the plane basis vectors
    # PCA (SVD) to find the plane basis vectors
    # PCA (SVD) to find the plane basis vectors
    # PCA (SVD) to find the plane basis vectors
    # PCA (SVD) to find the plane basis vectors
    # PCA (SVD) to find the plane basis vectors
    # PCA (SVD) to find the plane basis vectors
    # PCA (SVD) to find the plane basis vectors
    # PCA (SVD) to find the plane basis vectors
    # PCA (SVD) to find the plane basis vectors
    # PCA (SVD) to find the plane basis vectors
    # PCA (SVD) to find the plane basis vectors
    # PCA (SVD) to find the plane basis vectors
    # PCA (SVD) to find the plane basis vectors
    # PCA (SVD) to find the plane basis vectors
    # PCA (SVD) to find the plane basis vectors
    # PCA (SVD) to find the plane basis vectors
    # PCA (SVD) to find the plane basis vectors
    # PCA (SVD) to find the plane basis vectors
    # PCA (SVD) to find the plane basis vectors
    # PCA (SVD) to find the plane basis vectors
    # PCA (SVD) to find the plane basis vectors
    # PCA (SVD) to find the plane basis vectors
    # PCA (SVD) to find the plane basis vectors
    X = pts - pts.mean(axis=0)
    X = pts - pts.mean(axis=0)
    X = pts - pts.mean(axis=0)
    X = pts - pts.mean(axis=0)
    X = pts - pts.mean(axis=0)
    X = pts - pts.mean(axis=0)
    X = pts - pts.mean(axis=0)
    X = pts - pts.mean(axis=0)
    X = pts - pts.mean(axis=0)
    X = pts - pts.mean(axis=0)
    X = pts - pts.mean(axis=0)
    X = pts - pts.mean(axis=0)
    X = pts - pts.mean(axis=0)
    X = pts - pts.mean(axis=0)
    X = pts - pts.mean(axis=0)
    X = pts - pts.mean(axis=0)
    X = pts - pts.mean(axis=0)
    X = pts - pts.mean(axis=0)
    X = pts - pts.mean(axis=0)
    X = pts - pts.mean(axis=0)
    X = pts - pts.mean(axis=0)
    X = pts - pts.mean(axis=0)
    X = pts - pts.mean(axis=0)
    X = pts - pts.mean(axis=0)
    X = pts - pts.mean(axis=0)
    X = pts - pts.mean(axis=0)
    X = pts - pts.mean(axis=0)
    X = pts - pts.mean(axis=0)
    X = pts - pts.mean(axis=0)
    X = pts - pts.mean(axis=0)
    X = pts - pts.mean(axis=0)
    X = pts - pts.mean(axis=0)
    X = pts - pts.mean(axis=0)
    X = pts - pts.mean(axis=0)
    X = pts - pts.mean(axis=0)
    X = pts - pts.mean(axis=0)
    X = pts - pts.mean(axis=0)
    try:
    try:
    try:
    try:
    try:
    try:
    try:
    try:
    try:
    try:
    try:
    try:
    try:
    try:
    try:
    try:
    try:
    try:
    try:
    try:
    try:
    try:
    try:
    try:
    try:
    try:
    try:
    try:
    try:
    try:
    try:
    try:
    try:
    try:
    try:
    try:
    try:
        U,S,Vt = svd(X, full_matrices=False)
        U,S,Vt = svd(X, full_matrices=False)
        U,S,Vt = svd(X, full_matrices=False)
        U,S,Vt = svd(X, full_matrices=False)
        U,S,Vt = svd(X, full_matrices=False)
        U,S,Vt = svd(X, full_matrices=False)
        U,S,Vt = svd(X, full_matrices=False)
        U,S,Vt = svd(X, full_matrices=False)
        U,S,Vt = svd(X, full_matrices=False)
        U,S,Vt = svd(X, full_matrices=False)
        U,S,Vt = svd(X, full_matrices=False)
        U,S,Vt = svd(X, full_matrices=False)
        U,S,Vt = svd(X, full_matrices=False)
        U,S,Vt = svd(X, full_matrices=False)
        U,S,Vt = svd(X, full_matrices=False)
        U,S,Vt = svd(X, full_matrices=False)
        U,S,Vt = svd(X, full_matrices=False)
        U,S,Vt = svd(X, full_matrices=False)
        U,S,Vt = svd(X, full_matrices=False)
        U,S,Vt = svd(X, full_matrices=False)
        U,S,Vt = svd(X, full_matrices=False)
        U,S,Vt = svd(X, full_matrices=False)
        U,S,Vt = svd(X, full_matrices=False)
        U,S,Vt = svd(X, full_matrices=False)
        U,S,Vt = svd(X, full_matrices=False)
        U,S,Vt = svd(X, full_matrices=False)
        U,S,Vt = svd(X, full_matrices=False)
        U,S,Vt = svd(X, full_matrices=False)
        U,S,Vt = svd(X, full_matrices=False)
        U,S,Vt = svd(X, full_matrices=False)
        U,S,Vt = svd(X, full_matrices=False)
        U,S,Vt = svd(X, full_matrices=False)
        U,S,Vt = svd(X, full_matrices=False)
        U,S,Vt = svd(X, full_matrices=False)
        U,S,Vt = svd(X, full_matrices=False)
        U,S,Vt = svd(X, full_matrices=False)
        U,S,Vt = svd(X, full_matrices=False)
        Vs = Vt.T
        Vs = Vt.T
        Vs = Vt.T
        Vs = Vt.T
        Vs = Vt.T
        Vs = Vt.T
        Vs = Vt.T
        Vs = Vt.T
        Vs = Vt.T
        Vs = Vt.T
        Vs = Vt.T
        Vs = Vt.T
        Vs = Vt.T
        Vs = Vt.T
        Vs = Vt.T
        Vs = Vt.T
        Vs = Vt.T
        Vs = Vt.T
        Vs = Vt.T
        Vs = Vt.T
        Vs = Vt.T
        Vs = Vt.T
        Vs = Vt.T
        Vs = Vt.T
        Vs = Vt.T
        Vs = Vt.T
        Vs = Vt.T
        Vs = Vt.T
        Vs = Vt.T
        Vs = Vt.T
        Vs = Vt.T
        Vs = Vt.T
        Vs = Vt.T
        Vs = Vt.T
        Vs = Vt.T
        Vs = Vt.T
        Vs = Vt.T
    except Exception:
    except Exception:
    except Exception:
    except Exception:
    except Exception:
    except Exception:
    except Exception:
    except Exception:
    except Exception:
    except Exception:
    except Exception:
    except Exception:
    except Exception:
    except Exception:
    except Exception:
    except Exception:
    except Exception:
    except Exception:
    except Exception:
    except Exception:
    except Exception:
    except Exception:
    except Exception:
    except Exception:
    except Exception:
    except Exception:
    except Exception:
    except Exception:
    except Exception:
    except Exception:
    except Exception:
    except Exception:
    except Exception:
    except Exception:
    except Exception:
    except Exception:
    except Exception:
        Vs = np.eye(3)
        Vs = np.eye(3)
        Vs = np.eye(3)
        Vs = np.eye(3)
        Vs = np.eye(3)
        Vs = np.eye(3)
        Vs = np.eye(3)
        Vs = np.eye(3)
        Vs = np.eye(3)
        Vs = np.eye(3)
        Vs = np.eye(3)
        Vs = np.eye(3)
        Vs = np.eye(3)
        Vs = np.eye(3)
        Vs = np.eye(3)
        Vs = np.eye(3)
        Vs = np.eye(3)
        Vs = np.eye(3)
        Vs = np.eye(3)
        Vs = np.eye(3)
        Vs = np.eye(3)
        Vs = np.eye(3)
        Vs = np.eye(3)
        Vs = np.eye(3)
        Vs = np.eye(3)
        Vs = np.eye(3)
        Vs = np.eye(3)
        Vs = np.eye(3)
        Vs = np.eye(3)
        Vs = np.eye(3)
        Vs = np.eye(3)
        Vs = np.eye(3)
        Vs = np.eye(3)
        Vs = np.eye(3)
        Vs = np.eye(3)
        Vs = np.eye(3)
        Vs = np.eye(3)
    # Select two vectors perpendicular to axis_vec (smallest absolute dot product)
    # Select two vectors perpendicular to axis_vec (smallest absolute dot product)
    # Select two vectors perpendicular to axis_vec (smallest absolute dot product)
    # Select two vectors perpendicular to axis_vec (smallest absolute dot product)
    # Select two vectors perpendicular to axis_vec (smallest absolute dot product)
    # Select two vectors perpendicular to axis_vec (smallest absolute dot product)
    # Select two vectors perpendicular to axis_vec (smallest absolute dot product)
    # Select two vectors perpendicular to axis_vec (smallest absolute dot product)
    # Select two vectors perpendicular to axis_vec (smallest absolute dot product)
    # Select two vectors perpendicular to axis_vec (smallest absolute dot product)
    # Select two vectors perpendicular to axis_vec (smallest absolute dot product)
    # Select two vectors perpendicular to axis_vec (smallest absolute dot product)
    # Select two vectors perpendicular to axis_vec (smallest absolute dot product)
    # Select two vectors perpendicular to axis_vec (smallest absolute dot product)
    # Select two vectors perpendicular to axis_vec (smallest absolute dot product)
    # Select two vectors perpendicular to axis_vec (smallest absolute dot product)
    # Select two vectors perpendicular to axis_vec (smallest absolute dot product)
    # Select two vectors perpendicular to axis_vec (smallest absolute dot product)
    # Select two vectors perpendicular to axis_vec (smallest absolute dot product)
    # Select two vectors perpendicular to axis_vec (smallest absolute dot product)
    # Select two vectors perpendicular to axis_vec (smallest absolute dot product)
    # Select two vectors perpendicular to axis_vec (smallest absolute dot product)
    # Select two vectors perpendicular to axis_vec (smallest absolute dot product)
    # Select two vectors perpendicular to axis_vec (smallest absolute dot product)
    # Select two vectors perpendicular to axis_vec (smallest absolute dot product)
    # Select two vectors perpendicular to axis_vec (smallest absolute dot product)
    # Select two vectors perpendicular to axis_vec (smallest absolute dot product)
    # Select two vectors perpendicular to axis_vec (smallest absolute dot product)
    # Select two vectors perpendicular to axis_vec (smallest absolute dot product)
    # Select two vectors perpendicular to axis_vec (smallest absolute dot product)
    # Select two vectors perpendicular to axis_vec (smallest absolute dot product)
    # Select two vectors perpendicular to axis_vec (smallest absolute dot product)
    # Select two vectors perpendicular to axis_vec (smallest absolute dot product)
    # Select two vectors perpendicular to axis_vec (smallest absolute dot product)
    # Select two vectors perpendicular to axis_vec (smallest absolute dot product)
    # Select two vectors perpendicular to axis_vec (smallest absolute dot product)
    # Select two vectors perpendicular to axis_vec (smallest absolute dot product)
    dots = np.abs(Vs.T.dot(axis_vec))
    dots = np.abs(Vs.T.dot(axis_vec))
    dots = np.abs(Vs.T.dot(axis_vec))
    dots = np.abs(Vs.T.dot(axis_vec))
    dots = np.abs(Vs.T.dot(axis_vec))
    dots = np.abs(Vs.T.dot(axis_vec))
    dots = np.abs(Vs.T.dot(axis_vec))
    dots = np.abs(Vs.T.dot(axis_vec))
    dots = np.abs(Vs.T.dot(axis_vec))
    dots = np.abs(Vs.T.dot(axis_vec))
    dots = np.abs(Vs.T.dot(axis_vec))
    dots = np.abs(Vs.T.dot(axis_vec))
    dots = np.abs(Vs.T.dot(axis_vec))
    dots = np.abs(Vs.T.dot(axis_vec))
    dots = np.abs(Vs.T.dot(axis_vec))
    dots = np.abs(Vs.T.dot(axis_vec))
    dots = np.abs(Vs.T.dot(axis_vec))
    dots = np.abs(Vs.T.dot(axis_vec))
    dots = np.abs(Vs.T.dot(axis_vec))
    dots = np.abs(Vs.T.dot(axis_vec))
    dots = np.abs(Vs.T.dot(axis_vec))
    dots = np.abs(Vs.T.dot(axis_vec))
    dots = np.abs(Vs.T.dot(axis_vec))
    dots = np.abs(Vs.T.dot(axis_vec))
    dots = np.abs(Vs.T.dot(axis_vec))
    dots = np.abs(Vs.T.dot(axis_vec))
    dots = np.abs(Vs.T.dot(axis_vec))
    dots = np.abs(Vs.T.dot(axis_vec))
    dots = np.abs(Vs.T.dot(axis_vec))
    dots = np.abs(Vs.T.dot(axis_vec))
    dots = np.abs(Vs.T.dot(axis_vec))
    dots = np.abs(Vs.T.dot(axis_vec))
    dots = np.abs(Vs.T.dot(axis_vec))
    dots = np.abs(Vs.T.dot(axis_vec))
    dots = np.abs(Vs.T.dot(axis_vec))
    dots = np.abs(Vs.T.dot(axis_vec))
    dots = np.abs(Vs.T.dot(axis_vec))
    if dots.size < 2:
    if dots.size < 2:
    if dots.size < 2:
    if dots.size < 2:
    if dots.size < 2:
    if dots.size < 2:
    if dots.size < 2:
    if dots.size < 2:
    if dots.size < 2:
    if dots.size < 2:
    if dots.size < 2:
    if dots.size < 2:
    if dots.size < 2:
    if dots.size < 2:
    if dots.size < 2:
    if dots.size < 2:
    if dots.size < 2:
    if dots.size < 2:
    if dots.size < 2:
    if dots.size < 2:
    if dots.size < 2:
    if dots.size < 2:
    if dots.size < 2:
    if dots.size < 2:
    if dots.size < 2:
    if dots.size < 2:
    if dots.size < 2:
    if dots.size < 2:
    if dots.size < 2:
    if dots.size < 2:
    if dots.size < 2:
    if dots.size < 2:
    if dots.size < 2:
    if dots.size < 2:
    if dots.size < 2:
    if dots.size < 2:
    if dots.size < 2:
        Vs = np.eye(3); dots = np.abs(Vs.T.dot(axis_vec))
        Vs = np.eye(3); dots = np.abs(Vs.T.dot(axis_vec))
        Vs = np.eye(3); dots = np.abs(Vs.T.dot(axis_vec))
        Vs = np.eye(3); dots = np.abs(Vs.T.dot(axis_vec))
        Vs = np.eye(3); dots = np.abs(Vs.T.dot(axis_vec))
        Vs = np.eye(3); dots = np.abs(Vs.T.dot(axis_vec))
        Vs = np.eye(3); dots = np.abs(Vs.T.dot(axis_vec))
        Vs = np.eye(3); dots = np.abs(Vs.T.dot(axis_vec))
        Vs = np.eye(3); dots = np.abs(Vs.T.dot(axis_vec))
        Vs = np.eye(3); dots = np.abs(Vs.T.dot(axis_vec))
        Vs = np.eye(3); dots = np.abs(Vs.T.dot(axis_vec))
        Vs = np.eye(3); dots = np.abs(Vs.T.dot(axis_vec))
        Vs = np.eye(3); dots = np.abs(Vs.T.dot(axis_vec))
        Vs = np.eye(3); dots = np.abs(Vs.T.dot(axis_vec))
        Vs = np.eye(3); dots = np.abs(Vs.T.dot(axis_vec))
        Vs = np.eye(3); dots = np.abs(Vs.T.dot(axis_vec))
        Vs = np.eye(3); dots = np.abs(Vs.T.dot(axis_vec))
        Vs = np.eye(3); dots = np.abs(Vs.T.dot(axis_vec))
        Vs = np.eye(3); dots = np.abs(Vs.T.dot(axis_vec))
        Vs = np.eye(3); dots = np.abs(Vs.T.dot(axis_vec))
        Vs = np.eye(3); dots = np.abs(Vs.T.dot(axis_vec))
        Vs = np.eye(3); dots = np.abs(Vs.T.dot(axis_vec))
        Vs = np.eye(3); dots = np.abs(Vs.T.dot(axis_vec))
        Vs = np.eye(3); dots = np.abs(Vs.T.dot(axis_vec))
        Vs = np.eye(3); dots = np.abs(Vs.T.dot(axis_vec))
        Vs = np.eye(3); dots = np.abs(Vs.T.dot(axis_vec))
        Vs = np.eye(3); dots = np.abs(Vs.T.dot(axis_vec))
        Vs = np.eye(3); dots = np.abs(Vs.T.dot(axis_vec))
        Vs = np.eye(3); dots = np.abs(Vs.T.dot(axis_vec))
        Vs = np.eye(3); dots = np.abs(Vs.T.dot(axis_vec))
        Vs = np.eye(3); dots = np.abs(Vs.T.dot(axis_vec))
        Vs = np.eye(3); dots = np.abs(Vs.T.dot(axis_vec))
        Vs = np.eye(3); dots = np.abs(Vs.T.dot(axis_vec))
        Vs = np.eye(3); dots = np.abs(Vs.T.dot(axis_vec))
        Vs = np.eye(3); dots = np.abs(Vs.T.dot(axis_vec))
        Vs = np.eye(3); dots = np.abs(Vs.T.dot(axis_vec))
        Vs = np.eye(3); dots = np.abs(Vs.T.dot(axis_vec))
    order = np.argsort(dots)
    order = np.argsort(dots)
    order = np.argsort(dots)
    order = np.argsort(dots)
    order = np.argsort(dots)
    order = np.argsort(dots)
    order = np.argsort(dots)
    order = np.argsort(dots)
    order = np.argsort(dots)
    order = np.argsort(dots)
    order = np.argsort(dots)
    order = np.argsort(dots)
    order = np.argsort(dots)
    order = np.argsort(dots)
    order = np.argsort(dots)
    order = np.argsort(dots)
    order = np.argsort(dots)
    order = np.argsort(dots)
    order = np.argsort(dots)
    order = np.argsort(dots)
    order = np.argsort(dots)
    order = np.argsort(dots)
    order = np.argsort(dots)
    order = np.argsort(dots)
    order = np.argsort(dots)
    order = np.argsort(dots)
    order = np.argsort(dots)
    order = np.argsort(dots)
    order = np.argsort(dots)
    order = np.argsort(dots)
    order = np.argsort(dots)
    order = np.argsort(dots)
    order = np.argsort(dots)
    order = np.argsort(dots)
    order = np.argsort(dots)
    order = np.argsort(dots)
    order = np.argsort(dots)
    u_vec = Vs[:, order[0]]
    u_vec = Vs[:, order[0]]
    u_vec = Vs[:, order[0]]
    u_vec = Vs[:, order[0]]
    u_vec = Vs[:, order[0]]
    u_vec = Vs[:, order[0]]
    u_vec = Vs[:, order[0]]
    u_vec = Vs[:, order[0]]
    u_vec = Vs[:, order[0]]
    u_vec = Vs[:, order[0]]
    u_vec = Vs[:, order[0]]
    u_vec = Vs[:, order[0]]
    u_vec = Vs[:, order[0]]
    u_vec = Vs[:, order[0]]
    u_vec = Vs[:, order[0]]
    u_vec = Vs[:, order[0]]
    u_vec = Vs[:, order[0]]
    u_vec = Vs[:, order[0]]
    u_vec = Vs[:, order[0]]
    u_vec = Vs[:, order[0]]
    u_vec = Vs[:, order[0]]
    u_vec = Vs[:, order[0]]
    u_vec = Vs[:, order[0]]
    u_vec = Vs[:, order[0]]
    u_vec = Vs[:, order[0]]
    u_vec = Vs[:, order[0]]
    u_vec = Vs[:, order[0]]
    u_vec = Vs[:, order[0]]
    u_vec = Vs[:, order[0]]
    u_vec = Vs[:, order[0]]
    u_vec = Vs[:, order[0]]
    u_vec = Vs[:, order[0]]
    u_vec = Vs[:, order[0]]
    u_vec = Vs[:, order[0]]
    u_vec = Vs[:, order[0]]
    u_vec = Vs[:, order[0]]
    u_vec = Vs[:, order[0]]
    v_vec = Vs[:, order[1] if Vs.shape[1]>1 else order[0]]
    v_vec = Vs[:, order[1] if Vs.shape[1]>1 else order[0]]
    v_vec = Vs[:, order[1] if Vs.shape[1]>1 else order[0]]
    v_vec = Vs[:, order[1] if Vs.shape[1]>1 else order[0]]
    v_vec = Vs[:, order[1] if Vs.shape[1]>1 else order[0]]
    v_vec = Vs[:, order[1] if Vs.shape[1]>1 else order[0]]
    v_vec = Vs[:, order[1] if Vs.shape[1]>1 else order[0]]
    v_vec = Vs[:, order[1] if Vs.shape[1]>1 else order[0]]
    v_vec = Vs[:, order[1] if Vs.shape[1]>1 else order[0]]
    v_vec = Vs[:, order[1] if Vs.shape[1]>1 else order[0]]
    v_vec = Vs[:, order[1] if Vs.shape[1]>1 else order[0]]
    v_vec = Vs[:, order[1] if Vs.shape[1]>1 else order[0]]
    v_vec = Vs[:, order[1] if Vs.shape[1]>1 else order[0]]
    v_vec = Vs[:, order[1] if Vs.shape[1]>1 else order[0]]
    v_vec = Vs[:, order[1] if Vs.shape[1]>1 else order[0]]
    v_vec = Vs[:, order[1] if Vs.shape[1]>1 else order[0]]
    v_vec = Vs[:, order[1] if Vs.shape[1]>1 else order[0]]
    v_vec = Vs[:, order[1] if Vs.shape[1]>1 else order[0]]
    v_vec = Vs[:, order[1] if Vs.shape[1]>1 else order[0]]
    v_vec = Vs[:, order[1] if Vs.shape[1]>1 else order[0]]
    v_vec = Vs[:, order[1] if Vs.shape[1]>1 else order[0]]
    v_vec = Vs[:, order[1] if Vs.shape[1]>1 else order[0]]
    v_vec = Vs[:, order[1] if Vs.shape[1]>1 else order[0]]
    v_vec = Vs[:, order[1] if Vs.shape[1]>1 else order[0]]
    v_vec = Vs[:, order[1] if Vs.shape[1]>1 else order[0]]
    v_vec = Vs[:, order[1] if Vs.shape[1]>1 else order[0]]
    v_vec = Vs[:, order[1] if Vs.shape[1]>1 else order[0]]
    v_vec = Vs[:, order[1] if Vs.shape[1]>1 else order[0]]
    v_vec = Vs[:, order[1] if Vs.shape[1]>1 else order[0]]
    v_vec = Vs[:, order[1] if Vs.shape[1]>1 else order[0]]
    v_vec = Vs[:, order[1] if Vs.shape[1]>1 else order[0]]
    v_vec = Vs[:, order[1] if Vs.shape[1]>1 else order[0]]
    v_vec = Vs[:, order[1] if Vs.shape[1]>1 else order[0]]
    v_vec = Vs[:, order[1] if Vs.shape[1]>1 else order[0]]
    v_vec = Vs[:, order[1] if Vs.shape[1]>1 else order[0]]
    v_vec = Vs[:, order[1] if Vs.shape[1]>1 else order[0]]
    v_vec = Vs[:, order[1] if Vs.shape[1]>1 else order[0]]
    # orthonormalize
    # orthonormalize
    # orthonormalize
    # orthonormalize
    # orthonormalize
    # orthonormalize
    # orthonormalize
    # orthonormalize
    # orthonormalize
    # orthonormalize
    # orthonormalize
    # orthonormalize
    # orthonormalize
    # orthonormalize
    # orthonormalize
    # orthonormalize
    # orthonormalize
    # orthonormalize
    # orthonormalize
    # orthonormalize
    # orthonormalize
    # orthonormalize
    # orthonormalize
    # orthonormalize
    # orthonormalize
    # orthonormalize
    # orthonormalize
    # orthonormalize
    # orthonormalize
    # orthonormalize
    # orthonormalize
    # orthonormalize
    # orthonormalize
    # orthonormalize
    # orthonormalize
    # orthonormalize
    # orthonormalize
    def norm_safe(v):
    def norm_safe(v):
    def norm_safe(v):
    def norm_safe(v):
    def norm_safe(v):
    def norm_safe(v):
    def norm_safe(v):
    def norm_safe(v):
    def norm_safe(v):
    def norm_safe(v):
    def norm_safe(v):
    def norm_safe(v):
    def norm_safe(v):
    def norm_safe(v):
    def norm_safe(v):
    def norm_safe(v):
    def norm_safe(v):
    def norm_safe(v):
    def norm_safe(v):
    def norm_safe(v):
    def norm_safe(v):
    def norm_safe(v):
    def norm_safe(v):
    def norm_safe(v):
    def norm_safe(v):
    def norm_safe(v):
    def norm_safe(v):
    def norm_safe(v):
    def norm_safe(v):
    def norm_safe(v):
    def norm_safe(v):
    def norm_safe(v):
    def norm_safe(v):
    def norm_safe(v):
    def norm_safe(v):
    def norm_safe(v):
    def norm_safe(v):
        n = np.linalg.norm(v)
        n = np.linalg.norm(v)
        n = np.linalg.norm(v)
        n = np.linalg.norm(v)
        n = np.linalg.norm(v)
        n = np.linalg.norm(v)
        n = np.linalg.norm(v)
        n = np.linalg.norm(v)
        n = np.linalg.norm(v)
        n = np.linalg.norm(v)
        n = np.linalg.norm(v)
        n = np.linalg.norm(v)
        n = np.linalg.norm(v)
        n = np.linalg.norm(v)
        n = np.linalg.norm(v)
        n = np.linalg.norm(v)
        n = np.linalg.norm(v)
        n = np.linalg.norm(v)
        n = np.linalg.norm(v)
        n = np.linalg.norm(v)
        n = np.linalg.norm(v)
        n = np.linalg.norm(v)
        n = np.linalg.norm(v)
        n = np.linalg.norm(v)
        n = np.linalg.norm(v)
        n = np.linalg.norm(v)
        n = np.linalg.norm(v)
        n = np.linalg.norm(v)
        n = np.linalg.norm(v)
        n = np.linalg.norm(v)
        n = np.linalg.norm(v)
        n = np.linalg.norm(v)
        n = np.linalg.norm(v)
        n = np.linalg.norm(v)
        n = np.linalg.norm(v)
        n = np.linalg.norm(v)
        n = np.linalg.norm(v)
        return v/n if n>1e-12 else v
        return v/n if n>1e-12 else v
        return v/n if n>1e-12 else v
        return v/n if n>1e-12 else v
        return v/n if n>1e-12 else v
        return v/n if n>1e-12 else v
        return v/n if n>1e-12 else v
        return v/n if n>1e-12 else v
        return v/n if n>1e-12 else v
        return v/n if n>1e-12 else v
        return v/n if n>1e-12 else v
        return v/n if n>1e-12 else v
        return v/n if n>1e-12 else v
        return v/n if n>1e-12 else v
        return v/n if n>1e-12 else v
        return v/n if n>1e-12 else v
        return v/n if n>1e-12 else v
        return v/n if n>1e-12 else v
        return v/n if n>1e-12 else v
        return v/n if n>1e-12 else v
        return v/n if n>1e-12 else v
        return v/n if n>1e-12 else v
        return v/n if n>1e-12 else v
        return v/n if n>1e-12 else v
        return v/n if n>1e-12 else v
        return v/n if n>1e-12 else v
        return v/n if n>1e-12 else v
        return v/n if n>1e-12 else v
        return v/n if n>1e-12 else v
        return v/n if n>1e-12 else v
        return v/n if n>1e-12 else v
        return v/n if n>1e-12 else v
        return v/n if n>1e-12 else v
        return v/n if n>1e-12 else v
        return v/n if n>1e-12 else v
        return v/n if n>1e-12 else v
        return v/n if n>1e-12 else v
    u_vec = norm_safe(u_vec)
    u_vec = norm_safe(u_vec)
    u_vec = norm_safe(u_vec)
    u_vec = norm_safe(u_vec)
    u_vec = norm_safe(u_vec)
    u_vec = norm_safe(u_vec)
    u_vec = norm_safe(u_vec)
    u_vec = norm_safe(u_vec)
    u_vec = norm_safe(u_vec)
    u_vec = norm_safe(u_vec)
    u_vec = norm_safe(u_vec)
    u_vec = norm_safe(u_vec)
    u_vec = norm_safe(u_vec)
    u_vec = norm_safe(u_vec)
    u_vec = norm_safe(u_vec)
    u_vec = norm_safe(u_vec)
    u_vec = norm_safe(u_vec)
    u_vec = norm_safe(u_vec)
    u_vec = norm_safe(u_vec)
    u_vec = norm_safe(u_vec)
    u_vec = norm_safe(u_vec)
    u_vec = norm_safe(u_vec)
    u_vec = norm_safe(u_vec)
    u_vec = norm_safe(u_vec)
    u_vec = norm_safe(u_vec)
    u_vec = norm_safe(u_vec)
    u_vec = norm_safe(u_vec)
    u_vec = norm_safe(u_vec)
    u_vec = norm_safe(u_vec)
    u_vec = norm_safe(u_vec)
    u_vec = norm_safe(u_vec)
    u_vec = norm_safe(u_vec)
    u_vec = norm_safe(u_vec)
    u_vec = norm_safe(u_vec)
    u_vec = norm_safe(u_vec)
    u_vec = norm_safe(u_vec)
    u_vec = norm_safe(u_vec)
    v_vec = v_vec - np.dot(v_vec,u_vec)*u_vec
    v_vec = v_vec - np.dot(v_vec,u_vec)*u_vec
    v_vec = v_vec - np.dot(v_vec,u_vec)*u_vec
    v_vec = v_vec - np.dot(v_vec,u_vec)*u_vec
    v_vec = v_vec - np.dot(v_vec,u_vec)*u_vec
    v_vec = v_vec - np.dot(v_vec,u_vec)*u_vec
    v_vec = v_vec - np.dot(v_vec,u_vec)*u_vec
    v_vec = v_vec - np.dot(v_vec,u_vec)*u_vec
    v_vec = v_vec - np.dot(v_vec,u_vec)*u_vec
    v_vec = v_vec - np.dot(v_vec,u_vec)*u_vec
    v_vec = v_vec - np.dot(v_vec,u_vec)*u_vec
    v_vec = v_vec - np.dot(v_vec,u_vec)*u_vec
    v_vec = v_vec - np.dot(v_vec,u_vec)*u_vec
    v_vec = v_vec - np.dot(v_vec,u_vec)*u_vec
    v_vec = v_vec - np.dot(v_vec,u_vec)*u_vec
    v_vec = v_vec - np.dot(v_vec,u_vec)*u_vec
    v_vec = v_vec - np.dot(v_vec,u_vec)*u_vec
    v_vec = v_vec - np.dot(v_vec,u_vec)*u_vec
    v_vec = v_vec - np.dot(v_vec,u_vec)*u_vec
    v_vec = v_vec - np.dot(v_vec,u_vec)*u_vec
    v_vec = v_vec - np.dot(v_vec,u_vec)*u_vec
    v_vec = v_vec - np.dot(v_vec,u_vec)*u_vec
    v_vec = v_vec - np.dot(v_vec,u_vec)*u_vec
    v_vec = v_vec - np.dot(v_vec,u_vec)*u_vec
    v_vec = v_vec - np.dot(v_vec,u_vec)*u_vec
    v_vec = v_vec - np.dot(v_vec,u_vec)*u_vec
    v_vec = v_vec - np.dot(v_vec,u_vec)*u_vec
    v_vec = v_vec - np.dot(v_vec,u_vec)*u_vec
    v_vec = v_vec - np.dot(v_vec,u_vec)*u_vec
    v_vec = v_vec - np.dot(v_vec,u_vec)*u_vec
    v_vec = v_vec - np.dot(v_vec,u_vec)*u_vec
    v_vec = v_vec - np.dot(v_vec,u_vec)*u_vec
    v_vec = v_vec - np.dot(v_vec,u_vec)*u_vec
    v_vec = v_vec - np.dot(v_vec,u_vec)*u_vec
    v_vec = v_vec - np.dot(v_vec,u_vec)*u_vec
    v_vec = v_vec - np.dot(v_vec,u_vec)*u_vec
    v_vec = v_vec - np.dot(v_vec,u_vec)*u_vec
    v_vec = norm_safe(v_vec)
    v_vec = norm_safe(v_vec)
    v_vec = norm_safe(v_vec)
    v_vec = norm_safe(v_vec)
    v_vec = norm_safe(v_vec)
    v_vec = norm_safe(v_vec)
    v_vec = norm_safe(v_vec)
    v_vec = norm_safe(v_vec)
    v_vec = norm_safe(v_vec)
    v_vec = norm_safe(v_vec)
    v_vec = norm_safe(v_vec)
    v_vec = norm_safe(v_vec)
    v_vec = norm_safe(v_vec)
    v_vec = norm_safe(v_vec)
    v_vec = norm_safe(v_vec)
    v_vec = norm_safe(v_vec)
    v_vec = norm_safe(v_vec)
    v_vec = norm_safe(v_vec)
    v_vec = norm_safe(v_vec)
    v_vec = norm_safe(v_vec)
    v_vec = norm_safe(v_vec)
    v_vec = norm_safe(v_vec)
    v_vec = norm_safe(v_vec)
    v_vec = norm_safe(v_vec)
    v_vec = norm_safe(v_vec)
    v_vec = norm_safe(v_vec)
    v_vec = norm_safe(v_vec)
    v_vec = norm_safe(v_vec)
    v_vec = norm_safe(v_vec)
    v_vec = norm_safe(v_vec)
    v_vec = norm_safe(v_vec)
    v_vec = norm_safe(v_vec)
    v_vec = norm_safe(v_vec)
    v_vec = norm_safe(v_vec)
    v_vec = norm_safe(v_vec)
    v_vec = norm_safe(v_vec)
    v_vec = norm_safe(v_vec)
    # Compute 2D coordinates in the plane
    # Compute 2D coordinates in the plane
    # Compute 2D coordinates in the plane
    # Compute 2D coordinates in the plane
    # Compute 2D coordinates in the plane
    # Compute 2D coordinates in the plane
    # Compute 2D coordinates in the plane
    # Compute 2D coordinates in the plane
    # Compute 2D coordinates in the plane
    # Compute 2D coordinates in the plane
    # Compute 2D coordinates in the plane
    # Compute 2D coordinates in the plane
    # Compute 2D coordinates in the plane
    # Compute 2D coordinates in the plane
    # Compute 2D coordinates in the plane
    # Compute 2D coordinates in the plane
    # Compute 2D coordinates in the plane
    # Compute 2D coordinates in the plane
    # Compute 2D coordinates in the plane
    # Compute 2D coordinates in the plane
    # Compute 2D coordinates in the plane
    # Compute 2D coordinates in the plane
    # Compute 2D coordinates in the plane
    # Compute 2D coordinates in the plane
    # Compute 2D coordinates in the plane
    # Compute 2D coordinates in the plane
    # Compute 2D coordinates in the plane
    # Compute 2D coordinates in the plane
    # Compute 2D coordinates in the plane
    # Compute 2D coordinates in the plane
    # Compute 2D coordinates in the plane
    # Compute 2D coordinates in the plane
    # Compute 2D coordinates in the plane
    # Compute 2D coordinates in the plane
    # Compute 2D coordinates in the plane
    # Compute 2D coordinates in the plane
    # Compute 2D coordinates in the plane
    rel = pts - origin_world
    rel = pts - origin_world
    rel = pts - origin_world
    rel = pts - origin_world
    rel = pts - origin_world
    rel = pts - origin_world
    rel = pts - origin_world
    rel = pts - origin_world
    rel = pts - origin_world
    rel = pts - origin_world
    rel = pts - origin_world
    rel = pts - origin_world
    rel = pts - origin_world
    rel = pts - origin_world
    rel = pts - origin_world
    rel = pts - origin_world
    rel = pts - origin_world
    rel = pts - origin_world
    rel = pts - origin_world
    rel = pts - origin_world
    rel = pts - origin_world
    rel = pts - origin_world
    rel = pts - origin_world
    rel = pts - origin_world
    rel = pts - origin_world
    rel = pts - origin_world
    rel = pts - origin_world
    rel = pts - origin_world
    rel = pts - origin_world
    rel = pts - origin_world
    rel = pts - origin_world
    rel = pts - origin_world
    rel = pts - origin_world
    rel = pts - origin_world
    rel = pts - origin_world
    rel = pts - origin_world
    rel = pts - origin_world
    u_coords = rel.dot(u_vec)
    u_coords = rel.dot(u_vec)
    u_coords = rel.dot(u_vec)
    u_coords = rel.dot(u_vec)
    u_coords = rel.dot(u_vec)
    u_coords = rel.dot(u_vec)
    u_coords = rel.dot(u_vec)
    u_coords = rel.dot(u_vec)
    u_coords = rel.dot(u_vec)
    u_coords = rel.dot(u_vec)
    u_coords = rel.dot(u_vec)
    u_coords = rel.dot(u_vec)
    u_coords = rel.dot(u_vec)
    u_coords = rel.dot(u_vec)
    u_coords = rel.dot(u_vec)
    u_coords = rel.dot(u_vec)
    u_coords = rel.dot(u_vec)
    u_coords = rel.dot(u_vec)
    u_coords = rel.dot(u_vec)
    u_coords = rel.dot(u_vec)
    u_coords = rel.dot(u_vec)
    u_coords = rel.dot(u_vec)
    u_coords = rel.dot(u_vec)
    u_coords = rel.dot(u_vec)
    u_coords = rel.dot(u_vec)
    u_coords = rel.dot(u_vec)
    u_coords = rel.dot(u_vec)
    u_coords = rel.dot(u_vec)
    u_coords = rel.dot(u_vec)
    u_coords = rel.dot(u_vec)
    u_coords = rel.dot(u_vec)
    u_coords = rel.dot(u_vec)
    u_coords = rel.dot(u_vec)
    u_coords = rel.dot(u_vec)
    u_coords = rel.dot(u_vec)
    u_coords = rel.dot(u_vec)
    u_coords = rel.dot(u_vec)
    v_coords = rel.dot(v_vec)
    v_coords = rel.dot(v_vec)
    v_coords = rel.dot(v_vec)
    v_coords = rel.dot(v_vec)
    v_coords = rel.dot(v_vec)
    v_coords = rel.dot(v_vec)
    v_coords = rel.dot(v_vec)
    v_coords = rel.dot(v_vec)
    v_coords = rel.dot(v_vec)
    v_coords = rel.dot(v_vec)
    v_coords = rel.dot(v_vec)
    v_coords = rel.dot(v_vec)
    v_coords = rel.dot(v_vec)
    v_coords = rel.dot(v_vec)
    v_coords = rel.dot(v_vec)
    v_coords = rel.dot(v_vec)
    v_coords = rel.dot(v_vec)
    v_coords = rel.dot(v_vec)
    v_coords = rel.dot(v_vec)
    v_coords = rel.dot(v_vec)
    v_coords = rel.dot(v_vec)
    v_coords = rel.dot(v_vec)
    v_coords = rel.dot(v_vec)
    v_coords = rel.dot(v_vec)
    v_coords = rel.dot(v_vec)
    v_coords = rel.dot(v_vec)
    v_coords = rel.dot(v_vec)
    v_coords = rel.dot(v_vec)
    v_coords = rel.dot(v_vec)
    v_coords = rel.dot(v_vec)
    v_coords = rel.dot(v_vec)
    v_coords = rel.dot(v_vec)
    v_coords = rel.dot(v_vec)
    v_coords = rel.dot(v_vec)
    v_coords = rel.dot(v_vec)
    v_coords = rel.dot(v_vec)
    v_coords = rel.dot(v_vec)
    coords2d = np.column_stack([u_coords, v_coords])
    coords2d = np.column_stack([u_coords, v_coords])
    coords2d = np.column_stack([u_coords, v_coords])
    coords2d = np.column_stack([u_coords, v_coords])
    coords2d = np.column_stack([u_coords, v_coords])
    coords2d = np.column_stack([u_coords, v_coords])
    coords2d = np.column_stack([u_coords, v_coords])
    coords2d = np.column_stack([u_coords, v_coords])
    coords2d = np.column_stack([u_coords, v_coords])
    coords2d = np.column_stack([u_coords, v_coords])
    coords2d = np.column_stack([u_coords, v_coords])
    coords2d = np.column_stack([u_coords, v_coords])
    coords2d = np.column_stack([u_coords, v_coords])
    coords2d = np.column_stack([u_coords, v_coords])
    coords2d = np.column_stack([u_coords, v_coords])
    coords2d = np.column_stack([u_coords, v_coords])
    coords2d = np.column_stack([u_coords, v_coords])
    coords2d = np.column_stack([u_coords, v_coords])
    coords2d = np.column_stack([u_coords, v_coords])
    coords2d = np.column_stack([u_coords, v_coords])
    coords2d = np.column_stack([u_coords, v_coords])
    coords2d = np.column_stack([u_coords, v_coords])
    coords2d = np.column_stack([u_coords, v_coords])
    coords2d = np.column_stack([u_coords, v_coords])
    coords2d = np.column_stack([u_coords, v_coords])
    coords2d = np.column_stack([u_coords, v_coords])
    coords2d = np.column_stack([u_coords, v_coords])
    coords2d = np.column_stack([u_coords, v_coords])
    coords2d = np.column_stack([u_coords, v_coords])
    coords2d = np.column_stack([u_coords, v_coords])
    coords2d = np.column_stack([u_coords, v_coords])
    coords2d = np.column_stack([u_coords, v_coords])
    coords2d = np.column_stack([u_coords, v_coords])
    coords2d = np.column_stack([u_coords, v_coords])
    coords2d = np.column_stack([u_coords, v_coords])
    coords2d = np.column_stack([u_coords, v_coords])
    coords2d = np.column_stack([u_coords, v_coords])
    projected_world = origin_world + np.outer(u_coords, u_vec) + np.outer(v_coords, v_vec)
    projected_world = origin_world + np.outer(u_coords, u_vec) + np.outer(v_coords, v_vec)
    projected_world = origin_world + np.outer(u_coords, u_vec) + np.outer(v_coords, v_vec)
    projected_world = origin_world + np.outer(u_coords, u_vec) + np.outer(v_coords, v_vec)
    projected_world = origin_world + np.outer(u_coords, u_vec) + np.outer(v_coords, v_vec)
    projected_world = origin_world + np.outer(u_coords, u_vec) + np.outer(v_coords, v_vec)
    projected_world = origin_world + np.outer(u_coords, u_vec) + np.outer(v_coords, v_vec)
    projected_world = origin_world + np.outer(u_coords, u_vec) + np.outer(v_coords, v_vec)
    projected_world = origin_world + np.outer(u_coords, u_vec) + np.outer(v_coords, v_vec)
    projected_world = origin_world + np.outer(u_coords, u_vec) + np.outer(v_coords, v_vec)
    projected_world = origin_world + np.outer(u_coords, u_vec) + np.outer(v_coords, v_vec)
    projected_world = origin_world + np.outer(u_coords, u_vec) + np.outer(v_coords, v_vec)
    projected_world = origin_world + np.outer(u_coords, u_vec) + np.outer(v_coords, v_vec)
    projected_world = origin_world + np.outer(u_coords, u_vec) + np.outer(v_coords, v_vec)
    projected_world = origin_world + np.outer(u_coords, u_vec) + np.outer(v_coords, v_vec)
    projected_world = origin_world + np.outer(u_coords, u_vec) + np.outer(v_coords, v_vec)
    projected_world = origin_world + np.outer(u_coords, u_vec) + np.outer(v_coords, v_vec)
    projected_world = origin_world + np.outer(u_coords, u_vec) + np.outer(v_coords, v_vec)
    projected_world = origin_world + np.outer(u_coords, u_vec) + np.outer(v_coords, v_vec)
    projected_world = origin_world + np.outer(u_coords, u_vec) + np.outer(v_coords, v_vec)
    projected_world = origin_world + np.outer(u_coords, u_vec) + np.outer(v_coords, v_vec)
    projected_world = origin_world + np.outer(u_coords, u_vec) + np.outer(v_coords, v_vec)
    projected_world = origin_world + np.outer(u_coords, u_vec) + np.outer(v_coords, v_vec)
    projected_world = origin_world + np.outer(u_coords, u_vec) + np.outer(v_coords, v_vec)
    projected_world = origin_world + np.outer(u_coords, u_vec) + np.outer(v_coords, v_vec)
    projected_world = origin_world + np.outer(u_coords, u_vec) + np.outer(v_coords, v_vec)
    projected_world = origin_world + np.outer(u_coords, u_vec) + np.outer(v_coords, v_vec)
    projected_world = origin_world + np.outer(u_coords, u_vec) + np.outer(v_coords, v_vec)
    projected_world = origin_world + np.outer(u_coords, u_vec) + np.outer(v_coords, v_vec)
    projected_world = origin_world + np.outer(u_coords, u_vec) + np.outer(v_coords, v_vec)
    projected_world = origin_world + np.outer(u_coords, u_vec) + np.outer(v_coords, v_vec)
    projected_world = origin_world + np.outer(u_coords, u_vec) + np.outer(v_coords, v_vec)
    projected_world = origin_world + np.outer(u_coords, u_vec) + np.outer(v_coords, v_vec)
    projected_world = origin_world + np.outer(u_coords, u_vec) + np.outer(v_coords, v_vec)
    projected_world = origin_world + np.outer(u_coords, u_vec) + np.outer(v_coords, v_vec)
    projected_world = origin_world + np.outer(u_coords, u_vec) + np.outer(v_coords, v_vec)
    projected_world = origin_world + np.outer(u_coords, u_vec) + np.outer(v_coords, v_vec)
    return projected_world, coords2d, origin_world, u_vec, v_vec
    return projected_world, coords2d, origin_world, u_vec, v_vec
    return projected_world, coords2d, origin_world, u_vec, v_vec
    return projected_world, coords2d, origin_world, u_vec, v_vec
    return projected_world, coords2d, origin_world, u_vec, v_vec
    return projected_world, coords2d, origin_world, u_vec, v_vec
    return projected_world, coords2d, origin_world, u_vec, v_vec
    return projected_world, coords2d, origin_world, u_vec, v_vec
    return projected_world, coords2d, origin_world, u_vec, v_vec
    return projected_world, coords2d, origin_world, u_vec, v_vec
    return projected_world, coords2d, origin_world, u_vec, v_vec
    return projected_world, coords2d, origin_world, u_vec, v_vec
    return projected_world, coords2d, origin_world, u_vec, v_vec
    return projected_world, coords2d, origin_world, u_vec, v_vec
    return projected_world, coords2d, origin_world, u_vec, v_vec
    return projected_world, coords2d, origin_world, u_vec, v_vec
    return projected_world, coords2d, origin_world, u_vec, v_vec
    return projected_world, coords2d, origin_world, u_vec, v_vec
    return projected_world, coords2d, origin_world, u_vec, v_vec
    return projected_world, coords2d, origin_world, u_vec, v_vec
    return projected_world, coords2d, origin_world, u_vec, v_vec
    return projected_world, coords2d, origin_world, u_vec, v_vec
    return projected_world, coords2d, origin_world, u_vec, v_vec
    return projected_world, coords2d, origin_world, u_vec, v_vec
    return projected_world, coords2d, origin_world, u_vec, v_vec
    return projected_world, coords2d, origin_world, u_vec, v_vec
    return projected_world, coords2d, origin_world, u_vec, v_vec
    return projected_world, coords2d, origin_world, u_vec, v_vec
    return projected_world, coords2d, origin_world, u_vec, v_vec
    return projected_world, coords2d, origin_world, u_vec, v_vec
    return projected_world, coords2d, origin_world, u_vec, v_vec
    return projected_world, coords2d, origin_world, u_vec, v_vec
    return projected_world, coords2d, origin_world, u_vec, v_vec
    return projected_world, coords2d, origin_world, u_vec, v_vec
    return projected_world, coords2d, origin_world, u_vec, v_vec
    return projected_world, coords2d, origin_world, u_vec, v_vec
    return projected_world, coords2d, origin_world, u_vec, v_vec





































def compute_band_width(coords2d):
def compute_band_width(coords2d):
def compute_band_width(coords2d):
def compute_band_width(coords2d):
def compute_band_width(coords2d):
def compute_band_width(coords2d):
def compute_band_width(coords2d):
def compute_band_width(coords2d):
def compute_band_width(coords2d):
def compute_band_width(coords2d):
def compute_band_width(coords2d):
def compute_band_width(coords2d):
def compute_band_width(coords2d):
def compute_band_width(coords2d):
def compute_band_width(coords2d):
def compute_band_width(coords2d):
def compute_band_width(coords2d):
def compute_band_width(coords2d):
def compute_band_width(coords2d):
def compute_band_width(coords2d):
def compute_band_width(coords2d):
def compute_band_width(coords2d):
def compute_band_width(coords2d):
def compute_band_width(coords2d):
def compute_band_width(coords2d):
def compute_band_width(coords2d):
def compute_band_width(coords2d):
def compute_band_width(coords2d):
def compute_band_width(coords2d):
def compute_band_width(coords2d):
def compute_band_width(coords2d):
def compute_band_width(coords2d):
def compute_band_width(coords2d):
def compute_band_width(coords2d):
def compute_band_width(coords2d):
def compute_band_width(coords2d):
def compute_band_width(coords2d):
    if len(coords2d) < 3:
    if len(coords2d) < 3:
    if len(coords2d) < 3:
    if len(coords2d) < 3:
    if len(coords2d) < 3:
    if len(coords2d) < 3:
    if len(coords2d) < 3:
    if len(coords2d) < 3:
    if len(coords2d) < 3:
    if len(coords2d) < 3:
    if len(coords2d) < 3:
    if len(coords2d) < 3:
    if len(coords2d) < 3:
    if len(coords2d) < 3:
    if len(coords2d) < 3:
    if len(coords2d) < 3:
    if len(coords2d) < 3:
    if len(coords2d) < 3:
    if len(coords2d) < 3:
    if len(coords2d) < 3:
    if len(coords2d) < 3:
    if len(coords2d) < 3:
    if len(coords2d) < 3:
    if len(coords2d) < 3:
    if len(coords2d) < 3:
    if len(coords2d) < 3:
    if len(coords2d) < 3:
    if len(coords2d) < 3:
    if len(coords2d) < 3:
    if len(coords2d) < 3:
    if len(coords2d) < 3:
    if len(coords2d) < 3:
    if len(coords2d) < 3:
    if len(coords2d) < 3:
    if len(coords2d) < 3:
    if len(coords2d) < 3:
    if len(coords2d) < 3:
        return 0.0
        return 0.0
        return 0.0
        return 0.0
        return 0.0
        return 0.0
        return 0.0
        return 0.0
        return 0.0
        return 0.0
        return 0.0
        return 0.0
        return 0.0
        return 0.0
        return 0.0
        return 0.0
        return 0.0
        return 0.0
        return 0.0
        return 0.0
        return 0.0
        return 0.0
        return 0.0
        return 0.0
        return 0.0
        return 0.0
        return 0.0
        return 0.0
        return 0.0
        return 0.0
        return 0.0
        return 0.0
        return 0.0
        return 0.0
        return 0.0
        return 0.0
        return 0.0
    M = coords2d - coords2d.mean(axis=0)
    M = coords2d - coords2d.mean(axis=0)
    M = coords2d - coords2d.mean(axis=0)
    M = coords2d - coords2d.mean(axis=0)
    M = coords2d - coords2d.mean(axis=0)
    M = coords2d - coords2d.mean(axis=0)
    M = coords2d - coords2d.mean(axis=0)
    M = coords2d - coords2d.mean(axis=0)
    M = coords2d - coords2d.mean(axis=0)
    M = coords2d - coords2d.mean(axis=0)
    M = coords2d - coords2d.mean(axis=0)
    M = coords2d - coords2d.mean(axis=0)
    M = coords2d - coords2d.mean(axis=0)
    M = coords2d - coords2d.mean(axis=0)
    M = coords2d - coords2d.mean(axis=0)
    M = coords2d - coords2d.mean(axis=0)
    M = coords2d - coords2d.mean(axis=0)
    M = coords2d - coords2d.mean(axis=0)
    M = coords2d - coords2d.mean(axis=0)
    M = coords2d - coords2d.mean(axis=0)
    M = coords2d - coords2d.mean(axis=0)
    M = coords2d - coords2d.mean(axis=0)
    M = coords2d - coords2d.mean(axis=0)
    M = coords2d - coords2d.mean(axis=0)
    M = coords2d - coords2d.mean(axis=0)
    M = coords2d - coords2d.mean(axis=0)
    M = coords2d - coords2d.mean(axis=0)
    M = coords2d - coords2d.mean(axis=0)
    M = coords2d - coords2d.mean(axis=0)
    M = coords2d - coords2d.mean(axis=0)
    M = coords2d - coords2d.mean(axis=0)
    M = coords2d - coords2d.mean(axis=0)
    M = coords2d - coords2d.mean(axis=0)
    M = coords2d - coords2d.mean(axis=0)
    M = coords2d - coords2d.mean(axis=0)
    M = coords2d - coords2d.mean(axis=0)
    M = coords2d - coords2d.mean(axis=0)
    try:
    try:
    try:
    try:
    try:
    try:
    try:
    try:
    try:
    try:
    try:
    try:
    try:
    try:
    try:
    try:
    try:
    try:
    try:
    try:
    try:
    try:
    try:
    try:
    try:
    try:
    try:
    try:
    try:
    try:
    try:
    try:
    try:
    try:
    try:
    try:
    try:
        U,S,Vt = svd(M, full_matrices=False)
        U,S,Vt = svd(M, full_matrices=False)
        U,S,Vt = svd(M, full_matrices=False)
        U,S,Vt = svd(M, full_matrices=False)
        U,S,Vt = svd(M, full_matrices=False)
        U,S,Vt = svd(M, full_matrices=False)
        U,S,Vt = svd(M, full_matrices=False)
        U,S,Vt = svd(M, full_matrices=False)
        U,S,Vt = svd(M, full_matrices=False)
        U,S,Vt = svd(M, full_matrices=False)
        U,S,Vt = svd(M, full_matrices=False)
        U,S,Vt = svd(M, full_matrices=False)
        U,S,Vt = svd(M, full_matrices=False)
        U,S,Vt = svd(M, full_matrices=False)
        U,S,Vt = svd(M, full_matrices=False)
        U,S,Vt = svd(M, full_matrices=False)
        U,S,Vt = svd(M, full_matrices=False)
        U,S,Vt = svd(M, full_matrices=False)
        U,S,Vt = svd(M, full_matrices=False)
        U,S,Vt = svd(M, full_matrices=False)
        U,S,Vt = svd(M, full_matrices=False)
        U,S,Vt = svd(M, full_matrices=False)
        U,S,Vt = svd(M, full_matrices=False)
        U,S,Vt = svd(M, full_matrices=False)
        U,S,Vt = svd(M, full_matrices=False)
        U,S,Vt = svd(M, full_matrices=False)
        U,S,Vt = svd(M, full_matrices=False)
        U,S,Vt = svd(M, full_matrices=False)
        U,S,Vt = svd(M, full_matrices=False)
        U,S,Vt = svd(M, full_matrices=False)
        U,S,Vt = svd(M, full_matrices=False)
        U,S,Vt = svd(M, full_matrices=False)
        U,S,Vt = svd(M, full_matrices=False)
        U,S,Vt = svd(M, full_matrices=False)
        U,S,Vt = svd(M, full_matrices=False)
        U,S,Vt = svd(M, full_matrices=False)
        U,S,Vt = svd(M, full_matrices=False)
        # Second axis (bandwidth width direction)
        # Second axis (bandwidth width direction)
        # Second axis (bandwidth width direction)
        # Second axis (bandwidth width direction)
        # Second axis (bandwidth width direction)
        # Second axis (bandwidth width direction)
        # Second axis (bandwidth width direction)
        # Second axis (bandwidth width direction)
        # Second axis (bandwidth width direction)
        # Second axis (bandwidth width direction)
        # Second axis (bandwidth width direction)
        # Second axis (bandwidth width direction)
        # Second axis (bandwidth width direction)
        # Second axis (bandwidth width direction)
        # Second axis (bandwidth width direction)
        # Second axis (bandwidth width direction)
        # Second axis (bandwidth width direction)
        # Second axis (bandwidth width direction)
        # Second axis (bandwidth width direction)
        # Second axis (bandwidth width direction)
        # Second axis (bandwidth width direction)
        # Second axis (bandwidth width direction)
        # Second axis (bandwidth width direction)
        # Second axis (bandwidth width direction)
        # Second axis (bandwidth width direction)
        # Second axis (bandwidth width direction)
        # Second axis (bandwidth width direction)
        # Second axis (bandwidth width direction)
        # Second axis (bandwidth width direction)
        # Second axis (bandwidth width direction)
        # Second axis (bandwidth width direction)
        # Second axis (bandwidth width direction)
        # Second axis (bandwidth width direction)
        # Second axis (bandwidth width direction)
        # Second axis (bandwidth width direction)
        # Second axis (bandwidth width direction)
        # Second axis (bandwidth width direction)
        proj2 = M.dot(Vt.T[:,1])
        proj2 = M.dot(Vt.T[:,1])
        proj2 = M.dot(Vt.T[:,1])
        proj2 = M.dot(Vt.T[:,1])
        proj2 = M.dot(Vt.T[:,1])
        proj2 = M.dot(Vt.T[:,1])
        proj2 = M.dot(Vt.T[:,1])
        proj2 = M.dot(Vt.T[:,1])
        proj2 = M.dot(Vt.T[:,1])
        proj2 = M.dot(Vt.T[:,1])
        proj2 = M.dot(Vt.T[:,1])
        proj2 = M.dot(Vt.T[:,1])
        proj2 = M.dot(Vt.T[:,1])
        proj2 = M.dot(Vt.T[:,1])
        proj2 = M.dot(Vt.T[:,1])
        proj2 = M.dot(Vt.T[:,1])
        proj2 = M.dot(Vt.T[:,1])
        proj2 = M.dot(Vt.T[:,1])
        proj2 = M.dot(Vt.T[:,1])
        proj2 = M.dot(Vt.T[:,1])
        proj2 = M.dot(Vt.T[:,1])
        proj2 = M.dot(Vt.T[:,1])
        proj2 = M.dot(Vt.T[:,1])
        proj2 = M.dot(Vt.T[:,1])
        proj2 = M.dot(Vt.T[:,1])
        proj2 = M.dot(Vt.T[:,1])
        proj2 = M.dot(Vt.T[:,1])
        proj2 = M.dot(Vt.T[:,1])
        proj2 = M.dot(Vt.T[:,1])
        proj2 = M.dot(Vt.T[:,1])
        proj2 = M.dot(Vt.T[:,1])
        proj2 = M.dot(Vt.T[:,1])
        proj2 = M.dot(Vt.T[:,1])
        proj2 = M.dot(Vt.T[:,1])
        proj2 = M.dot(Vt.T[:,1])
        proj2 = M.dot(Vt.T[:,1])
        proj2 = M.dot(Vt.T[:,1])
        width = proj2.max() - proj2.min()
        width = proj2.max() - proj2.min()
        width = proj2.max() - proj2.min()
        width = proj2.max() - proj2.min()
        width = proj2.max() - proj2.min()
        width = proj2.max() - proj2.min()
        width = proj2.max() - proj2.min()
        width = proj2.max() - proj2.min()
        width = proj2.max() - proj2.min()
        width = proj2.max() - proj2.min()
        width = proj2.max() - proj2.min()
        width = proj2.max() - proj2.min()
        width = proj2.max() - proj2.min()
        width = proj2.max() - proj2.min()
        width = proj2.max() - proj2.min()
        width = proj2.max() - proj2.min()
        width = proj2.max() - proj2.min()
        width = proj2.max() - proj2.min()
        width = proj2.max() - proj2.min()
        width = proj2.max() - proj2.min()
        width = proj2.max() - proj2.min()
        width = proj2.max() - proj2.min()
        width = proj2.max() - proj2.min()
        width = proj2.max() - proj2.min()
        width = proj2.max() - proj2.min()
        width = proj2.max() - proj2.min()
        width = proj2.max() - proj2.min()
        width = proj2.max() - proj2.min()
        width = proj2.max() - proj2.min()
        width = proj2.max() - proj2.min()
        width = proj2.max() - proj2.min()
        width = proj2.max() - proj2.min()
        width = proj2.max() - proj2.min()
        width = proj2.max() - proj2.min()
        width = proj2.max() - proj2.min()
        width = proj2.max() - proj2.min()
        width = proj2.max() - proj2.min()
        return float(width)
        return float(width)
        return float(width)
        return float(width)
        return float(width)
        return float(width)
        return float(width)
        return float(width)
        return float(width)
        return float(width)
        return float(width)
        return float(width)
        return float(width)
        return float(width)
        return float(width)
        return float(width)
        return float(width)
        return float(width)
        return float(width)
        return float(width)
        return float(width)
        return float(width)
        return float(width)
        return float(width)
        return float(width)
        return float(width)
        return float(width)
        return float(width)
        return float(width)
        return float(width)
        return float(width)
        return float(width)
        return float(width)
        return float(width)
        return float(width)
        return float(width)
        return float(width)
    except Exception:
    except Exception:
    except Exception:
    except Exception:
    except Exception:
    except Exception:
    except Exception:
    except Exception:
    except Exception:
    except Exception:
    except Exception:
    except Exception:
    except Exception:
    except Exception:
    except Exception:
    except Exception:
    except Exception:
    except Exception:
    except Exception:
    except Exception:
    except Exception:
    except Exception:
    except Exception:
    except Exception:
    except Exception:
    except Exception:
    except Exception:
    except Exception:
    except Exception:
    except Exception:
    except Exception:
    except Exception:
    except Exception:
    except Exception:
    except Exception:
    except Exception:
    except Exception:
        return float(np.max(coords2d[:,1]) - np.min(coords2d[:,1]))
        return float(np.max(coords2d[:,1]) - np.min(coords2d[:,1]))
        return float(np.max(coords2d[:,1]) - np.min(coords2d[:,1]))
        return float(np.max(coords2d[:,1]) - np.min(coords2d[:,1]))
        return float(np.max(coords2d[:,1]) - np.min(coords2d[:,1]))
        return float(np.max(coords2d[:,1]) - np.min(coords2d[:,1]))
        return float(np.max(coords2d[:,1]) - np.min(coords2d[:,1]))
        return float(np.max(coords2d[:,1]) - np.min(coords2d[:,1]))
        return float(np.max(coords2d[:,1]) - np.min(coords2d[:,1]))
        return float(np.max(coords2d[:,1]) - np.min(coords2d[:,1]))
        return float(np.max(coords2d[:,1]) - np.min(coords2d[:,1]))
        return float(np.max(coords2d[:,1]) - np.min(coords2d[:,1]))
        return float(np.max(coords2d[:,1]) - np.min(coords2d[:,1]))
        return float(np.max(coords2d[:,1]) - np.min(coords2d[:,1]))
        return float(np.max(coords2d[:,1]) - np.min(coords2d[:,1]))
        return float(np.max(coords2d[:,1]) - np.min(coords2d[:,1]))
        return float(np.max(coords2d[:,1]) - np.min(coords2d[:,1]))
        return float(np.max(coords2d[:,1]) - np.min(coords2d[:,1]))
        return float(np.max(coords2d[:,1]) - np.min(coords2d[:,1]))
        return float(np.max(coords2d[:,1]) - np.min(coords2d[:,1]))
        return float(np.max(coords2d[:,1]) - np.min(coords2d[:,1]))
        return float(np.max(coords2d[:,1]) - np.min(coords2d[:,1]))
        return float(np.max(coords2d[:,1]) - np.min(coords2d[:,1]))
        return float(np.max(coords2d[:,1]) - np.min(coords2d[:,1]))
        return float(np.max(coords2d[:,1]) - np.min(coords2d[:,1]))
        return float(np.max(coords2d[:,1]) - np.min(coords2d[:,1]))
        return float(np.max(coords2d[:,1]) - np.min(coords2d[:,1]))
        return float(np.max(coords2d[:,1]) - np.min(coords2d[:,1]))
        return float(np.max(coords2d[:,1]) - np.min(coords2d[:,1]))
        return float(np.max(coords2d[:,1]) - np.min(coords2d[:,1]))
        return float(np.max(coords2d[:,1]) - np.min(coords2d[:,1]))
        return float(np.max(coords2d[:,1]) - np.min(coords2d[:,1]))
        return float(np.max(coords2d[:,1]) - np.min(coords2d[:,1]))
        return float(np.max(coords2d[:,1]) - np.min(coords2d[:,1]))
        return float(np.max(coords2d[:,1]) - np.min(coords2d[:,1]))
        return float(np.max(coords2d[:,1]) - np.min(coords2d[:,1]))
        return float(np.max(coords2d[:,1]) - np.min(coords2d[:,1]))

# %% [markdown]
# ## ---------- Point ordering and B-spline fitting ----------
# ## ---------- Point ordering and B-spline fitting ----------
# ## ---------- Point ordering and B-spline fitting ----------
# ## ---------- Point ordering and B-spline fitting ----------
# ## ---------- Point ordering and B-spline fitting ----------
# ## ---------- Point ordering and B-spline fitting ----------
# ## ---------- Point ordering and B-spline fitting ----------
# ## ---------- Point ordering and B-spline fitting ----------
# ## ---------- Point ordering and B-spline fitting ----------
# ## ---------- Point ordering and B-spline fitting ----------
# ## ---------- Point ordering and B-spline fitting ----------
# ## ---------- Point ordering and B-spline fitting ----------
# ## ---------- Point ordering and B-spline fitting ----------
# ## ---------- Point ordering and B-spline fitting ----------
# ## ---------- Point ordering and B-spline fitting ----------
# ## ---------- Point ordering and B-spline fitting ----------
# ## ---------- Point ordering and B-spline fitting ----------
# ## ---------- Point ordering and B-spline fitting ----------
# ## ---------- Point ordering and B-spline fitting ----------
# ## ---------- Point ordering and B-spline fitting ----------
# ## ---------- Point ordering and B-spline fitting ----------
# ## ---------- Point ordering and B-spline fitting ----------
# ## ---------- Point ordering and B-spline fitting ----------
# ## ---------- Point ordering and B-spline fitting ----------
# ## ---------- Point ordering and B-spline fitting ----------
# ## ---------- Point ordering and B-spline fitting ----------
# ## ---------- Point ordering and B-spline fitting ----------
# ## ---------- Point ordering and B-spline fitting ----------
# ## ---------- Point ordering and B-spline fitting ----------
# ## ---------- Point ordering and B-spline fitting ----------
# ## ---------- Point ordering and B-spline fitting ----------
# ## ---------- Point ordering and B-spline fitting ----------
# ## ---------- Point ordering and B-spline fitting ----------
# ## ---------- Point ordering and B-spline fitting ----------
# ## ---------- Point ordering and B-spline fitting ----------
# ## ---------- Point ordering and B-spline fitting ----------
# ## ---------- Point ordering and B-spline fitting ----------

# %%
def order_points_along_axis(coords2d):
def order_points_along_axis(coords2d):
def order_points_along_axis(coords2d):
def order_points_along_axis(coords2d):
def order_points_along_axis(coords2d):
def order_points_along_axis(coords2d):
def order_points_along_axis(coords2d):
def order_points_along_axis(coords2d):
def order_points_along_axis(coords2d):
def order_points_along_axis(coords2d):
def order_points_along_axis(coords2d):
def order_points_along_axis(coords2d):
def order_points_along_axis(coords2d):
def order_points_along_axis(coords2d):
def order_points_along_axis(coords2d):
def order_points_along_axis(coords2d):
def order_points_along_axis(coords2d):
def order_points_along_axis(coords2d):
def order_points_along_axis(coords2d):
def order_points_along_axis(coords2d):
def order_points_along_axis(coords2d):
def order_points_along_axis(coords2d):
def order_points_along_axis(coords2d):
def order_points_along_axis(coords2d):
def order_points_along_axis(coords2d):
def order_points_along_axis(coords2d):
def order_points_along_axis(coords2d):
def order_points_along_axis(coords2d):
def order_points_along_axis(coords2d):
def order_points_along_axis(coords2d):
def order_points_along_axis(coords2d):
def order_points_along_axis(coords2d):
def order_points_along_axis(coords2d):
def order_points_along_axis(coords2d):
def order_points_along_axis(coords2d):
def order_points_along_axis(coords2d):
def order_points_along_axis(coords2d):
    M = coords2d - coords2d.mean(axis=0)
    M = coords2d - coords2d.mean(axis=0)
    M = coords2d - coords2d.mean(axis=0)
    M = coords2d - coords2d.mean(axis=0)
    M = coords2d - coords2d.mean(axis=0)
    M = coords2d - coords2d.mean(axis=0)
    M = coords2d - coords2d.mean(axis=0)
    M = coords2d - coords2d.mean(axis=0)
    M = coords2d - coords2d.mean(axis=0)
    M = coords2d - coords2d.mean(axis=0)
    M = coords2d - coords2d.mean(axis=0)
    M = coords2d - coords2d.mean(axis=0)
    M = coords2d - coords2d.mean(axis=0)
    M = coords2d - coords2d.mean(axis=0)
    M = coords2d - coords2d.mean(axis=0)
    M = coords2d - coords2d.mean(axis=0)
    M = coords2d - coords2d.mean(axis=0)
    M = coords2d - coords2d.mean(axis=0)
    M = coords2d - coords2d.mean(axis=0)
    M = coords2d - coords2d.mean(axis=0)
    M = coords2d - coords2d.mean(axis=0)
    M = coords2d - coords2d.mean(axis=0)
    M = coords2d - coords2d.mean(axis=0)
    M = coords2d - coords2d.mean(axis=0)
    M = coords2d - coords2d.mean(axis=0)
    M = coords2d - coords2d.mean(axis=0)
    M = coords2d - coords2d.mean(axis=0)
    M = coords2d - coords2d.mean(axis=0)
    M = coords2d - coords2d.mean(axis=0)
    M = coords2d - coords2d.mean(axis=0)
    M = coords2d - coords2d.mean(axis=0)
    M = coords2d - coords2d.mean(axis=0)
    M = coords2d - coords2d.mean(axis=0)
    M = coords2d - coords2d.mean(axis=0)
    M = coords2d - coords2d.mean(axis=0)
    M = coords2d - coords2d.mean(axis=0)
    M = coords2d - coords2d.mean(axis=0)
    U,S,Vt = svd(M, full_matrices=False)
    U,S,Vt = svd(M, full_matrices=False)
    U,S,Vt = svd(M, full_matrices=False)
    U,S,Vt = svd(M, full_matrices=False)
    U,S,Vt = svd(M, full_matrices=False)
    U,S,Vt = svd(M, full_matrices=False)
    U,S,Vt = svd(M, full_matrices=False)
    U,S,Vt = svd(M, full_matrices=False)
    U,S,Vt = svd(M, full_matrices=False)
    U,S,Vt = svd(M, full_matrices=False)
    U,S,Vt = svd(M, full_matrices=False)
    U,S,Vt = svd(M, full_matrices=False)
    U,S,Vt = svd(M, full_matrices=False)
    U,S,Vt = svd(M, full_matrices=False)
    U,S,Vt = svd(M, full_matrices=False)
    U,S,Vt = svd(M, full_matrices=False)
    U,S,Vt = svd(M, full_matrices=False)
    U,S,Vt = svd(M, full_matrices=False)
    U,S,Vt = svd(M, full_matrices=False)
    U,S,Vt = svd(M, full_matrices=False)
    U,S,Vt = svd(M, full_matrices=False)
    U,S,Vt = svd(M, full_matrices=False)
    U,S,Vt = svd(M, full_matrices=False)
    U,S,Vt = svd(M, full_matrices=False)
    U,S,Vt = svd(M, full_matrices=False)
    U,S,Vt = svd(M, full_matrices=False)
    U,S,Vt = svd(M, full_matrices=False)
    U,S,Vt = svd(M, full_matrices=False)
    U,S,Vt = svd(M, full_matrices=False)
    U,S,Vt = svd(M, full_matrices=False)
    U,S,Vt = svd(M, full_matrices=False)
    U,S,Vt = svd(M, full_matrices=False)
    U,S,Vt = svd(M, full_matrices=False)
    U,S,Vt = svd(M, full_matrices=False)
    U,S,Vt = svd(M, full_matrices=False)
    U,S,Vt = svd(M, full_matrices=False)
    U,S,Vt = svd(M, full_matrices=False)
    t = M.dot(Vt.T[:,0])
    t = M.dot(Vt.T[:,0])
    t = M.dot(Vt.T[:,0])
    t = M.dot(Vt.T[:,0])
    t = M.dot(Vt.T[:,0])
    t = M.dot(Vt.T[:,0])
    t = M.dot(Vt.T[:,0])
    t = M.dot(Vt.T[:,0])
    t = M.dot(Vt.T[:,0])
    t = M.dot(Vt.T[:,0])
    t = M.dot(Vt.T[:,0])
    t = M.dot(Vt.T[:,0])
    t = M.dot(Vt.T[:,0])
    t = M.dot(Vt.T[:,0])
    t = M.dot(Vt.T[:,0])
    t = M.dot(Vt.T[:,0])
    t = M.dot(Vt.T[:,0])
    t = M.dot(Vt.T[:,0])
    t = M.dot(Vt.T[:,0])
    t = M.dot(Vt.T[:,0])
    t = M.dot(Vt.T[:,0])
    t = M.dot(Vt.T[:,0])
    t = M.dot(Vt.T[:,0])
    t = M.dot(Vt.T[:,0])
    t = M.dot(Vt.T[:,0])
    t = M.dot(Vt.T[:,0])
    t = M.dot(Vt.T[:,0])
    t = M.dot(Vt.T[:,0])
    t = M.dot(Vt.T[:,0])
    t = M.dot(Vt.T[:,0])
    t = M.dot(Vt.T[:,0])
    t = M.dot(Vt.T[:,0])
    t = M.dot(Vt.T[:,0])
    t = M.dot(Vt.T[:,0])
    t = M.dot(Vt.T[:,0])
    t = M.dot(Vt.T[:,0])
    t = M.dot(Vt.T[:,0])
    order = np.argsort(t)
    order = np.argsort(t)
    order = np.argsort(t)
    order = np.argsort(t)
    order = np.argsort(t)
    order = np.argsort(t)
    order = np.argsort(t)
    order = np.argsort(t)
    order = np.argsort(t)
    order = np.argsort(t)
    order = np.argsort(t)
    order = np.argsort(t)
    order = np.argsort(t)
    order = np.argsort(t)
    order = np.argsort(t)
    order = np.argsort(t)
    order = np.argsort(t)
    order = np.argsort(t)
    order = np.argsort(t)
    order = np.argsort(t)
    order = np.argsort(t)
    order = np.argsort(t)
    order = np.argsort(t)
    order = np.argsort(t)
    order = np.argsort(t)
    order = np.argsort(t)
    order = np.argsort(t)
    order = np.argsort(t)
    order = np.argsort(t)
    order = np.argsort(t)
    order = np.argsort(t)
    order = np.argsort(t)
    order = np.argsort(t)
    order = np.argsort(t)
    order = np.argsort(t)
    order = np.argsort(t)
    order = np.argsort(t)
    return order, t
    return order, t
    return order, t
    return order, t
    return order, t
    return order, t
    return order, t
    return order, t
    return order, t
    return order, t
    return order, t
    return order, t
    return order, t
    return order, t
    return order, t
    return order, t
    return order, t
    return order, t
    return order, t
    return order, t
    return order, t
    return order, t
    return order, t
    return order, t
    return order, t
    return order, t
    return order, t
    return order, t
    return order, t
    return order, t
    return order, t
    return order, t
    return order, t
    return order, t
    return order, t
    return order, t
    return order, t





































def fit_bspline_2d(pts2d, s=0.0, k=3):
def fit_bspline_2d(pts2d, s=0.0, k=3):
def fit_bspline_2d(pts2d, s=0.0, k=3):
def fit_bspline_2d(pts2d, s=0.0, k=3):
def fit_bspline_2d(pts2d, s=0.0, k=3):
def fit_bspline_2d(pts2d, s=0.0, k=3):
def fit_bspline_2d(pts2d, s=0.0, k=3):
def fit_bspline_2d(pts2d, s=0.0, k=3):
def fit_bspline_2d(pts2d, s=0.0, k=3):
def fit_bspline_2d(pts2d, s=0.0, k=3):
def fit_bspline_2d(pts2d, s=0.0, k=3):
def fit_bspline_2d(pts2d, s=0.0, k=3):
def fit_bspline_2d(pts2d, s=0.0, k=3):
def fit_bspline_2d(pts2d, s=0.0, k=3):
def fit_bspline_2d(pts2d, s=0.0, k=3):
def fit_bspline_2d(pts2d, s=0.0, k=3):
def fit_bspline_2d(pts2d, s=0.0, k=3):
def fit_bspline_2d(pts2d, s=0.0, k=3):
def fit_bspline_2d(pts2d, s=0.0, k=3):
def fit_bspline_2d(pts2d, s=0.0, k=3):
def fit_bspline_2d(pts2d, s=0.0, k=3):
def fit_bspline_2d(pts2d, s=0.0, k=3):
def fit_bspline_2d(pts2d, s=0.0, k=3):
def fit_bspline_2d(pts2d, s=0.0, k=3):
def fit_bspline_2d(pts2d, s=0.0, k=3):
def fit_bspline_2d(pts2d, s=0.0, k=3):
def fit_bspline_2d(pts2d, s=0.0, k=3):
def fit_bspline_2d(pts2d, s=0.0, k=3):
def fit_bspline_2d(pts2d, s=0.0, k=3):
def fit_bspline_2d(pts2d, s=0.0, k=3):
def fit_bspline_2d(pts2d, s=0.0, k=3):
def fit_bspline_2d(pts2d, s=0.0, k=3):
def fit_bspline_2d(pts2d, s=0.0, k=3):
def fit_bspline_2d(pts2d, s=0.0, k=3):
def fit_bspline_2d(pts2d, s=0.0, k=3):
def fit_bspline_2d(pts2d, s=0.0, k=3):
def fit_bspline_2d(pts2d, s=0.0, k=3):
    if pts2d.shape[0] < (k+1):
    if pts2d.shape[0] < (k+1):
    if pts2d.shape[0] < (k+1):
    if pts2d.shape[0] < (k+1):
    if pts2d.shape[0] < (k+1):
    if pts2d.shape[0] < (k+1):
    if pts2d.shape[0] < (k+1):
    if pts2d.shape[0] < (k+1):
    if pts2d.shape[0] < (k+1):
    if pts2d.shape[0] < (k+1):
    if pts2d.shape[0] < (k+1):
    if pts2d.shape[0] < (k+1):
    if pts2d.shape[0] < (k+1):
    if pts2d.shape[0] < (k+1):
    if pts2d.shape[0] < (k+1):
    if pts2d.shape[0] < (k+1):
    if pts2d.shape[0] < (k+1):
    if pts2d.shape[0] < (k+1):
    if pts2d.shape[0] < (k+1):
    if pts2d.shape[0] < (k+1):
    if pts2d.shape[0] < (k+1):
    if pts2d.shape[0] < (k+1):
    if pts2d.shape[0] < (k+1):
    if pts2d.shape[0] < (k+1):
    if pts2d.shape[0] < (k+1):
    if pts2d.shape[0] < (k+1):
    if pts2d.shape[0] < (k+1):
    if pts2d.shape[0] < (k+1):
    if pts2d.shape[0] < (k+1):
    if pts2d.shape[0] < (k+1):
    if pts2d.shape[0] < (k+1):
    if pts2d.shape[0] < (k+1):
    if pts2d.shape[0] < (k+1):
    if pts2d.shape[0] < (k+1):
    if pts2d.shape[0] < (k+1):
    if pts2d.shape[0] < (k+1):
    if pts2d.shape[0] < (k+1):
        return None
        return None
        return None
        return None
        return None
        return None
        return None
        return None
        return None
        return None
        return None
        return None
        return None
        return None
        return None
        return None
        return None
        return None
        return None
        return None
        return None
        return None
        return None
        return None
        return None
        return None
        return None
        return None
        return None
        return None
        return None
        return None
        return None
        return None
        return None
        return None
        return None
    try:
    try:
    try:
    try:
    try:
    try:
    try:
    try:
    try:
    try:
    try:
    try:
    try:
    try:
    try:
    try:
    try:
    try:
    try:
    try:
    try:
    try:
    try:
    try:
    try:
    try:
    try:
    try:
    try:
    try:
    try:
    try:
    try:
    try:
    try:
    try:
    try:
        tck, u = splprep([pts2d[:,0], pts2d[:,1]], s=s, k=min(k, pts2d.shape[0]-1))
        tck, u = splprep([pts2d[:,0], pts2d[:,1]], s=s, k=min(k, pts2d.shape[0]-1))
        tck, u = splprep([pts2d[:,0], pts2d[:,1]], s=s, k=min(k, pts2d.shape[0]-1))
        tck, u = splprep([pts2d[:,0], pts2d[:,1]], s=s, k=min(k, pts2d.shape[0]-1))
        tck, u = splprep([pts2d[:,0], pts2d[:,1]], s=s, k=min(k, pts2d.shape[0]-1))
        tck, u = splprep([pts2d[:,0], pts2d[:,1]], s=s, k=min(k, pts2d.shape[0]-1))
        tck, u = splprep([pts2d[:,0], pts2d[:,1]], s=s, k=min(k, pts2d.shape[0]-1))
        tck, u = splprep([pts2d[:,0], pts2d[:,1]], s=s, k=min(k, pts2d.shape[0]-1))
        tck, u = splprep([pts2d[:,0], pts2d[:,1]], s=s, k=min(k, pts2d.shape[0]-1))
        tck, u = splprep([pts2d[:,0], pts2d[:,1]], s=s, k=min(k, pts2d.shape[0]-1))
        tck, u = splprep([pts2d[:,0], pts2d[:,1]], s=s, k=min(k, pts2d.shape[0]-1))
        tck, u = splprep([pts2d[:,0], pts2d[:,1]], s=s, k=min(k, pts2d.shape[0]-1))
        tck, u = splprep([pts2d[:,0], pts2d[:,1]], s=s, k=min(k, pts2d.shape[0]-1))
        tck, u = splprep([pts2d[:,0], pts2d[:,1]], s=s, k=min(k, pts2d.shape[0]-1))
        tck, u = splprep([pts2d[:,0], pts2d[:,1]], s=s, k=min(k, pts2d.shape[0]-1))
        tck, u = splprep([pts2d[:,0], pts2d[:,1]], s=s, k=min(k, pts2d.shape[0]-1))
        tck, u = splprep([pts2d[:,0], pts2d[:,1]], s=s, k=min(k, pts2d.shape[0]-1))
        tck, u = splprep([pts2d[:,0], pts2d[:,1]], s=s, k=min(k, pts2d.shape[0]-1))
        tck, u = splprep([pts2d[:,0], pts2d[:,1]], s=s, k=min(k, pts2d.shape[0]-1))
        tck, u = splprep([pts2d[:,0], pts2d[:,1]], s=s, k=min(k, pts2d.shape[0]-1))
        tck, u = splprep([pts2d[:,0], pts2d[:,1]], s=s, k=min(k, pts2d.shape[0]-1))
        tck, u = splprep([pts2d[:,0], pts2d[:,1]], s=s, k=min(k, pts2d.shape[0]-1))
        tck, u = splprep([pts2d[:,0], pts2d[:,1]], s=s, k=min(k, pts2d.shape[0]-1))
        tck, u = splprep([pts2d[:,0], pts2d[:,1]], s=s, k=min(k, pts2d.shape[0]-1))
        tck, u = splprep([pts2d[:,0], pts2d[:,1]], s=s, k=min(k, pts2d.shape[0]-1))
        tck, u = splprep([pts2d[:,0], pts2d[:,1]], s=s, k=min(k, pts2d.shape[0]-1))
        tck, u = splprep([pts2d[:,0], pts2d[:,1]], s=s, k=min(k, pts2d.shape[0]-1))
        tck, u = splprep([pts2d[:,0], pts2d[:,1]], s=s, k=min(k, pts2d.shape[0]-1))
        tck, u = splprep([pts2d[:,0], pts2d[:,1]], s=s, k=min(k, pts2d.shape[0]-1))
        tck, u = splprep([pts2d[:,0], pts2d[:,1]], s=s, k=min(k, pts2d.shape[0]-1))
        tck, u = splprep([pts2d[:,0], pts2d[:,1]], s=s, k=min(k, pts2d.shape[0]-1))
        tck, u = splprep([pts2d[:,0], pts2d[:,1]], s=s, k=min(k, pts2d.shape[0]-1))
        tck, u = splprep([pts2d[:,0], pts2d[:,1]], s=s, k=min(k, pts2d.shape[0]-1))
        tck, u = splprep([pts2d[:,0], pts2d[:,1]], s=s, k=min(k, pts2d.shape[0]-1))
        tck, u = splprep([pts2d[:,0], pts2d[:,1]], s=s, k=min(k, pts2d.shape[0]-1))
        tck, u = splprep([pts2d[:,0], pts2d[:,1]], s=s, k=min(k, pts2d.shape[0]-1))
        tck, u = splprep([pts2d[:,0], pts2d[:,1]], s=s, k=min(k, pts2d.shape[0]-1))
        return tck, u
        return tck, u
        return tck, u
        return tck, u
        return tck, u
        return tck, u
        return tck, u
        return tck, u
        return tck, u
        return tck, u
        return tck, u
        return tck, u
        return tck, u
        return tck, u
        return tck, u
        return tck, u
        return tck, u
        return tck, u
        return tck, u
        return tck, u
        return tck, u
        return tck, u
        return tck, u
        return tck, u
        return tck, u
        return tck, u
        return tck, u
        return tck, u
        return tck, u
        return tck, u
        return tck, u
        return tck, u
        return tck, u
        return tck, u
        return tck, u
        return tck, u
        return tck, u
    except Exception:
    except Exception:
    except Exception:
    except Exception:
    except Exception:
    except Exception:
    except Exception:
    except Exception:
    except Exception:
    except Exception:
    except Exception:
    except Exception:
    except Exception:
    except Exception:
    except Exception:
    except Exception:
    except Exception:
    except Exception:
    except Exception:
    except Exception:
    except Exception:
    except Exception:
    except Exception:
    except Exception:
    except Exception:
    except Exception:
    except Exception:
    except Exception:
    except Exception:
    except Exception:
    except Exception:
    except Exception:
    except Exception:
    except Exception:
    except Exception:
    except Exception:
    except Exception:
        try:
        try:
        try:
        try:
        try:
        try:
        try:
        try:
        try:
        try:
        try:
        try:
        try:
        try:
        try:
        try:
        try:
        try:
        try:
        try:
        try:
        try:
        try:
        try:
        try:
        try:
        try:
        try:
        try:
        try:
        try:
        try:
        try:
        try:
        try:
        try:
        try:
            tck, u = splprep([pts2d[:,0], pts2d[:,1]], s=max(1.0,s), k=min(3, pts2d.shape[0]-1))
            tck, u = splprep([pts2d[:,0], pts2d[:,1]], s=max(1.0,s), k=min(3, pts2d.shape[0]-1))
            tck, u = splprep([pts2d[:,0], pts2d[:,1]], s=max(1.0,s), k=min(3, pts2d.shape[0]-1))
            tck, u = splprep([pts2d[:,0], pts2d[:,1]], s=max(1.0,s), k=min(3, pts2d.shape[0]-1))
            tck, u = splprep([pts2d[:,0], pts2d[:,1]], s=max(1.0,s), k=min(3, pts2d.shape[0]-1))
            tck, u = splprep([pts2d[:,0], pts2d[:,1]], s=max(1.0,s), k=min(3, pts2d.shape[0]-1))
            tck, u = splprep([pts2d[:,0], pts2d[:,1]], s=max(1.0,s), k=min(3, pts2d.shape[0]-1))
            tck, u = splprep([pts2d[:,0], pts2d[:,1]], s=max(1.0,s), k=min(3, pts2d.shape[0]-1))
            tck, u = splprep([pts2d[:,0], pts2d[:,1]], s=max(1.0,s), k=min(3, pts2d.shape[0]-1))
            tck, u = splprep([pts2d[:,0], pts2d[:,1]], s=max(1.0,s), k=min(3, pts2d.shape[0]-1))
            tck, u = splprep([pts2d[:,0], pts2d[:,1]], s=max(1.0,s), k=min(3, pts2d.shape[0]-1))
            tck, u = splprep([pts2d[:,0], pts2d[:,1]], s=max(1.0,s), k=min(3, pts2d.shape[0]-1))
            tck, u = splprep([pts2d[:,0], pts2d[:,1]], s=max(1.0,s), k=min(3, pts2d.shape[0]-1))
            tck, u = splprep([pts2d[:,0], pts2d[:,1]], s=max(1.0,s), k=min(3, pts2d.shape[0]-1))
            tck, u = splprep([pts2d[:,0], pts2d[:,1]], s=max(1.0,s), k=min(3, pts2d.shape[0]-1))
            tck, u = splprep([pts2d[:,0], pts2d[:,1]], s=max(1.0,s), k=min(3, pts2d.shape[0]-1))
            tck, u = splprep([pts2d[:,0], pts2d[:,1]], s=max(1.0,s), k=min(3, pts2d.shape[0]-1))
            tck, u = splprep([pts2d[:,0], pts2d[:,1]], s=max(1.0,s), k=min(3, pts2d.shape[0]-1))
            tck, u = splprep([pts2d[:,0], pts2d[:,1]], s=max(1.0,s), k=min(3, pts2d.shape[0]-1))
            tck, u = splprep([pts2d[:,0], pts2d[:,1]], s=max(1.0,s), k=min(3, pts2d.shape[0]-1))
            tck, u = splprep([pts2d[:,0], pts2d[:,1]], s=max(1.0,s), k=min(3, pts2d.shape[0]-1))
            tck, u = splprep([pts2d[:,0], pts2d[:,1]], s=max(1.0,s), k=min(3, pts2d.shape[0]-1))
            tck, u = splprep([pts2d[:,0], pts2d[:,1]], s=max(1.0,s), k=min(3, pts2d.shape[0]-1))
            tck, u = splprep([pts2d[:,0], pts2d[:,1]], s=max(1.0,s), k=min(3, pts2d.shape[0]-1))
            tck, u = splprep([pts2d[:,0], pts2d[:,1]], s=max(1.0,s), k=min(3, pts2d.shape[0]-1))
            tck, u = splprep([pts2d[:,0], pts2d[:,1]], s=max(1.0,s), k=min(3, pts2d.shape[0]-1))
            tck, u = splprep([pts2d[:,0], pts2d[:,1]], s=max(1.0,s), k=min(3, pts2d.shape[0]-1))
            tck, u = splprep([pts2d[:,0], pts2d[:,1]], s=max(1.0,s), k=min(3, pts2d.shape[0]-1))
            tck, u = splprep([pts2d[:,0], pts2d[:,1]], s=max(1.0,s), k=min(3, pts2d.shape[0]-1))
            tck, u = splprep([pts2d[:,0], pts2d[:,1]], s=max(1.0,s), k=min(3, pts2d.shape[0]-1))
            tck, u = splprep([pts2d[:,0], pts2d[:,1]], s=max(1.0,s), k=min(3, pts2d.shape[0]-1))
            tck, u = splprep([pts2d[:,0], pts2d[:,1]], s=max(1.0,s), k=min(3, pts2d.shape[0]-1))
            tck, u = splprep([pts2d[:,0], pts2d[:,1]], s=max(1.0,s), k=min(3, pts2d.shape[0]-1))
            tck, u = splprep([pts2d[:,0], pts2d[:,1]], s=max(1.0,s), k=min(3, pts2d.shape[0]-1))
            tck, u = splprep([pts2d[:,0], pts2d[:,1]], s=max(1.0,s), k=min(3, pts2d.shape[0]-1))
            tck, u = splprep([pts2d[:,0], pts2d[:,1]], s=max(1.0,s), k=min(3, pts2d.shape[0]-1))
            tck, u = splprep([pts2d[:,0], pts2d[:,1]], s=max(1.0,s), k=min(3, pts2d.shape[0]-1))
            return tck, u
            return tck, u
            return tck, u
            return tck, u
            return tck, u
            return tck, u
            return tck, u
            return tck, u
            return tck, u
            return tck, u
            return tck, u
            return tck, u
            return tck, u
            return tck, u
            return tck, u
            return tck, u
            return tck, u
            return tck, u
            return tck, u
            return tck, u
            return tck, u
            return tck, u
            return tck, u
            return tck, u
            return tck, u
            return tck, u
            return tck, u
            return tck, u
            return tck, u
            return tck, u
            return tck, u
            return tck, u
            return tck, u
            return tck, u
            return tck, u
            return tck, u
            return tck, u
        except Exception:
        except Exception:
        except Exception:
        except Exception:
        except Exception:
        except Exception:
        except Exception:
        except Exception:
        except Exception:
        except Exception:
        except Exception:
        except Exception:
        except Exception:
        except Exception:
        except Exception:
        except Exception:
        except Exception:
        except Exception:
        except Exception:
        except Exception:
        except Exception:
        except Exception:
        except Exception:
        except Exception:
        except Exception:
        except Exception:
        except Exception:
        except Exception:
        except Exception:
        except Exception:
        except Exception:
        except Exception:
        except Exception:
        except Exception:
        except Exception:
        except Exception:
        except Exception:
            return None
            return None
            return None
            return None
            return None
            return None
            return None
            return None
            return None
            return None
            return None
            return None
            return None
            return None
            return None
            return None
            return None
            return None
            return None
            return None
            return None
            return None
            return None
            return None
            return None
            return None
            return None
            return None
            return None
            return None
            return None
            return None
            return None
            return None
            return None
            return None
            return None





































def eval_bspline_2d(tck, n_samples=400):
def eval_bspline_2d(tck, n_samples=400):
def eval_bspline_2d(tck, n_samples=400):
def eval_bspline_2d(tck, n_samples=400):
def eval_bspline_2d(tck, n_samples=400):
def eval_bspline_2d(tck, n_samples=400):
def eval_bspline_2d(tck, n_samples=400):
def eval_bspline_2d(tck, n_samples=400):
def eval_bspline_2d(tck, n_samples=400):
def eval_bspline_2d(tck, n_samples=400):
def eval_bspline_2d(tck, n_samples=400):
def eval_bspline_2d(tck, n_samples=400):
def eval_bspline_2d(tck, n_samples=400):
def eval_bspline_2d(tck, n_samples=400):
def eval_bspline_2d(tck, n_samples=400):
def eval_bspline_2d(tck, n_samples=400):
def eval_bspline_2d(tck, n_samples=400):
def eval_bspline_2d(tck, n_samples=400):
def eval_bspline_2d(tck, n_samples=400):
def eval_bspline_2d(tck, n_samples=400):
def eval_bspline_2d(tck, n_samples=400):
def eval_bspline_2d(tck, n_samples=400):
def eval_bspline_2d(tck, n_samples=400):
def eval_bspline_2d(tck, n_samples=400):
def eval_bspline_2d(tck, n_samples=400):
def eval_bspline_2d(tck, n_samples=400):
def eval_bspline_2d(tck, n_samples=400):
def eval_bspline_2d(tck, n_samples=400):
def eval_bspline_2d(tck, n_samples=400):
def eval_bspline_2d(tck, n_samples=400):
def eval_bspline_2d(tck, n_samples=400):
def eval_bspline_2d(tck, n_samples=400):
def eval_bspline_2d(tck, n_samples=400):
def eval_bspline_2d(tck, n_samples=400):
def eval_bspline_2d(tck, n_samples=400):
def eval_bspline_2d(tck, n_samples=400):
def eval_bspline_2d(tck, n_samples=400):
    if tck is None:
    if tck is None:
    if tck is None:
    if tck is None:
    if tck is None:
    if tck is None:
    if tck is None:
    if tck is None:
    if tck is None:
    if tck is None:
    if tck is None:
    if tck is None:
    if tck is None:
    if tck is None:
    if tck is None:
    if tck is None:
    if tck is None:
    if tck is None:
    if tck is None:
    if tck is None:
    if tck is None:
    if tck is None:
    if tck is None:
    if tck is None:
    if tck is None:
    if tck is None:
    if tck is None:
    if tck is None:
    if tck is None:
    if tck is None:
    if tck is None:
    if tck is None:
    if tck is None:
    if tck is None:
    if tck is None:
    if tck is None:
    if tck is None:
        return None
        return None
        return None
        return None
        return None
        return None
        return None
        return None
        return None
        return None
        return None
        return None
        return None
        return None
        return None
        return None
        return None
        return None
        return None
        return None
        return None
        return None
        return None
        return None
        return None
        return None
        return None
        return None
        return None
        return None
        return None
        return None
        return None
        return None
        return None
        return None
        return None
    u = np.linspace(0,1,n_samples)
    u = np.linspace(0,1,n_samples)
    u = np.linspace(0,1,n_samples)
    u = np.linspace(0,1,n_samples)
    u = np.linspace(0,1,n_samples)
    u = np.linspace(0,1,n_samples)
    u = np.linspace(0,1,n_samples)
    u = np.linspace(0,1,n_samples)
    u = np.linspace(0,1,n_samples)
    u = np.linspace(0,1,n_samples)
    u = np.linspace(0,1,n_samples)
    u = np.linspace(0,1,n_samples)
    u = np.linspace(0,1,n_samples)
    u = np.linspace(0,1,n_samples)
    u = np.linspace(0,1,n_samples)
    u = np.linspace(0,1,n_samples)
    u = np.linspace(0,1,n_samples)
    u = np.linspace(0,1,n_samples)
    u = np.linspace(0,1,n_samples)
    u = np.linspace(0,1,n_samples)
    u = np.linspace(0,1,n_samples)
    u = np.linspace(0,1,n_samples)
    u = np.linspace(0,1,n_samples)
    u = np.linspace(0,1,n_samples)
    u = np.linspace(0,1,n_samples)
    u = np.linspace(0,1,n_samples)
    u = np.linspace(0,1,n_samples)
    u = np.linspace(0,1,n_samples)
    u = np.linspace(0,1,n_samples)
    u = np.linspace(0,1,n_samples)
    u = np.linspace(0,1,n_samples)
    u = np.linspace(0,1,n_samples)
    u = np.linspace(0,1,n_samples)
    u = np.linspace(0,1,n_samples)
    u = np.linspace(0,1,n_samples)
    u = np.linspace(0,1,n_samples)
    u = np.linspace(0,1,n_samples)
    x,y = splev(u, tck)
    x,y = splev(u, tck)
    x,y = splev(u, tck)
    x,y = splev(u, tck)
    x,y = splev(u, tck)
    x,y = splev(u, tck)
    x,y = splev(u, tck)
    x,y = splev(u, tck)
    x,y = splev(u, tck)
    x,y = splev(u, tck)
    x,y = splev(u, tck)
    x,y = splev(u, tck)
    x,y = splev(u, tck)
    x,y = splev(u, tck)
    x,y = splev(u, tck)
    x,y = splev(u, tck)
    x,y = splev(u, tck)
    x,y = splev(u, tck)
    x,y = splev(u, tck)
    x,y = splev(u, tck)
    x,y = splev(u, tck)
    x,y = splev(u, tck)
    x,y = splev(u, tck)
    x,y = splev(u, tck)
    x,y = splev(u, tck)
    x,y = splev(u, tck)
    x,y = splev(u, tck)
    x,y = splev(u, tck)
    x,y = splev(u, tck)
    x,y = splev(u, tck)
    x,y = splev(u, tck)
    x,y = splev(u, tck)
    x,y = splev(u, tck)
    x,y = splev(u, tck)
    x,y = splev(u, tck)
    x,y = splev(u, tck)
    x,y = splev(u, tck)
    return np.column_stack([x,y])    return np.column_stack([x,y])    return np.column_stack([x,y])    return np.column_stack([x,y])    return np.column_stack([x,y])    return np.column_stack([x,y])    return np.column_stack([x,y])    return np.column_stack([x,y])    return np.column_stack([x,y])    return np.column_stack([x,y])    return np.column_stack([x,y])    return np.column_stack([x,y])    return np.column_stack([x,y])    return np.column_stack([x,y])    return np.column_stack([x,y])    return np.column_stack([x,y])    return np.column_stack([x,y])    return np.column_stack([x,y])    return np.column_stack([x,y])    return np.column_stack([x,y])    return np.column_stack([x,y])    return np.column_stack([x,y])    return np.column_stack([x,y])    return np.column_stack([x,y])    return np.column_stack([x,y])    return np.column_stack([x,y])    return np.column_stack([x,y])    return np.column_stack([x,y])    return np.column_stack([x,y])    return np.column_stack([x,y])    return np.column_stack([x,y])    return np.column_stack([x,y])    return np.column_stack([x,y])    return np.column_stack([x,y])    return np.column_stack([x,y])    return np.column_stack([x,y])    return np.column_stack([x,y])

# %% [markdown]
# ### ---------- Control point extraction per paper (circles and geometric center) ----------
# ### ---------- Control point extraction per paper (circles and geometric center) ----------
# ### ---------- Control point extraction per paper (circles and geometric center) ----------
# ### ---------- Control point extraction per paper (circles and geometric center) ----------
# ### ---------- Control point extraction per paper (circles and geometric center) ----------
# ### ---------- Control point extraction per paper (circles and geometric center) ----------
# ### ---------- Control point extraction per paper (circles and geometric center) ----------
# ### ---------- Control point extraction per paper (circles and geometric center) ----------
# ### ---------- Control point extraction per paper (circles and geometric center) ----------
# ### ---------- Control point extraction per paper (circles and geometric center) ----------
# ### ---------- Control point extraction per paper (circles and geometric center) ----------
# ### ---------- Control point extraction per paper (circles and geometric center) ----------
# ### ---------- Control point extraction per paper (circles and geometric center) ----------
# ### ---------- Control point extraction per paper (circles and geometric center) ----------
# ### ---------- Control point extraction per paper (circles and geometric center) ----------
# ### ---------- Control point extraction per paper (circles and geometric center) ----------
# ### ---------- Control point extraction per paper (circles and geometric center) ----------
# ### ---------- Control point extraction per paper (circles and geometric center) ----------
# ### ---------- Control point extraction per paper (circles and geometric center) ----------
# ### ---------- Control point extraction per paper (circles and geometric center) ----------
# ### ---------- Control point extraction per paper (circles and geometric center) ----------
# ### ---------- Control point extraction per paper (circles and geometric center) ----------
# ### ---------- Control point extraction per paper (circles and geometric center) ----------
# ### ---------- Control point extraction per paper (circles and geometric center) ----------
# ### ---------- Control point extraction per paper (circles and geometric center) ----------
# ### ---------- Control point extraction per paper (circles and geometric center) ----------
# ### ---------- Control point extraction per paper (circles and geometric center) ----------
# ### ---------- Control point extraction per paper (circles and geometric center) ----------
# ### ---------- Control point extraction per paper (circles and geometric center) ----------
# ### ---------- Control point extraction per paper (circles and geometric center) ----------
# ### ---------- Control point extraction per paper (circles and geometric center) ----------
# ### ---------- Control point extraction per paper (circles and geometric center) ----------
# ### ---------- Control point extraction per paper (circles and geometric center) ----------
# ### ---------- Control point extraction per paper (circles and geometric center) ----------
# ### ---------- Control point extraction per paper (circles and geometric center) ----------
# ### ---------- Control point extraction per paper (circles and geometric center) ----------
# ### ---------- Control point extraction per paper (circles and geometric center) ----------

# %%
def extract_control_points(coords2d, pts3d, band_width, n_segments=60, circle_radius_factor=1.4, min_points_in_circle=3):
def extract_control_points(coords2d, pts3d, band_width, n_segments=60, circle_radius_factor=1.4, min_points_in_circle=3):
def extract_control_points(coords2d, pts3d, band_width, n_segments=60, circle_radius_factor=1.4, min_points_in_circle=3):
def extract_control_points(coords2d, pts3d, band_width, n_segments=60, circle_radius_factor=1.4, min_points_in_circle=3):
def extract_control_points(coords2d, pts3d, band_width, n_segments=60, circle_radius_factor=1.4, min_points_in_circle=3):
def extract_control_points(coords2d, pts3d, band_width, n_segments=60, circle_radius_factor=1.4, min_points_in_circle=3):
def extract_control_points(coords2d, pts3d, band_width, n_segments=60, circle_radius_factor=1.4, min_points_in_circle=3):
def extract_control_points(coords2d, pts3d, band_width, n_segments=60, circle_radius_factor=1.4, min_points_in_circle=3):
def extract_control_points(coords2d, pts3d, band_width, n_segments=60, circle_radius_factor=1.4, min_points_in_circle=3):
def extract_control_points(coords2d, pts3d, band_width, n_segments=60, circle_radius_factor=1.4, min_points_in_circle=3):
def extract_control_points(coords2d, pts3d, band_width, n_segments=60, circle_radius_factor=1.4, min_points_in_circle=3):
def extract_control_points(coords2d, pts3d, band_width, n_segments=60, circle_radius_factor=1.4, min_points_in_circle=3):
def extract_control_points(coords2d, pts3d, band_width, n_segments=60, circle_radius_factor=1.4, min_points_in_circle=3):
def extract_control_points(coords2d, pts3d, band_width, n_segments=60, circle_radius_factor=1.4, min_points_in_circle=3):
def extract_control_points(coords2d, pts3d, band_width, n_segments=60, circle_radius_factor=1.4, min_points_in_circle=3):
def extract_control_points(coords2d, pts3d, band_width, n_segments=60, circle_radius_factor=1.4, min_points_in_circle=3):
def extract_control_points(coords2d, pts3d, band_width, n_segments=60, circle_radius_factor=1.4, min_points_in_circle=3):
def extract_control_points(coords2d, pts3d, band_width, n_segments=60, circle_radius_factor=1.4, min_points_in_circle=3):
def extract_control_points(coords2d, pts3d, band_width, n_segments=60, circle_radius_factor=1.4, min_points_in_circle=3):
def extract_control_points(coords2d, pts3d, band_width, n_segments=60, circle_radius_factor=1.4, min_points_in_circle=3):
def extract_control_points(coords2d, pts3d, band_width, n_segments=60, circle_radius_factor=1.4, min_points_in_circle=3):
def extract_control_points(coords2d, pts3d, band_width, n_segments=60, circle_radius_factor=1.4, min_points_in_circle=3):
def extract_control_points(coords2d, pts3d, band_width, n_segments=60, circle_radius_factor=1.4, min_points_in_circle=3):
def extract_control_points(coords2d, pts3d, band_width, n_segments=60, circle_radius_factor=1.4, min_points_in_circle=3):
def extract_control_points(coords2d, pts3d, band_width, n_segments=60, circle_radius_factor=1.4, min_points_in_circle=3):
def extract_control_points(coords2d, pts3d, band_width, n_segments=60, circle_radius_factor=1.4, min_points_in_circle=3):
def extract_control_points(coords2d, pts3d, band_width, n_segments=60, circle_radius_factor=1.4, min_points_in_circle=3):
def extract_control_points(coords2d, pts3d, band_width, n_segments=60, circle_radius_factor=1.4, min_points_in_circle=3):
def extract_control_points(coords2d, pts3d, band_width, n_segments=60, circle_radius_factor=1.4, min_points_in_circle=3):
def extract_control_points(coords2d, pts3d, band_width, n_segments=60, circle_radius_factor=1.4, min_points_in_circle=3):
def extract_control_points(coords2d, pts3d, band_width, n_segments=60, circle_radius_factor=1.4, min_points_in_circle=3):
def extract_control_points(coords2d, pts3d, band_width, n_segments=60, circle_radius_factor=1.4, min_points_in_circle=3):
def extract_control_points(coords2d, pts3d, band_width, n_segments=60, circle_radius_factor=1.4, min_points_in_circle=3):
def extract_control_points(coords2d, pts3d, band_width, n_segments=60, circle_radius_factor=1.4, min_points_in_circle=3):
def extract_control_points(coords2d, pts3d, band_width, n_segments=60, circle_radius_factor=1.4, min_points_in_circle=3):
def extract_control_points(coords2d, pts3d, band_width, n_segments=60, circle_radius_factor=1.4, min_points_in_circle=3):
def extract_control_points(coords2d, pts3d, band_width, n_segments=60, circle_radius_factor=1.4, min_points_in_circle=3):
    L = len(coords2d)
    L = len(coords2d)
    L = len(coords2d)
    L = len(coords2d)
    L = len(coords2d)
    L = len(coords2d)
    L = len(coords2d)
    L = len(coords2d)
    L = len(coords2d)
    L = len(coords2d)
    L = len(coords2d)
    L = len(coords2d)
    L = len(coords2d)
    L = len(coords2d)
    L = len(coords2d)
    L = len(coords2d)
    L = len(coords2d)
    L = len(coords2d)
    L = len(coords2d)
    L = len(coords2d)
    L = len(coords2d)
    L = len(coords2d)
    L = len(coords2d)
    L = len(coords2d)
    L = len(coords2d)
    L = len(coords2d)
    L = len(coords2d)
    L = len(coords2d)
    L = len(coords2d)
    L = len(coords2d)
    L = len(coords2d)
    L = len(coords2d)
    L = len(coords2d)
    L = len(coords2d)
    L = len(coords2d)
    L = len(coords2d)
    L = len(coords2d)
    if L == 0:
    if L == 0:
    if L == 0:
    if L == 0:
    if L == 0:
    if L == 0:
    if L == 0:
    if L == 0:
    if L == 0:
    if L == 0:
    if L == 0:
    if L == 0:
    if L == 0:
    if L == 0:
    if L == 0:
    if L == 0:
    if L == 0:
    if L == 0:
    if L == 0:
    if L == 0:
    if L == 0:
    if L == 0:
    if L == 0:
    if L == 0:
    if L == 0:
    if L == 0:
    if L == 0:
    if L == 0:
    if L == 0:
    if L == 0:
    if L == 0:
    if L == 0:
    if L == 0:
    if L == 0:
    if L == 0:
    if L == 0:
    if L == 0:
        return np.zeros((0,2)), np.zeros((0,3))
        return np.zeros((0,2)), np.zeros((0,3))
        return np.zeros((0,2)), np.zeros((0,3))
        return np.zeros((0,2)), np.zeros((0,3))
        return np.zeros((0,2)), np.zeros((0,3))
        return np.zeros((0,2)), np.zeros((0,3))
        return np.zeros((0,2)), np.zeros((0,3))
        return np.zeros((0,2)), np.zeros((0,3))
        return np.zeros((0,2)), np.zeros((0,3))
        return np.zeros((0,2)), np.zeros((0,3))
        return np.zeros((0,2)), np.zeros((0,3))
        return np.zeros((0,2)), np.zeros((0,3))
        return np.zeros((0,2)), np.zeros((0,3))
        return np.zeros((0,2)), np.zeros((0,3))
        return np.zeros((0,2)), np.zeros((0,3))
        return np.zeros((0,2)), np.zeros((0,3))
        return np.zeros((0,2)), np.zeros((0,3))
        return np.zeros((0,2)), np.zeros((0,3))
        return np.zeros((0,2)), np.zeros((0,3))
        return np.zeros((0,2)), np.zeros((0,3))
        return np.zeros((0,2)), np.zeros((0,3))
        return np.zeros((0,2)), np.zeros((0,3))
        return np.zeros((0,2)), np.zeros((0,3))
        return np.zeros((0,2)), np.zeros((0,3))
        return np.zeros((0,2)), np.zeros((0,3))
        return np.zeros((0,2)), np.zeros((0,3))
        return np.zeros((0,2)), np.zeros((0,3))
        return np.zeros((0,2)), np.zeros((0,3))
        return np.zeros((0,2)), np.zeros((0,3))
        return np.zeros((0,2)), np.zeros((0,3))
        return np.zeros((0,2)), np.zeros((0,3))
        return np.zeros((0,2)), np.zeros((0,3))
        return np.zeros((0,2)), np.zeros((0,3))
        return np.zeros((0,2)), np.zeros((0,3))
        return np.zeros((0,2)), np.zeros((0,3))
        return np.zeros((0,2)), np.zeros((0,3))
        return np.zeros((0,2)), np.zeros((0,3))
    order, _ = order_points_along_axis(coords2d)
    order, _ = order_points_along_axis(coords2d)
    order, _ = order_points_along_axis(coords2d)
    order, _ = order_points_along_axis(coords2d)
    order, _ = order_points_along_axis(coords2d)
    order, _ = order_points_along_axis(coords2d)
    order, _ = order_points_along_axis(coords2d)
    order, _ = order_points_along_axis(coords2d)
    order, _ = order_points_along_axis(coords2d)
    order, _ = order_points_along_axis(coords2d)
    order, _ = order_points_along_axis(coords2d)
    order, _ = order_points_along_axis(coords2d)
    order, _ = order_points_along_axis(coords2d)
    order, _ = order_points_along_axis(coords2d)
    order, _ = order_points_along_axis(coords2d)
    order, _ = order_points_along_axis(coords2d)
    order, _ = order_points_along_axis(coords2d)
    order, _ = order_points_along_axis(coords2d)
    order, _ = order_points_along_axis(coords2d)
    order, _ = order_points_along_axis(coords2d)
    order, _ = order_points_along_axis(coords2d)
    order, _ = order_points_along_axis(coords2d)
    order, _ = order_points_along_axis(coords2d)
    order, _ = order_points_along_axis(coords2d)
    order, _ = order_points_along_axis(coords2d)
    order, _ = order_points_along_axis(coords2d)
    order, _ = order_points_along_axis(coords2d)
    order, _ = order_points_along_axis(coords2d)
    order, _ = order_points_along_axis(coords2d)
    order, _ = order_points_along_axis(coords2d)
    order, _ = order_points_along_axis(coords2d)
    order, _ = order_points_along_axis(coords2d)
    order, _ = order_points_along_axis(coords2d)
    order, _ = order_points_along_axis(coords2d)
    order, _ = order_points_along_axis(coords2d)
    order, _ = order_points_along_axis(coords2d)
    order, _ = order_points_along_axis(coords2d)
    ordered2d = coords2d[order]
    ordered2d = coords2d[order]
    ordered2d = coords2d[order]
    ordered2d = coords2d[order]
    ordered2d = coords2d[order]
    ordered2d = coords2d[order]
    ordered2d = coords2d[order]
    ordered2d = coords2d[order]
    ordered2d = coords2d[order]
    ordered2d = coords2d[order]
    ordered2d = coords2d[order]
    ordered2d = coords2d[order]
    ordered2d = coords2d[order]
    ordered2d = coords2d[order]
    ordered2d = coords2d[order]
    ordered2d = coords2d[order]
    ordered2d = coords2d[order]
    ordered2d = coords2d[order]
    ordered2d = coords2d[order]
    ordered2d = coords2d[order]
    ordered2d = coords2d[order]
    ordered2d = coords2d[order]
    ordered2d = coords2d[order]
    ordered2d = coords2d[order]
    ordered2d = coords2d[order]
    ordered2d = coords2d[order]
    ordered2d = coords2d[order]
    ordered2d = coords2d[order]
    ordered2d = coords2d[order]
    ordered2d = coords2d[order]
    ordered2d = coords2d[order]
    ordered2d = coords2d[order]
    ordered2d = coords2d[order]
    ordered2d = coords2d[order]
    ordered2d = coords2d[order]
    ordered2d = coords2d[order]
    ordered2d = coords2d[order]
    ordered3d = pts3d[order]
    ordered3d = pts3d[order]
    ordered3d = pts3d[order]
    ordered3d = pts3d[order]
    ordered3d = pts3d[order]
    ordered3d = pts3d[order]
    ordered3d = pts3d[order]
    ordered3d = pts3d[order]
    ordered3d = pts3d[order]
    ordered3d = pts3d[order]
    ordered3d = pts3d[order]
    ordered3d = pts3d[order]
    ordered3d = pts3d[order]
    ordered3d = pts3d[order]
    ordered3d = pts3d[order]
    ordered3d = pts3d[order]
    ordered3d = pts3d[order]
    ordered3d = pts3d[order]
    ordered3d = pts3d[order]
    ordered3d = pts3d[order]
    ordered3d = pts3d[order]
    ordered3d = pts3d[order]
    ordered3d = pts3d[order]
    ordered3d = pts3d[order]
    ordered3d = pts3d[order]
    ordered3d = pts3d[order]
    ordered3d = pts3d[order]
    ordered3d = pts3d[order]
    ordered3d = pts3d[order]
    ordered3d = pts3d[order]
    ordered3d = pts3d[order]
    ordered3d = pts3d[order]
    ordered3d = pts3d[order]
    ordered3d = pts3d[order]
    ordered3d = pts3d[order]
    ordered3d = pts3d[order]
    ordered3d = pts3d[order]
    idxs = np.linspace(0, L-1, n_segments, dtype=int)
    idxs = np.linspace(0, L-1, n_segments, dtype=int)
    idxs = np.linspace(0, L-1, n_segments, dtype=int)
    idxs = np.linspace(0, L-1, n_segments, dtype=int)
    idxs = np.linspace(0, L-1, n_segments, dtype=int)
    idxs = np.linspace(0, L-1, n_segments, dtype=int)
    idxs = np.linspace(0, L-1, n_segments, dtype=int)
    idxs = np.linspace(0, L-1, n_segments, dtype=int)
    idxs = np.linspace(0, L-1, n_segments, dtype=int)
    idxs = np.linspace(0, L-1, n_segments, dtype=int)
    idxs = np.linspace(0, L-1, n_segments, dtype=int)
    idxs = np.linspace(0, L-1, n_segments, dtype=int)
    idxs = np.linspace(0, L-1, n_segments, dtype=int)
    idxs = np.linspace(0, L-1, n_segments, dtype=int)
    idxs = np.linspace(0, L-1, n_segments, dtype=int)
    idxs = np.linspace(0, L-1, n_segments, dtype=int)
    idxs = np.linspace(0, L-1, n_segments, dtype=int)
    idxs = np.linspace(0, L-1, n_segments, dtype=int)
    idxs = np.linspace(0, L-1, n_segments, dtype=int)
    idxs = np.linspace(0, L-1, n_segments, dtype=int)
    idxs = np.linspace(0, L-1, n_segments, dtype=int)
    idxs = np.linspace(0, L-1, n_segments, dtype=int)
    idxs = np.linspace(0, L-1, n_segments, dtype=int)
    idxs = np.linspace(0, L-1, n_segments, dtype=int)
    idxs = np.linspace(0, L-1, n_segments, dtype=int)
    idxs = np.linspace(0, L-1, n_segments, dtype=int)
    idxs = np.linspace(0, L-1, n_segments, dtype=int)
    idxs = np.linspace(0, L-1, n_segments, dtype=int)
    idxs = np.linspace(0, L-1, n_segments, dtype=int)
    idxs = np.linspace(0, L-1, n_segments, dtype=int)
    idxs = np.linspace(0, L-1, n_segments, dtype=int)
    idxs = np.linspace(0, L-1, n_segments, dtype=int)
    idxs = np.linspace(0, L-1, n_segments, dtype=int)
    idxs = np.linspace(0, L-1, n_segments, dtype=int)
    idxs = np.linspace(0, L-1, n_segments, dtype=int)
    idxs = np.linspace(0, L-1, n_segments, dtype=int)
    idxs = np.linspace(0, L-1, n_segments, dtype=int)
    seg2d = ordered2d[idxs]
    seg2d = ordered2d[idxs]
    seg2d = ordered2d[idxs]
    seg2d = ordered2d[idxs]
    seg2d = ordered2d[idxs]
    seg2d = ordered2d[idxs]
    seg2d = ordered2d[idxs]
    seg2d = ordered2d[idxs]
    seg2d = ordered2d[idxs]
    seg2d = ordered2d[idxs]
    seg2d = ordered2d[idxs]
    seg2d = ordered2d[idxs]
    seg2d = ordered2d[idxs]
    seg2d = ordered2d[idxs]
    seg2d = ordered2d[idxs]
    seg2d = ordered2d[idxs]
    seg2d = ordered2d[idxs]
    seg2d = ordered2d[idxs]
    seg2d = ordered2d[idxs]
    seg2d = ordered2d[idxs]
    seg2d = ordered2d[idxs]
    seg2d = ordered2d[idxs]
    seg2d = ordered2d[idxs]
    seg2d = ordered2d[idxs]
    seg2d = ordered2d[idxs]
    seg2d = ordered2d[idxs]
    seg2d = ordered2d[idxs]
    seg2d = ordered2d[idxs]
    seg2d = ordered2d[idxs]
    seg2d = ordered2d[idxs]
    seg2d = ordered2d[idxs]
    seg2d = ordered2d[idxs]
    seg2d = ordered2d[idxs]
    seg2d = ordered2d[idxs]
    seg2d = ordered2d[idxs]
    seg2d = ordered2d[idxs]
    seg2d = ordered2d[idxs]
    seg3d = ordered3d[idxs]
    seg3d = ordered3d[idxs]
    seg3d = ordered3d[idxs]
    seg3d = ordered3d[idxs]
    seg3d = ordered3d[idxs]
    seg3d = ordered3d[idxs]
    seg3d = ordered3d[idxs]
    seg3d = ordered3d[idxs]
    seg3d = ordered3d[idxs]
    seg3d = ordered3d[idxs]
    seg3d = ordered3d[idxs]
    seg3d = ordered3d[idxs]
    seg3d = ordered3d[idxs]
    seg3d = ordered3d[idxs]
    seg3d = ordered3d[idxs]
    seg3d = ordered3d[idxs]
    seg3d = ordered3d[idxs]
    seg3d = ordered3d[idxs]
    seg3d = ordered3d[idxs]
    seg3d = ordered3d[idxs]
    seg3d = ordered3d[idxs]
    seg3d = ordered3d[idxs]
    seg3d = ordered3d[idxs]
    seg3d = ordered3d[idxs]
    seg3d = ordered3d[idxs]
    seg3d = ordered3d[idxs]
    seg3d = ordered3d[idxs]
    seg3d = ordered3d[idxs]
    seg3d = ordered3d[idxs]
    seg3d = ordered3d[idxs]
    seg3d = ordered3d[idxs]
    seg3d = ordered3d[idxs]
    seg3d = ordered3d[idxs]
    seg3d = ordered3d[idxs]
    seg3d = ordered3d[idxs]
    seg3d = ordered3d[idxs]
    seg3d = ordered3d[idxs]
    radius = max(1e-6, circle_radius_factor * max(band_width, 1e-6))
    radius = max(1e-6, circle_radius_factor * max(band_width, 1e-6))
    radius = max(1e-6, circle_radius_factor * max(band_width, 1e-6))
    radius = max(1e-6, circle_radius_factor * max(band_width, 1e-6))
    radius = max(1e-6, circle_radius_factor * max(band_width, 1e-6))
    radius = max(1e-6, circle_radius_factor * max(band_width, 1e-6))
    radius = max(1e-6, circle_radius_factor * max(band_width, 1e-6))
    radius = max(1e-6, circle_radius_factor * max(band_width, 1e-6))
    radius = max(1e-6, circle_radius_factor * max(band_width, 1e-6))
    radius = max(1e-6, circle_radius_factor * max(band_width, 1e-6))
    radius = max(1e-6, circle_radius_factor * max(band_width, 1e-6))
    radius = max(1e-6, circle_radius_factor * max(band_width, 1e-6))
    radius = max(1e-6, circle_radius_factor * max(band_width, 1e-6))
    radius = max(1e-6, circle_radius_factor * max(band_width, 1e-6))
    radius = max(1e-6, circle_radius_factor * max(band_width, 1e-6))
    radius = max(1e-6, circle_radius_factor * max(band_width, 1e-6))
    radius = max(1e-6, circle_radius_factor * max(band_width, 1e-6))
    radius = max(1e-6, circle_radius_factor * max(band_width, 1e-6))
    radius = max(1e-6, circle_radius_factor * max(band_width, 1e-6))
    radius = max(1e-6, circle_radius_factor * max(band_width, 1e-6))
    radius = max(1e-6, circle_radius_factor * max(band_width, 1e-6))
    radius = max(1e-6, circle_radius_factor * max(band_width, 1e-6))
    radius = max(1e-6, circle_radius_factor * max(band_width, 1e-6))
    radius = max(1e-6, circle_radius_factor * max(band_width, 1e-6))
    radius = max(1e-6, circle_radius_factor * max(band_width, 1e-6))
    radius = max(1e-6, circle_radius_factor * max(band_width, 1e-6))
    radius = max(1e-6, circle_radius_factor * max(band_width, 1e-6))
    radius = max(1e-6, circle_radius_factor * max(band_width, 1e-6))
    radius = max(1e-6, circle_radius_factor * max(band_width, 1e-6))
    radius = max(1e-6, circle_radius_factor * max(band_width, 1e-6))
    radius = max(1e-6, circle_radius_factor * max(band_width, 1e-6))
    radius = max(1e-6, circle_radius_factor * max(band_width, 1e-6))
    radius = max(1e-6, circle_radius_factor * max(band_width, 1e-6))
    radius = max(1e-6, circle_radius_factor * max(band_width, 1e-6))
    radius = max(1e-6, circle_radius_factor * max(band_width, 1e-6))
    radius = max(1e-6, circle_radius_factor * max(band_width, 1e-6))
    radius = max(1e-6, circle_radius_factor * max(band_width, 1e-6))
    centers2d = []
    centers2d = []
    centers2d = []
    centers2d = []
    centers2d = []
    centers2d = []
    centers2d = []
    centers2d = []
    centers2d = []
    centers2d = []
    centers2d = []
    centers2d = []
    centers2d = []
    centers2d = []
    centers2d = []
    centers2d = []
    centers2d = []
    centers2d = []
    centers2d = []
    centers2d = []
    centers2d = []
    centers2d = []
    centers2d = []
    centers2d = []
    centers2d = []
    centers2d = []
    centers2d = []
    centers2d = []
    centers2d = []
    centers2d = []
    centers2d = []
    centers2d = []
    centers2d = []
    centers2d = []
    centers2d = []
    centers2d = []
    centers2d = []
    centers3d = []
    centers3d = []
    centers3d = []
    centers3d = []
    centers3d = []
    centers3d = []
    centers3d = []
    centers3d = []
    centers3d = []
    centers3d = []
    centers3d = []
    centers3d = []
    centers3d = []
    centers3d = []
    centers3d = []
    centers3d = []
    centers3d = []
    centers3d = []
    centers3d = []
    centers3d = []
    centers3d = []
    centers3d = []
    centers3d = []
    centers3d = []
    centers3d = []
    centers3d = []
    centers3d = []
    centers3d = []
    centers3d = []
    centers3d = []
    centers3d = []
    centers3d = []
    centers3d = []
    centers3d = []
    centers3d = []
    centers3d = []
    centers3d = []
    for kp in seg2d:
    for kp in seg2d:
    for kp in seg2d:
    for kp in seg2d:
    for kp in seg2d:
    for kp in seg2d:
    for kp in seg2d:
    for kp in seg2d:
    for kp in seg2d:
    for kp in seg2d:
    for kp in seg2d:
    for kp in seg2d:
    for kp in seg2d:
    for kp in seg2d:
    for kp in seg2d:
    for kp in seg2d:
    for kp in seg2d:
    for kp in seg2d:
    for kp in seg2d:
    for kp in seg2d:
    for kp in seg2d:
    for kp in seg2d:
    for kp in seg2d:
    for kp in seg2d:
    for kp in seg2d:
    for kp in seg2d:
    for kp in seg2d:
    for kp in seg2d:
    for kp in seg2d:
    for kp in seg2d:
    for kp in seg2d:
    for kp in seg2d:
    for kp in seg2d:
    for kp in seg2d:
    for kp in seg2d:
    for kp in seg2d:
    for kp in seg2d:
        d = np.hypot(ordered2d[:,0]-kp[0], ordered2d[:,1]-kp[1])
        d = np.hypot(ordered2d[:,0]-kp[0], ordered2d[:,1]-kp[1])
        d = np.hypot(ordered2d[:,0]-kp[0], ordered2d[:,1]-kp[1])
        d = np.hypot(ordered2d[:,0]-kp[0], ordered2d[:,1]-kp[1])
        d = np.hypot(ordered2d[:,0]-kp[0], ordered2d[:,1]-kp[1])
        d = np.hypot(ordered2d[:,0]-kp[0], ordered2d[:,1]-kp[1])
        d = np.hypot(ordered2d[:,0]-kp[0], ordered2d[:,1]-kp[1])
        d = np.hypot(ordered2d[:,0]-kp[0], ordered2d[:,1]-kp[1])
        d = np.hypot(ordered2d[:,0]-kp[0], ordered2d[:,1]-kp[1])
        d = np.hypot(ordered2d[:,0]-kp[0], ordered2d[:,1]-kp[1])
        d = np.hypot(ordered2d[:,0]-kp[0], ordered2d[:,1]-kp[1])
        d = np.hypot(ordered2d[:,0]-kp[0], ordered2d[:,1]-kp[1])
        d = np.hypot(ordered2d[:,0]-kp[0], ordered2d[:,1]-kp[1])
        d = np.hypot(ordered2d[:,0]-kp[0], ordered2d[:,1]-kp[1])
        d = np.hypot(ordered2d[:,0]-kp[0], ordered2d[:,1]-kp[1])
        d = np.hypot(ordered2d[:,0]-kp[0], ordered2d[:,1]-kp[1])
        d = np.hypot(ordered2d[:,0]-kp[0], ordered2d[:,1]-kp[1])
        d = np.hypot(ordered2d[:,0]-kp[0], ordered2d[:,1]-kp[1])
        d = np.hypot(ordered2d[:,0]-kp[0], ordered2d[:,1]-kp[1])
        d = np.hypot(ordered2d[:,0]-kp[0], ordered2d[:,1]-kp[1])
        d = np.hypot(ordered2d[:,0]-kp[0], ordered2d[:,1]-kp[1])
        d = np.hypot(ordered2d[:,0]-kp[0], ordered2d[:,1]-kp[1])
        d = np.hypot(ordered2d[:,0]-kp[0], ordered2d[:,1]-kp[1])
        d = np.hypot(ordered2d[:,0]-kp[0], ordered2d[:,1]-kp[1])
        d = np.hypot(ordered2d[:,0]-kp[0], ordered2d[:,1]-kp[1])
        d = np.hypot(ordered2d[:,0]-kp[0], ordered2d[:,1]-kp[1])
        d = np.hypot(ordered2d[:,0]-kp[0], ordered2d[:,1]-kp[1])
        d = np.hypot(ordered2d[:,0]-kp[0], ordered2d[:,1]-kp[1])
        d = np.hypot(ordered2d[:,0]-kp[0], ordered2d[:,1]-kp[1])
        d = np.hypot(ordered2d[:,0]-kp[0], ordered2d[:,1]-kp[1])
        d = np.hypot(ordered2d[:,0]-kp[0], ordered2d[:,1]-kp[1])
        d = np.hypot(ordered2d[:,0]-kp[0], ordered2d[:,1]-kp[1])
        d = np.hypot(ordered2d[:,0]-kp[0], ordered2d[:,1]-kp[1])
        d = np.hypot(ordered2d[:,0]-kp[0], ordered2d[:,1]-kp[1])
        d = np.hypot(ordered2d[:,0]-kp[0], ordered2d[:,1]-kp[1])
        d = np.hypot(ordered2d[:,0]-kp[0], ordered2d[:,1]-kp[1])
        d = np.hypot(ordered2d[:,0]-kp[0], ordered2d[:,1]-kp[1])
        mask = d <= radius
        mask = d <= radius
        mask = d <= radius
        mask = d <= radius
        mask = d <= radius
        mask = d <= radius
        mask = d <= radius
        mask = d <= radius
        mask = d <= radius
        mask = d <= radius
        mask = d <= radius
        mask = d <= radius
        mask = d <= radius
        mask = d <= radius
        mask = d <= radius
        mask = d <= radius
        mask = d <= radius
        mask = d <= radius
        mask = d <= radius
        mask = d <= radius
        mask = d <= radius
        mask = d <= radius
        mask = d <= radius
        mask = d <= radius
        mask = d <= radius
        mask = d <= radius
        mask = d <= radius
        mask = d <= radius
        mask = d <= radius
        mask = d <= radius
        mask = d <= radius
        mask = d <= radius
        mask = d <= radius
        mask = d <= radius
        mask = d <= radius
        mask = d <= radius
        mask = d <= radius
        if np.sum(mask) >= min_points_in_circle:
        if np.sum(mask) >= min_points_in_circle:
        if np.sum(mask) >= min_points_in_circle:
        if np.sum(mask) >= min_points_in_circle:
        if np.sum(mask) >= min_points_in_circle:
        if np.sum(mask) >= min_points_in_circle:
        if np.sum(mask) >= min_points_in_circle:
        if np.sum(mask) >= min_points_in_circle:
        if np.sum(mask) >= min_points_in_circle:
        if np.sum(mask) >= min_points_in_circle:
        if np.sum(mask) >= min_points_in_circle:
        if np.sum(mask) >= min_points_in_circle:
        if np.sum(mask) >= min_points_in_circle:
        if np.sum(mask) >= min_points_in_circle:
        if np.sum(mask) >= min_points_in_circle:
        if np.sum(mask) >= min_points_in_circle:
        if np.sum(mask) >= min_points_in_circle:
        if np.sum(mask) >= min_points_in_circle:
        if np.sum(mask) >= min_points_in_circle:
        if np.sum(mask) >= min_points_in_circle:
        if np.sum(mask) >= min_points_in_circle:
        if np.sum(mask) >= min_points_in_circle:
        if np.sum(mask) >= min_points_in_circle:
        if np.sum(mask) >= min_points_in_circle:
        if np.sum(mask) >= min_points_in_circle:
        if np.sum(mask) >= min_points_in_circle:
        if np.sum(mask) >= min_points_in_circle:
        if np.sum(mask) >= min_points_in_circle:
        if np.sum(mask) >= min_points_in_circle:
        if np.sum(mask) >= min_points_in_circle:
        if np.sum(mask) >= min_points_in_circle:
        if np.sum(mask) >= min_points_in_circle:
        if np.sum(mask) >= min_points_in_circle:
        if np.sum(mask) >= min_points_in_circle:
        if np.sum(mask) >= min_points_in_circle:
        if np.sum(mask) >= min_points_in_circle:
        if np.sum(mask) >= min_points_in_circle:
            centers2d.append(ordered2d[mask].mean(axis=0))
            centers2d.append(ordered2d[mask].mean(axis=0))
            centers2d.append(ordered2d[mask].mean(axis=0))
            centers2d.append(ordered2d[mask].mean(axis=0))
            centers2d.append(ordered2d[mask].mean(axis=0))
            centers2d.append(ordered2d[mask].mean(axis=0))
            centers2d.append(ordered2d[mask].mean(axis=0))
            centers2d.append(ordered2d[mask].mean(axis=0))
            centers2d.append(ordered2d[mask].mean(axis=0))
            centers2d.append(ordered2d[mask].mean(axis=0))
            centers2d.append(ordered2d[mask].mean(axis=0))
            centers2d.append(ordered2d[mask].mean(axis=0))
            centers2d.append(ordered2d[mask].mean(axis=0))
            centers2d.append(ordered2d[mask].mean(axis=0))
            centers2d.append(ordered2d[mask].mean(axis=0))
            centers2d.append(ordered2d[mask].mean(axis=0))
            centers2d.append(ordered2d[mask].mean(axis=0))
            centers2d.append(ordered2d[mask].mean(axis=0))
            centers2d.append(ordered2d[mask].mean(axis=0))
            centers2d.append(ordered2d[mask].mean(axis=0))
            centers2d.append(ordered2d[mask].mean(axis=0))
            centers2d.append(ordered2d[mask].mean(axis=0))
            centers2d.append(ordered2d[mask].mean(axis=0))
            centers2d.append(ordered2d[mask].mean(axis=0))
            centers2d.append(ordered2d[mask].mean(axis=0))
            centers2d.append(ordered2d[mask].mean(axis=0))
            centers2d.append(ordered2d[mask].mean(axis=0))
            centers2d.append(ordered2d[mask].mean(axis=0))
            centers2d.append(ordered2d[mask].mean(axis=0))
            centers2d.append(ordered2d[mask].mean(axis=0))
            centers2d.append(ordered2d[mask].mean(axis=0))
            centers2d.append(ordered2d[mask].mean(axis=0))
            centers2d.append(ordered2d[mask].mean(axis=0))
            centers2d.append(ordered2d[mask].mean(axis=0))
            centers2d.append(ordered2d[mask].mean(axis=0))
            centers2d.append(ordered2d[mask].mean(axis=0))
            centers2d.append(ordered2d[mask].mean(axis=0))
            centers3d.append(ordered3d[mask].mean(axis=0))
            centers3d.append(ordered3d[mask].mean(axis=0))
            centers3d.append(ordered3d[mask].mean(axis=0))
            centers3d.append(ordered3d[mask].mean(axis=0))
            centers3d.append(ordered3d[mask].mean(axis=0))
            centers3d.append(ordered3d[mask].mean(axis=0))
            centers3d.append(ordered3d[mask].mean(axis=0))
            centers3d.append(ordered3d[mask].mean(axis=0))
            centers3d.append(ordered3d[mask].mean(axis=0))
            centers3d.append(ordered3d[mask].mean(axis=0))
            centers3d.append(ordered3d[mask].mean(axis=0))
            centers3d.append(ordered3d[mask].mean(axis=0))
            centers3d.append(ordered3d[mask].mean(axis=0))
            centers3d.append(ordered3d[mask].mean(axis=0))
            centers3d.append(ordered3d[mask].mean(axis=0))
            centers3d.append(ordered3d[mask].mean(axis=0))
            centers3d.append(ordered3d[mask].mean(axis=0))
            centers3d.append(ordered3d[mask].mean(axis=0))
            centers3d.append(ordered3d[mask].mean(axis=0))
            centers3d.append(ordered3d[mask].mean(axis=0))
            centers3d.append(ordered3d[mask].mean(axis=0))
            centers3d.append(ordered3d[mask].mean(axis=0))
            centers3d.append(ordered3d[mask].mean(axis=0))
            centers3d.append(ordered3d[mask].mean(axis=0))
            centers3d.append(ordered3d[mask].mean(axis=0))
            centers3d.append(ordered3d[mask].mean(axis=0))
            centers3d.append(ordered3d[mask].mean(axis=0))
            centers3d.append(ordered3d[mask].mean(axis=0))
            centers3d.append(ordered3d[mask].mean(axis=0))
            centers3d.append(ordered3d[mask].mean(axis=0))
            centers3d.append(ordered3d[mask].mean(axis=0))
            centers3d.append(ordered3d[mask].mean(axis=0))
            centers3d.append(ordered3d[mask].mean(axis=0))
            centers3d.append(ordered3d[mask].mean(axis=0))
            centers3d.append(ordered3d[mask].mean(axis=0))
            centers3d.append(ordered3d[mask].mean(axis=0))
            centers3d.append(ordered3d[mask].mean(axis=0))
    if len(centers2d) == 0:
    if len(centers2d) == 0:
    if len(centers2d) == 0:
    if len(centers2d) == 0:
    if len(centers2d) == 0:
    if len(centers2d) == 0:
    if len(centers2d) == 0:
    if len(centers2d) == 0:
    if len(centers2d) == 0:
    if len(centers2d) == 0:
    if len(centers2d) == 0:
    if len(centers2d) == 0:
    if len(centers2d) == 0:
    if len(centers2d) == 0:
    if len(centers2d) == 0:
    if len(centers2d) == 0:
    if len(centers2d) == 0:
    if len(centers2d) == 0:
    if len(centers2d) == 0:
    if len(centers2d) == 0:
    if len(centers2d) == 0:
    if len(centers2d) == 0:
    if len(centers2d) == 0:
    if len(centers2d) == 0:
    if len(centers2d) == 0:
    if len(centers2d) == 0:
    if len(centers2d) == 0:
    if len(centers2d) == 0:
    if len(centers2d) == 0:
    if len(centers2d) == 0:
    if len(centers2d) == 0:
    if len(centers2d) == 0:
    if len(centers2d) == 0:
    if len(centers2d) == 0:
    if len(centers2d) == 0:
    if len(centers2d) == 0:
    if len(centers2d) == 0:
        return np.zeros((0,2)), np.zeros((0,3))
        return np.zeros((0,2)), np.zeros((0,3))
        return np.zeros((0,2)), np.zeros((0,3))
        return np.zeros((0,2)), np.zeros((0,3))
        return np.zeros((0,2)), np.zeros((0,3))
        return np.zeros((0,2)), np.zeros((0,3))
        return np.zeros((0,2)), np.zeros((0,3))
        return np.zeros((0,2)), np.zeros((0,3))
        return np.zeros((0,2)), np.zeros((0,3))
        return np.zeros((0,2)), np.zeros((0,3))
        return np.zeros((0,2)), np.zeros((0,3))
        return np.zeros((0,2)), np.zeros((0,3))
        return np.zeros((0,2)), np.zeros((0,3))
        return np.zeros((0,2)), np.zeros((0,3))
        return np.zeros((0,2)), np.zeros((0,3))
        return np.zeros((0,2)), np.zeros((0,3))
        return np.zeros((0,2)), np.zeros((0,3))
        return np.zeros((0,2)), np.zeros((0,3))
        return np.zeros((0,2)), np.zeros((0,3))
        return np.zeros((0,2)), np.zeros((0,3))
        return np.zeros((0,2)), np.zeros((0,3))
        return np.zeros((0,2)), np.zeros((0,3))
        return np.zeros((0,2)), np.zeros((0,3))
        return np.zeros((0,2)), np.zeros((0,3))
        return np.zeros((0,2)), np.zeros((0,3))
        return np.zeros((0,2)), np.zeros((0,3))
        return np.zeros((0,2)), np.zeros((0,3))
        return np.zeros((0,2)), np.zeros((0,3))
        return np.zeros((0,2)), np.zeros((0,3))
        return np.zeros((0,2)), np.zeros((0,3))
        return np.zeros((0,2)), np.zeros((0,3))
        return np.zeros((0,2)), np.zeros((0,3))
        return np.zeros((0,2)), np.zeros((0,3))
        return np.zeros((0,2)), np.zeros((0,3))
        return np.zeros((0,2)), np.zeros((0,3))
        return np.zeros((0,2)), np.zeros((0,3))
        return np.zeros((0,2)), np.zeros((0,3))
    return np.vstack(centers2d), np.vstack(centers3d)
    return np.vstack(centers2d), np.vstack(centers3d)
    return np.vstack(centers2d), np.vstack(centers3d)
    return np.vstack(centers2d), np.vstack(centers3d)
    return np.vstack(centers2d), np.vstack(centers3d)
    return np.vstack(centers2d), np.vstack(centers3d)
    return np.vstack(centers2d), np.vstack(centers3d)
    return np.vstack(centers2d), np.vstack(centers3d)
    return np.vstack(centers2d), np.vstack(centers3d)
    return np.vstack(centers2d), np.vstack(centers3d)
    return np.vstack(centers2d), np.vstack(centers3d)
    return np.vstack(centers2d), np.vstack(centers3d)
    return np.vstack(centers2d), np.vstack(centers3d)
    return np.vstack(centers2d), np.vstack(centers3d)
    return np.vstack(centers2d), np.vstack(centers3d)
    return np.vstack(centers2d), np.vstack(centers3d)
    return np.vstack(centers2d), np.vstack(centers3d)
    return np.vstack(centers2d), np.vstack(centers3d)
    return np.vstack(centers2d), np.vstack(centers3d)
    return np.vstack(centers2d), np.vstack(centers3d)
    return np.vstack(centers2d), np.vstack(centers3d)
    return np.vstack(centers2d), np.vstack(centers3d)
    return np.vstack(centers2d), np.vstack(centers3d)
    return np.vstack(centers2d), np.vstack(centers3d)
    return np.vstack(centers2d), np.vstack(centers3d)
    return np.vstack(centers2d), np.vstack(centers3d)
    return np.vstack(centers2d), np.vstack(centers3d)
    return np.vstack(centers2d), np.vstack(centers3d)
    return np.vstack(centers2d), np.vstack(centers3d)
    return np.vstack(centers2d), np.vstack(centers3d)
    return np.vstack(centers2d), np.vstack(centers3d)
    return np.vstack(centers2d), np.vstack(centers3d)
    return np.vstack(centers2d), np.vstack(centers3d)
    return np.vstack(centers2d), np.vstack(centers3d)
    return np.vstack(centers2d), np.vstack(centers3d)
    return np.vstack(centers2d), np.vstack(centers3d)
    return np.vstack(centers2d), np.vstack(centers3d)

# %% [markdown]
# ### ---------- Per-point distance to curve within a slice ----------
# ### ---------- Per-point distance to curve within a slice ----------
# ### ---------- Per-point distance to curve within a slice ----------
# ### ---------- Per-point distance to curve within a slice ----------
# ### ---------- Per-point distance to curve within a slice ----------
# ### ---------- Per-point distance to curve within a slice ----------
# ### ---------- Per-point distance to curve within a slice ----------
# ### ---------- Per-point distance to curve within a slice ----------
# ### ---------- Per-point distance to curve within a slice ----------
# ### ---------- Per-point distance to curve within a slice ----------
# ### ---------- Per-point distance to curve within a slice ----------
# ### ---------- Per-point distance to curve within a slice ----------
# ### ---------- Per-point distance to curve within a slice ----------
# ### ---------- Per-point distance to curve within a slice ----------
# ### ---------- Per-point distance to curve within a slice ----------
# ### ---------- Per-point distance to curve within a slice ----------
# ### ---------- Per-point distance to curve within a slice ----------
# ### ---------- Per-point distance to curve within a slice ----------
# ### ---------- Per-point distance to curve within a slice ----------
# ### ---------- Per-point distance to curve within a slice ----------
# ### ---------- Per-point distance to curve within a slice ----------
# ### ---------- Per-point distance to curve within a slice ----------
# ### ---------- Per-point distance to curve within a slice ----------
# ### ---------- Per-point distance to curve within a slice ----------
# ### ---------- Per-point distance to curve within a slice ----------
# ### ---------- Per-point distance to curve within a slice ----------
# ### ---------- Per-point distance to curve within a slice ----------
# ### ---------- Per-point distance to curve within a slice ----------
# ### ---------- Per-point distance to curve within a slice ----------
# ### ---------- Per-point distance to curve within a slice ----------
# ### ---------- Per-point distance to curve within a slice ----------
# ### ---------- Per-point distance to curve within a slice ----------
# ### ---------- Per-point distance to curve within a slice ----------
# ### ---------- Per-point distance to curve within a slice ----------
# ### ---------- Per-point distance to curve within a slice ----------
# ### ---------- Per-point distance to curve within a slice ----------
# ### ---------- Per-point distance to curve within a slice ----------

# %%
def distances_to_curve(coords2d, curve2d_samples):
def distances_to_curve(coords2d, curve2d_samples):
def distances_to_curve(coords2d, curve2d_samples):
def distances_to_curve(coords2d, curve2d_samples):
def distances_to_curve(coords2d, curve2d_samples):
def distances_to_curve(coords2d, curve2d_samples):
def distances_to_curve(coords2d, curve2d_samples):
def distances_to_curve(coords2d, curve2d_samples):
def distances_to_curve(coords2d, curve2d_samples):
def distances_to_curve(coords2d, curve2d_samples):
def distances_to_curve(coords2d, curve2d_samples):
def distances_to_curve(coords2d, curve2d_samples):
def distances_to_curve(coords2d, curve2d_samples):
def distances_to_curve(coords2d, curve2d_samples):
def distances_to_curve(coords2d, curve2d_samples):
def distances_to_curve(coords2d, curve2d_samples):
def distances_to_curve(coords2d, curve2d_samples):
def distances_to_curve(coords2d, curve2d_samples):
def distances_to_curve(coords2d, curve2d_samples):
def distances_to_curve(coords2d, curve2d_samples):
def distances_to_curve(coords2d, curve2d_samples):
def distances_to_curve(coords2d, curve2d_samples):
def distances_to_curve(coords2d, curve2d_samples):
def distances_to_curve(coords2d, curve2d_samples):
def distances_to_curve(coords2d, curve2d_samples):
def distances_to_curve(coords2d, curve2d_samples):
def distances_to_curve(coords2d, curve2d_samples):
def distances_to_curve(coords2d, curve2d_samples):
def distances_to_curve(coords2d, curve2d_samples):
def distances_to_curve(coords2d, curve2d_samples):
def distances_to_curve(coords2d, curve2d_samples):
def distances_to_curve(coords2d, curve2d_samples):
def distances_to_curve(coords2d, curve2d_samples):
def distances_to_curve(coords2d, curve2d_samples):
def distances_to_curve(coords2d, curve2d_samples):
def distances_to_curve(coords2d, curve2d_samples):
def distances_to_curve(coords2d, curve2d_samples):
    if len(coords2d)==0 or curve2d_samples is None or len(curve2d_samples)==0:
    if len(coords2d)==0 or curve2d_samples is None or len(curve2d_samples)==0:
    if len(coords2d)==0 or curve2d_samples is None or len(curve2d_samples)==0:
    if len(coords2d)==0 or curve2d_samples is None or len(curve2d_samples)==0:
    if len(coords2d)==0 or curve2d_samples is None or len(curve2d_samples)==0:
    if len(coords2d)==0 or curve2d_samples is None or len(curve2d_samples)==0:
    if len(coords2d)==0 or curve2d_samples is None or len(curve2d_samples)==0:
    if len(coords2d)==0 or curve2d_samples is None or len(curve2d_samples)==0:
    if len(coords2d)==0 or curve2d_samples is None or len(curve2d_samples)==0:
    if len(coords2d)==0 or curve2d_samples is None or len(curve2d_samples)==0:
    if len(coords2d)==0 or curve2d_samples is None or len(curve2d_samples)==0:
    if len(coords2d)==0 or curve2d_samples is None or len(curve2d_samples)==0:
    if len(coords2d)==0 or curve2d_samples is None or len(curve2d_samples)==0:
    if len(coords2d)==0 or curve2d_samples is None or len(curve2d_samples)==0:
    if len(coords2d)==0 or curve2d_samples is None or len(curve2d_samples)==0:
    if len(coords2d)==0 or curve2d_samples is None or len(curve2d_samples)==0:
    if len(coords2d)==0 or curve2d_samples is None or len(curve2d_samples)==0:
    if len(coords2d)==0 or curve2d_samples is None or len(curve2d_samples)==0:
    if len(coords2d)==0 or curve2d_samples is None or len(curve2d_samples)==0:
    if len(coords2d)==0 or curve2d_samples is None or len(curve2d_samples)==0:
    if len(coords2d)==0 or curve2d_samples is None or len(curve2d_samples)==0:
    if len(coords2d)==0 or curve2d_samples is None or len(curve2d_samples)==0:
    if len(coords2d)==0 or curve2d_samples is None or len(curve2d_samples)==0:
    if len(coords2d)==0 or curve2d_samples is None or len(curve2d_samples)==0:
    if len(coords2d)==0 or curve2d_samples is None or len(curve2d_samples)==0:
    if len(coords2d)==0 or curve2d_samples is None or len(curve2d_samples)==0:
    if len(coords2d)==0 or curve2d_samples is None or len(curve2d_samples)==0:
    if len(coords2d)==0 or curve2d_samples is None or len(curve2d_samples)==0:
    if len(coords2d)==0 or curve2d_samples is None or len(curve2d_samples)==0:
    if len(coords2d)==0 or curve2d_samples is None or len(curve2d_samples)==0:
    if len(coords2d)==0 or curve2d_samples is None or len(curve2d_samples)==0:
    if len(coords2d)==0 or curve2d_samples is None or len(curve2d_samples)==0:
    if len(coords2d)==0 or curve2d_samples is None or len(curve2d_samples)==0:
    if len(coords2d)==0 or curve2d_samples is None or len(curve2d_samples)==0:
    if len(coords2d)==0 or curve2d_samples is None or len(curve2d_samples)==0:
    if len(coords2d)==0 or curve2d_samples is None or len(curve2d_samples)==0:
    if len(coords2d)==0 or curve2d_samples is None or len(curve2d_samples)==0:
        return np.array([])
        return np.array([])
        return np.array([])
        return np.array([])
        return np.array([])
        return np.array([])
        return np.array([])
        return np.array([])
        return np.array([])
        return np.array([])
        return np.array([])
        return np.array([])
        return np.array([])
        return np.array([])
        return np.array([])
        return np.array([])
        return np.array([])
        return np.array([])
        return np.array([])
        return np.array([])
        return np.array([])
        return np.array([])
        return np.array([])
        return np.array([])
        return np.array([])
        return np.array([])
        return np.array([])
        return np.array([])
        return np.array([])
        return np.array([])
        return np.array([])
        return np.array([])
        return np.array([])
        return np.array([])
        return np.array([])
        return np.array([])
        return np.array([])
    tree = KDTree(curve2d_samples)
    tree = KDTree(curve2d_samples)
    tree = KDTree(curve2d_samples)
    tree = KDTree(curve2d_samples)
    tree = KDTree(curve2d_samples)
    tree = KDTree(curve2d_samples)
    tree = KDTree(curve2d_samples)
    tree = KDTree(curve2d_samples)
    tree = KDTree(curve2d_samples)
    tree = KDTree(curve2d_samples)
    tree = KDTree(curve2d_samples)
    tree = KDTree(curve2d_samples)
    tree = KDTree(curve2d_samples)
    tree = KDTree(curve2d_samples)
    tree = KDTree(curve2d_samples)
    tree = KDTree(curve2d_samples)
    tree = KDTree(curve2d_samples)
    tree = KDTree(curve2d_samples)
    tree = KDTree(curve2d_samples)
    tree = KDTree(curve2d_samples)
    tree = KDTree(curve2d_samples)
    tree = KDTree(curve2d_samples)
    tree = KDTree(curve2d_samples)
    tree = KDTree(curve2d_samples)
    tree = KDTree(curve2d_samples)
    tree = KDTree(curve2d_samples)
    tree = KDTree(curve2d_samples)
    tree = KDTree(curve2d_samples)
    tree = KDTree(curve2d_samples)
    tree = KDTree(curve2d_samples)
    tree = KDTree(curve2d_samples)
    tree = KDTree(curve2d_samples)
    tree = KDTree(curve2d_samples)
    tree = KDTree(curve2d_samples)
    tree = KDTree(curve2d_samples)
    tree = KDTree(curve2d_samples)
    tree = KDTree(curve2d_samples)
    dists, _ = tree.query(coords2d, k=1)
    dists, _ = tree.query(coords2d, k=1)
    dists, _ = tree.query(coords2d, k=1)
    dists, _ = tree.query(coords2d, k=1)
    dists, _ = tree.query(coords2d, k=1)
    dists, _ = tree.query(coords2d, k=1)
    dists, _ = tree.query(coords2d, k=1)
    dists, _ = tree.query(coords2d, k=1)
    dists, _ = tree.query(coords2d, k=1)
    dists, _ = tree.query(coords2d, k=1)
    dists, _ = tree.query(coords2d, k=1)
    dists, _ = tree.query(coords2d, k=1)
    dists, _ = tree.query(coords2d, k=1)
    dists, _ = tree.query(coords2d, k=1)
    dists, _ = tree.query(coords2d, k=1)
    dists, _ = tree.query(coords2d, k=1)
    dists, _ = tree.query(coords2d, k=1)
    dists, _ = tree.query(coords2d, k=1)
    dists, _ = tree.query(coords2d, k=1)
    dists, _ = tree.query(coords2d, k=1)
    dists, _ = tree.query(coords2d, k=1)
    dists, _ = tree.query(coords2d, k=1)
    dists, _ = tree.query(coords2d, k=1)
    dists, _ = tree.query(coords2d, k=1)
    dists, _ = tree.query(coords2d, k=1)
    dists, _ = tree.query(coords2d, k=1)
    dists, _ = tree.query(coords2d, k=1)
    dists, _ = tree.query(coords2d, k=1)
    dists, _ = tree.query(coords2d, k=1)
    dists, _ = tree.query(coords2d, k=1)
    dists, _ = tree.query(coords2d, k=1)
    dists, _ = tree.query(coords2d, k=1)
    dists, _ = tree.query(coords2d, k=1)
    dists, _ = tree.query(coords2d, k=1)
    dists, _ = tree.query(coords2d, k=1)
    dists, _ = tree.query(coords2d, k=1)
    dists, _ = tree.query(coords2d, k=1)
    return dists.flatten()    return dists.flatten()    return dists.flatten()    return dists.flatten()    return dists.flatten()    return dists.flatten()    return dists.flatten()    return dists.flatten()    return dists.flatten()    return dists.flatten()    return dists.flatten()    return dists.flatten()    return dists.flatten()    return dists.flatten()    return dists.flatten()    return dists.flatten()    return dists.flatten()    return dists.flatten()    return dists.flatten()    return dists.flatten()    return dists.flatten()    return dists.flatten()    return dists.flatten()    return dists.flatten()    return dists.flatten()    return dists.flatten()    return dists.flatten()    return dists.flatten()    return dists.flatten()    return dists.flatten()    return dists.flatten()    return dists.flatten()    return dists.flatten()    return dists.flatten()    return dists.flatten()    return dists.flatten()    return dists.flatten()

# %% [markdown]
# ## ---------- Adaptive slicing (generate slice list: (indices, mid_plane)) ----------
# ## ---------- Adaptive slicing (generate slice list: (indices, mid_plane)) ----------
# ## ---------- Adaptive slicing (generate slice list: (indices, mid_plane)) ----------
# ## ---------- Adaptive slicing (generate slice list: (indices, mid_plane)) ----------
# ## ---------- Adaptive slicing (generate slice list: (indices, mid_plane)) ----------
# ## ---------- Adaptive slicing (generate slice list: (indices, mid_plane)) ----------
# ## ---------- Adaptive slicing (generate slice list: (indices, mid_plane)) ----------
# ## ---------- Adaptive slicing (generate slice list: (indices, mid_plane)) ----------
# ## ---------- Adaptive slicing (generate slice list: (indices, mid_plane)) ----------
# ## ---------- Adaptive slicing (generate slice list: (indices, mid_plane)) ----------
# ## ---------- Adaptive slicing (generate slice list: (indices, mid_plane)) ----------
# ## ---------- Adaptive slicing (generate slice list: (indices, mid_plane)) ----------
# ## ---------- Adaptive slicing (generate slice list: (indices, mid_plane)) ----------
# ## ---------- Adaptive slicing (generate slice list: (indices, mid_plane)) ----------
# ## ---------- Adaptive slicing (generate slice list: (indices, mid_plane)) ----------
# ## ---------- Adaptive slicing (generate slice list: (indices, mid_plane)) ----------
# ## ---------- Adaptive slicing (generate slice list: (indices, mid_plane)) ----------
# ## ---------- Adaptive slicing (generate slice list: (indices, mid_plane)) ----------
# ## ---------- Adaptive slicing (generate slice list: (indices, mid_plane)) ----------
# ## ---------- Adaptive slicing (generate slice list: (indices, mid_plane)) ----------
# ## ---------- Adaptive slicing (generate slice list: (indices, mid_plane)) ----------
# ## ---------- Adaptive slicing (generate slice list: (indices, mid_plane)) ----------
# ## ---------- Adaptive slicing (generate slice list: (indices, mid_plane)) ----------
# ## ---------- Adaptive slicing (generate slice list: (indices, mid_plane)) ----------
# ## ---------- Adaptive slicing (generate slice list: (indices, mid_plane)) ----------
# ## ---------- Adaptive slicing (generate slice list: (indices, mid_plane)) ----------
# ## ---------- Adaptive slicing (generate slice list: (indices, mid_plane)) ----------
# ## ---------- Adaptive slicing (generate slice list: (indices, mid_plane)) ----------
# ## ---------- Adaptive slicing (generate slice list: (indices, mid_plane)) ----------
# ## ---------- Adaptive slicing (generate slice list: (indices, mid_plane)) ----------
# ## ---------- Adaptive slicing (generate slice list: (indices, mid_plane)) ----------
# ## ---------- Adaptive slicing (generate slice list: (indices, mid_plane)) ----------
# ## ---------- Adaptive slicing (generate slice list: (indices, mid_plane)) ----------
# ## ---------- Adaptive slicing (generate slice list: (indices, mid_plane)) ----------
# ## ---------- Adaptive slicing (generate slice list: (indices, mid_plane)) ----------
# ## ---------- Adaptive slicing (generate slice list: (indices, mid_plane)) ----------
# ## ---------- Adaptive slicing (generate slice list: (indices, mid_plane)) ----------

# %%
def adaptive_slicing_indices(pts, axis=2, t_init=INITIAL_LAYER_THICKNESS, tmin=TMIN, tmax=TMAX, s_tol=SHAPE_ERROR_TOL):
def adaptive_slicing_indices(pts, axis=2, t_init=INITIAL_LAYER_THICKNESS, tmin=TMIN, tmax=TMAX, s_tol=SHAPE_ERROR_TOL):
def adaptive_slicing_indices(pts, axis=2, t_init=INITIAL_LAYER_THICKNESS, tmin=TMIN, tmax=TMAX, s_tol=SHAPE_ERROR_TOL):
def adaptive_slicing_indices(pts, axis=2, t_init=INITIAL_LAYER_THICKNESS, tmin=TMIN, tmax=TMAX, s_tol=SHAPE_ERROR_TOL):
def adaptive_slicing_indices(pts, axis=2, t_init=INITIAL_LAYER_THICKNESS, tmin=TMIN, tmax=TMAX, s_tol=SHAPE_ERROR_TOL):
def adaptive_slicing_indices(pts, axis=2, t_init=INITIAL_LAYER_THICKNESS, tmin=TMIN, tmax=TMAX, s_tol=SHAPE_ERROR_TOL):
def adaptive_slicing_indices(pts, axis=2, t_init=INITIAL_LAYER_THICKNESS, tmin=TMIN, tmax=TMAX, s_tol=SHAPE_ERROR_TOL):
def adaptive_slicing_indices(pts, axis=2, t_init=INITIAL_LAYER_THICKNESS, tmin=TMIN, tmax=TMAX, s_tol=SHAPE_ERROR_TOL):
def adaptive_slicing_indices(pts, axis=2, t_init=INITIAL_LAYER_THICKNESS, tmin=TMIN, tmax=TMAX, s_tol=SHAPE_ERROR_TOL):
def adaptive_slicing_indices(pts, axis=2, t_init=INITIAL_LAYER_THICKNESS, tmin=TMIN, tmax=TMAX, s_tol=SHAPE_ERROR_TOL):
def adaptive_slicing_indices(pts, axis=2, t_init=INITIAL_LAYER_THICKNESS, tmin=TMIN, tmax=TMAX, s_tol=SHAPE_ERROR_TOL):
def adaptive_slicing_indices(pts, axis=2, t_init=INITIAL_LAYER_THICKNESS, tmin=TMIN, tmax=TMAX, s_tol=SHAPE_ERROR_TOL):
def adaptive_slicing_indices(pts, axis=2, t_init=INITIAL_LAYER_THICKNESS, tmin=TMIN, tmax=TMAX, s_tol=SHAPE_ERROR_TOL):
def adaptive_slicing_indices(pts, axis=2, t_init=INITIAL_LAYER_THICKNESS, tmin=TMIN, tmax=TMAX, s_tol=SHAPE_ERROR_TOL):
def adaptive_slicing_indices(pts, axis=2, t_init=INITIAL_LAYER_THICKNESS, tmin=TMIN, tmax=TMAX, s_tol=SHAPE_ERROR_TOL):
def adaptive_slicing_indices(pts, axis=2, t_init=INITIAL_LAYER_THICKNESS, tmin=TMIN, tmax=TMAX, s_tol=SHAPE_ERROR_TOL):
def adaptive_slicing_indices(pts, axis=2, t_init=INITIAL_LAYER_THICKNESS, tmin=TMIN, tmax=TMAX, s_tol=SHAPE_ERROR_TOL):
def adaptive_slicing_indices(pts, axis=2, t_init=INITIAL_LAYER_THICKNESS, tmin=TMIN, tmax=TMAX, s_tol=SHAPE_ERROR_TOL):
def adaptive_slicing_indices(pts, axis=2, t_init=INITIAL_LAYER_THICKNESS, tmin=TMIN, tmax=TMAX, s_tol=SHAPE_ERROR_TOL):
def adaptive_slicing_indices(pts, axis=2, t_init=INITIAL_LAYER_THICKNESS, tmin=TMIN, tmax=TMAX, s_tol=SHAPE_ERROR_TOL):
def adaptive_slicing_indices(pts, axis=2, t_init=INITIAL_LAYER_THICKNESS, tmin=TMIN, tmax=TMAX, s_tol=SHAPE_ERROR_TOL):
def adaptive_slicing_indices(pts, axis=2, t_init=INITIAL_LAYER_THICKNESS, tmin=TMIN, tmax=TMAX, s_tol=SHAPE_ERROR_TOL):
def adaptive_slicing_indices(pts, axis=2, t_init=INITIAL_LAYER_THICKNESS, tmin=TMIN, tmax=TMAX, s_tol=SHAPE_ERROR_TOL):
def adaptive_slicing_indices(pts, axis=2, t_init=INITIAL_LAYER_THICKNESS, tmin=TMIN, tmax=TMAX, s_tol=SHAPE_ERROR_TOL):
def adaptive_slicing_indices(pts, axis=2, t_init=INITIAL_LAYER_THICKNESS, tmin=TMIN, tmax=TMAX, s_tol=SHAPE_ERROR_TOL):
def adaptive_slicing_indices(pts, axis=2, t_init=INITIAL_LAYER_THICKNESS, tmin=TMIN, tmax=TMAX, s_tol=SHAPE_ERROR_TOL):
def adaptive_slicing_indices(pts, axis=2, t_init=INITIAL_LAYER_THICKNESS, tmin=TMIN, tmax=TMAX, s_tol=SHAPE_ERROR_TOL):
def adaptive_slicing_indices(pts, axis=2, t_init=INITIAL_LAYER_THICKNESS, tmin=TMIN, tmax=TMAX, s_tol=SHAPE_ERROR_TOL):
def adaptive_slicing_indices(pts, axis=2, t_init=INITIAL_LAYER_THICKNESS, tmin=TMIN, tmax=TMAX, s_tol=SHAPE_ERROR_TOL):
def adaptive_slicing_indices(pts, axis=2, t_init=INITIAL_LAYER_THICKNESS, tmin=TMIN, tmax=TMAX, s_tol=SHAPE_ERROR_TOL):
def adaptive_slicing_indices(pts, axis=2, t_init=INITIAL_LAYER_THICKNESS, tmin=TMIN, tmax=TMAX, s_tol=SHAPE_ERROR_TOL):
def adaptive_slicing_indices(pts, axis=2, t_init=INITIAL_LAYER_THICKNESS, tmin=TMIN, tmax=TMAX, s_tol=SHAPE_ERROR_TOL):
def adaptive_slicing_indices(pts, axis=2, t_init=INITIAL_LAYER_THICKNESS, tmin=TMIN, tmax=TMAX, s_tol=SHAPE_ERROR_TOL):
def adaptive_slicing_indices(pts, axis=2, t_init=INITIAL_LAYER_THICKNESS, tmin=TMIN, tmax=TMAX, s_tol=SHAPE_ERROR_TOL):
def adaptive_slicing_indices(pts, axis=2, t_init=INITIAL_LAYER_THICKNESS, tmin=TMIN, tmax=TMAX, s_tol=SHAPE_ERROR_TOL):
def adaptive_slicing_indices(pts, axis=2, t_init=INITIAL_LAYER_THICKNESS, tmin=TMIN, tmax=TMAX, s_tol=SHAPE_ERROR_TOL):
def adaptive_slicing_indices(pts, axis=2, t_init=INITIAL_LAYER_THICKNESS, tmin=TMIN, tmax=TMAX, s_tol=SHAPE_ERROR_TOL):
    coords_axis = pts[:, axis]
    coords_axis = pts[:, axis]
    coords_axis = pts[:, axis]
    coords_axis = pts[:, axis]
    coords_axis = pts[:, axis]
    coords_axis = pts[:, axis]
    coords_axis = pts[:, axis]
    coords_axis = pts[:, axis]
    coords_axis = pts[:, axis]
    coords_axis = pts[:, axis]
    coords_axis = pts[:, axis]
    coords_axis = pts[:, axis]
    coords_axis = pts[:, axis]
    coords_axis = pts[:, axis]
    coords_axis = pts[:, axis]
    coords_axis = pts[:, axis]
    coords_axis = pts[:, axis]
    coords_axis = pts[:, axis]
    coords_axis = pts[:, axis]
    coords_axis = pts[:, axis]
    coords_axis = pts[:, axis]
    coords_axis = pts[:, axis]
    coords_axis = pts[:, axis]
    coords_axis = pts[:, axis]
    coords_axis = pts[:, axis]
    coords_axis = pts[:, axis]
    coords_axis = pts[:, axis]
    coords_axis = pts[:, axis]
    coords_axis = pts[:, axis]
    coords_axis = pts[:, axis]
    coords_axis = pts[:, axis]
    coords_axis = pts[:, axis]
    coords_axis = pts[:, axis]
    coords_axis = pts[:, axis]
    coords_axis = pts[:, axis]
    coords_axis = pts[:, axis]
    coords_axis = pts[:, axis]
    zmin, zmax = coords_axis.min(), coords_axis.max()
    zmin, zmax = coords_axis.min(), coords_axis.max()
    zmin, zmax = coords_axis.min(), coords_axis.max()
    zmin, zmax = coords_axis.min(), coords_axis.max()
    zmin, zmax = coords_axis.min(), coords_axis.max()
    zmin, zmax = coords_axis.min(), coords_axis.max()
    zmin, zmax = coords_axis.min(), coords_axis.max()
    zmin, zmax = coords_axis.min(), coords_axis.max()
    zmin, zmax = coords_axis.min(), coords_axis.max()
    zmin, zmax = coords_axis.min(), coords_axis.max()
    zmin, zmax = coords_axis.min(), coords_axis.max()
    zmin, zmax = coords_axis.min(), coords_axis.max()
    zmin, zmax = coords_axis.min(), coords_axis.max()
    zmin, zmax = coords_axis.min(), coords_axis.max()
    zmin, zmax = coords_axis.min(), coords_axis.max()
    zmin, zmax = coords_axis.min(), coords_axis.max()
    zmin, zmax = coords_axis.min(), coords_axis.max()
    zmin, zmax = coords_axis.min(), coords_axis.max()
    zmin, zmax = coords_axis.min(), coords_axis.max()
    zmin, zmax = coords_axis.min(), coords_axis.max()
    zmin, zmax = coords_axis.min(), coords_axis.max()
    zmin, zmax = coords_axis.min(), coords_axis.max()
    zmin, zmax = coords_axis.min(), coords_axis.max()
    zmin, zmax = coords_axis.min(), coords_axis.max()
    zmin, zmax = coords_axis.min(), coords_axis.max()
    zmin, zmax = coords_axis.min(), coords_axis.max()
    zmin, zmax = coords_axis.min(), coords_axis.max()
    zmin, zmax = coords_axis.min(), coords_axis.max()
    zmin, zmax = coords_axis.min(), coords_axis.max()
    zmin, zmax = coords_axis.min(), coords_axis.max()
    zmin, zmax = coords_axis.min(), coords_axis.max()
    zmin, zmax = coords_axis.min(), coords_axis.max()
    zmin, zmax = coords_axis.min(), coords_axis.max()
    zmin, zmax = coords_axis.min(), coords_axis.max()
    zmin, zmax = coords_axis.min(), coords_axis.max()
    zmin, zmax = coords_axis.min(), coords_axis.max()
    zmin, zmax = coords_axis.min(), coords_axis.max()
    z = zmin
    z = zmin
    z = zmin
    z = zmin
    z = zmin
    z = zmin
    z = zmin
    z = zmin
    z = zmin
    z = zmin
    z = zmin
    z = zmin
    z = zmin
    z = zmin
    z = zmin
    z = zmin
    z = zmin
    z = zmin
    z = zmin
    z = zmin
    z = zmin
    z = zmin
    z = zmin
    z = zmin
    z = zmin
    z = zmin
    z = zmin
    z = zmin
    z = zmin
    z = zmin
    z = zmin
    z = zmin
    z = zmin
    z = zmin
    z = zmin
    z = zmin
    z = zmin
    slices = []
    slices = []
    slices = []
    slices = []
    slices = []
    slices = []
    slices = []
    slices = []
    slices = []
    slices = []
    slices = []
    slices = []
    slices = []
    slices = []
    slices = []
    slices = []
    slices = []
    slices = []
    slices = []
    slices = []
    slices = []
    slices = []
    slices = []
    slices = []
    slices = []
    slices = []
    slices = []
    slices = []
    slices = []
    slices = []
    slices = []
    slices = []
    slices = []
    slices = []
    slices = []
    slices = []
    slices = []
    while z < zmax - 1e-9:
    while z < zmax - 1e-9:
    while z < zmax - 1e-9:
    while z < zmax - 1e-9:
    while z < zmax - 1e-9:
    while z < zmax - 1e-9:
    while z < zmax - 1e-9:
    while z < zmax - 1e-9:
    while z < zmax - 1e-9:
    while z < zmax - 1e-9:
    while z < zmax - 1e-9:
    while z < zmax - 1e-9:
    while z < zmax - 1e-9:
    while z < zmax - 1e-9:
    while z < zmax - 1e-9:
    while z < zmax - 1e-9:
    while z < zmax - 1e-9:
    while z < zmax - 1e-9:
    while z < zmax - 1e-9:
    while z < zmax - 1e-9:
    while z < zmax - 1e-9:
    while z < zmax - 1e-9:
    while z < zmax - 1e-9:
    while z < zmax - 1e-9:
    while z < zmax - 1e-9:
    while z < zmax - 1e-9:
    while z < zmax - 1e-9:
    while z < zmax - 1e-9:
    while z < zmax - 1e-9:
    while z < zmax - 1e-9:
    while z < zmax - 1e-9:
    while z < zmax - 1e-9:
    while z < zmax - 1e-9:
    while z < zmax - 1e-9:
    while z < zmax - 1e-9:
    while z < zmax - 1e-9:
    while z < zmax - 1e-9:
        t = t_init; iters = 0
        t = t_init; iters = 0
        t = t_init; iters = 0
        t = t_init; iters = 0
        t = t_init; iters = 0
        t = t_init; iters = 0
        t = t_init; iters = 0
        t = t_init; iters = 0
        t = t_init; iters = 0
        t = t_init; iters = 0
        t = t_init; iters = 0
        t = t_init; iters = 0
        t = t_init; iters = 0
        t = t_init; iters = 0
        t = t_init; iters = 0
        t = t_init; iters = 0
        t = t_init; iters = 0
        t = t_init; iters = 0
        t = t_init; iters = 0
        t = t_init; iters = 0
        t = t_init; iters = 0
        t = t_init; iters = 0
        t = t_init; iters = 0
        t = t_init; iters = 0
        t = t_init; iters = 0
        t = t_init; iters = 0
        t = t_init; iters = 0
        t = t_init; iters = 0
        t = t_init; iters = 0
        t = t_init; iters = 0
        t = t_init; iters = 0
        t = t_init; iters = 0
        t = t_init; iters = 0
        t = t_init; iters = 0
        t = t_init; iters = 0
        t = t_init; iters = 0
        t = t_init; iters = 0
        while True:
        while True:
        while True:
        while True:
        while True:
        while True:
        while True:
        while True:
        while True:
        while True:
        while True:
        while True:
        while True:
        while True:
        while True:
        while True:
        while True:
        while True:
        while True:
        while True:
        while True:
        while True:
        while True:
        while True:
        while True:
        while True:
        while True:
        while True:
        while True:
        while True:
        while True:
        while True:
        while True:
        while True:
        while True:
        while True:
        while True:
            z_low = z
            z_low = z
            z_low = z
            z_low = z
            z_low = z
            z_low = z
            z_low = z
            z_low = z
            z_low = z
            z_low = z
            z_low = z
            z_low = z
            z_low = z
            z_low = z
            z_low = z
            z_low = z
            z_low = z
            z_low = z
            z_low = z
            z_low = z
            z_low = z
            z_low = z
            z_low = z
            z_low = z
            z_low = z
            z_low = z
            z_low = z
            z_low = z
            z_low = z
            z_low = z
            z_low = z
            z_low = z
            z_low = z
            z_low = z
            z_low = z
            z_low = z
            z_low = z
            z_hi = min(z + t, zmax)
            z_hi = min(z + t, zmax)
            z_hi = min(z + t, zmax)
            z_hi = min(z + t, zmax)
            z_hi = min(z + t, zmax)
            z_hi = min(z + t, zmax)
            z_hi = min(z + t, zmax)
            z_hi = min(z + t, zmax)
            z_hi = min(z + t, zmax)
            z_hi = min(z + t, zmax)
            z_hi = min(z + t, zmax)
            z_hi = min(z + t, zmax)
            z_hi = min(z + t, zmax)
            z_hi = min(z + t, zmax)
            z_hi = min(z + t, zmax)
            z_hi = min(z + t, zmax)
            z_hi = min(z + t, zmax)
            z_hi = min(z + t, zmax)
            z_hi = min(z + t, zmax)
            z_hi = min(z + t, zmax)
            z_hi = min(z + t, zmax)
            z_hi = min(z + t, zmax)
            z_hi = min(z + t, zmax)
            z_hi = min(z + t, zmax)
            z_hi = min(z + t, zmax)
            z_hi = min(z + t, zmax)
            z_hi = min(z + t, zmax)
            z_hi = min(z + t, zmax)
            z_hi = min(z + t, zmax)
            z_hi = min(z + t, zmax)
            z_hi = min(z + t, zmax)
            z_hi = min(z + t, zmax)
            z_hi = min(z + t, zmax)
            z_hi = min(z + t, zmax)
            z_hi = min(z + t, zmax)
            z_hi = min(z + t, zmax)
            z_hi = min(z + t, zmax)
            mask = (coords_axis >= z_low - 1e-12) & (coords_axis <= z_hi + 1e-12)
            mask = (coords_axis >= z_low - 1e-12) & (coords_axis <= z_hi + 1e-12)
            mask = (coords_axis >= z_low - 1e-12) & (coords_axis <= z_hi + 1e-12)
            mask = (coords_axis >= z_low - 1e-12) & (coords_axis <= z_hi + 1e-12)
            mask = (coords_axis >= z_low - 1e-12) & (coords_axis <= z_hi + 1e-12)
            mask = (coords_axis >= z_low - 1e-12) & (coords_axis <= z_hi + 1e-12)
            mask = (coords_axis >= z_low - 1e-12) & (coords_axis <= z_hi + 1e-12)
            mask = (coords_axis >= z_low - 1e-12) & (coords_axis <= z_hi + 1e-12)
            mask = (coords_axis >= z_low - 1e-12) & (coords_axis <= z_hi + 1e-12)
            mask = (coords_axis >= z_low - 1e-12) & (coords_axis <= z_hi + 1e-12)
            mask = (coords_axis >= z_low - 1e-12) & (coords_axis <= z_hi + 1e-12)
            mask = (coords_axis >= z_low - 1e-12) & (coords_axis <= z_hi + 1e-12)
            mask = (coords_axis >= z_low - 1e-12) & (coords_axis <= z_hi + 1e-12)
            mask = (coords_axis >= z_low - 1e-12) & (coords_axis <= z_hi + 1e-12)
            mask = (coords_axis >= z_low - 1e-12) & (coords_axis <= z_hi + 1e-12)
            mask = (coords_axis >= z_low - 1e-12) & (coords_axis <= z_hi + 1e-12)
            mask = (coords_axis >= z_low - 1e-12) & (coords_axis <= z_hi + 1e-12)
            mask = (coords_axis >= z_low - 1e-12) & (coords_axis <= z_hi + 1e-12)
            mask = (coords_axis >= z_low - 1e-12) & (coords_axis <= z_hi + 1e-12)
            mask = (coords_axis >= z_low - 1e-12) & (coords_axis <= z_hi + 1e-12)
            mask = (coords_axis >= z_low - 1e-12) & (coords_axis <= z_hi + 1e-12)
            mask = (coords_axis >= z_low - 1e-12) & (coords_axis <= z_hi + 1e-12)
            mask = (coords_axis >= z_low - 1e-12) & (coords_axis <= z_hi + 1e-12)
            mask = (coords_axis >= z_low - 1e-12) & (coords_axis <= z_hi + 1e-12)
            mask = (coords_axis >= z_low - 1e-12) & (coords_axis <= z_hi + 1e-12)
            mask = (coords_axis >= z_low - 1e-12) & (coords_axis <= z_hi + 1e-12)
            mask = (coords_axis >= z_low - 1e-12) & (coords_axis <= z_hi + 1e-12)
            mask = (coords_axis >= z_low - 1e-12) & (coords_axis <= z_hi + 1e-12)
            mask = (coords_axis >= z_low - 1e-12) & (coords_axis <= z_hi + 1e-12)
            mask = (coords_axis >= z_low - 1e-12) & (coords_axis <= z_hi + 1e-12)
            mask = (coords_axis >= z_low - 1e-12) & (coords_axis <= z_hi + 1e-12)
            mask = (coords_axis >= z_low - 1e-12) & (coords_axis <= z_hi + 1e-12)
            mask = (coords_axis >= z_low - 1e-12) & (coords_axis <= z_hi + 1e-12)
            mask = (coords_axis >= z_low - 1e-12) & (coords_axis <= z_hi + 1e-12)
            mask = (coords_axis >= z_low - 1e-12) & (coords_axis <= z_hi + 1e-12)
            mask = (coords_axis >= z_low - 1e-12) & (coords_axis <= z_hi + 1e-12)
            mask = (coords_axis >= z_low - 1e-12) & (coords_axis <= z_hi + 1e-12)
            idxs = np.where(mask)[0]
            idxs = np.where(mask)[0]
            idxs = np.where(mask)[0]
            idxs = np.where(mask)[0]
            idxs = np.where(mask)[0]
            idxs = np.where(mask)[0]
            idxs = np.where(mask)[0]
            idxs = np.where(mask)[0]
            idxs = np.where(mask)[0]
            idxs = np.where(mask)[0]
            idxs = np.where(mask)[0]
            idxs = np.where(mask)[0]
            idxs = np.where(mask)[0]
            idxs = np.where(mask)[0]
            idxs = np.where(mask)[0]
            idxs = np.where(mask)[0]
            idxs = np.where(mask)[0]
            idxs = np.where(mask)[0]
            idxs = np.where(mask)[0]
            idxs = np.where(mask)[0]
            idxs = np.where(mask)[0]
            idxs = np.where(mask)[0]
            idxs = np.where(mask)[0]
            idxs = np.where(mask)[0]
            idxs = np.where(mask)[0]
            idxs = np.where(mask)[0]
            idxs = np.where(mask)[0]
            idxs = np.where(mask)[0]
            idxs = np.where(mask)[0]
            idxs = np.where(mask)[0]
            idxs = np.where(mask)[0]
            idxs = np.where(mask)[0]
            idxs = np.where(mask)[0]
            idxs = np.where(mask)[0]
            idxs = np.where(mask)[0]
            idxs = np.where(mask)[0]
            idxs = np.where(mask)[0]
            if idxs.size == 0:
            if idxs.size == 0:
            if idxs.size == 0:
            if idxs.size == 0:
            if idxs.size == 0:
            if idxs.size == 0:
            if idxs.size == 0:
            if idxs.size == 0:
            if idxs.size == 0:
            if idxs.size == 0:
            if idxs.size == 0:
            if idxs.size == 0:
            if idxs.size == 0:
            if idxs.size == 0:
            if idxs.size == 0:
            if idxs.size == 0:
            if idxs.size == 0:
            if idxs.size == 0:
            if idxs.size == 0:
            if idxs.size == 0:
            if idxs.size == 0:
            if idxs.size == 0:
            if idxs.size == 0:
            if idxs.size == 0:
            if idxs.size == 0:
            if idxs.size == 0:
            if idxs.size == 0:
            if idxs.size == 0:
            if idxs.size == 0:
            if idxs.size == 0:
            if idxs.size == 0:
            if idxs.size == 0:
            if idxs.size == 0:
            if idxs.size == 0:
            if idxs.size == 0:
            if idxs.size == 0:
            if idxs.size == 0:
                t = min(t*1.5, tmax); iters += 1
                t = min(t*1.5, tmax); iters += 1
                t = min(t*1.5, tmax); iters += 1
                t = min(t*1.5, tmax); iters += 1
                t = min(t*1.5, tmax); iters += 1
                t = min(t*1.5, tmax); iters += 1
                t = min(t*1.5, tmax); iters += 1
                t = min(t*1.5, tmax); iters += 1
                t = min(t*1.5, tmax); iters += 1
                t = min(t*1.5, tmax); iters += 1
                t = min(t*1.5, tmax); iters += 1
                t = min(t*1.5, tmax); iters += 1
                t = min(t*1.5, tmax); iters += 1
                t = min(t*1.5, tmax); iters += 1
                t = min(t*1.5, tmax); iters += 1
                t = min(t*1.5, tmax); iters += 1
                t = min(t*1.5, tmax); iters += 1
                t = min(t*1.5, tmax); iters += 1
                t = min(t*1.5, tmax); iters += 1
                t = min(t*1.5, tmax); iters += 1
                t = min(t*1.5, tmax); iters += 1
                t = min(t*1.5, tmax); iters += 1
                t = min(t*1.5, tmax); iters += 1
                t = min(t*1.5, tmax); iters += 1
                t = min(t*1.5, tmax); iters += 1
                t = min(t*1.5, tmax); iters += 1
                t = min(t*1.5, tmax); iters += 1
                t = min(t*1.5, tmax); iters += 1
                t = min(t*1.5, tmax); iters += 1
                t = min(t*1.5, tmax); iters += 1
                t = min(t*1.5, tmax); iters += 1
                t = min(t*1.5, tmax); iters += 1
                t = min(t*1.5, tmax); iters += 1
                t = min(t*1.5, tmax); iters += 1
                t = min(t*1.5, tmax); iters += 1
                t = min(t*1.5, tmax); iters += 1
                t = min(t*1.5, tmax); iters += 1
                if iters > MAX_SLICE_ITERS: break
                if iters > MAX_SLICE_ITERS: break
                if iters > MAX_SLICE_ITERS: break
                if iters > MAX_SLICE_ITERS: break
                if iters > MAX_SLICE_ITERS: break
                if iters > MAX_SLICE_ITERS: break
                if iters > MAX_SLICE_ITERS: break
                if iters > MAX_SLICE_ITERS: break
                if iters > MAX_SLICE_ITERS: break
                if iters > MAX_SLICE_ITERS: break
                if iters > MAX_SLICE_ITERS: break
                if iters > MAX_SLICE_ITERS: break
                if iters > MAX_SLICE_ITERS: break
                if iters > MAX_SLICE_ITERS: break
                if iters > MAX_SLICE_ITERS: break
                if iters > MAX_SLICE_ITERS: break
                if iters > MAX_SLICE_ITERS: break
                if iters > MAX_SLICE_ITERS: break
                if iters > MAX_SLICE_ITERS: break
                if iters > MAX_SLICE_ITERS: break
                if iters > MAX_SLICE_ITERS: break
                if iters > MAX_SLICE_ITERS: break
                if iters > MAX_SLICE_ITERS: break
                if iters > MAX_SLICE_ITERS: break
                if iters > MAX_SLICE_ITERS: break
                if iters > MAX_SLICE_ITERS: break
                if iters > MAX_SLICE_ITERS: break
                if iters > MAX_SLICE_ITERS: break
                if iters > MAX_SLICE_ITERS: break
                if iters > MAX_SLICE_ITERS: break
                if iters > MAX_SLICE_ITERS: break
                if iters > MAX_SLICE_ITERS: break
                if iters > MAX_SLICE_ITERS: break
                if iters > MAX_SLICE_ITERS: break
                if iters > MAX_SLICE_ITERS: break
                if iters > MAX_SLICE_ITERS: break
                if iters > MAX_SLICE_ITERS: break
                continue
                continue
                continue
                continue
                continue
                continue
                continue
                continue
                continue
                continue
                continue
                continue
                continue
                continue
                continue
                continue
                continue
                continue
                continue
                continue
                continue
                continue
                continue
                continue
                continue
                continue
                continue
                continue
                continue
                continue
                continue
                continue
                continue
                continue
                continue
                continue
                continue
            mid = 0.5*(z_low + z_hi)
            mid = 0.5*(z_low + z_hi)
            mid = 0.5*(z_low + z_hi)
            mid = 0.5*(z_low + z_hi)
            mid = 0.5*(z_low + z_hi)
            mid = 0.5*(z_low + z_hi)
            mid = 0.5*(z_low + z_hi)
            mid = 0.5*(z_low + z_hi)
            mid = 0.5*(z_low + z_hi)
            mid = 0.5*(z_low + z_hi)
            mid = 0.5*(z_low + z_hi)
            mid = 0.5*(z_low + z_hi)
            mid = 0.5*(z_low + z_hi)
            mid = 0.5*(z_low + z_hi)
            mid = 0.5*(z_low + z_hi)
            mid = 0.5*(z_low + z_hi)
            mid = 0.5*(z_low + z_hi)
            mid = 0.5*(z_low + z_hi)
            mid = 0.5*(z_low + z_hi)
            mid = 0.5*(z_low + z_hi)
            mid = 0.5*(z_low + z_hi)
            mid = 0.5*(z_low + z_hi)
            mid = 0.5*(z_low + z_hi)
            mid = 0.5*(z_low + z_hi)
            mid = 0.5*(z_low + z_hi)
            mid = 0.5*(z_low + z_hi)
            mid = 0.5*(z_low + z_hi)
            mid = 0.5*(z_low + z_hi)
            mid = 0.5*(z_low + z_hi)
            mid = 0.5*(z_low + z_hi)
            mid = 0.5*(z_low + z_hi)
            mid = 0.5*(z_low + z_hi)
            mid = 0.5*(z_low + z_hi)
            mid = 0.5*(z_low + z_hi)
            mid = 0.5*(z_low + z_hi)
            mid = 0.5*(z_low + z_hi)
            mid = 0.5*(z_low + z_hi)
            _, coords2d, *_ = project_to_plane(pts[idxs], axis, mid)
            _, coords2d, *_ = project_to_plane(pts[idxs], axis, mid)
            _, coords2d, *_ = project_to_plane(pts[idxs], axis, mid)
            _, coords2d, *_ = project_to_plane(pts[idxs], axis, mid)
            _, coords2d, *_ = project_to_plane(pts[idxs], axis, mid)
            _, coords2d, *_ = project_to_plane(pts[idxs], axis, mid)
            _, coords2d, *_ = project_to_plane(pts[idxs], axis, mid)
            _, coords2d, *_ = project_to_plane(pts[idxs], axis, mid)
            _, coords2d, *_ = project_to_plane(pts[idxs], axis, mid)
            _, coords2d, *_ = project_to_plane(pts[idxs], axis, mid)
            _, coords2d, *_ = project_to_plane(pts[idxs], axis, mid)
            _, coords2d, *_ = project_to_plane(pts[idxs], axis, mid)
            _, coords2d, *_ = project_to_plane(pts[idxs], axis, mid)
            _, coords2d, *_ = project_to_plane(pts[idxs], axis, mid)
            _, coords2d, *_ = project_to_plane(pts[idxs], axis, mid)
            _, coords2d, *_ = project_to_plane(pts[idxs], axis, mid)
            _, coords2d, *_ = project_to_plane(pts[idxs], axis, mid)
            _, coords2d, *_ = project_to_plane(pts[idxs], axis, mid)
            _, coords2d, *_ = project_to_plane(pts[idxs], axis, mid)
            _, coords2d, *_ = project_to_plane(pts[idxs], axis, mid)
            _, coords2d, *_ = project_to_plane(pts[idxs], axis, mid)
            _, coords2d, *_ = project_to_plane(pts[idxs], axis, mid)
            _, coords2d, *_ = project_to_plane(pts[idxs], axis, mid)
            _, coords2d, *_ = project_to_plane(pts[idxs], axis, mid)
            _, coords2d, *_ = project_to_plane(pts[idxs], axis, mid)
            _, coords2d, *_ = project_to_plane(pts[idxs], axis, mid)
            _, coords2d, *_ = project_to_plane(pts[idxs], axis, mid)
            _, coords2d, *_ = project_to_plane(pts[idxs], axis, mid)
            _, coords2d, *_ = project_to_plane(pts[idxs], axis, mid)
            _, coords2d, *_ = project_to_plane(pts[idxs], axis, mid)
            _, coords2d, *_ = project_to_plane(pts[idxs], axis, mid)
            _, coords2d, *_ = project_to_plane(pts[idxs], axis, mid)
            _, coords2d, *_ = project_to_plane(pts[idxs], axis, mid)
            _, coords2d, *_ = project_to_plane(pts[idxs], axis, mid)
            _, coords2d, *_ = project_to_plane(pts[idxs], axis, mid)
            _, coords2d, *_ = project_to_plane(pts[idxs], axis, mid)
            _, coords2d, *_ = project_to_plane(pts[idxs], axis, mid)
            bw = compute_band_width(coords2d)
            bw = compute_band_width(coords2d)
            bw = compute_band_width(coords2d)
            bw = compute_band_width(coords2d)
            bw = compute_band_width(coords2d)
            bw = compute_band_width(coords2d)
            bw = compute_band_width(coords2d)
            bw = compute_band_width(coords2d)
            bw = compute_band_width(coords2d)
            bw = compute_band_width(coords2d)
            bw = compute_band_width(coords2d)
            bw = compute_band_width(coords2d)
            bw = compute_band_width(coords2d)
            bw = compute_band_width(coords2d)
            bw = compute_band_width(coords2d)
            bw = compute_band_width(coords2d)
            bw = compute_band_width(coords2d)
            bw = compute_band_width(coords2d)
            bw = compute_band_width(coords2d)
            bw = compute_band_width(coords2d)
            bw = compute_band_width(coords2d)
            bw = compute_band_width(coords2d)
            bw = compute_band_width(coords2d)
            bw = compute_band_width(coords2d)
            bw = compute_band_width(coords2d)
            bw = compute_band_width(coords2d)
            bw = compute_band_width(coords2d)
            bw = compute_band_width(coords2d)
            bw = compute_band_width(coords2d)
            bw = compute_band_width(coords2d)
            bw = compute_band_width(coords2d)
            bw = compute_band_width(coords2d)
            bw = compute_band_width(coords2d)
            bw = compute_band_width(coords2d)
            bw = compute_band_width(coords2d)
            bw = compute_band_width(coords2d)
            bw = compute_band_width(coords2d)
            if bw > 2.0 * s_tol and t > tmin:
            if bw > 2.0 * s_tol and t > tmin:
            if bw > 2.0 * s_tol and t > tmin:
            if bw > 2.0 * s_tol and t > tmin:
            if bw > 2.0 * s_tol and t > tmin:
            if bw > 2.0 * s_tol and t > tmin:
            if bw > 2.0 * s_tol and t > tmin:
            if bw > 2.0 * s_tol and t > tmin:
            if bw > 2.0 * s_tol and t > tmin:
            if bw > 2.0 * s_tol and t > tmin:
            if bw > 2.0 * s_tol and t > tmin:
            if bw > 2.0 * s_tol and t > tmin:
            if bw > 2.0 * s_tol and t > tmin:
            if bw > 2.0 * s_tol and t > tmin:
            if bw > 2.0 * s_tol and t > tmin:
            if bw > 2.0 * s_tol and t > tmin:
            if bw > 2.0 * s_tol and t > tmin:
            if bw > 2.0 * s_tol and t > tmin:
            if bw > 2.0 * s_tol and t > tmin:
            if bw > 2.0 * s_tol and t > tmin:
            if bw > 2.0 * s_tol and t > tmin:
            if bw > 2.0 * s_tol and t > tmin:
            if bw > 2.0 * s_tol and t > tmin:
            if bw > 2.0 * s_tol and t > tmin:
            if bw > 2.0 * s_tol and t > tmin:
            if bw > 2.0 * s_tol and t > tmin:
            if bw > 2.0 * s_tol and t > tmin:
            if bw > 2.0 * s_tol and t > tmin:
            if bw > 2.0 * s_tol and t > tmin:
            if bw > 2.0 * s_tol and t > tmin:
            if bw > 2.0 * s_tol and t > tmin:
            if bw > 2.0 * s_tol and t > tmin:
            if bw > 2.0 * s_tol and t > tmin:
            if bw > 2.0 * s_tol and t > tmin:
            if bw > 2.0 * s_tol and t > tmin:
            if bw > 2.0 * s_tol and t > tmin:
            if bw > 2.0 * s_tol and t > tmin:
                new_t = t * (2.0 * s_tol / (bw + 1e-12))
                new_t = t * (2.0 * s_tol / (bw + 1e-12))
                new_t = t * (2.0 * s_tol / (bw + 1e-12))
                new_t = t * (2.0 * s_tol / (bw + 1e-12))
                new_t = t * (2.0 * s_tol / (bw + 1e-12))
                new_t = t * (2.0 * s_tol / (bw + 1e-12))
                new_t = t * (2.0 * s_tol / (bw + 1e-12))
                new_t = t * (2.0 * s_tol / (bw + 1e-12))
                new_t = t * (2.0 * s_tol / (bw + 1e-12))
                new_t = t * (2.0 * s_tol / (bw + 1e-12))
                new_t = t * (2.0 * s_tol / (bw + 1e-12))
                new_t = t * (2.0 * s_tol / (bw + 1e-12))
                new_t = t * (2.0 * s_tol / (bw + 1e-12))
                new_t = t * (2.0 * s_tol / (bw + 1e-12))
                new_t = t * (2.0 * s_tol / (bw + 1e-12))
                new_t = t * (2.0 * s_tol / (bw + 1e-12))
                new_t = t * (2.0 * s_tol / (bw + 1e-12))
                new_t = t * (2.0 * s_tol / (bw + 1e-12))
                new_t = t * (2.0 * s_tol / (bw + 1e-12))
                new_t = t * (2.0 * s_tol / (bw + 1e-12))
                new_t = t * (2.0 * s_tol / (bw + 1e-12))
                new_t = t * (2.0 * s_tol / (bw + 1e-12))
                new_t = t * (2.0 * s_tol / (bw + 1e-12))
                new_t = t * (2.0 * s_tol / (bw + 1e-12))
                new_t = t * (2.0 * s_tol / (bw + 1e-12))
                new_t = t * (2.0 * s_tol / (bw + 1e-12))
                new_t = t * (2.0 * s_tol / (bw + 1e-12))
                new_t = t * (2.0 * s_tol / (bw + 1e-12))
                new_t = t * (2.0 * s_tol / (bw + 1e-12))
                new_t = t * (2.0 * s_tol / (bw + 1e-12))
                new_t = t * (2.0 * s_tol / (bw + 1e-12))
                new_t = t * (2.0 * s_tol / (bw + 1e-12))
                new_t = t * (2.0 * s_tol / (bw + 1e-12))
                new_t = t * (2.0 * s_tol / (bw + 1e-12))
                new_t = t * (2.0 * s_tol / (bw + 1e-12))
                new_t = t * (2.0 * s_tol / (bw + 1e-12))
                new_t = t * (2.0 * s_tol / (bw + 1e-12))
                new_t = max(new_t, tmin)
                new_t = max(new_t, tmin)
                new_t = max(new_t, tmin)
                new_t = max(new_t, tmin)
                new_t = max(new_t, tmin)
                new_t = max(new_t, tmin)
                new_t = max(new_t, tmin)
                new_t = max(new_t, tmin)
                new_t = max(new_t, tmin)
                new_t = max(new_t, tmin)
                new_t = max(new_t, tmin)
                new_t = max(new_t, tmin)
                new_t = max(new_t, tmin)
                new_t = max(new_t, tmin)
                new_t = max(new_t, tmin)
                new_t = max(new_t, tmin)
                new_t = max(new_t, tmin)
                new_t = max(new_t, tmin)
                new_t = max(new_t, tmin)
                new_t = max(new_t, tmin)
                new_t = max(new_t, tmin)
                new_t = max(new_t, tmin)
                new_t = max(new_t, tmin)
                new_t = max(new_t, tmin)
                new_t = max(new_t, tmin)
                new_t = max(new_t, tmin)
                new_t = max(new_t, tmin)
                new_t = max(new_t, tmin)
                new_t = max(new_t, tmin)
                new_t = max(new_t, tmin)
                new_t = max(new_t, tmin)
                new_t = max(new_t, tmin)
                new_t = max(new_t, tmin)
                new_t = max(new_t, tmin)
                new_t = max(new_t, tmin)
                new_t = max(new_t, tmin)
                new_t = max(new_t, tmin)
                if new_t >= t - 1e-12:
                if new_t >= t - 1e-12:
                if new_t >= t - 1e-12:
                if new_t >= t - 1e-12:
                if new_t >= t - 1e-12:
                if new_t >= t - 1e-12:
                if new_t >= t - 1e-12:
                if new_t >= t - 1e-12:
                if new_t >= t - 1e-12:
                if new_t >= t - 1e-12:
                if new_t >= t - 1e-12:
                if new_t >= t - 1e-12:
                if new_t >= t - 1e-12:
                if new_t >= t - 1e-12:
                if new_t >= t - 1e-12:
                if new_t >= t - 1e-12:
                if new_t >= t - 1e-12:
                if new_t >= t - 1e-12:
                if new_t >= t - 1e-12:
                if new_t >= t - 1e-12:
                if new_t >= t - 1e-12:
                if new_t >= t - 1e-12:
                if new_t >= t - 1e-12:
                if new_t >= t - 1e-12:
                if new_t >= t - 1e-12:
                if new_t >= t - 1e-12:
                if new_t >= t - 1e-12:
                if new_t >= t - 1e-12:
                if new_t >= t - 1e-12:
                if new_t >= t - 1e-12:
                if new_t >= t - 1e-12:
                if new_t >= t - 1e-12:
                if new_t >= t - 1e-12:
                if new_t >= t - 1e-12:
                if new_t >= t - 1e-12:
                if new_t >= t - 1e-12:
                if new_t >= t - 1e-12:
                    break
                    break
                    break
                    break
                    break
                    break
                    break
                    break
                    break
                    break
                    break
                    break
                    break
                    break
                    break
                    break
                    break
                    break
                    break
                    break
                    break
                    break
                    break
                    break
                    break
                    break
                    break
                    break
                    break
                    break
                    break
                    break
                    break
                    break
                    break
                    break
                    break
                t = new_t; iters += 1
                t = new_t; iters += 1
                t = new_t; iters += 1
                t = new_t; iters += 1
                t = new_t; iters += 1
                t = new_t; iters += 1
                t = new_t; iters += 1
                t = new_t; iters += 1
                t = new_t; iters += 1
                t = new_t; iters += 1
                t = new_t; iters += 1
                t = new_t; iters += 1
                t = new_t; iters += 1
                t = new_t; iters += 1
                t = new_t; iters += 1
                t = new_t; iters += 1
                t = new_t; iters += 1
                t = new_t; iters += 1
                t = new_t; iters += 1
                t = new_t; iters += 1
                t = new_t; iters += 1
                t = new_t; iters += 1
                t = new_t; iters += 1
                t = new_t; iters += 1
                t = new_t; iters += 1
                t = new_t; iters += 1
                t = new_t; iters += 1
                t = new_t; iters += 1
                t = new_t; iters += 1
                t = new_t; iters += 1
                t = new_t; iters += 1
                t = new_t; iters += 1
                t = new_t; iters += 1
                t = new_t; iters += 1
                t = new_t; iters += 1
                t = new_t; iters += 1
                t = new_t; iters += 1
                if iters > MAX_SLICE_ITERS: break
                if iters > MAX_SLICE_ITERS: break
                if iters > MAX_SLICE_ITERS: break
                if iters > MAX_SLICE_ITERS: break
                if iters > MAX_SLICE_ITERS: break
                if iters > MAX_SLICE_ITERS: break
                if iters > MAX_SLICE_ITERS: break
                if iters > MAX_SLICE_ITERS: break
                if iters > MAX_SLICE_ITERS: break
                if iters > MAX_SLICE_ITERS: break
                if iters > MAX_SLICE_ITERS: break
                if iters > MAX_SLICE_ITERS: break
                if iters > MAX_SLICE_ITERS: break
                if iters > MAX_SLICE_ITERS: break
                if iters > MAX_SLICE_ITERS: break
                if iters > MAX_SLICE_ITERS: break
                if iters > MAX_SLICE_ITERS: break
                if iters > MAX_SLICE_ITERS: break
                if iters > MAX_SLICE_ITERS: break
                if iters > MAX_SLICE_ITERS: break
                if iters > MAX_SLICE_ITERS: break
                if iters > MAX_SLICE_ITERS: break
                if iters > MAX_SLICE_ITERS: break
                if iters > MAX_SLICE_ITERS: break
                if iters > MAX_SLICE_ITERS: break
                if iters > MAX_SLICE_ITERS: break
                if iters > MAX_SLICE_ITERS: break
                if iters > MAX_SLICE_ITERS: break
                if iters > MAX_SLICE_ITERS: break
                if iters > MAX_SLICE_ITERS: break
                if iters > MAX_SLICE_ITERS: break
                if iters > MAX_SLICE_ITERS: break
                if iters > MAX_SLICE_ITERS: break
                if iters > MAX_SLICE_ITERS: break
                if iters > MAX_SLICE_ITERS: break
                if iters > MAX_SLICE_ITERS: break
                if iters > MAX_SLICE_ITERS: break
                continue
                continue
                continue
                continue
                continue
                continue
                continue
                continue
                continue
                continue
                continue
                continue
                continue
                continue
                continue
                continue
                continue
                continue
                continue
                continue
                continue
                continue
                continue
                continue
                continue
                continue
                continue
                continue
                continue
                continue
                continue
                continue
                continue
                continue
                continue
                continue
                continue
            else:
            else:
            else:
            else:
            else:
            else:
            else:
            else:
            else:
            else:
            else:
            else:
            else:
            else:
            else:
            else:
            else:
            else:
            else:
            else:
            else:
            else:
            else:
            else:
            else:
            else:
            else:
            else:
            else:
            else:
            else:
            else:
            else:
            else:
            else:
            else:
            else:
                slices.append((idxs, mid))
                slices.append((idxs, mid))
                slices.append((idxs, mid))
                slices.append((idxs, mid))
                slices.append((idxs, mid))
                slices.append((idxs, mid))
                slices.append((idxs, mid))
                slices.append((idxs, mid))
                slices.append((idxs, mid))
                slices.append((idxs, mid))
                slices.append((idxs, mid))
                slices.append((idxs, mid))
                slices.append((idxs, mid))
                slices.append((idxs, mid))
                slices.append((idxs, mid))
                slices.append((idxs, mid))
                slices.append((idxs, mid))
                slices.append((idxs, mid))
                slices.append((idxs, mid))
                slices.append((idxs, mid))
                slices.append((idxs, mid))
                slices.append((idxs, mid))
                slices.append((idxs, mid))
                slices.append((idxs, mid))
                slices.append((idxs, mid))
                slices.append((idxs, mid))
                slices.append((idxs, mid))
                slices.append((idxs, mid))
                slices.append((idxs, mid))
                slices.append((idxs, mid))
                slices.append((idxs, mid))
                slices.append((idxs, mid))
                slices.append((idxs, mid))
                slices.append((idxs, mid))
                slices.append((idxs, mid))
                slices.append((idxs, mid))
                slices.append((idxs, mid))
                z = z_hi
                z = z_hi
                z = z_hi
                z = z_hi
                z = z_hi
                z = z_hi
                z = z_hi
                z = z_hi
                z = z_hi
                z = z_hi
                z = z_hi
                z = z_hi
                z = z_hi
                z = z_hi
                z = z_hi
                z = z_hi
                z = z_hi
                z = z_hi
                z = z_hi
                z = z_hi
                z = z_hi
                z = z_hi
                z = z_hi
                z = z_hi
                z = z_hi
                z = z_hi
                z = z_hi
                z = z_hi
                z = z_hi
                z = z_hi
                z = z_hi
                z = z_hi
                z = z_hi
                z = z_hi
                z = z_hi
                z = z_hi
                z = z_hi
                break
                break
                break
                break
                break
                break
                break
                break
                break
                break
                break
                break
                break
                break
                break
                break
                break
                break
                break
                break
                break
                break
                break
                break
                break
                break
                break
                break
                break
                break
                break
                break
                break
                break
                break
                break
                break
        if iters > 1000:
        if iters > 1000:
        if iters > 1000:
        if iters > 1000:
        if iters > 1000:
        if iters > 1000:
        if iters > 1000:
        if iters > 1000:
        if iters > 1000:
        if iters > 1000:
        if iters > 1000:
        if iters > 1000:
        if iters > 1000:
        if iters > 1000:
        if iters > 1000:
        if iters > 1000:
        if iters > 1000:
        if iters > 1000:
        if iters > 1000:
        if iters > 1000:
        if iters > 1000:
        if iters > 1000:
        if iters > 1000:
        if iters > 1000:
        if iters > 1000:
        if iters > 1000:
        if iters > 1000:
        if iters > 1000:
        if iters > 1000:
        if iters > 1000:
        if iters > 1000:
        if iters > 1000:
        if iters > 1000:
        if iters > 1000:
        if iters > 1000:
        if iters > 1000:
        if iters > 1000:
            break
            break
            break
            break
            break
            break
            break
            break
            break
            break
            break
            break
            break
            break
            break
            break
            break
            break
            break
            break
            break
            break
            break
            break
            break
            break
            break
            break
            break
            break
            break
            break
            break
            break
            break
            break
            break
    return slices    return slices    return slices    return slices    return slices    return slices    return slices    return slices    return slices    return slices    return slices    return slices    return slices    return slices    return slices    return slices    return slices    return slices    return slices    return slices    return slices    return slices    return slices    return slices    return slices    return slices    return slices    return slices    return slices    return slices    return slices    return slices    return slices    return slices    return slices    return slices    return slices

# %% [markdown]
# ## ---------- Process one slice: keep/remove decision only (no point displacement) ----------
# ## ---------- Process one slice: keep/remove decision only (no point displacement) ----------
# ## ---------- Process one slice: keep/remove decision only (no point displacement) ----------
# ## ---------- Process one slice: keep/remove decision only (no point displacement) ----------
# ## ---------- Process one slice: keep/remove decision only (no point displacement) ----------
# ## ---------- Process one slice: keep/remove decision only (no point displacement) ----------
# ## ---------- Process one slice: keep/remove decision only (no point displacement) ----------
# ## ---------- Process one slice: keep/remove decision only (no point displacement) ----------
# ## ---------- Process one slice: keep/remove decision only (no point displacement) ----------
# ## ---------- Process one slice: keep/remove decision only (no point displacement) ----------
# ## ---------- Process one slice: keep/remove decision only (no point displacement) ----------
# ## ---------- Process one slice: keep/remove decision only (no point displacement) ----------
# ## ---------- Process one slice: keep/remove decision only (no point displacement) ----------
# ## ---------- Process one slice: keep/remove decision only (no point displacement) ----------
# ## ---------- Process one slice: keep/remove decision only (no point displacement) ----------
# ## ---------- Process one slice: keep/remove decision only (no point displacement) ----------
# ## ---------- Process one slice: keep/remove decision only (no point displacement) ----------
# ## ---------- Process one slice: keep/remove decision only (no point displacement) ----------
# ## ---------- Process one slice: keep/remove decision only (no point displacement) ----------
# ## ---------- Process one slice: keep/remove decision only (no point displacement) ----------
# ## ---------- Process one slice: keep/remove decision only (no point displacement) ----------
# ## ---------- Process one slice: keep/remove decision only (no point displacement) ----------
# ## ---------- Process one slice: keep/remove decision only (no point displacement) ----------
# ## ---------- Process one slice: keep/remove decision only (no point displacement) ----------
# ## ---------- Process one slice: keep/remove decision only (no point displacement) ----------
# ## ---------- Process one slice: keep/remove decision only (no point displacement) ----------
# ## ---------- Process one slice: keep/remove decision only (no point displacement) ----------
# ## ---------- Process one slice: keep/remove decision only (no point displacement) ----------
# ## ---------- Process one slice: keep/remove decision only (no point displacement) ----------
# ## ---------- Process one slice: keep/remove decision only (no point displacement) ----------
# ## ---------- Process one slice: keep/remove decision only (no point displacement) ----------
# ## ---------- Process one slice: keep/remove decision only (no point displacement) ----------
# ## ---------- Process one slice: keep/remove decision only (no point displacement) ----------
# ## ---------- Process one slice: keep/remove decision only (no point displacement) ----------
# ## ---------- Process one slice: keep/remove decision only (no point displacement) ----------
# ## ---------- Process one slice: keep/remove decision only (no point displacement) ----------
# ## ---------- Process one slice: keep/remove decision only (no point displacement) ----------

# %%
def process_slice_keep_indices(points_idx, pts_all, axis, layer_plane_coord):
def process_slice_keep_indices(points_idx, pts_all, axis, layer_plane_coord):
def process_slice_keep_indices(points_idx, pts_all, axis, layer_plane_coord):
def process_slice_keep_indices(points_idx, pts_all, axis, layer_plane_coord):
def process_slice_keep_indices(points_idx, pts_all, axis, layer_plane_coord):
def process_slice_keep_indices(points_idx, pts_all, axis, layer_plane_coord):
def process_slice_keep_indices(points_idx, pts_all, axis, layer_plane_coord):
def process_slice_keep_indices(points_idx, pts_all, axis, layer_plane_coord):
def process_slice_keep_indices(points_idx, pts_all, axis, layer_plane_coord):
def process_slice_keep_indices(points_idx, pts_all, axis, layer_plane_coord):
def process_slice_keep_indices(points_idx, pts_all, axis, layer_plane_coord):
def process_slice_keep_indices(points_idx, pts_all, axis, layer_plane_coord):
def process_slice_keep_indices(points_idx, pts_all, axis, layer_plane_coord):
def process_slice_keep_indices(points_idx, pts_all, axis, layer_plane_coord):
def process_slice_keep_indices(points_idx, pts_all, axis, layer_plane_coord):
def process_slice_keep_indices(points_idx, pts_all, axis, layer_plane_coord):
def process_slice_keep_indices(points_idx, pts_all, axis, layer_plane_coord):
def process_slice_keep_indices(points_idx, pts_all, axis, layer_plane_coord):
def process_slice_keep_indices(points_idx, pts_all, axis, layer_plane_coord):
def process_slice_keep_indices(points_idx, pts_all, axis, layer_plane_coord):
def process_slice_keep_indices(points_idx, pts_all, axis, layer_plane_coord):
def process_slice_keep_indices(points_idx, pts_all, axis, layer_plane_coord):
def process_slice_keep_indices(points_idx, pts_all, axis, layer_plane_coord):
def process_slice_keep_indices(points_idx, pts_all, axis, layer_plane_coord):
def process_slice_keep_indices(points_idx, pts_all, axis, layer_plane_coord):
def process_slice_keep_indices(points_idx, pts_all, axis, layer_plane_coord):
def process_slice_keep_indices(points_idx, pts_all, axis, layer_plane_coord):
def process_slice_keep_indices(points_idx, pts_all, axis, layer_plane_coord):
def process_slice_keep_indices(points_idx, pts_all, axis, layer_plane_coord):
def process_slice_keep_indices(points_idx, pts_all, axis, layer_plane_coord):
def process_slice_keep_indices(points_idx, pts_all, axis, layer_plane_coord):
def process_slice_keep_indices(points_idx, pts_all, axis, layer_plane_coord):
def process_slice_keep_indices(points_idx, pts_all, axis, layer_plane_coord):
def process_slice_keep_indices(points_idx, pts_all, axis, layer_plane_coord):
def process_slice_keep_indices(points_idx, pts_all, axis, layer_plane_coord):
def process_slice_keep_indices(points_idx, pts_all, axis, layer_plane_coord):
def process_slice_keep_indices(points_idx, pts_all, axis, layer_plane_coord):
    pts_slice = pts_all[points_idx]
    pts_slice = pts_all[points_idx]
    pts_slice = pts_all[points_idx]
    pts_slice = pts_all[points_idx]
    pts_slice = pts_all[points_idx]
    pts_slice = pts_all[points_idx]
    pts_slice = pts_all[points_idx]
    pts_slice = pts_all[points_idx]
    pts_slice = pts_all[points_idx]
    pts_slice = pts_all[points_idx]
    pts_slice = pts_all[points_idx]
    pts_slice = pts_all[points_idx]
    pts_slice = pts_all[points_idx]
    pts_slice = pts_all[points_idx]
    pts_slice = pts_all[points_idx]
    pts_slice = pts_all[points_idx]
    pts_slice = pts_all[points_idx]
    pts_slice = pts_all[points_idx]
    pts_slice = pts_all[points_idx]
    pts_slice = pts_all[points_idx]
    pts_slice = pts_all[points_idx]
    pts_slice = pts_all[points_idx]
    pts_slice = pts_all[points_idx]
    pts_slice = pts_all[points_idx]
    pts_slice = pts_all[points_idx]
    pts_slice = pts_all[points_idx]
    pts_slice = pts_all[points_idx]
    pts_slice = pts_all[points_idx]
    pts_slice = pts_all[points_idx]
    pts_slice = pts_all[points_idx]
    pts_slice = pts_all[points_idx]
    pts_slice = pts_all[points_idx]
    pts_slice = pts_all[points_idx]
    pts_slice = pts_all[points_idx]
    pts_slice = pts_all[points_idx]
    pts_slice = pts_all[points_idx]
    pts_slice = pts_all[points_idx]
    if pts_slice.shape[0] == 0:
    if pts_slice.shape[0] == 0:
    if pts_slice.shape[0] == 0:
    if pts_slice.shape[0] == 0:
    if pts_slice.shape[0] == 0:
    if pts_slice.shape[0] == 0:
    if pts_slice.shape[0] == 0:
    if pts_slice.shape[0] == 0:
    if pts_slice.shape[0] == 0:
    if pts_slice.shape[0] == 0:
    if pts_slice.shape[0] == 0:
    if pts_slice.shape[0] == 0:
    if pts_slice.shape[0] == 0:
    if pts_slice.shape[0] == 0:
    if pts_slice.shape[0] == 0:
    if pts_slice.shape[0] == 0:
    if pts_slice.shape[0] == 0:
    if pts_slice.shape[0] == 0:
    if pts_slice.shape[0] == 0:
    if pts_slice.shape[0] == 0:
    if pts_slice.shape[0] == 0:
    if pts_slice.shape[0] == 0:
    if pts_slice.shape[0] == 0:
    if pts_slice.shape[0] == 0:
    if pts_slice.shape[0] == 0:
    if pts_slice.shape[0] == 0:
    if pts_slice.shape[0] == 0:
    if pts_slice.shape[0] == 0:
    if pts_slice.shape[0] == 0:
    if pts_slice.shape[0] == 0:
    if pts_slice.shape[0] == 0:
    if pts_slice.shape[0] == 0:
    if pts_slice.shape[0] == 0:
    if pts_slice.shape[0] == 0:
    if pts_slice.shape[0] == 0:
    if pts_slice.shape[0] == 0:
    if pts_slice.shape[0] == 0:
        return np.array([], dtype=int), {'n':0, 'kept':0, 'removed':0}
        return np.array([], dtype=int), {'n':0, 'kept':0, 'removed':0}
        return np.array([], dtype=int), {'n':0, 'kept':0, 'removed':0}
        return np.array([], dtype=int), {'n':0, 'kept':0, 'removed':0}
        return np.array([], dtype=int), {'n':0, 'kept':0, 'removed':0}
        return np.array([], dtype=int), {'n':0, 'kept':0, 'removed':0}
        return np.array([], dtype=int), {'n':0, 'kept':0, 'removed':0}
        return np.array([], dtype=int), {'n':0, 'kept':0, 'removed':0}
        return np.array([], dtype=int), {'n':0, 'kept':0, 'removed':0}
        return np.array([], dtype=int), {'n':0, 'kept':0, 'removed':0}
        return np.array([], dtype=int), {'n':0, 'kept':0, 'removed':0}
        return np.array([], dtype=int), {'n':0, 'kept':0, 'removed':0}
        return np.array([], dtype=int), {'n':0, 'kept':0, 'removed':0}
        return np.array([], dtype=int), {'n':0, 'kept':0, 'removed':0}
        return np.array([], dtype=int), {'n':0, 'kept':0, 'removed':0}
        return np.array([], dtype=int), {'n':0, 'kept':0, 'removed':0}
        return np.array([], dtype=int), {'n':0, 'kept':0, 'removed':0}
        return np.array([], dtype=int), {'n':0, 'kept':0, 'removed':0}
        return np.array([], dtype=int), {'n':0, 'kept':0, 'removed':0}
        return np.array([], dtype=int), {'n':0, 'kept':0, 'removed':0}
        return np.array([], dtype=int), {'n':0, 'kept':0, 'removed':0}
        return np.array([], dtype=int), {'n':0, 'kept':0, 'removed':0}
        return np.array([], dtype=int), {'n':0, 'kept':0, 'removed':0}
        return np.array([], dtype=int), {'n':0, 'kept':0, 'removed':0}
        return np.array([], dtype=int), {'n':0, 'kept':0, 'removed':0}
        return np.array([], dtype=int), {'n':0, 'kept':0, 'removed':0}
        return np.array([], dtype=int), {'n':0, 'kept':0, 'removed':0}
        return np.array([], dtype=int), {'n':0, 'kept':0, 'removed':0}
        return np.array([], dtype=int), {'n':0, 'kept':0, 'removed':0}
        return np.array([], dtype=int), {'n':0, 'kept':0, 'removed':0}
        return np.array([], dtype=int), {'n':0, 'kept':0, 'removed':0}
        return np.array([], dtype=int), {'n':0, 'kept':0, 'removed':0}
        return np.array([], dtype=int), {'n':0, 'kept':0, 'removed':0}
        return np.array([], dtype=int), {'n':0, 'kept':0, 'removed':0}
        return np.array([], dtype=int), {'n':0, 'kept':0, 'removed':0}
        return np.array([], dtype=int), {'n':0, 'kept':0, 'removed':0}
        return np.array([], dtype=int), {'n':0, 'kept':0, 'removed':0}
    _, coords2d, _, _, _ = project_to_plane(pts_slice, axis, layer_plane_coord)
    _, coords2d, _, _, _ = project_to_plane(pts_slice, axis, layer_plane_coord)
    _, coords2d, _, _, _ = project_to_plane(pts_slice, axis, layer_plane_coord)
    _, coords2d, _, _, _ = project_to_plane(pts_slice, axis, layer_plane_coord)
    _, coords2d, _, _, _ = project_to_plane(pts_slice, axis, layer_plane_coord)
    _, coords2d, _, _, _ = project_to_plane(pts_slice, axis, layer_plane_coord)
    _, coords2d, _, _, _ = project_to_plane(pts_slice, axis, layer_plane_coord)
    _, coords2d, _, _, _ = project_to_plane(pts_slice, axis, layer_plane_coord)
    _, coords2d, _, _, _ = project_to_plane(pts_slice, axis, layer_plane_coord)
    _, coords2d, _, _, _ = project_to_plane(pts_slice, axis, layer_plane_coord)
    _, coords2d, _, _, _ = project_to_plane(pts_slice, axis, layer_plane_coord)
    _, coords2d, _, _, _ = project_to_plane(pts_slice, axis, layer_plane_coord)
    _, coords2d, _, _, _ = project_to_plane(pts_slice, axis, layer_plane_coord)
    _, coords2d, _, _, _ = project_to_plane(pts_slice, axis, layer_plane_coord)
    _, coords2d, _, _, _ = project_to_plane(pts_slice, axis, layer_plane_coord)
    _, coords2d, _, _, _ = project_to_plane(pts_slice, axis, layer_plane_coord)
    _, coords2d, _, _, _ = project_to_plane(pts_slice, axis, layer_plane_coord)
    _, coords2d, _, _, _ = project_to_plane(pts_slice, axis, layer_plane_coord)
    _, coords2d, _, _, _ = project_to_plane(pts_slice, axis, layer_plane_coord)
    _, coords2d, _, _, _ = project_to_plane(pts_slice, axis, layer_plane_coord)
    _, coords2d, _, _, _ = project_to_plane(pts_slice, axis, layer_plane_coord)
    _, coords2d, _, _, _ = project_to_plane(pts_slice, axis, layer_plane_coord)
    _, coords2d, _, _, _ = project_to_plane(pts_slice, axis, layer_plane_coord)
    _, coords2d, _, _, _ = project_to_plane(pts_slice, axis, layer_plane_coord)
    _, coords2d, _, _, _ = project_to_plane(pts_slice, axis, layer_plane_coord)
    _, coords2d, _, _, _ = project_to_plane(pts_slice, axis, layer_plane_coord)
    _, coords2d, _, _, _ = project_to_plane(pts_slice, axis, layer_plane_coord)
    _, coords2d, _, _, _ = project_to_plane(pts_slice, axis, layer_plane_coord)
    _, coords2d, _, _, _ = project_to_plane(pts_slice, axis, layer_plane_coord)
    _, coords2d, _, _, _ = project_to_plane(pts_slice, axis, layer_plane_coord)
    _, coords2d, _, _, _ = project_to_plane(pts_slice, axis, layer_plane_coord)
    _, coords2d, _, _, _ = project_to_plane(pts_slice, axis, layer_plane_coord)
    _, coords2d, _, _, _ = project_to_plane(pts_slice, axis, layer_plane_coord)
    _, coords2d, _, _, _ = project_to_plane(pts_slice, axis, layer_plane_coord)
    _, coords2d, _, _, _ = project_to_plane(pts_slice, axis, layer_plane_coord)
    _, coords2d, _, _, _ = project_to_plane(pts_slice, axis, layer_plane_coord)
    _, coords2d, _, _, _ = project_to_plane(pts_slice, axis, layer_plane_coord)
    band_w = compute_band_width(coords2d)
    band_w = compute_band_width(coords2d)
    band_w = compute_band_width(coords2d)
    band_w = compute_band_width(coords2d)
    band_w = compute_band_width(coords2d)
    band_w = compute_band_width(coords2d)
    band_w = compute_band_width(coords2d)
    band_w = compute_band_width(coords2d)
    band_w = compute_band_width(coords2d)
    band_w = compute_band_width(coords2d)
    band_w = compute_band_width(coords2d)
    band_w = compute_band_width(coords2d)
    band_w = compute_band_width(coords2d)
    band_w = compute_band_width(coords2d)
    band_w = compute_band_width(coords2d)
    band_w = compute_band_width(coords2d)
    band_w = compute_band_width(coords2d)
    band_w = compute_band_width(coords2d)
    band_w = compute_band_width(coords2d)
    band_w = compute_band_width(coords2d)
    band_w = compute_band_width(coords2d)
    band_w = compute_band_width(coords2d)
    band_w = compute_band_width(coords2d)
    band_w = compute_band_width(coords2d)
    band_w = compute_band_width(coords2d)
    band_w = compute_band_width(coords2d)
    band_w = compute_band_width(coords2d)
    band_w = compute_band_width(coords2d)
    band_w = compute_band_width(coords2d)
    band_w = compute_band_width(coords2d)
    band_w = compute_band_width(coords2d)
    band_w = compute_band_width(coords2d)
    band_w = compute_band_width(coords2d)
    band_w = compute_band_width(coords2d)
    band_w = compute_band_width(coords2d)
    band_w = compute_band_width(coords2d)
    band_w = compute_band_width(coords2d)
    # Sample for initial fit
    # Sample for initial fit
    # Sample for initial fit
    # Sample for initial fit
    # Sample for initial fit
    # Sample for initial fit
    # Sample for initial fit
    # Sample for initial fit
    # Sample for initial fit
    # Sample for initial fit
    # Sample for initial fit
    # Sample for initial fit
    # Sample for initial fit
    # Sample for initial fit
    # Sample for initial fit
    # Sample for initial fit
    # Sample for initial fit
    # Sample for initial fit
    # Sample for initial fit
    # Sample for initial fit
    # Sample for initial fit
    # Sample for initial fit
    # Sample for initial fit
    # Sample for initial fit
    # Sample for initial fit
    # Sample for initial fit
    # Sample for initial fit
    # Sample for initial fit
    # Sample for initial fit
    # Sample for initial fit
    # Sample for initial fit
    # Sample for initial fit
    # Sample for initial fit
    # Sample for initial fit
    # Sample for initial fit
    # Sample for initial fit
    # Sample for initial fit
    order, _ = order_points_along_axis(coords2d)
    order, _ = order_points_along_axis(coords2d)
    order, _ = order_points_along_axis(coords2d)
    order, _ = order_points_along_axis(coords2d)
    order, _ = order_points_along_axis(coords2d)
    order, _ = order_points_along_axis(coords2d)
    order, _ = order_points_along_axis(coords2d)
    order, _ = order_points_along_axis(coords2d)
    order, _ = order_points_along_axis(coords2d)
    order, _ = order_points_along_axis(coords2d)
    order, _ = order_points_along_axis(coords2d)
    order, _ = order_points_along_axis(coords2d)
    order, _ = order_points_along_axis(coords2d)
    order, _ = order_points_along_axis(coords2d)
    order, _ = order_points_along_axis(coords2d)
    order, _ = order_points_along_axis(coords2d)
    order, _ = order_points_along_axis(coords2d)
    order, _ = order_points_along_axis(coords2d)
    order, _ = order_points_along_axis(coords2d)
    order, _ = order_points_along_axis(coords2d)
    order, _ = order_points_along_axis(coords2d)
    order, _ = order_points_along_axis(coords2d)
    order, _ = order_points_along_axis(coords2d)
    order, _ = order_points_along_axis(coords2d)
    order, _ = order_points_along_axis(coords2d)
    order, _ = order_points_along_axis(coords2d)
    order, _ = order_points_along_axis(coords2d)
    order, _ = order_points_along_axis(coords2d)
    order, _ = order_points_along_axis(coords2d)
    order, _ = order_points_along_axis(coords2d)
    order, _ = order_points_along_axis(coords2d)
    order, _ = order_points_along_axis(coords2d)
    order, _ = order_points_along_axis(coords2d)
    order, _ = order_points_along_axis(coords2d)
    order, _ = order_points_along_axis(coords2d)
    order, _ = order_points_along_axis(coords2d)
    order, _ = order_points_along_axis(coords2d)
    ordered2d = coords2d[order]
    ordered2d = coords2d[order]
    ordered2d = coords2d[order]
    ordered2d = coords2d[order]
    ordered2d = coords2d[order]
    ordered2d = coords2d[order]
    ordered2d = coords2d[order]
    ordered2d = coords2d[order]
    ordered2d = coords2d[order]
    ordered2d = coords2d[order]
    ordered2d = coords2d[order]
    ordered2d = coords2d[order]
    ordered2d = coords2d[order]
    ordered2d = coords2d[order]
    ordered2d = coords2d[order]
    ordered2d = coords2d[order]
    ordered2d = coords2d[order]
    ordered2d = coords2d[order]
    ordered2d = coords2d[order]
    ordered2d = coords2d[order]
    ordered2d = coords2d[order]
    ordered2d = coords2d[order]
    ordered2d = coords2d[order]
    ordered2d = coords2d[order]
    ordered2d = coords2d[order]
    ordered2d = coords2d[order]
    ordered2d = coords2d[order]
    ordered2d = coords2d[order]
    ordered2d = coords2d[order]
    ordered2d = coords2d[order]
    ordered2d = coords2d[order]
    ordered2d = coords2d[order]
    ordered2d = coords2d[order]
    ordered2d = coords2d[order]
    ordered2d = coords2d[order]
    ordered2d = coords2d[order]
    ordered2d = coords2d[order]
    ordered3d = pts_slice[order]
    ordered3d = pts_slice[order]
    ordered3d = pts_slice[order]
    ordered3d = pts_slice[order]
    ordered3d = pts_slice[order]
    ordered3d = pts_slice[order]
    ordered3d = pts_slice[order]
    ordered3d = pts_slice[order]
    ordered3d = pts_slice[order]
    ordered3d = pts_slice[order]
    ordered3d = pts_slice[order]
    ordered3d = pts_slice[order]
    ordered3d = pts_slice[order]
    ordered3d = pts_slice[order]
    ordered3d = pts_slice[order]
    ordered3d = pts_slice[order]
    ordered3d = pts_slice[order]
    ordered3d = pts_slice[order]
    ordered3d = pts_slice[order]
    ordered3d = pts_slice[order]
    ordered3d = pts_slice[order]
    ordered3d = pts_slice[order]
    ordered3d = pts_slice[order]
    ordered3d = pts_slice[order]
    ordered3d = pts_slice[order]
    ordered3d = pts_slice[order]
    ordered3d = pts_slice[order]
    ordered3d = pts_slice[order]
    ordered3d = pts_slice[order]
    ordered3d = pts_slice[order]
    ordered3d = pts_slice[order]
    ordered3d = pts_slice[order]
    ordered3d = pts_slice[order]
    ordered3d = pts_slice[order]
    ordered3d = pts_slice[order]
    ordered3d = pts_slice[order]
    ordered3d = pts_slice[order]
    if ordered2d.shape[0] > SAMPLE_POINTS_FOR_INITIAL:
    if ordered2d.shape[0] > SAMPLE_POINTS_FOR_INITIAL:
    if ordered2d.shape[0] > SAMPLE_POINTS_FOR_INITIAL:
    if ordered2d.shape[0] > SAMPLE_POINTS_FOR_INITIAL:
    if ordered2d.shape[0] > SAMPLE_POINTS_FOR_INITIAL:
    if ordered2d.shape[0] > SAMPLE_POINTS_FOR_INITIAL:
    if ordered2d.shape[0] > SAMPLE_POINTS_FOR_INITIAL:
    if ordered2d.shape[0] > SAMPLE_POINTS_FOR_INITIAL:
    if ordered2d.shape[0] > SAMPLE_POINTS_FOR_INITIAL:
    if ordered2d.shape[0] > SAMPLE_POINTS_FOR_INITIAL:
    if ordered2d.shape[0] > SAMPLE_POINTS_FOR_INITIAL:
    if ordered2d.shape[0] > SAMPLE_POINTS_FOR_INITIAL:
    if ordered2d.shape[0] > SAMPLE_POINTS_FOR_INITIAL:
    if ordered2d.shape[0] > SAMPLE_POINTS_FOR_INITIAL:
    if ordered2d.shape[0] > SAMPLE_POINTS_FOR_INITIAL:
    if ordered2d.shape[0] > SAMPLE_POINTS_FOR_INITIAL:
    if ordered2d.shape[0] > SAMPLE_POINTS_FOR_INITIAL:
    if ordered2d.shape[0] > SAMPLE_POINTS_FOR_INITIAL:
    if ordered2d.shape[0] > SAMPLE_POINTS_FOR_INITIAL:
    if ordered2d.shape[0] > SAMPLE_POINTS_FOR_INITIAL:
    if ordered2d.shape[0] > SAMPLE_POINTS_FOR_INITIAL:
    if ordered2d.shape[0] > SAMPLE_POINTS_FOR_INITIAL:
    if ordered2d.shape[0] > SAMPLE_POINTS_FOR_INITIAL:
    if ordered2d.shape[0] > SAMPLE_POINTS_FOR_INITIAL:
    if ordered2d.shape[0] > SAMPLE_POINTS_FOR_INITIAL:
    if ordered2d.shape[0] > SAMPLE_POINTS_FOR_INITIAL:
    if ordered2d.shape[0] > SAMPLE_POINTS_FOR_INITIAL:
    if ordered2d.shape[0] > SAMPLE_POINTS_FOR_INITIAL:
    if ordered2d.shape[0] > SAMPLE_POINTS_FOR_INITIAL:
    if ordered2d.shape[0] > SAMPLE_POINTS_FOR_INITIAL:
    if ordered2d.shape[0] > SAMPLE_POINTS_FOR_INITIAL:
    if ordered2d.shape[0] > SAMPLE_POINTS_FOR_INITIAL:
    if ordered2d.shape[0] > SAMPLE_POINTS_FOR_INITIAL:
    if ordered2d.shape[0] > SAMPLE_POINTS_FOR_INITIAL:
    if ordered2d.shape[0] > SAMPLE_POINTS_FOR_INITIAL:
    if ordered2d.shape[0] > SAMPLE_POINTS_FOR_INITIAL:
    if ordered2d.shape[0] > SAMPLE_POINTS_FOR_INITIAL:
        idxs = np.linspace(0, ordered2d.shape[0]-1, SAMPLE_POINTS_FOR_INITIAL, dtype=int)
        idxs = np.linspace(0, ordered2d.shape[0]-1, SAMPLE_POINTS_FOR_INITIAL, dtype=int)
        idxs = np.linspace(0, ordered2d.shape[0]-1, SAMPLE_POINTS_FOR_INITIAL, dtype=int)
        idxs = np.linspace(0, ordered2d.shape[0]-1, SAMPLE_POINTS_FOR_INITIAL, dtype=int)
        idxs = np.linspace(0, ordered2d.shape[0]-1, SAMPLE_POINTS_FOR_INITIAL, dtype=int)
        idxs = np.linspace(0, ordered2d.shape[0]-1, SAMPLE_POINTS_FOR_INITIAL, dtype=int)
        idxs = np.linspace(0, ordered2d.shape[0]-1, SAMPLE_POINTS_FOR_INITIAL, dtype=int)
        idxs = np.linspace(0, ordered2d.shape[0]-1, SAMPLE_POINTS_FOR_INITIAL, dtype=int)
        idxs = np.linspace(0, ordered2d.shape[0]-1, SAMPLE_POINTS_FOR_INITIAL, dtype=int)
        idxs = np.linspace(0, ordered2d.shape[0]-1, SAMPLE_POINTS_FOR_INITIAL, dtype=int)
        idxs = np.linspace(0, ordered2d.shape[0]-1, SAMPLE_POINTS_FOR_INITIAL, dtype=int)
        idxs = np.linspace(0, ordered2d.shape[0]-1, SAMPLE_POINTS_FOR_INITIAL, dtype=int)
        idxs = np.linspace(0, ordered2d.shape[0]-1, SAMPLE_POINTS_FOR_INITIAL, dtype=int)
        idxs = np.linspace(0, ordered2d.shape[0]-1, SAMPLE_POINTS_FOR_INITIAL, dtype=int)
        idxs = np.linspace(0, ordered2d.shape[0]-1, SAMPLE_POINTS_FOR_INITIAL, dtype=int)
        idxs = np.linspace(0, ordered2d.shape[0]-1, SAMPLE_POINTS_FOR_INITIAL, dtype=int)
        idxs = np.linspace(0, ordered2d.shape[0]-1, SAMPLE_POINTS_FOR_INITIAL, dtype=int)
        idxs = np.linspace(0, ordered2d.shape[0]-1, SAMPLE_POINTS_FOR_INITIAL, dtype=int)
        idxs = np.linspace(0, ordered2d.shape[0]-1, SAMPLE_POINTS_FOR_INITIAL, dtype=int)
        idxs = np.linspace(0, ordered2d.shape[0]-1, SAMPLE_POINTS_FOR_INITIAL, dtype=int)
        idxs = np.linspace(0, ordered2d.shape[0]-1, SAMPLE_POINTS_FOR_INITIAL, dtype=int)
        idxs = np.linspace(0, ordered2d.shape[0]-1, SAMPLE_POINTS_FOR_INITIAL, dtype=int)
        idxs = np.linspace(0, ordered2d.shape[0]-1, SAMPLE_POINTS_FOR_INITIAL, dtype=int)
        idxs = np.linspace(0, ordered2d.shape[0]-1, SAMPLE_POINTS_FOR_INITIAL, dtype=int)
        idxs = np.linspace(0, ordered2d.shape[0]-1, SAMPLE_POINTS_FOR_INITIAL, dtype=int)
        idxs = np.linspace(0, ordered2d.shape[0]-1, SAMPLE_POINTS_FOR_INITIAL, dtype=int)
        idxs = np.linspace(0, ordered2d.shape[0]-1, SAMPLE_POINTS_FOR_INITIAL, dtype=int)
        idxs = np.linspace(0, ordered2d.shape[0]-1, SAMPLE_POINTS_FOR_INITIAL, dtype=int)
        idxs = np.linspace(0, ordered2d.shape[0]-1, SAMPLE_POINTS_FOR_INITIAL, dtype=int)
        idxs = np.linspace(0, ordered2d.shape[0]-1, SAMPLE_POINTS_FOR_INITIAL, dtype=int)
        idxs = np.linspace(0, ordered2d.shape[0]-1, SAMPLE_POINTS_FOR_INITIAL, dtype=int)
        idxs = np.linspace(0, ordered2d.shape[0]-1, SAMPLE_POINTS_FOR_INITIAL, dtype=int)
        idxs = np.linspace(0, ordered2d.shape[0]-1, SAMPLE_POINTS_FOR_INITIAL, dtype=int)
        idxs = np.linspace(0, ordered2d.shape[0]-1, SAMPLE_POINTS_FOR_INITIAL, dtype=int)
        idxs = np.linspace(0, ordered2d.shape[0]-1, SAMPLE_POINTS_FOR_INITIAL, dtype=int)
        idxs = np.linspace(0, ordered2d.shape[0]-1, SAMPLE_POINTS_FOR_INITIAL, dtype=int)
        idxs = np.linspace(0, ordered2d.shape[0]-1, SAMPLE_POINTS_FOR_INITIAL, dtype=int)
        sample2d = ordered2d[idxs]
        sample2d = ordered2d[idxs]
        sample2d = ordered2d[idxs]
        sample2d = ordered2d[idxs]
        sample2d = ordered2d[idxs]
        sample2d = ordered2d[idxs]
        sample2d = ordered2d[idxs]
        sample2d = ordered2d[idxs]
        sample2d = ordered2d[idxs]
        sample2d = ordered2d[idxs]
        sample2d = ordered2d[idxs]
        sample2d = ordered2d[idxs]
        sample2d = ordered2d[idxs]
        sample2d = ordered2d[idxs]
        sample2d = ordered2d[idxs]
        sample2d = ordered2d[idxs]
        sample2d = ordered2d[idxs]
        sample2d = ordered2d[idxs]
        sample2d = ordered2d[idxs]
        sample2d = ordered2d[idxs]
        sample2d = ordered2d[idxs]
        sample2d = ordered2d[idxs]
        sample2d = ordered2d[idxs]
        sample2d = ordered2d[idxs]
        sample2d = ordered2d[idxs]
        sample2d = ordered2d[idxs]
        sample2d = ordered2d[idxs]
        sample2d = ordered2d[idxs]
        sample2d = ordered2d[idxs]
        sample2d = ordered2d[idxs]
        sample2d = ordered2d[idxs]
        sample2d = ordered2d[idxs]
        sample2d = ordered2d[idxs]
        sample2d = ordered2d[idxs]
        sample2d = ordered2d[idxs]
        sample2d = ordered2d[idxs]
        sample2d = ordered2d[idxs]
    else:
    else:
    else:
    else:
    else:
    else:
    else:
    else:
    else:
    else:
    else:
    else:
    else:
    else:
    else:
    else:
    else:
    else:
    else:
    else:
    else:
    else:
    else:
    else:
    else:
    else:
    else:
    else:
    else:
    else:
    else:
    else:
    else:
    else:
    else:
    else:
    else:
        sample2d = ordered2d
        sample2d = ordered2d
        sample2d = ordered2d
        sample2d = ordered2d
        sample2d = ordered2d
        sample2d = ordered2d
        sample2d = ordered2d
        sample2d = ordered2d
        sample2d = ordered2d
        sample2d = ordered2d
        sample2d = ordered2d
        sample2d = ordered2d
        sample2d = ordered2d
        sample2d = ordered2d
        sample2d = ordered2d
        sample2d = ordered2d
        sample2d = ordered2d
        sample2d = ordered2d
        sample2d = ordered2d
        sample2d = ordered2d
        sample2d = ordered2d
        sample2d = ordered2d
        sample2d = ordered2d
        sample2d = ordered2d
        sample2d = ordered2d
        sample2d = ordered2d
        sample2d = ordered2d
        sample2d = ordered2d
        sample2d = ordered2d
        sample2d = ordered2d
        sample2d = ordered2d
        sample2d = ordered2d
        sample2d = ordered2d
        sample2d = ordered2d
        sample2d = ordered2d
        sample2d = ordered2d
        sample2d = ordered2d
    tck = None
    tck = None
    tck = None
    tck = None
    tck = None
    tck = None
    tck = None
    tck = None
    tck = None
    tck = None
    tck = None
    tck = None
    tck = None
    tck = None
    tck = None
    tck = None
    tck = None
    tck = None
    tck = None
    tck = None
    tck = None
    tck = None
    tck = None
    tck = None
    tck = None
    tck = None
    tck = None
    tck = None
    tck = None
    tck = None
    tck = None
    tck = None
    tck = None
    tck = None
    tck = None
    tck = None
    tck = None
    if sample2d.shape[0] >= 4:
    if sample2d.shape[0] >= 4:
    if sample2d.shape[0] >= 4:
    if sample2d.shape[0] >= 4:
    if sample2d.shape[0] >= 4:
    if sample2d.shape[0] >= 4:
    if sample2d.shape[0] >= 4:
    if sample2d.shape[0] >= 4:
    if sample2d.shape[0] >= 4:
    if sample2d.shape[0] >= 4:
    if sample2d.shape[0] >= 4:
    if sample2d.shape[0] >= 4:
    if sample2d.shape[0] >= 4:
    if sample2d.shape[0] >= 4:
    if sample2d.shape[0] >= 4:
    if sample2d.shape[0] >= 4:
    if sample2d.shape[0] >= 4:
    if sample2d.shape[0] >= 4:
    if sample2d.shape[0] >= 4:
    if sample2d.shape[0] >= 4:
    if sample2d.shape[0] >= 4:
    if sample2d.shape[0] >= 4:
    if sample2d.shape[0] >= 4:
    if sample2d.shape[0] >= 4:
    if sample2d.shape[0] >= 4:
    if sample2d.shape[0] >= 4:
    if sample2d.shape[0] >= 4:
    if sample2d.shape[0] >= 4:
    if sample2d.shape[0] >= 4:
    if sample2d.shape[0] >= 4:
    if sample2d.shape[0] >= 4:
    if sample2d.shape[0] >= 4:
    if sample2d.shape[0] >= 4:
    if sample2d.shape[0] >= 4:
    if sample2d.shape[0] >= 4:
    if sample2d.shape[0] >= 4:
    if sample2d.shape[0] >= 4:
        res = fit_bspline_2d(sample2d, s=0.0, k=3)
        res = fit_bspline_2d(sample2d, s=0.0, k=3)
        res = fit_bspline_2d(sample2d, s=0.0, k=3)
        res = fit_bspline_2d(sample2d, s=0.0, k=3)
        res = fit_bspline_2d(sample2d, s=0.0, k=3)
        res = fit_bspline_2d(sample2d, s=0.0, k=3)
        res = fit_bspline_2d(sample2d, s=0.0, k=3)
        res = fit_bspline_2d(sample2d, s=0.0, k=3)
        res = fit_bspline_2d(sample2d, s=0.0, k=3)
        res = fit_bspline_2d(sample2d, s=0.0, k=3)
        res = fit_bspline_2d(sample2d, s=0.0, k=3)
        res = fit_bspline_2d(sample2d, s=0.0, k=3)
        res = fit_bspline_2d(sample2d, s=0.0, k=3)
        res = fit_bspline_2d(sample2d, s=0.0, k=3)
        res = fit_bspline_2d(sample2d, s=0.0, k=3)
        res = fit_bspline_2d(sample2d, s=0.0, k=3)
        res = fit_bspline_2d(sample2d, s=0.0, k=3)
        res = fit_bspline_2d(sample2d, s=0.0, k=3)
        res = fit_bspline_2d(sample2d, s=0.0, k=3)
        res = fit_bspline_2d(sample2d, s=0.0, k=3)
        res = fit_bspline_2d(sample2d, s=0.0, k=3)
        res = fit_bspline_2d(sample2d, s=0.0, k=3)
        res = fit_bspline_2d(sample2d, s=0.0, k=3)
        res = fit_bspline_2d(sample2d, s=0.0, k=3)
        res = fit_bspline_2d(sample2d, s=0.0, k=3)
        res = fit_bspline_2d(sample2d, s=0.0, k=3)
        res = fit_bspline_2d(sample2d, s=0.0, k=3)
        res = fit_bspline_2d(sample2d, s=0.0, k=3)
        res = fit_bspline_2d(sample2d, s=0.0, k=3)
        res = fit_bspline_2d(sample2d, s=0.0, k=3)
        res = fit_bspline_2d(sample2d, s=0.0, k=3)
        res = fit_bspline_2d(sample2d, s=0.0, k=3)
        res = fit_bspline_2d(sample2d, s=0.0, k=3)
        res = fit_bspline_2d(sample2d, s=0.0, k=3)
        res = fit_bspline_2d(sample2d, s=0.0, k=3)
        res = fit_bspline_2d(sample2d, s=0.0, k=3)
        res = fit_bspline_2d(sample2d, s=0.0, k=3)
        if res is not None:
        if res is not None:
        if res is not None:
        if res is not None:
        if res is not None:
        if res is not None:
        if res is not None:
        if res is not None:
        if res is not None:
        if res is not None:
        if res is not None:
        if res is not None:
        if res is not None:
        if res is not None:
        if res is not None:
        if res is not None:
        if res is not None:
        if res is not None:
        if res is not None:
        if res is not None:
        if res is not None:
        if res is not None:
        if res is not None:
        if res is not None:
        if res is not None:
        if res is not None:
        if res is not None:
        if res is not None:
        if res is not None:
        if res is not None:
        if res is not None:
        if res is not None:
        if res is not None:
        if res is not None:
        if res is not None:
        if res is not None:
        if res is not None:
            tck, _ = res
            tck, _ = res
            tck, _ = res
            tck, _ = res
            tck, _ = res
            tck, _ = res
            tck, _ = res
            tck, _ = res
            tck, _ = res
            tck, _ = res
            tck, _ = res
            tck, _ = res
            tck, _ = res
            tck, _ = res
            tck, _ = res
            tck, _ = res
            tck, _ = res
            tck, _ = res
            tck, _ = res
            tck, _ = res
            tck, _ = res
            tck, _ = res
            tck, _ = res
            tck, _ = res
            tck, _ = res
            tck, _ = res
            tck, _ = res
            tck, _ = res
            tck, _ = res
            tck, _ = res
            tck, _ = res
            tck, _ = res
            tck, _ = res
            tck, _ = res
            tck, _ = res
            tck, _ = res
            tck, _ = res
    if tck is None:
    if tck is None:
    if tck is None:
    if tck is None:
    if tck is None:
    if tck is None:
    if tck is None:
    if tck is None:
    if tck is None:
    if tck is None:
    if tck is None:
    if tck is None:
    if tck is None:
    if tck is None:
    if tck is None:
    if tck is None:
    if tck is None:
    if tck is None:
    if tck is None:
    if tck is None:
    if tck is None:
    if tck is None:
    if tck is None:
    if tck is None:
    if tck is None:
    if tck is None:
    if tck is None:
    if tck is None:
    if tck is None:
    if tck is None:
    if tck is None:
    if tck is None:
    if tck is None:
    if tck is None:
    if tck is None:
    if tck is None:
    if tck is None:
        # fallback: if no valid curve found, retain all points
        # fallback: if no valid curve found, retain all points
        # fallback: if no valid curve found, retain all points
        # fallback: if no valid curve found, retain all points
        # fallback: if no valid curve found, retain all points
        # fallback: if no valid curve found, retain all points
        # fallback: if no valid curve found, retain all points
        # fallback: if no valid curve found, retain all points
        # fallback: if no valid curve found, retain all points
        # fallback: if no valid curve found, retain all points
        # fallback: if no valid curve found, retain all points
        # fallback: if no valid curve found, retain all points
        # fallback: if no valid curve found, retain all points
        # fallback: if no valid curve found, retain all points
        # fallback: if no valid curve found, retain all points
        # fallback: if no valid curve found, retain all points
        # fallback: if no valid curve found, retain all points
        # fallback: if no valid curve found, retain all points
        # fallback: if no valid curve found, retain all points
        # fallback: if no valid curve found, retain all points
        # fallback: if no valid curve found, retain all points
        # fallback: if no valid curve found, retain all points
        # fallback: if no valid curve found, retain all points
        # fallback: if no valid curve found, retain all points
        # fallback: if no valid curve found, retain all points
        # fallback: if no valid curve found, retain all points
        # fallback: if no valid curve found, retain all points
        # fallback: if no valid curve found, retain all points
        # fallback: if no valid curve found, retain all points
        # fallback: if no valid curve found, retain all points
        # fallback: if no valid curve found, retain all points
        # fallback: if no valid curve found, retain all points
        # fallback: if no valid curve found, retain all points
        # fallback: if no valid curve found, retain all points
        # fallback: if no valid curve found, retain all points
        # fallback: if no valid curve found, retain all points
        # fallback: if no valid curve found, retain all points
        kept_indices = np.array(points_idx, dtype=int)
        kept_indices = np.array(points_idx, dtype=int)
        kept_indices = np.array(points_idx, dtype=int)
        kept_indices = np.array(points_idx, dtype=int)
        kept_indices = np.array(points_idx, dtype=int)
        kept_indices = np.array(points_idx, dtype=int)
        kept_indices = np.array(points_idx, dtype=int)
        kept_indices = np.array(points_idx, dtype=int)
        kept_indices = np.array(points_idx, dtype=int)
        kept_indices = np.array(points_idx, dtype=int)
        kept_indices = np.array(points_idx, dtype=int)
        kept_indices = np.array(points_idx, dtype=int)
        kept_indices = np.array(points_idx, dtype=int)
        kept_indices = np.array(points_idx, dtype=int)
        kept_indices = np.array(points_idx, dtype=int)
        kept_indices = np.array(points_idx, dtype=int)
        kept_indices = np.array(points_idx, dtype=int)
        kept_indices = np.array(points_idx, dtype=int)
        kept_indices = np.array(points_idx, dtype=int)
        kept_indices = np.array(points_idx, dtype=int)
        kept_indices = np.array(points_idx, dtype=int)
        kept_indices = np.array(points_idx, dtype=int)
        kept_indices = np.array(points_idx, dtype=int)
        kept_indices = np.array(points_idx, dtype=int)
        kept_indices = np.array(points_idx, dtype=int)
        kept_indices = np.array(points_idx, dtype=int)
        kept_indices = np.array(points_idx, dtype=int)
        kept_indices = np.array(points_idx, dtype=int)
        kept_indices = np.array(points_idx, dtype=int)
        kept_indices = np.array(points_idx, dtype=int)
        kept_indices = np.array(points_idx, dtype=int)
        kept_indices = np.array(points_idx, dtype=int)
        kept_indices = np.array(points_idx, dtype=int)
        kept_indices = np.array(points_idx, dtype=int)
        kept_indices = np.array(points_idx, dtype=int)
        kept_indices = np.array(points_idx, dtype=int)
        kept_indices = np.array(points_idx, dtype=int)
        info = {'n': pts_slice.shape[0], 'band_width': band_w, 'note':'no_curve', 
        info = {'n': pts_slice.shape[0], 'band_width': band_w, 'note':'no_curve', 
        info = {'n': pts_slice.shape[0], 'band_width': band_w, 'note':'no_curve', 
        info = {'n': pts_slice.shape[0], 'band_width': band_w, 'note':'no_curve', 
        info = {'n': pts_slice.shape[0], 'band_width': band_w, 'note':'no_curve', 
        info = {'n': pts_slice.shape[0], 'band_width': band_w, 'note':'no_curve', 
        info = {'n': pts_slice.shape[0], 'band_width': band_w, 'note':'no_curve', 
        info = {'n': pts_slice.shape[0], 'band_width': band_w, 'note':'no_curve', 
        info = {'n': pts_slice.shape[0], 'band_width': band_w, 'note':'no_curve', 
        info = {'n': pts_slice.shape[0], 'band_width': band_w, 'note':'no_curve', 
        info = {'n': pts_slice.shape[0], 'band_width': band_w, 'note':'no_curve', 
        info = {'n': pts_slice.shape[0], 'band_width': band_w, 'note':'no_curve', 
        info = {'n': pts_slice.shape[0], 'band_width': band_w, 'note':'no_curve', 
        info = {'n': pts_slice.shape[0], 'band_width': band_w, 'note':'no_curve', 
        info = {'n': pts_slice.shape[0], 'band_width': band_w, 'note':'no_curve', 
        info = {'n': pts_slice.shape[0], 'band_width': band_w, 'note':'no_curve', 
        info = {'n': pts_slice.shape[0], 'band_width': band_w, 'note':'no_curve', 
        info = {'n': pts_slice.shape[0], 'band_width': band_w, 'note':'no_curve', 
        info = {'n': pts_slice.shape[0], 'band_width': band_w, 'note':'no_curve', 
        info = {'n': pts_slice.shape[0], 'band_width': band_w, 'note':'no_curve', 
        info = {'n': pts_slice.shape[0], 'band_width': band_w, 'note':'no_curve', 
        info = {'n': pts_slice.shape[0], 'band_width': band_w, 'note':'no_curve', 
        info = {'n': pts_slice.shape[0], 'band_width': band_w, 'note':'no_curve', 
        info = {'n': pts_slice.shape[0], 'band_width': band_w, 'note':'no_curve', 
        info = {'n': pts_slice.shape[0], 'band_width': band_w, 'note':'no_curve', 
        info = {'n': pts_slice.shape[0], 'band_width': band_w, 'note':'no_curve', 
        info = {'n': pts_slice.shape[0], 'band_width': band_w, 'note':'no_curve', 
        info = {'n': pts_slice.shape[0], 'band_width': band_w, 'note':'no_curve', 
        info = {'n': pts_slice.shape[0], 'band_width': band_w, 'note':'no_curve', 
        info = {'n': pts_slice.shape[0], 'band_width': band_w, 'note':'no_curve', 
        info = {'n': pts_slice.shape[0], 'band_width': band_w, 'note':'no_curve', 
        info = {'n': pts_slice.shape[0], 'band_width': band_w, 'note':'no_curve', 
        info = {'n': pts_slice.shape[0], 'band_width': band_w, 'note':'no_curve', 
        info = {'n': pts_slice.shape[0], 'band_width': band_w, 'note':'no_curve', 
        info = {'n': pts_slice.shape[0], 'band_width': band_w, 'note':'no_curve', 
        info = {'n': pts_slice.shape[0], 'band_width': band_w, 'note':'no_curve', 
        info = {'n': pts_slice.shape[0], 'band_width': band_w, 'note':'no_curve', 
                'kept': len(kept_indices), 'removed': 0}
                'kept': len(kept_indices), 'removed': 0}
                'kept': len(kept_indices), 'removed': 0}
                'kept': len(kept_indices), 'removed': 0}
                'kept': len(kept_indices), 'removed': 0}
                'kept': len(kept_indices), 'removed': 0}
                'kept': len(kept_indices), 'removed': 0}
                'kept': len(kept_indices), 'removed': 0}
                'kept': len(kept_indices), 'removed': 0}
                'kept': len(kept_indices), 'removed': 0}
                'kept': len(kept_indices), 'removed': 0}
                'kept': len(kept_indices), 'removed': 0}
                'kept': len(kept_indices), 'removed': 0}
                'kept': len(kept_indices), 'removed': 0}
                'kept': len(kept_indices), 'removed': 0}
                'kept': len(kept_indices), 'removed': 0}
                'kept': len(kept_indices), 'removed': 0}
                'kept': len(kept_indices), 'removed': 0}
                'kept': len(kept_indices), 'removed': 0}
                'kept': len(kept_indices), 'removed': 0}
                'kept': len(kept_indices), 'removed': 0}
                'kept': len(kept_indices), 'removed': 0}
                'kept': len(kept_indices), 'removed': 0}
                'kept': len(kept_indices), 'removed': 0}
                'kept': len(kept_indices), 'removed': 0}
                'kept': len(kept_indices), 'removed': 0}
                'kept': len(kept_indices), 'removed': 0}
                'kept': len(kept_indices), 'removed': 0}
                'kept': len(kept_indices), 'removed': 0}
                'kept': len(kept_indices), 'removed': 0}
                'kept': len(kept_indices), 'removed': 0}
                'kept': len(kept_indices), 'removed': 0}
                'kept': len(kept_indices), 'removed': 0}
                'kept': len(kept_indices), 'removed': 0}
                'kept': len(kept_indices), 'removed': 0}
                'kept': len(kept_indices), 'removed': 0}
                'kept': len(kept_indices), 'removed': 0}
        return kept_indices, info
        return kept_indices, info
        return kept_indices, info
        return kept_indices, info
        return kept_indices, info
        return kept_indices, info
        return kept_indices, info
        return kept_indices, info
        return kept_indices, info
        return kept_indices, info
        return kept_indices, info
        return kept_indices, info
        return kept_indices, info
        return kept_indices, info
        return kept_indices, info
        return kept_indices, info
        return kept_indices, info
        return kept_indices, info
        return kept_indices, info
        return kept_indices, info
        return kept_indices, info
        return kept_indices, info
        return kept_indices, info
        return kept_indices, info
        return kept_indices, info
        return kept_indices, info
        return kept_indices, info
        return kept_indices, info
        return kept_indices, info
        return kept_indices, info
        return kept_indices, info
        return kept_indices, info
        return kept_indices, info
        return kept_indices, info
        return kept_indices, info
        return kept_indices, info
        return kept_indices, info





































    # Control points and final curve (per paper)
    # Control points and final curve (per paper)
    # Control points and final curve (per paper)
    # Control points and final curve (per paper)
    # Control points and final curve (per paper)
    # Control points and final curve (per paper)
    # Control points and final curve (per paper)
    # Control points and final curve (per paper)
    # Control points and final curve (per paper)
    # Control points and final curve (per paper)
    # Control points and final curve (per paper)
    # Control points and final curve (per paper)
    # Control points and final curve (per paper)
    # Control points and final curve (per paper)
    # Control points and final curve (per paper)
    # Control points and final curve (per paper)
    # Control points and final curve (per paper)
    # Control points and final curve (per paper)
    # Control points and final curve (per paper)
    # Control points and final curve (per paper)
    # Control points and final curve (per paper)
    # Control points and final curve (per paper)
    # Control points and final curve (per paper)
    # Control points and final curve (per paper)
    # Control points and final curve (per paper)
    # Control points and final curve (per paper)
    # Control points and final curve (per paper)
    # Control points and final curve (per paper)
    # Control points and final curve (per paper)
    # Control points and final curve (per paper)
    # Control points and final curve (per paper)
    # Control points and final curve (per paper)
    # Control points and final curve (per paper)
    # Control points and final curve (per paper)
    # Control points and final curve (per paper)
    # Control points and final curve (per paper)
    # Control points and final curve (per paper)
    centers2d, centers3d = extract_control_points(coords2d, pts_slice, band_w,
    centers2d, centers3d = extract_control_points(coords2d, pts_slice, band_w,
    centers2d, centers3d = extract_control_points(coords2d, pts_slice, band_w,
    centers2d, centers3d = extract_control_points(coords2d, pts_slice, band_w,
    centers2d, centers3d = extract_control_points(coords2d, pts_slice, band_w,
    centers2d, centers3d = extract_control_points(coords2d, pts_slice, band_w,
    centers2d, centers3d = extract_control_points(coords2d, pts_slice, band_w,
    centers2d, centers3d = extract_control_points(coords2d, pts_slice, band_w,
    centers2d, centers3d = extract_control_points(coords2d, pts_slice, band_w,
    centers2d, centers3d = extract_control_points(coords2d, pts_slice, band_w,
    centers2d, centers3d = extract_control_points(coords2d, pts_slice, band_w,
    centers2d, centers3d = extract_control_points(coords2d, pts_slice, band_w,
    centers2d, centers3d = extract_control_points(coords2d, pts_slice, band_w,
    centers2d, centers3d = extract_control_points(coords2d, pts_slice, band_w,
    centers2d, centers3d = extract_control_points(coords2d, pts_slice, band_w,
    centers2d, centers3d = extract_control_points(coords2d, pts_slice, band_w,
    centers2d, centers3d = extract_control_points(coords2d, pts_slice, band_w,
    centers2d, centers3d = extract_control_points(coords2d, pts_slice, band_w,
    centers2d, centers3d = extract_control_points(coords2d, pts_slice, band_w,
    centers2d, centers3d = extract_control_points(coords2d, pts_slice, band_w,
    centers2d, centers3d = extract_control_points(coords2d, pts_slice, band_w,
    centers2d, centers3d = extract_control_points(coords2d, pts_slice, band_w,
    centers2d, centers3d = extract_control_points(coords2d, pts_slice, band_w,
    centers2d, centers3d = extract_control_points(coords2d, pts_slice, band_w,
    centers2d, centers3d = extract_control_points(coords2d, pts_slice, band_w,
    centers2d, centers3d = extract_control_points(coords2d, pts_slice, band_w,
    centers2d, centers3d = extract_control_points(coords2d, pts_slice, band_w,
    centers2d, centers3d = extract_control_points(coords2d, pts_slice, band_w,
    centers2d, centers3d = extract_control_points(coords2d, pts_slice, band_w,
    centers2d, centers3d = extract_control_points(coords2d, pts_slice, band_w,
    centers2d, centers3d = extract_control_points(coords2d, pts_slice, band_w,
    centers2d, centers3d = extract_control_points(coords2d, pts_slice, band_w,
    centers2d, centers3d = extract_control_points(coords2d, pts_slice, band_w,
    centers2d, centers3d = extract_control_points(coords2d, pts_slice, band_w,
    centers2d, centers3d = extract_control_points(coords2d, pts_slice, band_w,
    centers2d, centers3d = extract_control_points(coords2d, pts_slice, band_w,
    centers2d, centers3d = extract_control_points(coords2d, pts_slice, band_w,
                                                  n_segments=60, circle_radius_factor=CIRCLE_RADIUS_FACTOR,
                                                  n_segments=60, circle_radius_factor=CIRCLE_RADIUS_FACTOR,
                                                  n_segments=60, circle_radius_factor=CIRCLE_RADIUS_FACTOR,
                                                  n_segments=60, circle_radius_factor=CIRCLE_RADIUS_FACTOR,
                                                  n_segments=60, circle_radius_factor=CIRCLE_RADIUS_FACTOR,
                                                  n_segments=60, circle_radius_factor=CIRCLE_RADIUS_FACTOR,
                                                  n_segments=60, circle_radius_factor=CIRCLE_RADIUS_FACTOR,
                                                  n_segments=60, circle_radius_factor=CIRCLE_RADIUS_FACTOR,
                                                  n_segments=60, circle_radius_factor=CIRCLE_RADIUS_FACTOR,
                                                  n_segments=60, circle_radius_factor=CIRCLE_RADIUS_FACTOR,
                                                  n_segments=60, circle_radius_factor=CIRCLE_RADIUS_FACTOR,
                                                  n_segments=60, circle_radius_factor=CIRCLE_RADIUS_FACTOR,
                                                  n_segments=60, circle_radius_factor=CIRCLE_RADIUS_FACTOR,
                                                  n_segments=60, circle_radius_factor=CIRCLE_RADIUS_FACTOR,
                                                  n_segments=60, circle_radius_factor=CIRCLE_RADIUS_FACTOR,
                                                  n_segments=60, circle_radius_factor=CIRCLE_RADIUS_FACTOR,
                                                  n_segments=60, circle_radius_factor=CIRCLE_RADIUS_FACTOR,
                                                  n_segments=60, circle_radius_factor=CIRCLE_RADIUS_FACTOR,
                                                  n_segments=60, circle_radius_factor=CIRCLE_RADIUS_FACTOR,
                                                  n_segments=60, circle_radius_factor=CIRCLE_RADIUS_FACTOR,
                                                  n_segments=60, circle_radius_factor=CIRCLE_RADIUS_FACTOR,
                                                  n_segments=60, circle_radius_factor=CIRCLE_RADIUS_FACTOR,
                                                  n_segments=60, circle_radius_factor=CIRCLE_RADIUS_FACTOR,
                                                  n_segments=60, circle_radius_factor=CIRCLE_RADIUS_FACTOR,
                                                  n_segments=60, circle_radius_factor=CIRCLE_RADIUS_FACTOR,
                                                  n_segments=60, circle_radius_factor=CIRCLE_RADIUS_FACTOR,
                                                  n_segments=60, circle_radius_factor=CIRCLE_RADIUS_FACTOR,
                                                  n_segments=60, circle_radius_factor=CIRCLE_RADIUS_FACTOR,
                                                  n_segments=60, circle_radius_factor=CIRCLE_RADIUS_FACTOR,
                                                  n_segments=60, circle_radius_factor=CIRCLE_RADIUS_FACTOR,
                                                  n_segments=60, circle_radius_factor=CIRCLE_RADIUS_FACTOR,
                                                  n_segments=60, circle_radius_factor=CIRCLE_RADIUS_FACTOR,
                                                  n_segments=60, circle_radius_factor=CIRCLE_RADIUS_FACTOR,
                                                  n_segments=60, circle_radius_factor=CIRCLE_RADIUS_FACTOR,
                                                  n_segments=60, circle_radius_factor=CIRCLE_RADIUS_FACTOR,
                                                  n_segments=60, circle_radius_factor=CIRCLE_RADIUS_FACTOR,
                                                  n_segments=60, circle_radius_factor=CIRCLE_RADIUS_FACTOR,
                                                  min_points_in_circle=MIN_POINTS_IN_CIRCLE)
                                                  min_points_in_circle=MIN_POINTS_IN_CIRCLE)
                                                  min_points_in_circle=MIN_POINTS_IN_CIRCLE)
                                                  min_points_in_circle=MIN_POINTS_IN_CIRCLE)
                                                  min_points_in_circle=MIN_POINTS_IN_CIRCLE)
                                                  min_points_in_circle=MIN_POINTS_IN_CIRCLE)
                                                  min_points_in_circle=MIN_POINTS_IN_CIRCLE)
                                                  min_points_in_circle=MIN_POINTS_IN_CIRCLE)
                                                  min_points_in_circle=MIN_POINTS_IN_CIRCLE)
                                                  min_points_in_circle=MIN_POINTS_IN_CIRCLE)
                                                  min_points_in_circle=MIN_POINTS_IN_CIRCLE)
                                                  min_points_in_circle=MIN_POINTS_IN_CIRCLE)
                                                  min_points_in_circle=MIN_POINTS_IN_CIRCLE)
                                                  min_points_in_circle=MIN_POINTS_IN_CIRCLE)
                                                  min_points_in_circle=MIN_POINTS_IN_CIRCLE)
                                                  min_points_in_circle=MIN_POINTS_IN_CIRCLE)
                                                  min_points_in_circle=MIN_POINTS_IN_CIRCLE)
                                                  min_points_in_circle=MIN_POINTS_IN_CIRCLE)
                                                  min_points_in_circle=MIN_POINTS_IN_CIRCLE)
                                                  min_points_in_circle=MIN_POINTS_IN_CIRCLE)
                                                  min_points_in_circle=MIN_POINTS_IN_CIRCLE)
                                                  min_points_in_circle=MIN_POINTS_IN_CIRCLE)
                                                  min_points_in_circle=MIN_POINTS_IN_CIRCLE)
                                                  min_points_in_circle=MIN_POINTS_IN_CIRCLE)
                                                  min_points_in_circle=MIN_POINTS_IN_CIRCLE)
                                                  min_points_in_circle=MIN_POINTS_IN_CIRCLE)
                                                  min_points_in_circle=MIN_POINTS_IN_CIRCLE)
                                                  min_points_in_circle=MIN_POINTS_IN_CIRCLE)
                                                  min_points_in_circle=MIN_POINTS_IN_CIRCLE)
                                                  min_points_in_circle=MIN_POINTS_IN_CIRCLE)
                                                  min_points_in_circle=MIN_POINTS_IN_CIRCLE)
                                                  min_points_in_circle=MIN_POINTS_IN_CIRCLE)
                                                  min_points_in_circle=MIN_POINTS_IN_CIRCLE)
                                                  min_points_in_circle=MIN_POINTS_IN_CIRCLE)
                                                  min_points_in_circle=MIN_POINTS_IN_CIRCLE)
                                                  min_points_in_circle=MIN_POINTS_IN_CIRCLE)
                                                  min_points_in_circle=MIN_POINTS_IN_CIRCLE)
    if centers2d.shape[0] < 2:
    if centers2d.shape[0] < 2:
    if centers2d.shape[0] < 2:
    if centers2d.shape[0] < 2:
    if centers2d.shape[0] < 2:
    if centers2d.shape[0] < 2:
    if centers2d.shape[0] < 2:
    if centers2d.shape[0] < 2:
    if centers2d.shape[0] < 2:
    if centers2d.shape[0] < 2:
    if centers2d.shape[0] < 2:
    if centers2d.shape[0] < 2:
    if centers2d.shape[0] < 2:
    if centers2d.shape[0] < 2:
    if centers2d.shape[0] < 2:
    if centers2d.shape[0] < 2:
    if centers2d.shape[0] < 2:
    if centers2d.shape[0] < 2:
    if centers2d.shape[0] < 2:
    if centers2d.shape[0] < 2:
    if centers2d.shape[0] < 2:
    if centers2d.shape[0] < 2:
    if centers2d.shape[0] < 2:
    if centers2d.shape[0] < 2:
    if centers2d.shape[0] < 2:
    if centers2d.shape[0] < 2:
    if centers2d.shape[0] < 2:
    if centers2d.shape[0] < 2:
    if centers2d.shape[0] < 2:
    if centers2d.shape[0] < 2:
    if centers2d.shape[0] < 2:
    if centers2d.shape[0] < 2:
    if centers2d.shape[0] < 2:
    if centers2d.shape[0] < 2:
    if centers2d.shape[0] < 2:
    if centers2d.shape[0] < 2:
    if centers2d.shape[0] < 2:
        # if too few control points: fallback keep all
        # if too few control points: fallback keep all
        # if too few control points: fallback keep all
        # if too few control points: fallback keep all
        # if too few control points: fallback keep all
        # if too few control points: fallback keep all
        # if too few control points: fallback keep all
        # if too few control points: fallback keep all
        # if too few control points: fallback keep all
        # if too few control points: fallback keep all
        # if too few control points: fallback keep all
        # if too few control points: fallback keep all
        # if too few control points: fallback keep all
        # if too few control points: fallback keep all
        # if too few control points: fallback keep all
        # if too few control points: fallback keep all
        # if too few control points: fallback keep all
        # if too few control points: fallback keep all
        # if too few control points: fallback keep all
        # if too few control points: fallback keep all
        # if too few control points: fallback keep all
        # if too few control points: fallback keep all
        # if too few control points: fallback keep all
        # if too few control points: fallback keep all
        # if too few control points: fallback keep all
        # if too few control points: fallback keep all
        # if too few control points: fallback keep all
        # if too few control points: fallback keep all
        # if too few control points: fallback keep all
        # if too few control points: fallback keep all
        # if too few control points: fallback keep all
        # if too few control points: fallback keep all
        # if too few control points: fallback keep all
        # if too few control points: fallback keep all
        # if too few control points: fallback keep all
        # if too few control points: fallback keep all
        # if too few control points: fallback keep all
        kept_indices = np.array(points_idx, dtype=int)
        kept_indices = np.array(points_idx, dtype=int)
        kept_indices = np.array(points_idx, dtype=int)
        kept_indices = np.array(points_idx, dtype=int)
        kept_indices = np.array(points_idx, dtype=int)
        kept_indices = np.array(points_idx, dtype=int)
        kept_indices = np.array(points_idx, dtype=int)
        kept_indices = np.array(points_idx, dtype=int)
        kept_indices = np.array(points_idx, dtype=int)
        kept_indices = np.array(points_idx, dtype=int)
        kept_indices = np.array(points_idx, dtype=int)
        kept_indices = np.array(points_idx, dtype=int)
        kept_indices = np.array(points_idx, dtype=int)
        kept_indices = np.array(points_idx, dtype=int)
        kept_indices = np.array(points_idx, dtype=int)
        kept_indices = np.array(points_idx, dtype=int)
        kept_indices = np.array(points_idx, dtype=int)
        kept_indices = np.array(points_idx, dtype=int)
        kept_indices = np.array(points_idx, dtype=int)
        kept_indices = np.array(points_idx, dtype=int)
        kept_indices = np.array(points_idx, dtype=int)
        kept_indices = np.array(points_idx, dtype=int)
        kept_indices = np.array(points_idx, dtype=int)
        kept_indices = np.array(points_idx, dtype=int)
        kept_indices = np.array(points_idx, dtype=int)
        kept_indices = np.array(points_idx, dtype=int)
        kept_indices = np.array(points_idx, dtype=int)
        kept_indices = np.array(points_idx, dtype=int)
        kept_indices = np.array(points_idx, dtype=int)
        kept_indices = np.array(points_idx, dtype=int)
        kept_indices = np.array(points_idx, dtype=int)
        kept_indices = np.array(points_idx, dtype=int)
        kept_indices = np.array(points_idx, dtype=int)
        kept_indices = np.array(points_idx, dtype=int)
        kept_indices = np.array(points_idx, dtype=int)
        kept_indices = np.array(points_idx, dtype=int)
        kept_indices = np.array(points_idx, dtype=int)
        info = {'n': pts_slice.shape[0], 'band_width': band_w, 'note':'no_centers',
        info = {'n': pts_slice.shape[0], 'band_width': band_w, 'note':'no_centers',
        info = {'n': pts_slice.shape[0], 'band_width': band_w, 'note':'no_centers',
        info = {'n': pts_slice.shape[0], 'band_width': band_w, 'note':'no_centers',
        info = {'n': pts_slice.shape[0], 'band_width': band_w, 'note':'no_centers',
        info = {'n': pts_slice.shape[0], 'band_width': band_w, 'note':'no_centers',
        info = {'n': pts_slice.shape[0], 'band_width': band_w, 'note':'no_centers',
        info = {'n': pts_slice.shape[0], 'band_width': band_w, 'note':'no_centers',
        info = {'n': pts_slice.shape[0], 'band_width': band_w, 'note':'no_centers',
        info = {'n': pts_slice.shape[0], 'band_width': band_w, 'note':'no_centers',
        info = {'n': pts_slice.shape[0], 'band_width': band_w, 'note':'no_centers',
        info = {'n': pts_slice.shape[0], 'band_width': band_w, 'note':'no_centers',
        info = {'n': pts_slice.shape[0], 'band_width': band_w, 'note':'no_centers',
        info = {'n': pts_slice.shape[0], 'band_width': band_w, 'note':'no_centers',
        info = {'n': pts_slice.shape[0], 'band_width': band_w, 'note':'no_centers',
        info = {'n': pts_slice.shape[0], 'band_width': band_w, 'note':'no_centers',
        info = {'n': pts_slice.shape[0], 'band_width': band_w, 'note':'no_centers',
        info = {'n': pts_slice.shape[0], 'band_width': band_w, 'note':'no_centers',
        info = {'n': pts_slice.shape[0], 'band_width': band_w, 'note':'no_centers',
        info = {'n': pts_slice.shape[0], 'band_width': band_w, 'note':'no_centers',
        info = {'n': pts_slice.shape[0], 'band_width': band_w, 'note':'no_centers',
        info = {'n': pts_slice.shape[0], 'band_width': band_w, 'note':'no_centers',
        info = {'n': pts_slice.shape[0], 'band_width': band_w, 'note':'no_centers',
        info = {'n': pts_slice.shape[0], 'band_width': band_w, 'note':'no_centers',
        info = {'n': pts_slice.shape[0], 'band_width': band_w, 'note':'no_centers',
        info = {'n': pts_slice.shape[0], 'band_width': band_w, 'note':'no_centers',
        info = {'n': pts_slice.shape[0], 'band_width': band_w, 'note':'no_centers',
        info = {'n': pts_slice.shape[0], 'band_width': band_w, 'note':'no_centers',
        info = {'n': pts_slice.shape[0], 'band_width': band_w, 'note':'no_centers',
        info = {'n': pts_slice.shape[0], 'band_width': band_w, 'note':'no_centers',
        info = {'n': pts_slice.shape[0], 'band_width': band_w, 'note':'no_centers',
        info = {'n': pts_slice.shape[0], 'band_width': band_w, 'note':'no_centers',
        info = {'n': pts_slice.shape[0], 'band_width': band_w, 'note':'no_centers',
        info = {'n': pts_slice.shape[0], 'band_width': band_w, 'note':'no_centers',
        info = {'n': pts_slice.shape[0], 'band_width': band_w, 'note':'no_centers',
        info = {'n': pts_slice.shape[0], 'band_width': band_w, 'note':'no_centers',
        info = {'n': pts_slice.shape[0], 'band_width': band_w, 'note':'no_centers',
                'kept': len(kept_indices), 'removed': 0}
                'kept': len(kept_indices), 'removed': 0}
                'kept': len(kept_indices), 'removed': 0}
                'kept': len(kept_indices), 'removed': 0}
                'kept': len(kept_indices), 'removed': 0}
                'kept': len(kept_indices), 'removed': 0}
                'kept': len(kept_indices), 'removed': 0}
                'kept': len(kept_indices), 'removed': 0}
                'kept': len(kept_indices), 'removed': 0}
                'kept': len(kept_indices), 'removed': 0}
                'kept': len(kept_indices), 'removed': 0}
                'kept': len(kept_indices), 'removed': 0}
                'kept': len(kept_indices), 'removed': 0}
                'kept': len(kept_indices), 'removed': 0}
                'kept': len(kept_indices), 'removed': 0}
                'kept': len(kept_indices), 'removed': 0}
                'kept': len(kept_indices), 'removed': 0}
                'kept': len(kept_indices), 'removed': 0}
                'kept': len(kept_indices), 'removed': 0}
                'kept': len(kept_indices), 'removed': 0}
                'kept': len(kept_indices), 'removed': 0}
                'kept': len(kept_indices), 'removed': 0}
                'kept': len(kept_indices), 'removed': 0}
                'kept': len(kept_indices), 'removed': 0}
                'kept': len(kept_indices), 'removed': 0}
                'kept': len(kept_indices), 'removed': 0}
                'kept': len(kept_indices), 'removed': 0}
                'kept': len(kept_indices), 'removed': 0}
                'kept': len(kept_indices), 'removed': 0}
                'kept': len(kept_indices), 'removed': 0}
                'kept': len(kept_indices), 'removed': 0}
                'kept': len(kept_indices), 'removed': 0}
                'kept': len(kept_indices), 'removed': 0}
                'kept': len(kept_indices), 'removed': 0}
                'kept': len(kept_indices), 'removed': 0}
                'kept': len(kept_indices), 'removed': 0}
                'kept': len(kept_indices), 'removed': 0}
        return kept_indices, info
        return kept_indices, info
        return kept_indices, info
        return kept_indices, info
        return kept_indices, info
        return kept_indices, info
        return kept_indices, info
        return kept_indices, info
        return kept_indices, info
        return kept_indices, info
        return kept_indices, info
        return kept_indices, info
        return kept_indices, info
        return kept_indices, info
        return kept_indices, info
        return kept_indices, info
        return kept_indices, info
        return kept_indices, info
        return kept_indices, info
        return kept_indices, info
        return kept_indices, info
        return kept_indices, info
        return kept_indices, info
        return kept_indices, info
        return kept_indices, info
        return kept_indices, info
        return kept_indices, info
        return kept_indices, info
        return kept_indices, info
        return kept_indices, info
        return kept_indices, info
        return kept_indices, info
        return kept_indices, info
        return kept_indices, info
        return kept_indices, info
        return kept_indices, info
        return kept_indices, info





































    tck2 = None
    tck2 = None
    tck2 = None
    tck2 = None
    tck2 = None
    tck2 = None
    tck2 = None
    tck2 = None
    tck2 = None
    tck2 = None
    tck2 = None
    tck2 = None
    tck2 = None
    tck2 = None
    tck2 = None
    tck2 = None
    tck2 = None
    tck2 = None
    tck2 = None
    tck2 = None
    tck2 = None
    tck2 = None
    tck2 = None
    tck2 = None
    tck2 = None
    tck2 = None
    tck2 = None
    tck2 = None
    tck2 = None
    tck2 = None
    tck2 = None
    tck2 = None
    tck2 = None
    tck2 = None
    tck2 = None
    tck2 = None
    tck2 = None
    res2 = fit_bspline_2d(centers2d, s=0.0, k=3)
    res2 = fit_bspline_2d(centers2d, s=0.0, k=3)
    res2 = fit_bspline_2d(centers2d, s=0.0, k=3)
    res2 = fit_bspline_2d(centers2d, s=0.0, k=3)
    res2 = fit_bspline_2d(centers2d, s=0.0, k=3)
    res2 = fit_bspline_2d(centers2d, s=0.0, k=3)
    res2 = fit_bspline_2d(centers2d, s=0.0, k=3)
    res2 = fit_bspline_2d(centers2d, s=0.0, k=3)
    res2 = fit_bspline_2d(centers2d, s=0.0, k=3)
    res2 = fit_bspline_2d(centers2d, s=0.0, k=3)
    res2 = fit_bspline_2d(centers2d, s=0.0, k=3)
    res2 = fit_bspline_2d(centers2d, s=0.0, k=3)
    res2 = fit_bspline_2d(centers2d, s=0.0, k=3)
    res2 = fit_bspline_2d(centers2d, s=0.0, k=3)
    res2 = fit_bspline_2d(centers2d, s=0.0, k=3)
    res2 = fit_bspline_2d(centers2d, s=0.0, k=3)
    res2 = fit_bspline_2d(centers2d, s=0.0, k=3)
    res2 = fit_bspline_2d(centers2d, s=0.0, k=3)
    res2 = fit_bspline_2d(centers2d, s=0.0, k=3)
    res2 = fit_bspline_2d(centers2d, s=0.0, k=3)
    res2 = fit_bspline_2d(centers2d, s=0.0, k=3)
    res2 = fit_bspline_2d(centers2d, s=0.0, k=3)
    res2 = fit_bspline_2d(centers2d, s=0.0, k=3)
    res2 = fit_bspline_2d(centers2d, s=0.0, k=3)
    res2 = fit_bspline_2d(centers2d, s=0.0, k=3)
    res2 = fit_bspline_2d(centers2d, s=0.0, k=3)
    res2 = fit_bspline_2d(centers2d, s=0.0, k=3)
    res2 = fit_bspline_2d(centers2d, s=0.0, k=3)
    res2 = fit_bspline_2d(centers2d, s=0.0, k=3)
    res2 = fit_bspline_2d(centers2d, s=0.0, k=3)
    res2 = fit_bspline_2d(centers2d, s=0.0, k=3)
    res2 = fit_bspline_2d(centers2d, s=0.0, k=3)
    res2 = fit_bspline_2d(centers2d, s=0.0, k=3)
    res2 = fit_bspline_2d(centers2d, s=0.0, k=3)
    res2 = fit_bspline_2d(centers2d, s=0.0, k=3)
    res2 = fit_bspline_2d(centers2d, s=0.0, k=3)
    res2 = fit_bspline_2d(centers2d, s=0.0, k=3)
    if res2 is None:
    if res2 is None:
    if res2 is None:
    if res2 is None:
    if res2 is None:
    if res2 is None:
    if res2 is None:
    if res2 is None:
    if res2 is None:
    if res2 is None:
    if res2 is None:
    if res2 is None:
    if res2 is None:
    if res2 is None:
    if res2 is None:
    if res2 is None:
    if res2 is None:
    if res2 is None:
    if res2 is None:
    if res2 is None:
    if res2 is None:
    if res2 is None:
    if res2 is None:
    if res2 is None:
    if res2 is None:
    if res2 is None:
    if res2 is None:
    if res2 is None:
    if res2 is None:
    if res2 is None:
    if res2 is None:
    if res2 is None:
    if res2 is None:
    if res2 is None:
    if res2 is None:
    if res2 is None:
    if res2 is None:
        kept_indices = np.array(points_idx, dtype=int)
        kept_indices = np.array(points_idx, dtype=int)
        kept_indices = np.array(points_idx, dtype=int)
        kept_indices = np.array(points_idx, dtype=int)
        kept_indices = np.array(points_idx, dtype=int)
        kept_indices = np.array(points_idx, dtype=int)
        kept_indices = np.array(points_idx, dtype=int)
        kept_indices = np.array(points_idx, dtype=int)
        kept_indices = np.array(points_idx, dtype=int)
        kept_indices = np.array(points_idx, dtype=int)
        kept_indices = np.array(points_idx, dtype=int)
        kept_indices = np.array(points_idx, dtype=int)
        kept_indices = np.array(points_idx, dtype=int)
        kept_indices = np.array(points_idx, dtype=int)
        kept_indices = np.array(points_idx, dtype=int)
        kept_indices = np.array(points_idx, dtype=int)
        kept_indices = np.array(points_idx, dtype=int)
        kept_indices = np.array(points_idx, dtype=int)
        kept_indices = np.array(points_idx, dtype=int)
        kept_indices = np.array(points_idx, dtype=int)
        kept_indices = np.array(points_idx, dtype=int)
        kept_indices = np.array(points_idx, dtype=int)
        kept_indices = np.array(points_idx, dtype=int)
        kept_indices = np.array(points_idx, dtype=int)
        kept_indices = np.array(points_idx, dtype=int)
        kept_indices = np.array(points_idx, dtype=int)
        kept_indices = np.array(points_idx, dtype=int)
        kept_indices = np.array(points_idx, dtype=int)
        kept_indices = np.array(points_idx, dtype=int)
        kept_indices = np.array(points_idx, dtype=int)
        kept_indices = np.array(points_idx, dtype=int)
        kept_indices = np.array(points_idx, dtype=int)
        kept_indices = np.array(points_idx, dtype=int)
        kept_indices = np.array(points_idx, dtype=int)
        kept_indices = np.array(points_idx, dtype=int)
        kept_indices = np.array(points_idx, dtype=int)
        kept_indices = np.array(points_idx, dtype=int)
        info = {'n': pts_slice.shape[0], 'band_width': band_w, 'note':'no_final_curve',
        info = {'n': pts_slice.shape[0], 'band_width': band_w, 'note':'no_final_curve',
        info = {'n': pts_slice.shape[0], 'band_width': band_w, 'note':'no_final_curve',
        info = {'n': pts_slice.shape[0], 'band_width': band_w, 'note':'no_final_curve',
        info = {'n': pts_slice.shape[0], 'band_width': band_w, 'note':'no_final_curve',
        info = {'n': pts_slice.shape[0], 'band_width': band_w, 'note':'no_final_curve',
        info = {'n': pts_slice.shape[0], 'band_width': band_w, 'note':'no_final_curve',
        info = {'n': pts_slice.shape[0], 'band_width': band_w, 'note':'no_final_curve',
        info = {'n': pts_slice.shape[0], 'band_width': band_w, 'note':'no_final_curve',
        info = {'n': pts_slice.shape[0], 'band_width': band_w, 'note':'no_final_curve',
        info = {'n': pts_slice.shape[0], 'band_width': band_w, 'note':'no_final_curve',
        info = {'n': pts_slice.shape[0], 'band_width': band_w, 'note':'no_final_curve',
        info = {'n': pts_slice.shape[0], 'band_width': band_w, 'note':'no_final_curve',
        info = {'n': pts_slice.shape[0], 'band_width': band_w, 'note':'no_final_curve',
        info = {'n': pts_slice.shape[0], 'band_width': band_w, 'note':'no_final_curve',
        info = {'n': pts_slice.shape[0], 'band_width': band_w, 'note':'no_final_curve',
        info = {'n': pts_slice.shape[0], 'band_width': band_w, 'note':'no_final_curve',
        info = {'n': pts_slice.shape[0], 'band_width': band_w, 'note':'no_final_curve',
        info = {'n': pts_slice.shape[0], 'band_width': band_w, 'note':'no_final_curve',
        info = {'n': pts_slice.shape[0], 'band_width': band_w, 'note':'no_final_curve',
        info = {'n': pts_slice.shape[0], 'band_width': band_w, 'note':'no_final_curve',
        info = {'n': pts_slice.shape[0], 'band_width': band_w, 'note':'no_final_curve',
        info = {'n': pts_slice.shape[0], 'band_width': band_w, 'note':'no_final_curve',
        info = {'n': pts_slice.shape[0], 'band_width': band_w, 'note':'no_final_curve',
        info = {'n': pts_slice.shape[0], 'band_width': band_w, 'note':'no_final_curve',
        info = {'n': pts_slice.shape[0], 'band_width': band_w, 'note':'no_final_curve',
        info = {'n': pts_slice.shape[0], 'band_width': band_w, 'note':'no_final_curve',
        info = {'n': pts_slice.shape[0], 'band_width': band_w, 'note':'no_final_curve',
        info = {'n': pts_slice.shape[0], 'band_width': band_w, 'note':'no_final_curve',
        info = {'n': pts_slice.shape[0], 'band_width': band_w, 'note':'no_final_curve',
        info = {'n': pts_slice.shape[0], 'band_width': band_w, 'note':'no_final_curve',
        info = {'n': pts_slice.shape[0], 'band_width': band_w, 'note':'no_final_curve',
        info = {'n': pts_slice.shape[0], 'band_width': band_w, 'note':'no_final_curve',
        info = {'n': pts_slice.shape[0], 'band_width': band_w, 'note':'no_final_curve',
        info = {'n': pts_slice.shape[0], 'band_width': band_w, 'note':'no_final_curve',
        info = {'n': pts_slice.shape[0], 'band_width': band_w, 'note':'no_final_curve',
        info = {'n': pts_slice.shape[0], 'band_width': band_w, 'note':'no_final_curve',
                'kept': len(kept_indices), 'removed': 0}
                'kept': len(kept_indices), 'removed': 0}
                'kept': len(kept_indices), 'removed': 0}
                'kept': len(kept_indices), 'removed': 0}
                'kept': len(kept_indices), 'removed': 0}
                'kept': len(kept_indices), 'removed': 0}
                'kept': len(kept_indices), 'removed': 0}
                'kept': len(kept_indices), 'removed': 0}
                'kept': len(kept_indices), 'removed': 0}
                'kept': len(kept_indices), 'removed': 0}
                'kept': len(kept_indices), 'removed': 0}
                'kept': len(kept_indices), 'removed': 0}
                'kept': len(kept_indices), 'removed': 0}
                'kept': len(kept_indices), 'removed': 0}
                'kept': len(kept_indices), 'removed': 0}
                'kept': len(kept_indices), 'removed': 0}
                'kept': len(kept_indices), 'removed': 0}
                'kept': len(kept_indices), 'removed': 0}
                'kept': len(kept_indices), 'removed': 0}
                'kept': len(kept_indices), 'removed': 0}
                'kept': len(kept_indices), 'removed': 0}
                'kept': len(kept_indices), 'removed': 0}
                'kept': len(kept_indices), 'removed': 0}
                'kept': len(kept_indices), 'removed': 0}
                'kept': len(kept_indices), 'removed': 0}
                'kept': len(kept_indices), 'removed': 0}
                'kept': len(kept_indices), 'removed': 0}
                'kept': len(kept_indices), 'removed': 0}
                'kept': len(kept_indices), 'removed': 0}
                'kept': len(kept_indices), 'removed': 0}
                'kept': len(kept_indices), 'removed': 0}
                'kept': len(kept_indices), 'removed': 0}
                'kept': len(kept_indices), 'removed': 0}
                'kept': len(kept_indices), 'removed': 0}
                'kept': len(kept_indices), 'removed': 0}
                'kept': len(kept_indices), 'removed': 0}
                'kept': len(kept_indices), 'removed': 0}
        return kept_indices, info
        return kept_indices, info
        return kept_indices, info
        return kept_indices, info
        return kept_indices, info
        return kept_indices, info
        return kept_indices, info
        return kept_indices, info
        return kept_indices, info
        return kept_indices, info
        return kept_indices, info
        return kept_indices, info
        return kept_indices, info
        return kept_indices, info
        return kept_indices, info
        return kept_indices, info
        return kept_indices, info
        return kept_indices, info
        return kept_indices, info
        return kept_indices, info
        return kept_indices, info
        return kept_indices, info
        return kept_indices, info
        return kept_indices, info
        return kept_indices, info
        return kept_indices, info
        return kept_indices, info
        return kept_indices, info
        return kept_indices, info
        return kept_indices, info
        return kept_indices, info
        return kept_indices, info
        return kept_indices, info
        return kept_indices, info
        return kept_indices, info
        return kept_indices, info
        return kept_indices, info





































    tck2, _ = res2
    tck2, _ = res2
    tck2, _ = res2
    tck2, _ = res2
    tck2, _ = res2
    tck2, _ = res2
    tck2, _ = res2
    tck2, _ = res2
    tck2, _ = res2
    tck2, _ = res2
    tck2, _ = res2
    tck2, _ = res2
    tck2, _ = res2
    tck2, _ = res2
    tck2, _ = res2
    tck2, _ = res2
    tck2, _ = res2
    tck2, _ = res2
    tck2, _ = res2
    tck2, _ = res2
    tck2, _ = res2
    tck2, _ = res2
    tck2, _ = res2
    tck2, _ = res2
    tck2, _ = res2
    tck2, _ = res2
    tck2, _ = res2
    tck2, _ = res2
    tck2, _ = res2
    tck2, _ = res2
    tck2, _ = res2
    tck2, _ = res2
    tck2, _ = res2
    tck2, _ = res2
    tck2, _ = res2
    tck2, _ = res2
    tck2, _ = res2
    curve_final = eval_bspline_2d(tck2, n_samples=CURVE_SAMPLES)
    curve_final = eval_bspline_2d(tck2, n_samples=CURVE_SAMPLES)
    curve_final = eval_bspline_2d(tck2, n_samples=CURVE_SAMPLES)
    curve_final = eval_bspline_2d(tck2, n_samples=CURVE_SAMPLES)
    curve_final = eval_bspline_2d(tck2, n_samples=CURVE_SAMPLES)
    curve_final = eval_bspline_2d(tck2, n_samples=CURVE_SAMPLES)
    curve_final = eval_bspline_2d(tck2, n_samples=CURVE_SAMPLES)
    curve_final = eval_bspline_2d(tck2, n_samples=CURVE_SAMPLES)
    curve_final = eval_bspline_2d(tck2, n_samples=CURVE_SAMPLES)
    curve_final = eval_bspline_2d(tck2, n_samples=CURVE_SAMPLES)
    curve_final = eval_bspline_2d(tck2, n_samples=CURVE_SAMPLES)
    curve_final = eval_bspline_2d(tck2, n_samples=CURVE_SAMPLES)
    curve_final = eval_bspline_2d(tck2, n_samples=CURVE_SAMPLES)
    curve_final = eval_bspline_2d(tck2, n_samples=CURVE_SAMPLES)
    curve_final = eval_bspline_2d(tck2, n_samples=CURVE_SAMPLES)
    curve_final = eval_bspline_2d(tck2, n_samples=CURVE_SAMPLES)
    curve_final = eval_bspline_2d(tck2, n_samples=CURVE_SAMPLES)
    curve_final = eval_bspline_2d(tck2, n_samples=CURVE_SAMPLES)
    curve_final = eval_bspline_2d(tck2, n_samples=CURVE_SAMPLES)
    curve_final = eval_bspline_2d(tck2, n_samples=CURVE_SAMPLES)
    curve_final = eval_bspline_2d(tck2, n_samples=CURVE_SAMPLES)
    curve_final = eval_bspline_2d(tck2, n_samples=CURVE_SAMPLES)
    curve_final = eval_bspline_2d(tck2, n_samples=CURVE_SAMPLES)
    curve_final = eval_bspline_2d(tck2, n_samples=CURVE_SAMPLES)
    curve_final = eval_bspline_2d(tck2, n_samples=CURVE_SAMPLES)
    curve_final = eval_bspline_2d(tck2, n_samples=CURVE_SAMPLES)
    curve_final = eval_bspline_2d(tck2, n_samples=CURVE_SAMPLES)
    curve_final = eval_bspline_2d(tck2, n_samples=CURVE_SAMPLES)
    curve_final = eval_bspline_2d(tck2, n_samples=CURVE_SAMPLES)
    curve_final = eval_bspline_2d(tck2, n_samples=CURVE_SAMPLES)
    curve_final = eval_bspline_2d(tck2, n_samples=CURVE_SAMPLES)
    curve_final = eval_bspline_2d(tck2, n_samples=CURVE_SAMPLES)
    curve_final = eval_bspline_2d(tck2, n_samples=CURVE_SAMPLES)
    curve_final = eval_bspline_2d(tck2, n_samples=CURVE_SAMPLES)
    curve_final = eval_bspline_2d(tck2, n_samples=CURVE_SAMPLES)
    curve_final = eval_bspline_2d(tck2, n_samples=CURVE_SAMPLES)
    curve_final = eval_bspline_2d(tck2, n_samples=CURVE_SAMPLES)
    dists = distances_to_curve(coords2d, curve_final)
    dists = distances_to_curve(coords2d, curve_final)
    dists = distances_to_curve(coords2d, curve_final)
    dists = distances_to_curve(coords2d, curve_final)
    dists = distances_to_curve(coords2d, curve_final)
    dists = distances_to_curve(coords2d, curve_final)
    dists = distances_to_curve(coords2d, curve_final)
    dists = distances_to_curve(coords2d, curve_final)
    dists = distances_to_curve(coords2d, curve_final)
    dists = distances_to_curve(coords2d, curve_final)
    dists = distances_to_curve(coords2d, curve_final)
    dists = distances_to_curve(coords2d, curve_final)
    dists = distances_to_curve(coords2d, curve_final)
    dists = distances_to_curve(coords2d, curve_final)
    dists = distances_to_curve(coords2d, curve_final)
    dists = distances_to_curve(coords2d, curve_final)
    dists = distances_to_curve(coords2d, curve_final)
    dists = distances_to_curve(coords2d, curve_final)
    dists = distances_to_curve(coords2d, curve_final)
    dists = distances_to_curve(coords2d, curve_final)
    dists = distances_to_curve(coords2d, curve_final)
    dists = distances_to_curve(coords2d, curve_final)
    dists = distances_to_curve(coords2d, curve_final)
    dists = distances_to_curve(coords2d, curve_final)
    dists = distances_to_curve(coords2d, curve_final)
    dists = distances_to_curve(coords2d, curve_final)
    dists = distances_to_curve(coords2d, curve_final)
    dists = distances_to_curve(coords2d, curve_final)
    dists = distances_to_curve(coords2d, curve_final)
    dists = distances_to_curve(coords2d, curve_final)
    dists = distances_to_curve(coords2d, curve_final)
    dists = distances_to_curve(coords2d, curve_final)
    dists = distances_to_curve(coords2d, curve_final)
    dists = distances_to_curve(coords2d, curve_final)
    dists = distances_to_curve(coords2d, curve_final)
    dists = distances_to_curve(coords2d, curve_final)
    dists = distances_to_curve(coords2d, curve_final)
    # if band_w == 0 (line or very thin): fall back to median nn
    # if band_w == 0 (line or very thin): fall back to median nn
    # if band_w == 0 (line or very thin): fall back to median nn
    # if band_w == 0 (line or very thin): fall back to median nn
    # if band_w == 0 (line or very thin): fall back to median nn
    # if band_w == 0 (line or very thin): fall back to median nn
    # if band_w == 0 (line or very thin): fall back to median nn
    # if band_w == 0 (line or very thin): fall back to median nn
    # if band_w == 0 (line or very thin): fall back to median nn
    # if band_w == 0 (line or very thin): fall back to median nn
    # if band_w == 0 (line or very thin): fall back to median nn
    # if band_w == 0 (line or very thin): fall back to median nn
    # if band_w == 0 (line or very thin): fall back to median nn
    # if band_w == 0 (line or very thin): fall back to median nn
    # if band_w == 0 (line or very thin): fall back to median nn
    # if band_w == 0 (line or very thin): fall back to median nn
    # if band_w == 0 (line or very thin): fall back to median nn
    # if band_w == 0 (line or very thin): fall back to median nn
    # if band_w == 0 (line or very thin): fall back to median nn
    # if band_w == 0 (line or very thin): fall back to median nn
    # if band_w == 0 (line or very thin): fall back to median nn
    # if band_w == 0 (line or very thin): fall back to median nn
    # if band_w == 0 (line or very thin): fall back to median nn
    # if band_w == 0 (line or very thin): fall back to median nn
    # if band_w == 0 (line or very thin): fall back to median nn
    # if band_w == 0 (line or very thin): fall back to median nn
    # if band_w == 0 (line or very thin): fall back to median nn
    # if band_w == 0 (line or very thin): fall back to median nn
    # if band_w == 0 (line or very thin): fall back to median nn
    # if band_w == 0 (line or very thin): fall back to median nn
    # if band_w == 0 (line or very thin): fall back to median nn
    # if band_w == 0 (line or very thin): fall back to median nn
    # if band_w == 0 (line or very thin): fall back to median nn
    # if band_w == 0 (line or very thin): fall back to median nn
    # if band_w == 0 (line or very thin): fall back to median nn
    # if band_w == 0 (line or very thin): fall back to median nn
    # if band_w == 0 (line or very thin): fall back to median nn
    if pts_slice.shape[0] > 1:
    if pts_slice.shape[0] > 1:
    if pts_slice.shape[0] > 1:
    if pts_slice.shape[0] > 1:
    if pts_slice.shape[0] > 1:
    if pts_slice.shape[0] > 1:
    if pts_slice.shape[0] > 1:
    if pts_slice.shape[0] > 1:
    if pts_slice.shape[0] > 1:
    if pts_slice.shape[0] > 1:
    if pts_slice.shape[0] > 1:
    if pts_slice.shape[0] > 1:
    if pts_slice.shape[0] > 1:
    if pts_slice.shape[0] > 1:
    if pts_slice.shape[0] > 1:
    if pts_slice.shape[0] > 1:
    if pts_slice.shape[0] > 1:
    if pts_slice.shape[0] > 1:
    if pts_slice.shape[0] > 1:
    if pts_slice.shape[0] > 1:
    if pts_slice.shape[0] > 1:
    if pts_slice.shape[0] > 1:
    if pts_slice.shape[0] > 1:
    if pts_slice.shape[0] > 1:
    if pts_slice.shape[0] > 1:
    if pts_slice.shape[0] > 1:
    if pts_slice.shape[0] > 1:
    if pts_slice.shape[0] > 1:
    if pts_slice.shape[0] > 1:
    if pts_slice.shape[0] > 1:
    if pts_slice.shape[0] > 1:
    if pts_slice.shape[0] > 1:
    if pts_slice.shape[0] > 1:
    if pts_slice.shape[0] > 1:
    if pts_slice.shape[0] > 1:
    if pts_slice.shape[0] > 1:
    if pts_slice.shape[0] > 1:
        nn = NearestNeighbors(n_neighbors=min(10, pts_slice.shape[0]), algorithm='kd_tree').fit(coords2d)
        nn = NearestNeighbors(n_neighbors=min(10, pts_slice.shape[0]), algorithm='kd_tree').fit(coords2d)
        nn = NearestNeighbors(n_neighbors=min(10, pts_slice.shape[0]), algorithm='kd_tree').fit(coords2d)
        nn = NearestNeighbors(n_neighbors=min(10, pts_slice.shape[0]), algorithm='kd_tree').fit(coords2d)
        nn = NearestNeighbors(n_neighbors=min(10, pts_slice.shape[0]), algorithm='kd_tree').fit(coords2d)
        nn = NearestNeighbors(n_neighbors=min(10, pts_slice.shape[0]), algorithm='kd_tree').fit(coords2d)
        nn = NearestNeighbors(n_neighbors=min(10, pts_slice.shape[0]), algorithm='kd_tree').fit(coords2d)
        nn = NearestNeighbors(n_neighbors=min(10, pts_slice.shape[0]), algorithm='kd_tree').fit(coords2d)
        nn = NearestNeighbors(n_neighbors=min(10, pts_slice.shape[0]), algorithm='kd_tree').fit(coords2d)
        nn = NearestNeighbors(n_neighbors=min(10, pts_slice.shape[0]), algorithm='kd_tree').fit(coords2d)
        nn = NearestNeighbors(n_neighbors=min(10, pts_slice.shape[0]), algorithm='kd_tree').fit(coords2d)
        nn = NearestNeighbors(n_neighbors=min(10, pts_slice.shape[0]), algorithm='kd_tree').fit(coords2d)
        nn = NearestNeighbors(n_neighbors=min(10, pts_slice.shape[0]), algorithm='kd_tree').fit(coords2d)
        nn = NearestNeighbors(n_neighbors=min(10, pts_slice.shape[0]), algorithm='kd_tree').fit(coords2d)
        nn = NearestNeighbors(n_neighbors=min(10, pts_slice.shape[0]), algorithm='kd_tree').fit(coords2d)
        nn = NearestNeighbors(n_neighbors=min(10, pts_slice.shape[0]), algorithm='kd_tree').fit(coords2d)
        nn = NearestNeighbors(n_neighbors=min(10, pts_slice.shape[0]), algorithm='kd_tree').fit(coords2d)
        nn = NearestNeighbors(n_neighbors=min(10, pts_slice.shape[0]), algorithm='kd_tree').fit(coords2d)
        nn = NearestNeighbors(n_neighbors=min(10, pts_slice.shape[0]), algorithm='kd_tree').fit(coords2d)
        nn = NearestNeighbors(n_neighbors=min(10, pts_slice.shape[0]), algorithm='kd_tree').fit(coords2d)
        nn = NearestNeighbors(n_neighbors=min(10, pts_slice.shape[0]), algorithm='kd_tree').fit(coords2d)
        nn = NearestNeighbors(n_neighbors=min(10, pts_slice.shape[0]), algorithm='kd_tree').fit(coords2d)
        nn = NearestNeighbors(n_neighbors=min(10, pts_slice.shape[0]), algorithm='kd_tree').fit(coords2d)
        nn = NearestNeighbors(n_neighbors=min(10, pts_slice.shape[0]), algorithm='kd_tree').fit(coords2d)
        nn = NearestNeighbors(n_neighbors=min(10, pts_slice.shape[0]), algorithm='kd_tree').fit(coords2d)
        nn = NearestNeighbors(n_neighbors=min(10, pts_slice.shape[0]), algorithm='kd_tree').fit(coords2d)
        nn = NearestNeighbors(n_neighbors=min(10, pts_slice.shape[0]), algorithm='kd_tree').fit(coords2d)
        nn = NearestNeighbors(n_neighbors=min(10, pts_slice.shape[0]), algorithm='kd_tree').fit(coords2d)
        nn = NearestNeighbors(n_neighbors=min(10, pts_slice.shape[0]), algorithm='kd_tree').fit(coords2d)
        nn = NearestNeighbors(n_neighbors=min(10, pts_slice.shape[0]), algorithm='kd_tree').fit(coords2d)
        nn = NearestNeighbors(n_neighbors=min(10, pts_slice.shape[0]), algorithm='kd_tree').fit(coords2d)
        nn = NearestNeighbors(n_neighbors=min(10, pts_slice.shape[0]), algorithm='kd_tree').fit(coords2d)
        nn = NearestNeighbors(n_neighbors=min(10, pts_slice.shape[0]), algorithm='kd_tree').fit(coords2d)
        nn = NearestNeighbors(n_neighbors=min(10, pts_slice.shape[0]), algorithm='kd_tree').fit(coords2d)
        nn = NearestNeighbors(n_neighbors=min(10, pts_slice.shape[0]), algorithm='kd_tree').fit(coords2d)
        nn = NearestNeighbors(n_neighbors=min(10, pts_slice.shape[0]), algorithm='kd_tree').fit(coords2d)
        nn = NearestNeighbors(n_neighbors=min(10, pts_slice.shape[0]), algorithm='kd_tree').fit(coords2d)
        dd,_ = nn.kneighbors(coords2d)
        dd,_ = nn.kneighbors(coords2d)
        dd,_ = nn.kneighbors(coords2d)
        dd,_ = nn.kneighbors(coords2d)
        dd,_ = nn.kneighbors(coords2d)
        dd,_ = nn.kneighbors(coords2d)
        dd,_ = nn.kneighbors(coords2d)
        dd,_ = nn.kneighbors(coords2d)
        dd,_ = nn.kneighbors(coords2d)
        dd,_ = nn.kneighbors(coords2d)
        dd,_ = nn.kneighbors(coords2d)
        dd,_ = nn.kneighbors(coords2d)
        dd,_ = nn.kneighbors(coords2d)
        dd,_ = nn.kneighbors(coords2d)
        dd,_ = nn.kneighbors(coords2d)
        dd,_ = nn.kneighbors(coords2d)
        dd,_ = nn.kneighbors(coords2d)
        dd,_ = nn.kneighbors(coords2d)
        dd,_ = nn.kneighbors(coords2d)
        dd,_ = nn.kneighbors(coords2d)
        dd,_ = nn.kneighbors(coords2d)
        dd,_ = nn.kneighbors(coords2d)
        dd,_ = nn.kneighbors(coords2d)
        dd,_ = nn.kneighbors(coords2d)
        dd,_ = nn.kneighbors(coords2d)
        dd,_ = nn.kneighbors(coords2d)
        dd,_ = nn.kneighbors(coords2d)
        dd,_ = nn.kneighbors(coords2d)
        dd,_ = nn.kneighbors(coords2d)
        dd,_ = nn.kneighbors(coords2d)
        dd,_ = nn.kneighbors(coords2d)
        dd,_ = nn.kneighbors(coords2d)
        dd,_ = nn.kneighbors(coords2d)
        dd,_ = nn.kneighbors(coords2d)
        dd,_ = nn.kneighbors(coords2d)
        dd,_ = nn.kneighbors(coords2d)
        dd,_ = nn.kneighbors(coords2d)
        median_nn = float(np.median(dd[:,1])) if dd.shape[1]>1 else float(np.median(dd[:,0]))
        median_nn = float(np.median(dd[:,1])) if dd.shape[1]>1 else float(np.median(dd[:,0]))
        median_nn = float(np.median(dd[:,1])) if dd.shape[1]>1 else float(np.median(dd[:,0]))
        median_nn = float(np.median(dd[:,1])) if dd.shape[1]>1 else float(np.median(dd[:,0]))
        median_nn = float(np.median(dd[:,1])) if dd.shape[1]>1 else float(np.median(dd[:,0]))
        median_nn = float(np.median(dd[:,1])) if dd.shape[1]>1 else float(np.median(dd[:,0]))
        median_nn = float(np.median(dd[:,1])) if dd.shape[1]>1 else float(np.median(dd[:,0]))
        median_nn = float(np.median(dd[:,1])) if dd.shape[1]>1 else float(np.median(dd[:,0]))
        median_nn = float(np.median(dd[:,1])) if dd.shape[1]>1 else float(np.median(dd[:,0]))
        median_nn = float(np.median(dd[:,1])) if dd.shape[1]>1 else float(np.median(dd[:,0]))
        median_nn = float(np.median(dd[:,1])) if dd.shape[1]>1 else float(np.median(dd[:,0]))
        median_nn = float(np.median(dd[:,1])) if dd.shape[1]>1 else float(np.median(dd[:,0]))
        median_nn = float(np.median(dd[:,1])) if dd.shape[1]>1 else float(np.median(dd[:,0]))
        median_nn = float(np.median(dd[:,1])) if dd.shape[1]>1 else float(np.median(dd[:,0]))
        median_nn = float(np.median(dd[:,1])) if dd.shape[1]>1 else float(np.median(dd[:,0]))
        median_nn = float(np.median(dd[:,1])) if dd.shape[1]>1 else float(np.median(dd[:,0]))
        median_nn = float(np.median(dd[:,1])) if dd.shape[1]>1 else float(np.median(dd[:,0]))
        median_nn = float(np.median(dd[:,1])) if dd.shape[1]>1 else float(np.median(dd[:,0]))
        median_nn = float(np.median(dd[:,1])) if dd.shape[1]>1 else float(np.median(dd[:,0]))
        median_nn = float(np.median(dd[:,1])) if dd.shape[1]>1 else float(np.median(dd[:,0]))
        median_nn = float(np.median(dd[:,1])) if dd.shape[1]>1 else float(np.median(dd[:,0]))
        median_nn = float(np.median(dd[:,1])) if dd.shape[1]>1 else float(np.median(dd[:,0]))
        median_nn = float(np.median(dd[:,1])) if dd.shape[1]>1 else float(np.median(dd[:,0]))
        median_nn = float(np.median(dd[:,1])) if dd.shape[1]>1 else float(np.median(dd[:,0]))
        median_nn = float(np.median(dd[:,1])) if dd.shape[1]>1 else float(np.median(dd[:,0]))
        median_nn = float(np.median(dd[:,1])) if dd.shape[1]>1 else float(np.median(dd[:,0]))
        median_nn = float(np.median(dd[:,1])) if dd.shape[1]>1 else float(np.median(dd[:,0]))
        median_nn = float(np.median(dd[:,1])) if dd.shape[1]>1 else float(np.median(dd[:,0]))
        median_nn = float(np.median(dd[:,1])) if dd.shape[1]>1 else float(np.median(dd[:,0]))
        median_nn = float(np.median(dd[:,1])) if dd.shape[1]>1 else float(np.median(dd[:,0]))
        median_nn = float(np.median(dd[:,1])) if dd.shape[1]>1 else float(np.median(dd[:,0]))
        median_nn = float(np.median(dd[:,1])) if dd.shape[1]>1 else float(np.median(dd[:,0]))
        median_nn = float(np.median(dd[:,1])) if dd.shape[1]>1 else float(np.median(dd[:,0]))
        median_nn = float(np.median(dd[:,1])) if dd.shape[1]>1 else float(np.median(dd[:,0]))
        median_nn = float(np.median(dd[:,1])) if dd.shape[1]>1 else float(np.median(dd[:,0]))
        median_nn = float(np.median(dd[:,1])) if dd.shape[1]>1 else float(np.median(dd[:,0]))
        median_nn = float(np.median(dd[:,1])) if dd.shape[1]>1 else float(np.median(dd[:,0]))
    else:
    else:
    else:
    else:
    else:
    else:
    else:
    else:
    else:
    else:
    else:
    else:
    else:
    else:
    else:
    else:
    else:
    else:
    else:
    else:
    else:
    else:
    else:
    else:
    else:
    else:
    else:
    else:
    else:
    else:
    else:
    else:
    else:
    else:
    else:
    else:
    else:
        median_nn = 0.0
        median_nn = 0.0
        median_nn = 0.0
        median_nn = 0.0
        median_nn = 0.0
        median_nn = 0.0
        median_nn = 0.0
        median_nn = 0.0
        median_nn = 0.0
        median_nn = 0.0
        median_nn = 0.0
        median_nn = 0.0
        median_nn = 0.0
        median_nn = 0.0
        median_nn = 0.0
        median_nn = 0.0
        median_nn = 0.0
        median_nn = 0.0
        median_nn = 0.0
        median_nn = 0.0
        median_nn = 0.0
        median_nn = 0.0
        median_nn = 0.0
        median_nn = 0.0
        median_nn = 0.0
        median_nn = 0.0
        median_nn = 0.0
        median_nn = 0.0
        median_nn = 0.0
        median_nn = 0.0
        median_nn = 0.0
        median_nn = 0.0
        median_nn = 0.0
        median_nn = 0.0
        median_nn = 0.0
        median_nn = 0.0
        median_nn = 0.0
    thresh = DIST_FACTOR_TO_CURVE * max(band_w, median_nn, 1e-6)
    thresh = DIST_FACTOR_TO_CURVE * max(band_w, median_nn, 1e-6)
    thresh = DIST_FACTOR_TO_CURVE * max(band_w, median_nn, 1e-6)
    thresh = DIST_FACTOR_TO_CURVE * max(band_w, median_nn, 1e-6)
    thresh = DIST_FACTOR_TO_CURVE * max(band_w, median_nn, 1e-6)
    thresh = DIST_FACTOR_TO_CURVE * max(band_w, median_nn, 1e-6)
    thresh = DIST_FACTOR_TO_CURVE * max(band_w, median_nn, 1e-6)
    thresh = DIST_FACTOR_TO_CURVE * max(band_w, median_nn, 1e-6)
    thresh = DIST_FACTOR_TO_CURVE * max(band_w, median_nn, 1e-6)
    thresh = DIST_FACTOR_TO_CURVE * max(band_w, median_nn, 1e-6)
    thresh = DIST_FACTOR_TO_CURVE * max(band_w, median_nn, 1e-6)
    thresh = DIST_FACTOR_TO_CURVE * max(band_w, median_nn, 1e-6)
    thresh = DIST_FACTOR_TO_CURVE * max(band_w, median_nn, 1e-6)
    thresh = DIST_FACTOR_TO_CURVE * max(band_w, median_nn, 1e-6)
    thresh = DIST_FACTOR_TO_CURVE * max(band_w, median_nn, 1e-6)
    thresh = DIST_FACTOR_TO_CURVE * max(band_w, median_nn, 1e-6)
    thresh = DIST_FACTOR_TO_CURVE * max(band_w, median_nn, 1e-6)
    thresh = DIST_FACTOR_TO_CURVE * max(band_w, median_nn, 1e-6)
    thresh = DIST_FACTOR_TO_CURVE * max(band_w, median_nn, 1e-6)
    thresh = DIST_FACTOR_TO_CURVE * max(band_w, median_nn, 1e-6)
    thresh = DIST_FACTOR_TO_CURVE * max(band_w, median_nn, 1e-6)
    thresh = DIST_FACTOR_TO_CURVE * max(band_w, median_nn, 1e-6)
    thresh = DIST_FACTOR_TO_CURVE * max(band_w, median_nn, 1e-6)
    thresh = DIST_FACTOR_TO_CURVE * max(band_w, median_nn, 1e-6)
    thresh = DIST_FACTOR_TO_CURVE * max(band_w, median_nn, 1e-6)
    thresh = DIST_FACTOR_TO_CURVE * max(band_w, median_nn, 1e-6)
    thresh = DIST_FACTOR_TO_CURVE * max(band_w, median_nn, 1e-6)
    thresh = DIST_FACTOR_TO_CURVE * max(band_w, median_nn, 1e-6)
    thresh = DIST_FACTOR_TO_CURVE * max(band_w, median_nn, 1e-6)
    thresh = DIST_FACTOR_TO_CURVE * max(band_w, median_nn, 1e-6)
    thresh = DIST_FACTOR_TO_CURVE * max(band_w, median_nn, 1e-6)
    thresh = DIST_FACTOR_TO_CURVE * max(band_w, median_nn, 1e-6)
    thresh = DIST_FACTOR_TO_CURVE * max(band_w, median_nn, 1e-6)
    thresh = DIST_FACTOR_TO_CURVE * max(band_w, median_nn, 1e-6)
    thresh = DIST_FACTOR_TO_CURVE * max(band_w, median_nn, 1e-6)
    thresh = DIST_FACTOR_TO_CURVE * max(band_w, median_nn, 1e-6)
    thresh = DIST_FACTOR_TO_CURVE * max(band_w, median_nn, 1e-6)
    keep_mask = dists <= thresh
    keep_mask = dists <= thresh
    keep_mask = dists <= thresh
    keep_mask = dists <= thresh
    keep_mask = dists <= thresh
    keep_mask = dists <= thresh
    keep_mask = dists <= thresh
    keep_mask = dists <= thresh
    keep_mask = dists <= thresh
    keep_mask = dists <= thresh
    keep_mask = dists <= thresh
    keep_mask = dists <= thresh
    keep_mask = dists <= thresh
    keep_mask = dists <= thresh
    keep_mask = dists <= thresh
    keep_mask = dists <= thresh
    keep_mask = dists <= thresh
    keep_mask = dists <= thresh
    keep_mask = dists <= thresh
    keep_mask = dists <= thresh
    keep_mask = dists <= thresh
    keep_mask = dists <= thresh
    keep_mask = dists <= thresh
    keep_mask = dists <= thresh
    keep_mask = dists <= thresh
    keep_mask = dists <= thresh
    keep_mask = dists <= thresh
    keep_mask = dists <= thresh
    keep_mask = dists <= thresh
    keep_mask = dists <= thresh
    keep_mask = dists <= thresh
    keep_mask = dists <= thresh
    keep_mask = dists <= thresh
    keep_mask = dists <= thresh
    keep_mask = dists <= thresh
    keep_mask = dists <= thresh
    keep_mask = dists <= thresh
    kept_indices = np.array(points_idx)[keep_mask]
    kept_indices = np.array(points_idx)[keep_mask]
    kept_indices = np.array(points_idx)[keep_mask]
    kept_indices = np.array(points_idx)[keep_mask]
    kept_indices = np.array(points_idx)[keep_mask]
    kept_indices = np.array(points_idx)[keep_mask]
    kept_indices = np.array(points_idx)[keep_mask]
    kept_indices = np.array(points_idx)[keep_mask]
    kept_indices = np.array(points_idx)[keep_mask]
    kept_indices = np.array(points_idx)[keep_mask]
    kept_indices = np.array(points_idx)[keep_mask]
    kept_indices = np.array(points_idx)[keep_mask]
    kept_indices = np.array(points_idx)[keep_mask]
    kept_indices = np.array(points_idx)[keep_mask]
    kept_indices = np.array(points_idx)[keep_mask]
    kept_indices = np.array(points_idx)[keep_mask]
    kept_indices = np.array(points_idx)[keep_mask]
    kept_indices = np.array(points_idx)[keep_mask]
    kept_indices = np.array(points_idx)[keep_mask]
    kept_indices = np.array(points_idx)[keep_mask]
    kept_indices = np.array(points_idx)[keep_mask]
    kept_indices = np.array(points_idx)[keep_mask]
    kept_indices = np.array(points_idx)[keep_mask]
    kept_indices = np.array(points_idx)[keep_mask]
    kept_indices = np.array(points_idx)[keep_mask]
    kept_indices = np.array(points_idx)[keep_mask]
    kept_indices = np.array(points_idx)[keep_mask]
    kept_indices = np.array(points_idx)[keep_mask]
    kept_indices = np.array(points_idx)[keep_mask]
    kept_indices = np.array(points_idx)[keep_mask]
    kept_indices = np.array(points_idx)[keep_mask]
    kept_indices = np.array(points_idx)[keep_mask]
    kept_indices = np.array(points_idx)[keep_mask]
    kept_indices = np.array(points_idx)[keep_mask]
    kept_indices = np.array(points_idx)[keep_mask]
    kept_indices = np.array(points_idx)[keep_mask]
    kept_indices = np.array(points_idx)[keep_mask]
    info = {'n': pts_slice.shape[0], 'band_width': band_w, 'median_nn': median_nn,
    info = {'n': pts_slice.shape[0], 'band_width': band_w, 'median_nn': median_nn,
    info = {'n': pts_slice.shape[0], 'band_width': band_w, 'median_nn': median_nn,
    info = {'n': pts_slice.shape[0], 'band_width': band_w, 'median_nn': median_nn,
    info = {'n': pts_slice.shape[0], 'band_width': band_w, 'median_nn': median_nn,
    info = {'n': pts_slice.shape[0], 'band_width': band_w, 'median_nn': median_nn,
    info = {'n': pts_slice.shape[0], 'band_width': band_w, 'median_nn': median_nn,
    info = {'n': pts_slice.shape[0], 'band_width': band_w, 'median_nn': median_nn,
    info = {'n': pts_slice.shape[0], 'band_width': band_w, 'median_nn': median_nn,
    info = {'n': pts_slice.shape[0], 'band_width': band_w, 'median_nn': median_nn,
    info = {'n': pts_slice.shape[0], 'band_width': band_w, 'median_nn': median_nn,
    info = {'n': pts_slice.shape[0], 'band_width': band_w, 'median_nn': median_nn,
    info = {'n': pts_slice.shape[0], 'band_width': band_w, 'median_nn': median_nn,
    info = {'n': pts_slice.shape[0], 'band_width': band_w, 'median_nn': median_nn,
    info = {'n': pts_slice.shape[0], 'band_width': band_w, 'median_nn': median_nn,
    info = {'n': pts_slice.shape[0], 'band_width': band_w, 'median_nn': median_nn,
    info = {'n': pts_slice.shape[0], 'band_width': band_w, 'median_nn': median_nn,
    info = {'n': pts_slice.shape[0], 'band_width': band_w, 'median_nn': median_nn,
    info = {'n': pts_slice.shape[0], 'band_width': band_w, 'median_nn': median_nn,
    info = {'n': pts_slice.shape[0], 'band_width': band_w, 'median_nn': median_nn,
    info = {'n': pts_slice.shape[0], 'band_width': band_w, 'median_nn': median_nn,
    info = {'n': pts_slice.shape[0], 'band_width': band_w, 'median_nn': median_nn,
    info = {'n': pts_slice.shape[0], 'band_width': band_w, 'median_nn': median_nn,
    info = {'n': pts_slice.shape[0], 'band_width': band_w, 'median_nn': median_nn,
    info = {'n': pts_slice.shape[0], 'band_width': band_w, 'median_nn': median_nn,
    info = {'n': pts_slice.shape[0], 'band_width': band_w, 'median_nn': median_nn,
    info = {'n': pts_slice.shape[0], 'band_width': band_w, 'median_nn': median_nn,
    info = {'n': pts_slice.shape[0], 'band_width': band_w, 'median_nn': median_nn,
    info = {'n': pts_slice.shape[0], 'band_width': band_w, 'median_nn': median_nn,
    info = {'n': pts_slice.shape[0], 'band_width': band_w, 'median_nn': median_nn,
    info = {'n': pts_slice.shape[0], 'band_width': band_w, 'median_nn': median_nn,
    info = {'n': pts_slice.shape[0], 'band_width': band_w, 'median_nn': median_nn,
    info = {'n': pts_slice.shape[0], 'band_width': band_w, 'median_nn': median_nn,
    info = {'n': pts_slice.shape[0], 'band_width': band_w, 'median_nn': median_nn,
    info = {'n': pts_slice.shape[0], 'band_width': band_w, 'median_nn': median_nn,
    info = {'n': pts_slice.shape[0], 'band_width': band_w, 'median_nn': median_nn,
    info = {'n': pts_slice.shape[0], 'band_width': band_w, 'median_nn': median_nn,
            'thresh': thresh, 'kept': int(keep_mask.sum()), 'removed': int(np.sum(~keep_mask))}
            'thresh': thresh, 'kept': int(keep_mask.sum()), 'removed': int(np.sum(~keep_mask))}
            'thresh': thresh, 'kept': int(keep_mask.sum()), 'removed': int(np.sum(~keep_mask))}
            'thresh': thresh, 'kept': int(keep_mask.sum()), 'removed': int(np.sum(~keep_mask))}
            'thresh': thresh, 'kept': int(keep_mask.sum()), 'removed': int(np.sum(~keep_mask))}
            'thresh': thresh, 'kept': int(keep_mask.sum()), 'removed': int(np.sum(~keep_mask))}
            'thresh': thresh, 'kept': int(keep_mask.sum()), 'removed': int(np.sum(~keep_mask))}
            'thresh': thresh, 'kept': int(keep_mask.sum()), 'removed': int(np.sum(~keep_mask))}
            'thresh': thresh, 'kept': int(keep_mask.sum()), 'removed': int(np.sum(~keep_mask))}
            'thresh': thresh, 'kept': int(keep_mask.sum()), 'removed': int(np.sum(~keep_mask))}
            'thresh': thresh, 'kept': int(keep_mask.sum()), 'removed': int(np.sum(~keep_mask))}
            'thresh': thresh, 'kept': int(keep_mask.sum()), 'removed': int(np.sum(~keep_mask))}
            'thresh': thresh, 'kept': int(keep_mask.sum()), 'removed': int(np.sum(~keep_mask))}
            'thresh': thresh, 'kept': int(keep_mask.sum()), 'removed': int(np.sum(~keep_mask))}
            'thresh': thresh, 'kept': int(keep_mask.sum()), 'removed': int(np.sum(~keep_mask))}
            'thresh': thresh, 'kept': int(keep_mask.sum()), 'removed': int(np.sum(~keep_mask))}
            'thresh': thresh, 'kept': int(keep_mask.sum()), 'removed': int(np.sum(~keep_mask))}
            'thresh': thresh, 'kept': int(keep_mask.sum()), 'removed': int(np.sum(~keep_mask))}
            'thresh': thresh, 'kept': int(keep_mask.sum()), 'removed': int(np.sum(~keep_mask))}
            'thresh': thresh, 'kept': int(keep_mask.sum()), 'removed': int(np.sum(~keep_mask))}
            'thresh': thresh, 'kept': int(keep_mask.sum()), 'removed': int(np.sum(~keep_mask))}
            'thresh': thresh, 'kept': int(keep_mask.sum()), 'removed': int(np.sum(~keep_mask))}
            'thresh': thresh, 'kept': int(keep_mask.sum()), 'removed': int(np.sum(~keep_mask))}
            'thresh': thresh, 'kept': int(keep_mask.sum()), 'removed': int(np.sum(~keep_mask))}
            'thresh': thresh, 'kept': int(keep_mask.sum()), 'removed': int(np.sum(~keep_mask))}
            'thresh': thresh, 'kept': int(keep_mask.sum()), 'removed': int(np.sum(~keep_mask))}
            'thresh': thresh, 'kept': int(keep_mask.sum()), 'removed': int(np.sum(~keep_mask))}
            'thresh': thresh, 'kept': int(keep_mask.sum()), 'removed': int(np.sum(~keep_mask))}
            'thresh': thresh, 'kept': int(keep_mask.sum()), 'removed': int(np.sum(~keep_mask))}
            'thresh': thresh, 'kept': int(keep_mask.sum()), 'removed': int(np.sum(~keep_mask))}
            'thresh': thresh, 'kept': int(keep_mask.sum()), 'removed': int(np.sum(~keep_mask))}
            'thresh': thresh, 'kept': int(keep_mask.sum()), 'removed': int(np.sum(~keep_mask))}
            'thresh': thresh, 'kept': int(keep_mask.sum()), 'removed': int(np.sum(~keep_mask))}
            'thresh': thresh, 'kept': int(keep_mask.sum()), 'removed': int(np.sum(~keep_mask))}
            'thresh': thresh, 'kept': int(keep_mask.sum()), 'removed': int(np.sum(~keep_mask))}
            'thresh': thresh, 'kept': int(keep_mask.sum()), 'removed': int(np.sum(~keep_mask))}
            'thresh': thresh, 'kept': int(keep_mask.sum()), 'removed': int(np.sum(~keep_mask))}
    return kept_indices, info    return kept_indices, info    return kept_indices, info    return kept_indices, info    return kept_indices, info    return kept_indices, info    return kept_indices, info    return kept_indices, info    return kept_indices, info    return kept_indices, info    return kept_indices, info    return kept_indices, info    return kept_indices, info    return kept_indices, info    return kept_indices, info    return kept_indices, info    return kept_indices, info    return kept_indices, info    return kept_indices, info    return kept_indices, info    return kept_indices, info    return kept_indices, info    return kept_indices, info    return kept_indices, info    return kept_indices, info    return kept_indices, info    return kept_indices, info    return kept_indices, info    return kept_indices, info    return kept_indices, info    return kept_indices, info    return kept_indices, info    return kept_indices, info    return kept_indices, info    return kept_indices, info    return kept_indices, info    return kept_indices, info

# %% [markdown]
# ### ---------- Final stage: cluster-based pruning of small components (in 3D space) ----------
# ### ---------- Final stage: cluster-based pruning of small components (in 3D space) ----------
# ### ---------- Final stage: cluster-based pruning of small components (in 3D space) ----------
# ### ---------- Final stage: cluster-based pruning of small components (in 3D space) ----------
# ### ---------- Final stage: cluster-based pruning of small components (in 3D space) ----------
# ### ---------- Final stage: cluster-based pruning of small components (in 3D space) ----------
# ### ---------- Final stage: cluster-based pruning of small components (in 3D space) ----------
# ### ---------- Final stage: cluster-based pruning of small components (in 3D space) ----------
# ### ---------- Final stage: cluster-based pruning of small components (in 3D space) ----------
# ### ---------- Final stage: cluster-based pruning of small components (in 3D space) ----------
# ### ---------- Final stage: cluster-based pruning of small components (in 3D space) ----------
# ### ---------- Final stage: cluster-based pruning of small components (in 3D space) ----------
# ### ---------- Final stage: cluster-based pruning of small components (in 3D space) ----------
# ### ---------- Final stage: cluster-based pruning of small components (in 3D space) ----------
# ### ---------- Final stage: cluster-based pruning of small components (in 3D space) ----------
# ### ---------- Final stage: cluster-based pruning of small components (in 3D space) ----------
# ### ---------- Final stage: cluster-based pruning of small components (in 3D space) ----------
# ### ---------- Final stage: cluster-based pruning of small components (in 3D space) ----------
# ### ---------- Final stage: cluster-based pruning of small components (in 3D space) ----------
# ### ---------- Final stage: cluster-based pruning of small components (in 3D space) ----------
# ### ---------- Final stage: cluster-based pruning of small components (in 3D space) ----------
# ### ---------- Final stage: cluster-based pruning of small components (in 3D space) ----------
# ### ---------- Final stage: cluster-based pruning of small components (in 3D space) ----------
# ### ---------- Final stage: cluster-based pruning of small components (in 3D space) ----------
# ### ---------- Final stage: cluster-based pruning of small components (in 3D space) ----------
# ### ---------- Final stage: cluster-based pruning of small components (in 3D space) ----------
# ### ---------- Final stage: cluster-based pruning of small components (in 3D space) ----------
# ### ---------- Final stage: cluster-based pruning of small components (in 3D space) ----------
# ### ---------- Final stage: cluster-based pruning of small components (in 3D space) ----------
# ### ---------- Final stage: cluster-based pruning of small components (in 3D space) ----------
# ### ---------- Final stage: cluster-based pruning of small components (in 3D space) ----------
# ### ---------- Final stage: cluster-based pruning of small components (in 3D space) ----------
# ### ---------- Final stage: cluster-based pruning of small components (in 3D space) ----------
# ### ---------- Final stage: cluster-based pruning of small components (in 3D space) ----------
# ### ---------- Final stage: cluster-based pruning of small components (in 3D space) ----------
# ### ---------- Final stage: cluster-based pruning of small components (in 3D space) ----------
# ### ---------- Final stage: cluster-based pruning of small components (in 3D space) ----------

# %%
def prune_small_clusters(pts_kept, original_indices):
def prune_small_clusters(pts_kept, original_indices):
def prune_small_clusters(pts_kept, original_indices):
def prune_small_clusters(pts_kept, original_indices):
def prune_small_clusters(pts_kept, original_indices):
def prune_small_clusters(pts_kept, original_indices):
def prune_small_clusters(pts_kept, original_indices):
def prune_small_clusters(pts_kept, original_indices):
def prune_small_clusters(pts_kept, original_indices):
def prune_small_clusters(pts_kept, original_indices):
def prune_small_clusters(pts_kept, original_indices):
def prune_small_clusters(pts_kept, original_indices):
def prune_small_clusters(pts_kept, original_indices):
def prune_small_clusters(pts_kept, original_indices):
def prune_small_clusters(pts_kept, original_indices):
def prune_small_clusters(pts_kept, original_indices):
def prune_small_clusters(pts_kept, original_indices):
def prune_small_clusters(pts_kept, original_indices):
def prune_small_clusters(pts_kept, original_indices):
def prune_small_clusters(pts_kept, original_indices):
def prune_small_clusters(pts_kept, original_indices):
def prune_small_clusters(pts_kept, original_indices):
def prune_small_clusters(pts_kept, original_indices):
def prune_small_clusters(pts_kept, original_indices):
def prune_small_clusters(pts_kept, original_indices):
def prune_small_clusters(pts_kept, original_indices):
def prune_small_clusters(pts_kept, original_indices):
def prune_small_clusters(pts_kept, original_indices):
def prune_small_clusters(pts_kept, original_indices):
def prune_small_clusters(pts_kept, original_indices):
def prune_small_clusters(pts_kept, original_indices):
def prune_small_clusters(pts_kept, original_indices):
def prune_small_clusters(pts_kept, original_indices):
def prune_small_clusters(pts_kept, original_indices):
def prune_small_clusters(pts_kept, original_indices):
def prune_small_clusters(pts_kept, original_indices):
def prune_small_clusters(pts_kept, original_indices):
    if len(pts_kept) == 0:
    if len(pts_kept) == 0:
    if len(pts_kept) == 0:
    if len(pts_kept) == 0:
    if len(pts_kept) == 0:
    if len(pts_kept) == 0:
    if len(pts_kept) == 0:
    if len(pts_kept) == 0:
    if len(pts_kept) == 0:
    if len(pts_kept) == 0:
    if len(pts_kept) == 0:
    if len(pts_kept) == 0:
    if len(pts_kept) == 0:
    if len(pts_kept) == 0:
    if len(pts_kept) == 0:
    if len(pts_kept) == 0:
    if len(pts_kept) == 0:
    if len(pts_kept) == 0:
    if len(pts_kept) == 0:
    if len(pts_kept) == 0:
    if len(pts_kept) == 0:
    if len(pts_kept) == 0:
    if len(pts_kept) == 0:
    if len(pts_kept) == 0:
    if len(pts_kept) == 0:
    if len(pts_kept) == 0:
    if len(pts_kept) == 0:
    if len(pts_kept) == 0:
    if len(pts_kept) == 0:
    if len(pts_kept) == 0:
    if len(pts_kept) == 0:
    if len(pts_kept) == 0:
    if len(pts_kept) == 0:
    if len(pts_kept) == 0:
    if len(pts_kept) == 0:
    if len(pts_kept) == 0:
    if len(pts_kept) == 0:
        return np.array([], dtype=int), {'n_clusters_kept':0}
        return np.array([], dtype=int), {'n_clusters_kept':0}
        return np.array([], dtype=int), {'n_clusters_kept':0}
        return np.array([], dtype=int), {'n_clusters_kept':0}
        return np.array([], dtype=int), {'n_clusters_kept':0}
        return np.array([], dtype=int), {'n_clusters_kept':0}
        return np.array([], dtype=int), {'n_clusters_kept':0}
        return np.array([], dtype=int), {'n_clusters_kept':0}
        return np.array([], dtype=int), {'n_clusters_kept':0}
        return np.array([], dtype=int), {'n_clusters_kept':0}
        return np.array([], dtype=int), {'n_clusters_kept':0}
        return np.array([], dtype=int), {'n_clusters_kept':0}
        return np.array([], dtype=int), {'n_clusters_kept':0}
        return np.array([], dtype=int), {'n_clusters_kept':0}
        return np.array([], dtype=int), {'n_clusters_kept':0}
        return np.array([], dtype=int), {'n_clusters_kept':0}
        return np.array([], dtype=int), {'n_clusters_kept':0}
        return np.array([], dtype=int), {'n_clusters_kept':0}
        return np.array([], dtype=int), {'n_clusters_kept':0}
        return np.array([], dtype=int), {'n_clusters_kept':0}
        return np.array([], dtype=int), {'n_clusters_kept':0}
        return np.array([], dtype=int), {'n_clusters_kept':0}
        return np.array([], dtype=int), {'n_clusters_kept':0}
        return np.array([], dtype=int), {'n_clusters_kept':0}
        return np.array([], dtype=int), {'n_clusters_kept':0}
        return np.array([], dtype=int), {'n_clusters_kept':0}
        return np.array([], dtype=int), {'n_clusters_kept':0}
        return np.array([], dtype=int), {'n_clusters_kept':0}
        return np.array([], dtype=int), {'n_clusters_kept':0}
        return np.array([], dtype=int), {'n_clusters_kept':0}
        return np.array([], dtype=int), {'n_clusters_kept':0}
        return np.array([], dtype=int), {'n_clusters_kept':0}
        return np.array([], dtype=int), {'n_clusters_kept':0}
        return np.array([], dtype=int), {'n_clusters_kept':0}
        return np.array([], dtype=int), {'n_clusters_kept':0}
        return np.array([], dtype=int), {'n_clusters_kept':0}
        return np.array([], dtype=int), {'n_clusters_kept':0}
    # compute global median_nn to determine DBSCAN eps
    # compute global median_nn to determine DBSCAN eps
    # compute global median_nn to determine DBSCAN eps
    # compute global median_nn to determine DBSCAN eps
    # compute global median_nn to determine DBSCAN eps
    # compute global median_nn to determine DBSCAN eps
    # compute global median_nn to determine DBSCAN eps
    # compute global median_nn to determine DBSCAN eps
    # compute global median_nn to determine DBSCAN eps
    # compute global median_nn to determine DBSCAN eps
    # compute global median_nn to determine DBSCAN eps
    # compute global median_nn to determine DBSCAN eps
    # compute global median_nn to determine DBSCAN eps
    # compute global median_nn to determine DBSCAN eps
    # compute global median_nn to determine DBSCAN eps
    # compute global median_nn to determine DBSCAN eps
    # compute global median_nn to determine DBSCAN eps
    # compute global median_nn to determine DBSCAN eps
    # compute global median_nn to determine DBSCAN eps
    # compute global median_nn to determine DBSCAN eps
    # compute global median_nn to determine DBSCAN eps
    # compute global median_nn to determine DBSCAN eps
    # compute global median_nn to determine DBSCAN eps
    # compute global median_nn to determine DBSCAN eps
    # compute global median_nn to determine DBSCAN eps
    # compute global median_nn to determine DBSCAN eps
    # compute global median_nn to determine DBSCAN eps
    # compute global median_nn to determine DBSCAN eps
    # compute global median_nn to determine DBSCAN eps
    # compute global median_nn to determine DBSCAN eps
    # compute global median_nn to determine DBSCAN eps
    # compute global median_nn to determine DBSCAN eps
    # compute global median_nn to determine DBSCAN eps
    # compute global median_nn to determine DBSCAN eps
    # compute global median_nn to determine DBSCAN eps
    # compute global median_nn to determine DBSCAN eps
    # compute global median_nn to determine DBSCAN eps
    nn_all = NearestNeighbors(n_neighbors=min(10, len(pts_kept)), algorithm='kd_tree').fit(pts_kept)
    nn_all = NearestNeighbors(n_neighbors=min(10, len(pts_kept)), algorithm='kd_tree').fit(pts_kept)
    nn_all = NearestNeighbors(n_neighbors=min(10, len(pts_kept)), algorithm='kd_tree').fit(pts_kept)
    nn_all = NearestNeighbors(n_neighbors=min(10, len(pts_kept)), algorithm='kd_tree').fit(pts_kept)
    nn_all = NearestNeighbors(n_neighbors=min(10, len(pts_kept)), algorithm='kd_tree').fit(pts_kept)
    nn_all = NearestNeighbors(n_neighbors=min(10, len(pts_kept)), algorithm='kd_tree').fit(pts_kept)
    nn_all = NearestNeighbors(n_neighbors=min(10, len(pts_kept)), algorithm='kd_tree').fit(pts_kept)
    nn_all = NearestNeighbors(n_neighbors=min(10, len(pts_kept)), algorithm='kd_tree').fit(pts_kept)
    nn_all = NearestNeighbors(n_neighbors=min(10, len(pts_kept)), algorithm='kd_tree').fit(pts_kept)
    nn_all = NearestNeighbors(n_neighbors=min(10, len(pts_kept)), algorithm='kd_tree').fit(pts_kept)
    nn_all = NearestNeighbors(n_neighbors=min(10, len(pts_kept)), algorithm='kd_tree').fit(pts_kept)
    nn_all = NearestNeighbors(n_neighbors=min(10, len(pts_kept)), algorithm='kd_tree').fit(pts_kept)
    nn_all = NearestNeighbors(n_neighbors=min(10, len(pts_kept)), algorithm='kd_tree').fit(pts_kept)
    nn_all = NearestNeighbors(n_neighbors=min(10, len(pts_kept)), algorithm='kd_tree').fit(pts_kept)
    nn_all = NearestNeighbors(n_neighbors=min(10, len(pts_kept)), algorithm='kd_tree').fit(pts_kept)
    nn_all = NearestNeighbors(n_neighbors=min(10, len(pts_kept)), algorithm='kd_tree').fit(pts_kept)
    nn_all = NearestNeighbors(n_neighbors=min(10, len(pts_kept)), algorithm='kd_tree').fit(pts_kept)
    nn_all = NearestNeighbors(n_neighbors=min(10, len(pts_kept)), algorithm='kd_tree').fit(pts_kept)
    nn_all = NearestNeighbors(n_neighbors=min(10, len(pts_kept)), algorithm='kd_tree').fit(pts_kept)
    nn_all = NearestNeighbors(n_neighbors=min(10, len(pts_kept)), algorithm='kd_tree').fit(pts_kept)
    nn_all = NearestNeighbors(n_neighbors=min(10, len(pts_kept)), algorithm='kd_tree').fit(pts_kept)
    nn_all = NearestNeighbors(n_neighbors=min(10, len(pts_kept)), algorithm='kd_tree').fit(pts_kept)
    nn_all = NearestNeighbors(n_neighbors=min(10, len(pts_kept)), algorithm='kd_tree').fit(pts_kept)
    nn_all = NearestNeighbors(n_neighbors=min(10, len(pts_kept)), algorithm='kd_tree').fit(pts_kept)
    nn_all = NearestNeighbors(n_neighbors=min(10, len(pts_kept)), algorithm='kd_tree').fit(pts_kept)
    nn_all = NearestNeighbors(n_neighbors=min(10, len(pts_kept)), algorithm='kd_tree').fit(pts_kept)
    nn_all = NearestNeighbors(n_neighbors=min(10, len(pts_kept)), algorithm='kd_tree').fit(pts_kept)
    nn_all = NearestNeighbors(n_neighbors=min(10, len(pts_kept)), algorithm='kd_tree').fit(pts_kept)
    nn_all = NearestNeighbors(n_neighbors=min(10, len(pts_kept)), algorithm='kd_tree').fit(pts_kept)
    nn_all = NearestNeighbors(n_neighbors=min(10, len(pts_kept)), algorithm='kd_tree').fit(pts_kept)
    nn_all = NearestNeighbors(n_neighbors=min(10, len(pts_kept)), algorithm='kd_tree').fit(pts_kept)
    nn_all = NearestNeighbors(n_neighbors=min(10, len(pts_kept)), algorithm='kd_tree').fit(pts_kept)
    nn_all = NearestNeighbors(n_neighbors=min(10, len(pts_kept)), algorithm='kd_tree').fit(pts_kept)
    nn_all = NearestNeighbors(n_neighbors=min(10, len(pts_kept)), algorithm='kd_tree').fit(pts_kept)
    nn_all = NearestNeighbors(n_neighbors=min(10, len(pts_kept)), algorithm='kd_tree').fit(pts_kept)
    nn_all = NearestNeighbors(n_neighbors=min(10, len(pts_kept)), algorithm='kd_tree').fit(pts_kept)
    nn_all = NearestNeighbors(n_neighbors=min(10, len(pts_kept)), algorithm='kd_tree').fit(pts_kept)
    d,_ = nn_all.kneighbors(pts_kept)
    d,_ = nn_all.kneighbors(pts_kept)
    d,_ = nn_all.kneighbors(pts_kept)
    d,_ = nn_all.kneighbors(pts_kept)
    d,_ = nn_all.kneighbors(pts_kept)
    d,_ = nn_all.kneighbors(pts_kept)
    d,_ = nn_all.kneighbors(pts_kept)
    d,_ = nn_all.kneighbors(pts_kept)
    d,_ = nn_all.kneighbors(pts_kept)
    d,_ = nn_all.kneighbors(pts_kept)
    d,_ = nn_all.kneighbors(pts_kept)
    d,_ = nn_all.kneighbors(pts_kept)
    d,_ = nn_all.kneighbors(pts_kept)
    d,_ = nn_all.kneighbors(pts_kept)
    d,_ = nn_all.kneighbors(pts_kept)
    d,_ = nn_all.kneighbors(pts_kept)
    d,_ = nn_all.kneighbors(pts_kept)
    d,_ = nn_all.kneighbors(pts_kept)
    d,_ = nn_all.kneighbors(pts_kept)
    d,_ = nn_all.kneighbors(pts_kept)
    d,_ = nn_all.kneighbors(pts_kept)
    d,_ = nn_all.kneighbors(pts_kept)
    d,_ = nn_all.kneighbors(pts_kept)
    d,_ = nn_all.kneighbors(pts_kept)
    d,_ = nn_all.kneighbors(pts_kept)
    d,_ = nn_all.kneighbors(pts_kept)
    d,_ = nn_all.kneighbors(pts_kept)
    d,_ = nn_all.kneighbors(pts_kept)
    d,_ = nn_all.kneighbors(pts_kept)
    d,_ = nn_all.kneighbors(pts_kept)
    d,_ = nn_all.kneighbors(pts_kept)
    d,_ = nn_all.kneighbors(pts_kept)
    d,_ = nn_all.kneighbors(pts_kept)
    d,_ = nn_all.kneighbors(pts_kept)
    d,_ = nn_all.kneighbors(pts_kept)
    d,_ = nn_all.kneighbors(pts_kept)
    d,_ = nn_all.kneighbors(pts_kept)
    median_nn = float(np.median(d[:, -1]))
    median_nn = float(np.median(d[:, -1]))
    median_nn = float(np.median(d[:, -1]))
    median_nn = float(np.median(d[:, -1]))
    median_nn = float(np.median(d[:, -1]))
    median_nn = float(np.median(d[:, -1]))
    median_nn = float(np.median(d[:, -1]))
    median_nn = float(np.median(d[:, -1]))
    median_nn = float(np.median(d[:, -1]))
    median_nn = float(np.median(d[:, -1]))
    median_nn = float(np.median(d[:, -1]))
    median_nn = float(np.median(d[:, -1]))
    median_nn = float(np.median(d[:, -1]))
    median_nn = float(np.median(d[:, -1]))
    median_nn = float(np.median(d[:, -1]))
    median_nn = float(np.median(d[:, -1]))
    median_nn = float(np.median(d[:, -1]))
    median_nn = float(np.median(d[:, -1]))
    median_nn = float(np.median(d[:, -1]))
    median_nn = float(np.median(d[:, -1]))
    median_nn = float(np.median(d[:, -1]))
    median_nn = float(np.median(d[:, -1]))
    median_nn = float(np.median(d[:, -1]))
    median_nn = float(np.median(d[:, -1]))
    median_nn = float(np.median(d[:, -1]))
    median_nn = float(np.median(d[:, -1]))
    median_nn = float(np.median(d[:, -1]))
    median_nn = float(np.median(d[:, -1]))
    median_nn = float(np.median(d[:, -1]))
    median_nn = float(np.median(d[:, -1]))
    median_nn = float(np.median(d[:, -1]))
    median_nn = float(np.median(d[:, -1]))
    median_nn = float(np.median(d[:, -1]))
    median_nn = float(np.median(d[:, -1]))
    median_nn = float(np.median(d[:, -1]))
    median_nn = float(np.median(d[:, -1]))
    median_nn = float(np.median(d[:, -1]))
    eps = DBSCAN_EPS_FACTOR * max(median_nn, 1e-6)
    eps = DBSCAN_EPS_FACTOR * max(median_nn, 1e-6)
    eps = DBSCAN_EPS_FACTOR * max(median_nn, 1e-6)
    eps = DBSCAN_EPS_FACTOR * max(median_nn, 1e-6)
    eps = DBSCAN_EPS_FACTOR * max(median_nn, 1e-6)
    eps = DBSCAN_EPS_FACTOR * max(median_nn, 1e-6)
    eps = DBSCAN_EPS_FACTOR * max(median_nn, 1e-6)
    eps = DBSCAN_EPS_FACTOR * max(median_nn, 1e-6)
    eps = DBSCAN_EPS_FACTOR * max(median_nn, 1e-6)
    eps = DBSCAN_EPS_FACTOR * max(median_nn, 1e-6)
    eps = DBSCAN_EPS_FACTOR * max(median_nn, 1e-6)
    eps = DBSCAN_EPS_FACTOR * max(median_nn, 1e-6)
    eps = DBSCAN_EPS_FACTOR * max(median_nn, 1e-6)
    eps = DBSCAN_EPS_FACTOR * max(median_nn, 1e-6)
    eps = DBSCAN_EPS_FACTOR * max(median_nn, 1e-6)
    eps = DBSCAN_EPS_FACTOR * max(median_nn, 1e-6)
    eps = DBSCAN_EPS_FACTOR * max(median_nn, 1e-6)
    eps = DBSCAN_EPS_FACTOR * max(median_nn, 1e-6)
    eps = DBSCAN_EPS_FACTOR * max(median_nn, 1e-6)
    eps = DBSCAN_EPS_FACTOR * max(median_nn, 1e-6)
    eps = DBSCAN_EPS_FACTOR * max(median_nn, 1e-6)
    eps = DBSCAN_EPS_FACTOR * max(median_nn, 1e-6)
    eps = DBSCAN_EPS_FACTOR * max(median_nn, 1e-6)
    eps = DBSCAN_EPS_FACTOR * max(median_nn, 1e-6)
    eps = DBSCAN_EPS_FACTOR * max(median_nn, 1e-6)
    eps = DBSCAN_EPS_FACTOR * max(median_nn, 1e-6)
    eps = DBSCAN_EPS_FACTOR * max(median_nn, 1e-6)
    eps = DBSCAN_EPS_FACTOR * max(median_nn, 1e-6)
    eps = DBSCAN_EPS_FACTOR * max(median_nn, 1e-6)
    eps = DBSCAN_EPS_FACTOR * max(median_nn, 1e-6)
    eps = DBSCAN_EPS_FACTOR * max(median_nn, 1e-6)
    eps = DBSCAN_EPS_FACTOR * max(median_nn, 1e-6)
    eps = DBSCAN_EPS_FACTOR * max(median_nn, 1e-6)
    eps = DBSCAN_EPS_FACTOR * max(median_nn, 1e-6)
    eps = DBSCAN_EPS_FACTOR * max(median_nn, 1e-6)
    eps = DBSCAN_EPS_FACTOR * max(median_nn, 1e-6)
    eps = DBSCAN_EPS_FACTOR * max(median_nn, 1e-6)
    db = DBSCAN(eps=eps, min_samples=DBSCAN_MIN_SAMPLES).fit(pts_kept)
    db = DBSCAN(eps=eps, min_samples=DBSCAN_MIN_SAMPLES).fit(pts_kept)
    db = DBSCAN(eps=eps, min_samples=DBSCAN_MIN_SAMPLES).fit(pts_kept)
    db = DBSCAN(eps=eps, min_samples=DBSCAN_MIN_SAMPLES).fit(pts_kept)
    db = DBSCAN(eps=eps, min_samples=DBSCAN_MIN_SAMPLES).fit(pts_kept)
    db = DBSCAN(eps=eps, min_samples=DBSCAN_MIN_SAMPLES).fit(pts_kept)
    db = DBSCAN(eps=eps, min_samples=DBSCAN_MIN_SAMPLES).fit(pts_kept)
    db = DBSCAN(eps=eps, min_samples=DBSCAN_MIN_SAMPLES).fit(pts_kept)
    db = DBSCAN(eps=eps, min_samples=DBSCAN_MIN_SAMPLES).fit(pts_kept)
    db = DBSCAN(eps=eps, min_samples=DBSCAN_MIN_SAMPLES).fit(pts_kept)
    db = DBSCAN(eps=eps, min_samples=DBSCAN_MIN_SAMPLES).fit(pts_kept)
    db = DBSCAN(eps=eps, min_samples=DBSCAN_MIN_SAMPLES).fit(pts_kept)
    db = DBSCAN(eps=eps, min_samples=DBSCAN_MIN_SAMPLES).fit(pts_kept)
    db = DBSCAN(eps=eps, min_samples=DBSCAN_MIN_SAMPLES).fit(pts_kept)
    db = DBSCAN(eps=eps, min_samples=DBSCAN_MIN_SAMPLES).fit(pts_kept)
    db = DBSCAN(eps=eps, min_samples=DBSCAN_MIN_SAMPLES).fit(pts_kept)
    db = DBSCAN(eps=eps, min_samples=DBSCAN_MIN_SAMPLES).fit(pts_kept)
    db = DBSCAN(eps=eps, min_samples=DBSCAN_MIN_SAMPLES).fit(pts_kept)
    db = DBSCAN(eps=eps, min_samples=DBSCAN_MIN_SAMPLES).fit(pts_kept)
    db = DBSCAN(eps=eps, min_samples=DBSCAN_MIN_SAMPLES).fit(pts_kept)
    db = DBSCAN(eps=eps, min_samples=DBSCAN_MIN_SAMPLES).fit(pts_kept)
    db = DBSCAN(eps=eps, min_samples=DBSCAN_MIN_SAMPLES).fit(pts_kept)
    db = DBSCAN(eps=eps, min_samples=DBSCAN_MIN_SAMPLES).fit(pts_kept)
    db = DBSCAN(eps=eps, min_samples=DBSCAN_MIN_SAMPLES).fit(pts_kept)
    db = DBSCAN(eps=eps, min_samples=DBSCAN_MIN_SAMPLES).fit(pts_kept)
    db = DBSCAN(eps=eps, min_samples=DBSCAN_MIN_SAMPLES).fit(pts_kept)
    db = DBSCAN(eps=eps, min_samples=DBSCAN_MIN_SAMPLES).fit(pts_kept)
    db = DBSCAN(eps=eps, min_samples=DBSCAN_MIN_SAMPLES).fit(pts_kept)
    db = DBSCAN(eps=eps, min_samples=DBSCAN_MIN_SAMPLES).fit(pts_kept)
    db = DBSCAN(eps=eps, min_samples=DBSCAN_MIN_SAMPLES).fit(pts_kept)
    db = DBSCAN(eps=eps, min_samples=DBSCAN_MIN_SAMPLES).fit(pts_kept)
    db = DBSCAN(eps=eps, min_samples=DBSCAN_MIN_SAMPLES).fit(pts_kept)
    db = DBSCAN(eps=eps, min_samples=DBSCAN_MIN_SAMPLES).fit(pts_kept)
    db = DBSCAN(eps=eps, min_samples=DBSCAN_MIN_SAMPLES).fit(pts_kept)
    db = DBSCAN(eps=eps, min_samples=DBSCAN_MIN_SAMPLES).fit(pts_kept)
    db = DBSCAN(eps=eps, min_samples=DBSCAN_MIN_SAMPLES).fit(pts_kept)
    db = DBSCAN(eps=eps, min_samples=DBSCAN_MIN_SAMPLES).fit(pts_kept)
    labels = db.labels_
    labels = db.labels_
    labels = db.labels_
    labels = db.labels_
    labels = db.labels_
    labels = db.labels_
    labels = db.labels_
    labels = db.labels_
    labels = db.labels_
    labels = db.labels_
    labels = db.labels_
    labels = db.labels_
    labels = db.labels_
    labels = db.labels_
    labels = db.labels_
    labels = db.labels_
    labels = db.labels_
    labels = db.labels_
    labels = db.labels_
    labels = db.labels_
    labels = db.labels_
    labels = db.labels_
    labels = db.labels_
    labels = db.labels_
    labels = db.labels_
    labels = db.labels_
    labels = db.labels_
    labels = db.labels_
    labels = db.labels_
    labels = db.labels_
    labels = db.labels_
    labels = db.labels_
    labels = db.labels_
    labels = db.labels_
    labels = db.labels_
    labels = db.labels_
    labels = db.labels_
    # list of valid clusters
    # list of valid clusters
    # list of valid clusters
    # list of valid clusters
    # list of valid clusters
    # list of valid clusters
    # list of valid clusters
    # list of valid clusters
    # list of valid clusters
    # list of valid clusters
    # list of valid clusters
    # list of valid clusters
    # list of valid clusters
    # list of valid clusters
    # list of valid clusters
    # list of valid clusters
    # list of valid clusters
    # list of valid clusters
    # list of valid clusters
    # list of valid clusters
    # list of valid clusters
    # list of valid clusters
    # list of valid clusters
    # list of valid clusters
    # list of valid clusters
    # list of valid clusters
    # list of valid clusters
    # list of valid clusters
    # list of valid clusters
    # list of valid clusters
    # list of valid clusters
    # list of valid clusters
    # list of valid clusters
    # list of valid clusters
    # list of valid clusters
    # list of valid clusters
    # list of valid clusters
    unique, counts = np.unique(labels[labels>=0], return_counts=True) if np.any(labels>=0) else (np.array([]), np.array([]))
    unique, counts = np.unique(labels[labels>=0], return_counts=True) if np.any(labels>=0) else (np.array([]), np.array([]))
    unique, counts = np.unique(labels[labels>=0], return_counts=True) if np.any(labels>=0) else (np.array([]), np.array([]))
    unique, counts = np.unique(labels[labels>=0], return_counts=True) if np.any(labels>=0) else (np.array([]), np.array([]))
    unique, counts = np.unique(labels[labels>=0], return_counts=True) if np.any(labels>=0) else (np.array([]), np.array([]))
    unique, counts = np.unique(labels[labels>=0], return_counts=True) if np.any(labels>=0) else (np.array([]), np.array([]))
    unique, counts = np.unique(labels[labels>=0], return_counts=True) if np.any(labels>=0) else (np.array([]), np.array([]))
    unique, counts = np.unique(labels[labels>=0], return_counts=True) if np.any(labels>=0) else (np.array([]), np.array([]))
    unique, counts = np.unique(labels[labels>=0], return_counts=True) if np.any(labels>=0) else (np.array([]), np.array([]))
    unique, counts = np.unique(labels[labels>=0], return_counts=True) if np.any(labels>=0) else (np.array([]), np.array([]))
    unique, counts = np.unique(labels[labels>=0], return_counts=True) if np.any(labels>=0) else (np.array([]), np.array([]))
    unique, counts = np.unique(labels[labels>=0], return_counts=True) if np.any(labels>=0) else (np.array([]), np.array([]))
    unique, counts = np.unique(labels[labels>=0], return_counts=True) if np.any(labels>=0) else (np.array([]), np.array([]))
    unique, counts = np.unique(labels[labels>=0], return_counts=True) if np.any(labels>=0) else (np.array([]), np.array([]))
    unique, counts = np.unique(labels[labels>=0], return_counts=True) if np.any(labels>=0) else (np.array([]), np.array([]))
    unique, counts = np.unique(labels[labels>=0], return_counts=True) if np.any(labels>=0) else (np.array([]), np.array([]))
    unique, counts = np.unique(labels[labels>=0], return_counts=True) if np.any(labels>=0) else (np.array([]), np.array([]))
    unique, counts = np.unique(labels[labels>=0], return_counts=True) if np.any(labels>=0) else (np.array([]), np.array([]))
    unique, counts = np.unique(labels[labels>=0], return_counts=True) if np.any(labels>=0) else (np.array([]), np.array([]))
    unique, counts = np.unique(labels[labels>=0], return_counts=True) if np.any(labels>=0) else (np.array([]), np.array([]))
    unique, counts = np.unique(labels[labels>=0], return_counts=True) if np.any(labels>=0) else (np.array([]), np.array([]))
    unique, counts = np.unique(labels[labels>=0], return_counts=True) if np.any(labels>=0) else (np.array([]), np.array([]))
    unique, counts = np.unique(labels[labels>=0], return_counts=True) if np.any(labels>=0) else (np.array([]), np.array([]))
    unique, counts = np.unique(labels[labels>=0], return_counts=True) if np.any(labels>=0) else (np.array([]), np.array([]))
    unique, counts = np.unique(labels[labels>=0], return_counts=True) if np.any(labels>=0) else (np.array([]), np.array([]))
    unique, counts = np.unique(labels[labels>=0], return_counts=True) if np.any(labels>=0) else (np.array([]), np.array([]))
    unique, counts = np.unique(labels[labels>=0], return_counts=True) if np.any(labels>=0) else (np.array([]), np.array([]))
    unique, counts = np.unique(labels[labels>=0], return_counts=True) if np.any(labels>=0) else (np.array([]), np.array([]))
    unique, counts = np.unique(labels[labels>=0], return_counts=True) if np.any(labels>=0) else (np.array([]), np.array([]))
    unique, counts = np.unique(labels[labels>=0], return_counts=True) if np.any(labels>=0) else (np.array([]), np.array([]))
    unique, counts = np.unique(labels[labels>=0], return_counts=True) if np.any(labels>=0) else (np.array([]), np.array([]))
    unique, counts = np.unique(labels[labels>=0], return_counts=True) if np.any(labels>=0) else (np.array([]), np.array([]))
    unique, counts = np.unique(labels[labels>=0], return_counts=True) if np.any(labels>=0) else (np.array([]), np.array([]))
    unique, counts = np.unique(labels[labels>=0], return_counts=True) if np.any(labels>=0) else (np.array([]), np.array([]))
    unique, counts = np.unique(labels[labels>=0], return_counts=True) if np.any(labels>=0) else (np.array([]), np.array([]))
    unique, counts = np.unique(labels[labels>=0], return_counts=True) if np.any(labels>=0) else (np.array([]), np.array([]))
    unique, counts = np.unique(labels[labels>=0], return_counts=True) if np.any(labels>=0) else (np.array([]), np.array([]))
    valid_clusters = set([int(u) for u,c in zip(unique,counts) if c >= MIN_CLUSTER_SIZE])
    valid_clusters = set([int(u) for u,c in zip(unique,counts) if c >= MIN_CLUSTER_SIZE])
    valid_clusters = set([int(u) for u,c in zip(unique,counts) if c >= MIN_CLUSTER_SIZE])
    valid_clusters = set([int(u) for u,c in zip(unique,counts) if c >= MIN_CLUSTER_SIZE])
    valid_clusters = set([int(u) for u,c in zip(unique,counts) if c >= MIN_CLUSTER_SIZE])
    valid_clusters = set([int(u) for u,c in zip(unique,counts) if c >= MIN_CLUSTER_SIZE])
    valid_clusters = set([int(u) for u,c in zip(unique,counts) if c >= MIN_CLUSTER_SIZE])
    valid_clusters = set([int(u) for u,c in zip(unique,counts) if c >= MIN_CLUSTER_SIZE])
    valid_clusters = set([int(u) for u,c in zip(unique,counts) if c >= MIN_CLUSTER_SIZE])
    valid_clusters = set([int(u) for u,c in zip(unique,counts) if c >= MIN_CLUSTER_SIZE])
    valid_clusters = set([int(u) for u,c in zip(unique,counts) if c >= MIN_CLUSTER_SIZE])
    valid_clusters = set([int(u) for u,c in zip(unique,counts) if c >= MIN_CLUSTER_SIZE])
    valid_clusters = set([int(u) for u,c in zip(unique,counts) if c >= MIN_CLUSTER_SIZE])
    valid_clusters = set([int(u) for u,c in zip(unique,counts) if c >= MIN_CLUSTER_SIZE])
    valid_clusters = set([int(u) for u,c in zip(unique,counts) if c >= MIN_CLUSTER_SIZE])
    valid_clusters = set([int(u) for u,c in zip(unique,counts) if c >= MIN_CLUSTER_SIZE])
    valid_clusters = set([int(u) for u,c in zip(unique,counts) if c >= MIN_CLUSTER_SIZE])
    valid_clusters = set([int(u) for u,c in zip(unique,counts) if c >= MIN_CLUSTER_SIZE])
    valid_clusters = set([int(u) for u,c in zip(unique,counts) if c >= MIN_CLUSTER_SIZE])
    valid_clusters = set([int(u) for u,c in zip(unique,counts) if c >= MIN_CLUSTER_SIZE])
    valid_clusters = set([int(u) for u,c in zip(unique,counts) if c >= MIN_CLUSTER_SIZE])
    valid_clusters = set([int(u) for u,c in zip(unique,counts) if c >= MIN_CLUSTER_SIZE])
    valid_clusters = set([int(u) for u,c in zip(unique,counts) if c >= MIN_CLUSTER_SIZE])
    valid_clusters = set([int(u) for u,c in zip(unique,counts) if c >= MIN_CLUSTER_SIZE])
    valid_clusters = set([int(u) for u,c in zip(unique,counts) if c >= MIN_CLUSTER_SIZE])
    valid_clusters = set([int(u) for u,c in zip(unique,counts) if c >= MIN_CLUSTER_SIZE])
    valid_clusters = set([int(u) for u,c in zip(unique,counts) if c >= MIN_CLUSTER_SIZE])
    valid_clusters = set([int(u) for u,c in zip(unique,counts) if c >= MIN_CLUSTER_SIZE])
    valid_clusters = set([int(u) for u,c in zip(unique,counts) if c >= MIN_CLUSTER_SIZE])
    valid_clusters = set([int(u) for u,c in zip(unique,counts) if c >= MIN_CLUSTER_SIZE])
    valid_clusters = set([int(u) for u,c in zip(unique,counts) if c >= MIN_CLUSTER_SIZE])
    valid_clusters = set([int(u) for u,c in zip(unique,counts) if c >= MIN_CLUSTER_SIZE])
    valid_clusters = set([int(u) for u,c in zip(unique,counts) if c >= MIN_CLUSTER_SIZE])
    valid_clusters = set([int(u) for u,c in zip(unique,counts) if c >= MIN_CLUSTER_SIZE])
    valid_clusters = set([int(u) for u,c in zip(unique,counts) if c >= MIN_CLUSTER_SIZE])
    valid_clusters = set([int(u) for u,c in zip(unique,counts) if c >= MIN_CLUSTER_SIZE])
    valid_clusters = set([int(u) for u,c in zip(unique,counts) if c >= MIN_CLUSTER_SIZE])
    keep_mask = np.array([ (lab in valid_clusters) for lab in labels ], dtype=bool)
    keep_mask = np.array([ (lab in valid_clusters) for lab in labels ], dtype=bool)
    keep_mask = np.array([ (lab in valid_clusters) for lab in labels ], dtype=bool)
    keep_mask = np.array([ (lab in valid_clusters) for lab in labels ], dtype=bool)
    keep_mask = np.array([ (lab in valid_clusters) for lab in labels ], dtype=bool)
    keep_mask = np.array([ (lab in valid_clusters) for lab in labels ], dtype=bool)
    keep_mask = np.array([ (lab in valid_clusters) for lab in labels ], dtype=bool)
    keep_mask = np.array([ (lab in valid_clusters) for lab in labels ], dtype=bool)
    keep_mask = np.array([ (lab in valid_clusters) for lab in labels ], dtype=bool)
    keep_mask = np.array([ (lab in valid_clusters) for lab in labels ], dtype=bool)
    keep_mask = np.array([ (lab in valid_clusters) for lab in labels ], dtype=bool)
    keep_mask = np.array([ (lab in valid_clusters) for lab in labels ], dtype=bool)
    keep_mask = np.array([ (lab in valid_clusters) for lab in labels ], dtype=bool)
    keep_mask = np.array([ (lab in valid_clusters) for lab in labels ], dtype=bool)
    keep_mask = np.array([ (lab in valid_clusters) for lab in labels ], dtype=bool)
    keep_mask = np.array([ (lab in valid_clusters) for lab in labels ], dtype=bool)
    keep_mask = np.array([ (lab in valid_clusters) for lab in labels ], dtype=bool)
    keep_mask = np.array([ (lab in valid_clusters) for lab in labels ], dtype=bool)
    keep_mask = np.array([ (lab in valid_clusters) for lab in labels ], dtype=bool)
    keep_mask = np.array([ (lab in valid_clusters) for lab in labels ], dtype=bool)
    keep_mask = np.array([ (lab in valid_clusters) for lab in labels ], dtype=bool)
    keep_mask = np.array([ (lab in valid_clusters) for lab in labels ], dtype=bool)
    keep_mask = np.array([ (lab in valid_clusters) for lab in labels ], dtype=bool)
    keep_mask = np.array([ (lab in valid_clusters) for lab in labels ], dtype=bool)
    keep_mask = np.array([ (lab in valid_clusters) for lab in labels ], dtype=bool)
    keep_mask = np.array([ (lab in valid_clusters) for lab in labels ], dtype=bool)
    keep_mask = np.array([ (lab in valid_clusters) for lab in labels ], dtype=bool)
    keep_mask = np.array([ (lab in valid_clusters) for lab in labels ], dtype=bool)
    keep_mask = np.array([ (lab in valid_clusters) for lab in labels ], dtype=bool)
    keep_mask = np.array([ (lab in valid_clusters) for lab in labels ], dtype=bool)
    keep_mask = np.array([ (lab in valid_clusters) for lab in labels ], dtype=bool)
    keep_mask = np.array([ (lab in valid_clusters) for lab in labels ], dtype=bool)
    keep_mask = np.array([ (lab in valid_clusters) for lab in labels ], dtype=bool)
    keep_mask = np.array([ (lab in valid_clusters) for lab in labels ], dtype=bool)
    keep_mask = np.array([ (lab in valid_clusters) for lab in labels ], dtype=bool)
    keep_mask = np.array([ (lab in valid_clusters) for lab in labels ], dtype=bool)
    keep_mask = np.array([ (lab in valid_clusters) for lab in labels ], dtype=bool)
    # noise points (lab==-1) are dropped
    # noise points (lab==-1) are dropped
    # noise points (lab==-1) are dropped
    # noise points (lab==-1) are dropped
    # noise points (lab==-1) are dropped
    # noise points (lab==-1) are dropped
    # noise points (lab==-1) are dropped
    # noise points (lab==-1) are dropped
    # noise points (lab==-1) are dropped
    # noise points (lab==-1) are dropped
    # noise points (lab==-1) are dropped
    # noise points (lab==-1) are dropped
    # noise points (lab==-1) are dropped
    # noise points (lab==-1) are dropped
    # noise points (lab==-1) are dropped
    # noise points (lab==-1) are dropped
    # noise points (lab==-1) are dropped
    # noise points (lab==-1) are dropped
    # noise points (lab==-1) are dropped
    # noise points (lab==-1) are dropped
    # noise points (lab==-1) are dropped
    # noise points (lab==-1) are dropped
    # noise points (lab==-1) are dropped
    # noise points (lab==-1) are dropped
    # noise points (lab==-1) are dropped
    # noise points (lab==-1) are dropped
    # noise points (lab==-1) are dropped
    # noise points (lab==-1) are dropped
    # noise points (lab==-1) are dropped
    # noise points (lab==-1) are dropped
    # noise points (lab==-1) are dropped
    # noise points (lab==-1) are dropped
    # noise points (lab==-1) are dropped
    # noise points (lab==-1) are dropped
    # noise points (lab==-1) are dropped
    # noise points (lab==-1) are dropped
    # noise points (lab==-1) are dropped
    kept_idx_final = np.array(original_indices)[keep_mask]
    kept_idx_final = np.array(original_indices)[keep_mask]
    kept_idx_final = np.array(original_indices)[keep_mask]
    kept_idx_final = np.array(original_indices)[keep_mask]
    kept_idx_final = np.array(original_indices)[keep_mask]
    kept_idx_final = np.array(original_indices)[keep_mask]
    kept_idx_final = np.array(original_indices)[keep_mask]
    kept_idx_final = np.array(original_indices)[keep_mask]
    kept_idx_final = np.array(original_indices)[keep_mask]
    kept_idx_final = np.array(original_indices)[keep_mask]
    kept_idx_final = np.array(original_indices)[keep_mask]
    kept_idx_final = np.array(original_indices)[keep_mask]
    kept_idx_final = np.array(original_indices)[keep_mask]
    kept_idx_final = np.array(original_indices)[keep_mask]
    kept_idx_final = np.array(original_indices)[keep_mask]
    kept_idx_final = np.array(original_indices)[keep_mask]
    kept_idx_final = np.array(original_indices)[keep_mask]
    kept_idx_final = np.array(original_indices)[keep_mask]
    kept_idx_final = np.array(original_indices)[keep_mask]
    kept_idx_final = np.array(original_indices)[keep_mask]
    kept_idx_final = np.array(original_indices)[keep_mask]
    kept_idx_final = np.array(original_indices)[keep_mask]
    kept_idx_final = np.array(original_indices)[keep_mask]
    kept_idx_final = np.array(original_indices)[keep_mask]
    kept_idx_final = np.array(original_indices)[keep_mask]
    kept_idx_final = np.array(original_indices)[keep_mask]
    kept_idx_final = np.array(original_indices)[keep_mask]
    kept_idx_final = np.array(original_indices)[keep_mask]
    kept_idx_final = np.array(original_indices)[keep_mask]
    kept_idx_final = np.array(original_indices)[keep_mask]
    kept_idx_final = np.array(original_indices)[keep_mask]
    kept_idx_final = np.array(original_indices)[keep_mask]
    kept_idx_final = np.array(original_indices)[keep_mask]
    kept_idx_final = np.array(original_indices)[keep_mask]
    kept_idx_final = np.array(original_indices)[keep_mask]
    kept_idx_final = np.array(original_indices)[keep_mask]
    kept_idx_final = np.array(original_indices)[keep_mask]
    info = {'n_before': len(original_indices), 'n_after': int(keep_mask.sum()), 'median_nn': median_nn, 'eps': eps, 'n_clusters_kept': len(valid_clusters)}
    info = {'n_before': len(original_indices), 'n_after': int(keep_mask.sum()), 'median_nn': median_nn, 'eps': eps, 'n_clusters_kept': len(valid_clusters)}
    info = {'n_before': len(original_indices), 'n_after': int(keep_mask.sum()), 'median_nn': median_nn, 'eps': eps, 'n_clusters_kept': len(valid_clusters)}
    info = {'n_before': len(original_indices), 'n_after': int(keep_mask.sum()), 'median_nn': median_nn, 'eps': eps, 'n_clusters_kept': len(valid_clusters)}
    info = {'n_before': len(original_indices), 'n_after': int(keep_mask.sum()), 'median_nn': median_nn, 'eps': eps, 'n_clusters_kept': len(valid_clusters)}
    info = {'n_before': len(original_indices), 'n_after': int(keep_mask.sum()), 'median_nn': median_nn, 'eps': eps, 'n_clusters_kept': len(valid_clusters)}
    info = {'n_before': len(original_indices), 'n_after': int(keep_mask.sum()), 'median_nn': median_nn, 'eps': eps, 'n_clusters_kept': len(valid_clusters)}
    info = {'n_before': len(original_indices), 'n_after': int(keep_mask.sum()), 'median_nn': median_nn, 'eps': eps, 'n_clusters_kept': len(valid_clusters)}
    info = {'n_before': len(original_indices), 'n_after': int(keep_mask.sum()), 'median_nn': median_nn, 'eps': eps, 'n_clusters_kept': len(valid_clusters)}
    info = {'n_before': len(original_indices), 'n_after': int(keep_mask.sum()), 'median_nn': median_nn, 'eps': eps, 'n_clusters_kept': len(valid_clusters)}
    info = {'n_before': len(original_indices), 'n_after': int(keep_mask.sum()), 'median_nn': median_nn, 'eps': eps, 'n_clusters_kept': len(valid_clusters)}
    info = {'n_before': len(original_indices), 'n_after': int(keep_mask.sum()), 'median_nn': median_nn, 'eps': eps, 'n_clusters_kept': len(valid_clusters)}
    info = {'n_before': len(original_indices), 'n_after': int(keep_mask.sum()), 'median_nn': median_nn, 'eps': eps, 'n_clusters_kept': len(valid_clusters)}
    info = {'n_before': len(original_indices), 'n_after': int(keep_mask.sum()), 'median_nn': median_nn, 'eps': eps, 'n_clusters_kept': len(valid_clusters)}
    info = {'n_before': len(original_indices), 'n_after': int(keep_mask.sum()), 'median_nn': median_nn, 'eps': eps, 'n_clusters_kept': len(valid_clusters)}
    info = {'n_before': len(original_indices), 'n_after': int(keep_mask.sum()), 'median_nn': median_nn, 'eps': eps, 'n_clusters_kept': len(valid_clusters)}
    info = {'n_before': len(original_indices), 'n_after': int(keep_mask.sum()), 'median_nn': median_nn, 'eps': eps, 'n_clusters_kept': len(valid_clusters)}
    info = {'n_before': len(original_indices), 'n_after': int(keep_mask.sum()), 'median_nn': median_nn, 'eps': eps, 'n_clusters_kept': len(valid_clusters)}
    info = {'n_before': len(original_indices), 'n_after': int(keep_mask.sum()), 'median_nn': median_nn, 'eps': eps, 'n_clusters_kept': len(valid_clusters)}
    info = {'n_before': len(original_indices), 'n_after': int(keep_mask.sum()), 'median_nn': median_nn, 'eps': eps, 'n_clusters_kept': len(valid_clusters)}
    info = {'n_before': len(original_indices), 'n_after': int(keep_mask.sum()), 'median_nn': median_nn, 'eps': eps, 'n_clusters_kept': len(valid_clusters)}
    info = {'n_before': len(original_indices), 'n_after': int(keep_mask.sum()), 'median_nn': median_nn, 'eps': eps, 'n_clusters_kept': len(valid_clusters)}
    info = {'n_before': len(original_indices), 'n_after': int(keep_mask.sum()), 'median_nn': median_nn, 'eps': eps, 'n_clusters_kept': len(valid_clusters)}
    info = {'n_before': len(original_indices), 'n_after': int(keep_mask.sum()), 'median_nn': median_nn, 'eps': eps, 'n_clusters_kept': len(valid_clusters)}
    info = {'n_before': len(original_indices), 'n_after': int(keep_mask.sum()), 'median_nn': median_nn, 'eps': eps, 'n_clusters_kept': len(valid_clusters)}
    info = {'n_before': len(original_indices), 'n_after': int(keep_mask.sum()), 'median_nn': median_nn, 'eps': eps, 'n_clusters_kept': len(valid_clusters)}
    info = {'n_before': len(original_indices), 'n_after': int(keep_mask.sum()), 'median_nn': median_nn, 'eps': eps, 'n_clusters_kept': len(valid_clusters)}
    info = {'n_before': len(original_indices), 'n_after': int(keep_mask.sum()), 'median_nn': median_nn, 'eps': eps, 'n_clusters_kept': len(valid_clusters)}
    info = {'n_before': len(original_indices), 'n_after': int(keep_mask.sum()), 'median_nn': median_nn, 'eps': eps, 'n_clusters_kept': len(valid_clusters)}
    info = {'n_before': len(original_indices), 'n_after': int(keep_mask.sum()), 'median_nn': median_nn, 'eps': eps, 'n_clusters_kept': len(valid_clusters)}
    info = {'n_before': len(original_indices), 'n_after': int(keep_mask.sum()), 'median_nn': median_nn, 'eps': eps, 'n_clusters_kept': len(valid_clusters)}
    info = {'n_before': len(original_indices), 'n_after': int(keep_mask.sum()), 'median_nn': median_nn, 'eps': eps, 'n_clusters_kept': len(valid_clusters)}
    info = {'n_before': len(original_indices), 'n_after': int(keep_mask.sum()), 'median_nn': median_nn, 'eps': eps, 'n_clusters_kept': len(valid_clusters)}
    info = {'n_before': len(original_indices), 'n_after': int(keep_mask.sum()), 'median_nn': median_nn, 'eps': eps, 'n_clusters_kept': len(valid_clusters)}
    info = {'n_before': len(original_indices), 'n_after': int(keep_mask.sum()), 'median_nn': median_nn, 'eps': eps, 'n_clusters_kept': len(valid_clusters)}
    info = {'n_before': len(original_indices), 'n_after': int(keep_mask.sum()), 'median_nn': median_nn, 'eps': eps, 'n_clusters_kept': len(valid_clusters)}
    info = {'n_before': len(original_indices), 'n_after': int(keep_mask.sum()), 'median_nn': median_nn, 'eps': eps, 'n_clusters_kept': len(valid_clusters)}
    return kept_idx_final, info    return kept_idx_final, info    return kept_idx_final, info    return kept_idx_final, info    return kept_idx_final, info    return kept_idx_final, info    return kept_idx_final, info    return kept_idx_final, info    return kept_idx_final, info    return kept_idx_final, info    return kept_idx_final, info    return kept_idx_final, info    return kept_idx_final, info    return kept_idx_final, info    return kept_idx_final, info    return kept_idx_final, info    return kept_idx_final, info    return kept_idx_final, info    return kept_idx_final, info    return kept_idx_final, info    return kept_idx_final, info    return kept_idx_final, info    return kept_idx_final, info    return kept_idx_final, info    return kept_idx_final, info    return kept_idx_final, info    return kept_idx_final, info    return kept_idx_final, info    return kept_idx_final, info    return kept_idx_final, info    return kept_idx_final, info    return kept_idx_final, info    return kept_idx_final, info    return kept_idx_final, info    return kept_idx_final, info    return kept_idx_final, info    return kept_idx_final, info

# %% [markdown]
# ## ---------- Function: plot results ----------
# ## ---------- Function: plot results ----------
# ## ---------- Function: plot results ----------
# ## ---------- Function: plot results ----------
# ## ---------- Function: plot results ----------
# ## ---------- Function: plot results ----------
# ## ---------- Function: plot results ----------
# ## ---------- Function: plot results ----------
# ## ---------- Function: plot results ----------
# ## ---------- Function: plot results ----------
# ## ---------- Function: plot results ----------
# ## ---------- Function: plot results ----------
# ## ---------- Function: plot results ----------
# ## ---------- Function: plot results ----------
# ## ---------- Function: plot results ----------
# ## ---------- Function: plot results ----------
# ## ---------- Function: plot results ----------
# ## ---------- Function: plot results ----------
# ## ---------- Function: plot results ----------
# ## ---------- Function: plot results ----------
# ## ---------- Function: plot results ----------
# ## ---------- Function: plot results ----------
# ## ---------- Function: plot results ----------
# ## ---------- Function: plot results ----------
# ## ---------- Function: plot results ----------
# ## ---------- Function: plot results ----------
# ## ---------- Function: plot results ----------
# ## ---------- Function: plot results ----------
# ## ---------- Function: plot results ----------
# ## ---------- Function: plot results ----------
# ## ---------- Function: plot results ----------
# ## ---------- Function: plot results ----------
# ## ---------- Function: plot results ----------
# ## ---------- Function: plot results ----------
# ## ---------- Function: plot results ----------
# ## ---------- Function: plot results ----------
# ## ---------- Function: plot results ----------

# %%
def plot_results(original_points, filtered_points, stats, output_dir):
def plot_results(original_points, filtered_points, stats, output_dir):
def plot_results(original_points, filtered_points, stats, output_dir):
def plot_results(original_points, filtered_points, stats, output_dir):
def plot_results(original_points, filtered_points, stats, output_dir):
def plot_results(original_points, filtered_points, stats, output_dir):
def plot_results(original_points, filtered_points, stats, output_dir):
def plot_results(original_points, filtered_points, stats, output_dir):
def plot_results(original_points, filtered_points, stats, output_dir):
def plot_results(original_points, filtered_points, stats, output_dir):
def plot_results(original_points, filtered_points, stats, output_dir):
def plot_results(original_points, filtered_points, stats, output_dir):
def plot_results(original_points, filtered_points, stats, output_dir):
def plot_results(original_points, filtered_points, stats, output_dir):
def plot_results(original_points, filtered_points, stats, output_dir):
def plot_results(original_points, filtered_points, stats, output_dir):
def plot_results(original_points, filtered_points, stats, output_dir):
def plot_results(original_points, filtered_points, stats, output_dir):
def plot_results(original_points, filtered_points, stats, output_dir):
def plot_results(original_points, filtered_points, stats, output_dir):
def plot_results(original_points, filtered_points, stats, output_dir):
def plot_results(original_points, filtered_points, stats, output_dir):
def plot_results(original_points, filtered_points, stats, output_dir):
def plot_results(original_points, filtered_points, stats, output_dir):
def plot_results(original_points, filtered_points, stats, output_dir):
def plot_results(original_points, filtered_points, stats, output_dir):
def plot_results(original_points, filtered_points, stats, output_dir):
def plot_results(original_points, filtered_points, stats, output_dir):
def plot_results(original_points, filtered_points, stats, output_dir):
def plot_results(original_points, filtered_points, stats, output_dir):
def plot_results(original_points, filtered_points, stats, output_dir):
def plot_results(original_points, filtered_points, stats, output_dir):
def plot_results(original_points, filtered_points, stats, output_dir):
def plot_results(original_points, filtered_points, stats, output_dir):
def plot_results(original_points, filtered_points, stats, output_dir):
def plot_results(original_points, filtered_points, stats, output_dir):
def plot_results(original_points, filtered_points, stats, output_dir):
    """Show comparison plots."""
    """Show comparison plots."""
    """Show comparison plots."""
    """Show comparison plots."""
    """Show comparison plots."""
    """Show comparison plots."""
    """Show comparison plots."""
    """Show comparison plots."""
    """Show comparison plots."""
    """Show comparison plots."""
    """Show comparison plots."""
    """Show comparison plots."""
    """Show comparison plots."""
    """Show comparison plots."""
    """Show comparison plots."""
    """Show comparison plots."""
    """Show comparison plots."""
    """Show comparison plots."""
    """Show comparison plots."""
    """Show comparison plots."""
    """Show comparison plots."""
    """Show comparison plots."""
    """Show comparison plots."""
    """Show comparison plots."""
    """Show comparison plots."""
    """Show comparison plots."""
    """Show comparison plots."""
    """Show comparison plots."""
    """Show comparison plots."""
    """Show comparison plots."""
    """Show comparison plots."""
    """Show comparison plots."""
    """Show comparison plots."""
    """Show comparison plots."""
    """Show comparison plots."""
    """Show comparison plots."""
    """Show comparison plots."""
    print("\n📊 Generating visualization plots...")
    print("\n📊 Generating visualization plots...")
    print("\n📊 Generating visualization plots...")
    print("\n📊 Generating visualization plots...")
    print("\n📊 Generating visualization plots...")
    print("\n📊 Generating visualization plots...")
    print("\n📊 Generating visualization plots...")
    print("\n📊 Generating visualization plots...")
    print("\n📊 Generating visualization plots...")
    print("\n📊 Generating visualization plots...")
    print("\n📊 Generating visualization plots...")
    print("\n📊 Generating visualization plots...")
    print("\n📊 Generating visualization plots...")
    print("\n📊 Generating visualization plots...")
    print("\n📊 Generating visualization plots...")
    print("\n📊 Generating visualization plots...")
    print("\n📊 Generating visualization plots...")
    print("\n📊 Generating visualization plots...")
    print("\n📊 Generating visualization plots...")
    print("\n📊 Generating visualization plots...")
    print("\n📊 Generating visualization plots...")
    print("\n📊 Generating visualization plots...")
    print("\n📊 Generating visualization plots...")
    print("\n📊 Generating visualization plots...")
    print("\n📊 Generating visualization plots...")
    print("\n📊 Generating visualization plots...")
    print("\n📊 Generating visualization plots...")
    print("\n📊 Generating visualization plots...")
    print("\n📊 Generating visualization plots...")
    print("\n📊 Generating visualization plots...")
    print("\n📊 Generating visualization plots...")
    print("\n📊 Generating visualization plots...")
    print("\n📊 Generating visualization plots...")
    print("\n📊 Generating visualization plots...")
    print("\n📊 Generating visualization plots...")
    print("\n📊 Generating visualization plots...")
    print("\n📊 Generating visualization plots...")
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    fig = plt.figure(figsize=(20, 12))
    fig = plt.figure(figsize=(20, 12))
    fig = plt.figure(figsize=(20, 12))
    fig = plt.figure(figsize=(20, 12))
    fig = plt.figure(figsize=(20, 12))
    fig = plt.figure(figsize=(20, 12))
    fig = plt.figure(figsize=(20, 12))
    fig = plt.figure(figsize=(20, 12))
    fig = plt.figure(figsize=(20, 12))
    fig = plt.figure(figsize=(20, 12))
    fig = plt.figure(figsize=(20, 12))
    fig = plt.figure(figsize=(20, 12))
    fig = plt.figure(figsize=(20, 12))
    fig = plt.figure(figsize=(20, 12))
    fig = plt.figure(figsize=(20, 12))
    fig = plt.figure(figsize=(20, 12))
    fig = plt.figure(figsize=(20, 12))
    fig = plt.figure(figsize=(20, 12))
    fig = plt.figure(figsize=(20, 12))
    fig = plt.figure(figsize=(20, 12))
    fig = plt.figure(figsize=(20, 12))
    fig = plt.figure(figsize=(20, 12))
    fig = plt.figure(figsize=(20, 12))
    fig = plt.figure(figsize=(20, 12))
    fig = plt.figure(figsize=(20, 12))
    fig = plt.figure(figsize=(20, 12))
    fig = plt.figure(figsize=(20, 12))
    fig = plt.figure(figsize=(20, 12))
    fig = plt.figure(figsize=(20, 12))
    fig = plt.figure(figsize=(20, 12))
    fig = plt.figure(figsize=(20, 12))
    fig = plt.figure(figsize=(20, 12))
    fig = plt.figure(figsize=(20, 12))
    fig = plt.figure(figsize=(20, 12))
    fig = plt.figure(figsize=(20, 12))
    fig = plt.figure(figsize=(20, 12))
    fig = plt.figure(figsize=(20, 12))
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    # Plot 1: original data
    # Plot 1: original data
    # Plot 1: original data
    # Plot 1: original data
    # Plot 1: original data
    # Plot 1: original data
    # Plot 1: original data
    # Plot 1: original data
    # Plot 1: original data
    # Plot 1: original data
    # Plot 1: original data
    # Plot 1: original data
    # Plot 1: original data
    # Plot 1: original data
    # Plot 1: original data
    # Plot 1: original data
    # Plot 1: original data
    # Plot 1: original data
    # Plot 1: original data
    # Plot 1: original data
    # Plot 1: original data
    # Plot 1: original data
    # Plot 1: original data
    # Plot 1: original data
    # Plot 1: original data
    # Plot 1: original data
    # Plot 1: original data
    # Plot 1: original data
    # Plot 1: original data
    # Plot 1: original data
    # Plot 1: original data
    # Plot 1: original data
    # Plot 1: original data
    # Plot 1: original data
    # Plot 1: original data
    # Plot 1: original data
    # Plot 1: original data
    ax1 = fig.add_subplot(231, projection='3d')
    ax1 = fig.add_subplot(231, projection='3d')
    ax1 = fig.add_subplot(231, projection='3d')
    ax1 = fig.add_subplot(231, projection='3d')
    ax1 = fig.add_subplot(231, projection='3d')
    ax1 = fig.add_subplot(231, projection='3d')
    ax1 = fig.add_subplot(231, projection='3d')
    ax1 = fig.add_subplot(231, projection='3d')
    ax1 = fig.add_subplot(231, projection='3d')
    ax1 = fig.add_subplot(231, projection='3d')
    ax1 = fig.add_subplot(231, projection='3d')
    ax1 = fig.add_subplot(231, projection='3d')
    ax1 = fig.add_subplot(231, projection='3d')
    ax1 = fig.add_subplot(231, projection='3d')
    ax1 = fig.add_subplot(231, projection='3d')
    ax1 = fig.add_subplot(231, projection='3d')
    ax1 = fig.add_subplot(231, projection='3d')
    ax1 = fig.add_subplot(231, projection='3d')
    ax1 = fig.add_subplot(231, projection='3d')
    ax1 = fig.add_subplot(231, projection='3d')
    ax1 = fig.add_subplot(231, projection='3d')
    ax1 = fig.add_subplot(231, projection='3d')
    ax1 = fig.add_subplot(231, projection='3d')
    ax1 = fig.add_subplot(231, projection='3d')
    ax1 = fig.add_subplot(231, projection='3d')
    ax1 = fig.add_subplot(231, projection='3d')
    ax1 = fig.add_subplot(231, projection='3d')
    ax1 = fig.add_subplot(231, projection='3d')
    ax1 = fig.add_subplot(231, projection='3d')
    ax1 = fig.add_subplot(231, projection='3d')
    ax1 = fig.add_subplot(231, projection='3d')
    ax1 = fig.add_subplot(231, projection='3d')
    ax1 = fig.add_subplot(231, projection='3d')
    ax1 = fig.add_subplot(231, projection='3d')
    ax1 = fig.add_subplot(231, projection='3d')
    ax1 = fig.add_subplot(231, projection='3d')
    ax1 = fig.add_subplot(231, projection='3d')
    ax1.scatter(original_points[:, 0], original_points[:, 1], original_points[:, 2], 
    ax1.scatter(original_points[:, 0], original_points[:, 1], original_points[:, 2], 
    ax1.scatter(original_points[:, 0], original_points[:, 1], original_points[:, 2], 
    ax1.scatter(original_points[:, 0], original_points[:, 1], original_points[:, 2], 
    ax1.scatter(original_points[:, 0], original_points[:, 1], original_points[:, 2], 
    ax1.scatter(original_points[:, 0], original_points[:, 1], original_points[:, 2], 
    ax1.scatter(original_points[:, 0], original_points[:, 1], original_points[:, 2], 
    ax1.scatter(original_points[:, 0], original_points[:, 1], original_points[:, 2], 
    ax1.scatter(original_points[:, 0], original_points[:, 1], original_points[:, 2], 
    ax1.scatter(original_points[:, 0], original_points[:, 1], original_points[:, 2], 
    ax1.scatter(original_points[:, 0], original_points[:, 1], original_points[:, 2], 
    ax1.scatter(original_points[:, 0], original_points[:, 1], original_points[:, 2], 
    ax1.scatter(original_points[:, 0], original_points[:, 1], original_points[:, 2], 
    ax1.scatter(original_points[:, 0], original_points[:, 1], original_points[:, 2], 
    ax1.scatter(original_points[:, 0], original_points[:, 1], original_points[:, 2], 
    ax1.scatter(original_points[:, 0], original_points[:, 1], original_points[:, 2], 
    ax1.scatter(original_points[:, 0], original_points[:, 1], original_points[:, 2], 
    ax1.scatter(original_points[:, 0], original_points[:, 1], original_points[:, 2], 
    ax1.scatter(original_points[:, 0], original_points[:, 1], original_points[:, 2], 
    ax1.scatter(original_points[:, 0], original_points[:, 1], original_points[:, 2], 
    ax1.scatter(original_points[:, 0], original_points[:, 1], original_points[:, 2], 
    ax1.scatter(original_points[:, 0], original_points[:, 1], original_points[:, 2], 
    ax1.scatter(original_points[:, 0], original_points[:, 1], original_points[:, 2], 
    ax1.scatter(original_points[:, 0], original_points[:, 1], original_points[:, 2], 
    ax1.scatter(original_points[:, 0], original_points[:, 1], original_points[:, 2], 
    ax1.scatter(original_points[:, 0], original_points[:, 1], original_points[:, 2], 
    ax1.scatter(original_points[:, 0], original_points[:, 1], original_points[:, 2], 
    ax1.scatter(original_points[:, 0], original_points[:, 1], original_points[:, 2], 
    ax1.scatter(original_points[:, 0], original_points[:, 1], original_points[:, 2], 
    ax1.scatter(original_points[:, 0], original_points[:, 1], original_points[:, 2], 
    ax1.scatter(original_points[:, 0], original_points[:, 1], original_points[:, 2], 
    ax1.scatter(original_points[:, 0], original_points[:, 1], original_points[:, 2], 
    ax1.scatter(original_points[:, 0], original_points[:, 1], original_points[:, 2], 
    ax1.scatter(original_points[:, 0], original_points[:, 1], original_points[:, 2], 
    ax1.scatter(original_points[:, 0], original_points[:, 1], original_points[:, 2], 
    ax1.scatter(original_points[:, 0], original_points[:, 1], original_points[:, 2], 
    ax1.scatter(original_points[:, 0], original_points[:, 1], original_points[:, 2], 
                alpha=0.6, s=2, c='blue')
                alpha=0.6, s=2, c='blue')
                alpha=0.6, s=2, c='blue')
                alpha=0.6, s=2, c='blue')
                alpha=0.6, s=2, c='blue')
                alpha=0.6, s=2, c='blue')
                alpha=0.6, s=2, c='blue')
                alpha=0.6, s=2, c='blue')
                alpha=0.6, s=2, c='blue')
                alpha=0.6, s=2, c='blue')
                alpha=0.6, s=2, c='blue')
                alpha=0.6, s=2, c='blue')
                alpha=0.6, s=2, c='blue')
                alpha=0.6, s=2, c='blue')
                alpha=0.6, s=2, c='blue')
                alpha=0.6, s=2, c='blue')
                alpha=0.6, s=2, c='blue')
                alpha=0.6, s=2, c='blue')
                alpha=0.6, s=2, c='blue')
                alpha=0.6, s=2, c='blue')
                alpha=0.6, s=2, c='blue')
                alpha=0.6, s=2, c='blue')
                alpha=0.6, s=2, c='blue')
                alpha=0.6, s=2, c='blue')
                alpha=0.6, s=2, c='blue')
                alpha=0.6, s=2, c='blue')
                alpha=0.6, s=2, c='blue')
                alpha=0.6, s=2, c='blue')
                alpha=0.6, s=2, c='blue')
                alpha=0.6, s=2, c='blue')
                alpha=0.6, s=2, c='blue')
                alpha=0.6, s=2, c='blue')
                alpha=0.6, s=2, c='blue')
                alpha=0.6, s=2, c='blue')
                alpha=0.6, s=2, c='blue')
                alpha=0.6, s=2, c='blue')
                alpha=0.6, s=2, c='blue')
    ax1.set_title(f'Original Data\n{len(original_points):,} points')
    ax1.set_title(f'Original Data\n{len(original_points):,} points')
    ax1.set_title(f'Original Data\n{len(original_points):,} points')
    ax1.set_title(f'Original Data\n{len(original_points):,} points')
    ax1.set_title(f'Original Data\n{len(original_points):,} points')
    ax1.set_title(f'Original Data\n{len(original_points):,} points')
    ax1.set_title(f'Original Data\n{len(original_points):,} points')
    ax1.set_title(f'Original Data\n{len(original_points):,} points')
    ax1.set_title(f'Original Data\n{len(original_points):,} points')
    ax1.set_title(f'Original Data\n{len(original_points):,} points')
    ax1.set_title(f'Original Data\n{len(original_points):,} points')
    ax1.set_title(f'Original Data\n{len(original_points):,} points')
    ax1.set_title(f'Original Data\n{len(original_points):,} points')
    ax1.set_title(f'Original Data\n{len(original_points):,} points')
    ax1.set_title(f'Original Data\n{len(original_points):,} points')
    ax1.set_title(f'Original Data\n{len(original_points):,} points')
    ax1.set_title(f'Original Data\n{len(original_points):,} points')
    ax1.set_title(f'Original Data\n{len(original_points):,} points')
    ax1.set_title(f'Original Data\n{len(original_points):,} points')
    ax1.set_title(f'Original Data\n{len(original_points):,} points')
    ax1.set_title(f'Original Data\n{len(original_points):,} points')
    ax1.set_title(f'Original Data\n{len(original_points):,} points')
    ax1.set_title(f'Original Data\n{len(original_points):,} points')
    ax1.set_title(f'Original Data\n{len(original_points):,} points')
    ax1.set_title(f'Original Data\n{len(original_points):,} points')
    ax1.set_title(f'Original Data\n{len(original_points):,} points')
    ax1.set_title(f'Original Data\n{len(original_points):,} points')
    ax1.set_title(f'Original Data\n{len(original_points):,} points')
    ax1.set_title(f'Original Data\n{len(original_points):,} points')
    ax1.set_title(f'Original Data\n{len(original_points):,} points')
    ax1.set_title(f'Original Data\n{len(original_points):,} points')
    ax1.set_title(f'Original Data\n{len(original_points):,} points')
    ax1.set_title(f'Original Data\n{len(original_points):,} points')
    ax1.set_title(f'Original Data\n{len(original_points):,} points')
    ax1.set_title(f'Original Data\n{len(original_points):,} points')
    ax1.set_title(f'Original Data\n{len(original_points):,} points')
    ax1.set_title(f'Original Data\n{len(original_points):,} points')
    ax1.set_xlabel('X')
    ax1.set_xlabel('X')
    ax1.set_xlabel('X')
    ax1.set_xlabel('X')
    ax1.set_xlabel('X')
    ax1.set_xlabel('X')
    ax1.set_xlabel('X')
    ax1.set_xlabel('X')
    ax1.set_xlabel('X')
    ax1.set_xlabel('X')
    ax1.set_xlabel('X')
    ax1.set_xlabel('X')
    ax1.set_xlabel('X')
    ax1.set_xlabel('X')
    ax1.set_xlabel('X')
    ax1.set_xlabel('X')
    ax1.set_xlabel('X')
    ax1.set_xlabel('X')
    ax1.set_xlabel('X')
    ax1.set_xlabel('X')
    ax1.set_xlabel('X')
    ax1.set_xlabel('X')
    ax1.set_xlabel('X')
    ax1.set_xlabel('X')
    ax1.set_xlabel('X')
    ax1.set_xlabel('X')
    ax1.set_xlabel('X')
    ax1.set_xlabel('X')
    ax1.set_xlabel('X')
    ax1.set_xlabel('X')
    ax1.set_xlabel('X')
    ax1.set_xlabel('X')
    ax1.set_xlabel('X')
    ax1.set_xlabel('X')
    ax1.set_xlabel('X')
    ax1.set_xlabel('X')
    ax1.set_xlabel('X')
    ax1.set_ylabel('Y')
    ax1.set_ylabel('Y')
    ax1.set_ylabel('Y')
    ax1.set_ylabel('Y')
    ax1.set_ylabel('Y')
    ax1.set_ylabel('Y')
    ax1.set_ylabel('Y')
    ax1.set_ylabel('Y')
    ax1.set_ylabel('Y')
    ax1.set_ylabel('Y')
    ax1.set_ylabel('Y')
    ax1.set_ylabel('Y')
    ax1.set_ylabel('Y')
    ax1.set_ylabel('Y')
    ax1.set_ylabel('Y')
    ax1.set_ylabel('Y')
    ax1.set_ylabel('Y')
    ax1.set_ylabel('Y')
    ax1.set_ylabel('Y')
    ax1.set_ylabel('Y')
    ax1.set_ylabel('Y')
    ax1.set_ylabel('Y')
    ax1.set_ylabel('Y')
    ax1.set_ylabel('Y')
    ax1.set_ylabel('Y')
    ax1.set_ylabel('Y')
    ax1.set_ylabel('Y')
    ax1.set_ylabel('Y')
    ax1.set_ylabel('Y')
    ax1.set_ylabel('Y')
    ax1.set_ylabel('Y')
    ax1.set_ylabel('Y')
    ax1.set_ylabel('Y')
    ax1.set_ylabel('Y')
    ax1.set_ylabel('Y')
    ax1.set_ylabel('Y')
    ax1.set_ylabel('Y')
    ax1.set_zlabel('Z')
    ax1.set_zlabel('Z')
    ax1.set_zlabel('Z')
    ax1.set_zlabel('Z')
    ax1.set_zlabel('Z')
    ax1.set_zlabel('Z')
    ax1.set_zlabel('Z')
    ax1.set_zlabel('Z')
    ax1.set_zlabel('Z')
    ax1.set_zlabel('Z')
    ax1.set_zlabel('Z')
    ax1.set_zlabel('Z')
    ax1.set_zlabel('Z')
    ax1.set_zlabel('Z')
    ax1.set_zlabel('Z')
    ax1.set_zlabel('Z')
    ax1.set_zlabel('Z')
    ax1.set_zlabel('Z')
    ax1.set_zlabel('Z')
    ax1.set_zlabel('Z')
    ax1.set_zlabel('Z')
    ax1.set_zlabel('Z')
    ax1.set_zlabel('Z')
    ax1.set_zlabel('Z')
    ax1.set_zlabel('Z')
    ax1.set_zlabel('Z')
    ax1.set_zlabel('Z')
    ax1.set_zlabel('Z')
    ax1.set_zlabel('Z')
    ax1.set_zlabel('Z')
    ax1.set_zlabel('Z')
    ax1.set_zlabel('Z')
    ax1.set_zlabel('Z')
    ax1.set_zlabel('Z')
    ax1.set_zlabel('Z')
    ax1.set_zlabel('Z')
    ax1.set_zlabel('Z')
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    # Plot 2: filtered data
    # Plot 2: filtered data
    # Plot 2: filtered data
    # Plot 2: filtered data
    # Plot 2: filtered data
    # Plot 2: filtered data
    # Plot 2: filtered data
    # Plot 2: filtered data
    # Plot 2: filtered data
    # Plot 2: filtered data
    # Plot 2: filtered data
    # Plot 2: filtered data
    # Plot 2: filtered data
    # Plot 2: filtered data
    # Plot 2: filtered data
    # Plot 2: filtered data
    # Plot 2: filtered data
    # Plot 2: filtered data
    # Plot 2: filtered data
    # Plot 2: filtered data
    # Plot 2: filtered data
    # Plot 2: filtered data
    # Plot 2: filtered data
    # Plot 2: filtered data
    # Plot 2: filtered data
    # Plot 2: filtered data
    # Plot 2: filtered data
    # Plot 2: filtered data
    # Plot 2: filtered data
    # Plot 2: filtered data
    # Plot 2: filtered data
    # Plot 2: filtered data
    # Plot 2: filtered data
    # Plot 2: filtered data
    # Plot 2: filtered data
    # Plot 2: filtered data
    # Plot 2: filtered data
    ax2 = fig.add_subplot(232, projection='3d')
    ax2 = fig.add_subplot(232, projection='3d')
    ax2 = fig.add_subplot(232, projection='3d')
    ax2 = fig.add_subplot(232, projection='3d')
    ax2 = fig.add_subplot(232, projection='3d')
    ax2 = fig.add_subplot(232, projection='3d')
    ax2 = fig.add_subplot(232, projection='3d')
    ax2 = fig.add_subplot(232, projection='3d')
    ax2 = fig.add_subplot(232, projection='3d')
    ax2 = fig.add_subplot(232, projection='3d')
    ax2 = fig.add_subplot(232, projection='3d')
    ax2 = fig.add_subplot(232, projection='3d')
    ax2 = fig.add_subplot(232, projection='3d')
    ax2 = fig.add_subplot(232, projection='3d')
    ax2 = fig.add_subplot(232, projection='3d')
    ax2 = fig.add_subplot(232, projection='3d')
    ax2 = fig.add_subplot(232, projection='3d')
    ax2 = fig.add_subplot(232, projection='3d')
    ax2 = fig.add_subplot(232, projection='3d')
    ax2 = fig.add_subplot(232, projection='3d')
    ax2 = fig.add_subplot(232, projection='3d')
    ax2 = fig.add_subplot(232, projection='3d')
    ax2 = fig.add_subplot(232, projection='3d')
    ax2 = fig.add_subplot(232, projection='3d')
    ax2 = fig.add_subplot(232, projection='3d')
    ax2 = fig.add_subplot(232, projection='3d')
    ax2 = fig.add_subplot(232, projection='3d')
    ax2 = fig.add_subplot(232, projection='3d')
    ax2 = fig.add_subplot(232, projection='3d')
    ax2 = fig.add_subplot(232, projection='3d')
    ax2 = fig.add_subplot(232, projection='3d')
    ax2 = fig.add_subplot(232, projection='3d')
    ax2 = fig.add_subplot(232, projection='3d')
    ax2 = fig.add_subplot(232, projection='3d')
    ax2 = fig.add_subplot(232, projection='3d')
    ax2 = fig.add_subplot(232, projection='3d')
    ax2 = fig.add_subplot(232, projection='3d')
    ax2.scatter(filtered_points[:, 0], filtered_points[:, 1], filtered_points[:, 2], 
    ax2.scatter(filtered_points[:, 0], filtered_points[:, 1], filtered_points[:, 2], 
    ax2.scatter(filtered_points[:, 0], filtered_points[:, 1], filtered_points[:, 2], 
    ax2.scatter(filtered_points[:, 0], filtered_points[:, 1], filtered_points[:, 2], 
    ax2.scatter(filtered_points[:, 0], filtered_points[:, 1], filtered_points[:, 2], 
    ax2.scatter(filtered_points[:, 0], filtered_points[:, 1], filtered_points[:, 2], 
    ax2.scatter(filtered_points[:, 0], filtered_points[:, 1], filtered_points[:, 2], 
    ax2.scatter(filtered_points[:, 0], filtered_points[:, 1], filtered_points[:, 2], 
    ax2.scatter(filtered_points[:, 0], filtered_points[:, 1], filtered_points[:, 2], 
    ax2.scatter(filtered_points[:, 0], filtered_points[:, 1], filtered_points[:, 2], 
    ax2.scatter(filtered_points[:, 0], filtered_points[:, 1], filtered_points[:, 2], 
    ax2.scatter(filtered_points[:, 0], filtered_points[:, 1], filtered_points[:, 2], 
    ax2.scatter(filtered_points[:, 0], filtered_points[:, 1], filtered_points[:, 2], 
    ax2.scatter(filtered_points[:, 0], filtered_points[:, 1], filtered_points[:, 2], 
    ax2.scatter(filtered_points[:, 0], filtered_points[:, 1], filtered_points[:, 2], 
    ax2.scatter(filtered_points[:, 0], filtered_points[:, 1], filtered_points[:, 2], 
    ax2.scatter(filtered_points[:, 0], filtered_points[:, 1], filtered_points[:, 2], 
    ax2.scatter(filtered_points[:, 0], filtered_points[:, 1], filtered_points[:, 2], 
    ax2.scatter(filtered_points[:, 0], filtered_points[:, 1], filtered_points[:, 2], 
    ax2.scatter(filtered_points[:, 0], filtered_points[:, 1], filtered_points[:, 2], 
    ax2.scatter(filtered_points[:, 0], filtered_points[:, 1], filtered_points[:, 2], 
    ax2.scatter(filtered_points[:, 0], filtered_points[:, 1], filtered_points[:, 2], 
    ax2.scatter(filtered_points[:, 0], filtered_points[:, 1], filtered_points[:, 2], 
    ax2.scatter(filtered_points[:, 0], filtered_points[:, 1], filtered_points[:, 2], 
    ax2.scatter(filtered_points[:, 0], filtered_points[:, 1], filtered_points[:, 2], 
    ax2.scatter(filtered_points[:, 0], filtered_points[:, 1], filtered_points[:, 2], 
    ax2.scatter(filtered_points[:, 0], filtered_points[:, 1], filtered_points[:, 2], 
    ax2.scatter(filtered_points[:, 0], filtered_points[:, 1], filtered_points[:, 2], 
    ax2.scatter(filtered_points[:, 0], filtered_points[:, 1], filtered_points[:, 2], 
    ax2.scatter(filtered_points[:, 0], filtered_points[:, 1], filtered_points[:, 2], 
    ax2.scatter(filtered_points[:, 0], filtered_points[:, 1], filtered_points[:, 2], 
    ax2.scatter(filtered_points[:, 0], filtered_points[:, 1], filtered_points[:, 2], 
    ax2.scatter(filtered_points[:, 0], filtered_points[:, 1], filtered_points[:, 2], 
    ax2.scatter(filtered_points[:, 0], filtered_points[:, 1], filtered_points[:, 2], 
    ax2.scatter(filtered_points[:, 0], filtered_points[:, 1], filtered_points[:, 2], 
    ax2.scatter(filtered_points[:, 0], filtered_points[:, 1], filtered_points[:, 2], 
    ax2.scatter(filtered_points[:, 0], filtered_points[:, 1], filtered_points[:, 2], 
                alpha=0.8, s=3, c='green')
                alpha=0.8, s=3, c='green')
                alpha=0.8, s=3, c='green')
                alpha=0.8, s=3, c='green')
                alpha=0.8, s=3, c='green')
                alpha=0.8, s=3, c='green')
                alpha=0.8, s=3, c='green')
                alpha=0.8, s=3, c='green')
                alpha=0.8, s=3, c='green')
                alpha=0.8, s=3, c='green')
                alpha=0.8, s=3, c='green')
                alpha=0.8, s=3, c='green')
                alpha=0.8, s=3, c='green')
                alpha=0.8, s=3, c='green')
                alpha=0.8, s=3, c='green')
                alpha=0.8, s=3, c='green')
                alpha=0.8, s=3, c='green')
                alpha=0.8, s=3, c='green')
                alpha=0.8, s=3, c='green')
                alpha=0.8, s=3, c='green')
                alpha=0.8, s=3, c='green')
                alpha=0.8, s=3, c='green')
                alpha=0.8, s=3, c='green')
                alpha=0.8, s=3, c='green')
                alpha=0.8, s=3, c='green')
                alpha=0.8, s=3, c='green')
                alpha=0.8, s=3, c='green')
                alpha=0.8, s=3, c='green')
                alpha=0.8, s=3, c='green')
                alpha=0.8, s=3, c='green')
                alpha=0.8, s=3, c='green')
                alpha=0.8, s=3, c='green')
                alpha=0.8, s=3, c='green')
                alpha=0.8, s=3, c='green')
                alpha=0.8, s=3, c='green')
                alpha=0.8, s=3, c='green')
                alpha=0.8, s=3, c='green')
    ax2.set_title(f'Filtered Data\n{len(filtered_points):,} points')
    ax2.set_title(f'Filtered Data\n{len(filtered_points):,} points')
    ax2.set_title(f'Filtered Data\n{len(filtered_points):,} points')
    ax2.set_title(f'Filtered Data\n{len(filtered_points):,} points')
    ax2.set_title(f'Filtered Data\n{len(filtered_points):,} points')
    ax2.set_title(f'Filtered Data\n{len(filtered_points):,} points')
    ax2.set_title(f'Filtered Data\n{len(filtered_points):,} points')
    ax2.set_title(f'Filtered Data\n{len(filtered_points):,} points')
    ax2.set_title(f'Filtered Data\n{len(filtered_points):,} points')
    ax2.set_title(f'Filtered Data\n{len(filtered_points):,} points')
    ax2.set_title(f'Filtered Data\n{len(filtered_points):,} points')
    ax2.set_title(f'Filtered Data\n{len(filtered_points):,} points')
    ax2.set_title(f'Filtered Data\n{len(filtered_points):,} points')
    ax2.set_title(f'Filtered Data\n{len(filtered_points):,} points')
    ax2.set_title(f'Filtered Data\n{len(filtered_points):,} points')
    ax2.set_title(f'Filtered Data\n{len(filtered_points):,} points')
    ax2.set_title(f'Filtered Data\n{len(filtered_points):,} points')
    ax2.set_title(f'Filtered Data\n{len(filtered_points):,} points')
    ax2.set_title(f'Filtered Data\n{len(filtered_points):,} points')
    ax2.set_title(f'Filtered Data\n{len(filtered_points):,} points')
    ax2.set_title(f'Filtered Data\n{len(filtered_points):,} points')
    ax2.set_title(f'Filtered Data\n{len(filtered_points):,} points')
    ax2.set_title(f'Filtered Data\n{len(filtered_points):,} points')
    ax2.set_title(f'Filtered Data\n{len(filtered_points):,} points')
    ax2.set_title(f'Filtered Data\n{len(filtered_points):,} points')
    ax2.set_title(f'Filtered Data\n{len(filtered_points):,} points')
    ax2.set_title(f'Filtered Data\n{len(filtered_points):,} points')
    ax2.set_title(f'Filtered Data\n{len(filtered_points):,} points')
    ax2.set_title(f'Filtered Data\n{len(filtered_points):,} points')
    ax2.set_title(f'Filtered Data\n{len(filtered_points):,} points')
    ax2.set_title(f'Filtered Data\n{len(filtered_points):,} points')
    ax2.set_title(f'Filtered Data\n{len(filtered_points):,} points')
    ax2.set_title(f'Filtered Data\n{len(filtered_points):,} points')
    ax2.set_title(f'Filtered Data\n{len(filtered_points):,} points')
    ax2.set_title(f'Filtered Data\n{len(filtered_points):,} points')
    ax2.set_title(f'Filtered Data\n{len(filtered_points):,} points')
    ax2.set_title(f'Filtered Data\n{len(filtered_points):,} points')
    ax2.set_xlabel('X')
    ax2.set_xlabel('X')
    ax2.set_xlabel('X')
    ax2.set_xlabel('X')
    ax2.set_xlabel('X')
    ax2.set_xlabel('X')
    ax2.set_xlabel('X')
    ax2.set_xlabel('X')
    ax2.set_xlabel('X')
    ax2.set_xlabel('X')
    ax2.set_xlabel('X')
    ax2.set_xlabel('X')
    ax2.set_xlabel('X')
    ax2.set_xlabel('X')
    ax2.set_xlabel('X')
    ax2.set_xlabel('X')
    ax2.set_xlabel('X')
    ax2.set_xlabel('X')
    ax2.set_xlabel('X')
    ax2.set_xlabel('X')
    ax2.set_xlabel('X')
    ax2.set_xlabel('X')
    ax2.set_xlabel('X')
    ax2.set_xlabel('X')
    ax2.set_xlabel('X')
    ax2.set_xlabel('X')
    ax2.set_xlabel('X')
    ax2.set_xlabel('X')
    ax2.set_xlabel('X')
    ax2.set_xlabel('X')
    ax2.set_xlabel('X')
    ax2.set_xlabel('X')
    ax2.set_xlabel('X')
    ax2.set_xlabel('X')
    ax2.set_xlabel('X')
    ax2.set_xlabel('X')
    ax2.set_xlabel('X')
    ax2.set_ylabel('Y')
    ax2.set_ylabel('Y')
    ax2.set_ylabel('Y')
    ax2.set_ylabel('Y')
    ax2.set_ylabel('Y')
    ax2.set_ylabel('Y')
    ax2.set_ylabel('Y')
    ax2.set_ylabel('Y')
    ax2.set_ylabel('Y')
    ax2.set_ylabel('Y')
    ax2.set_ylabel('Y')
    ax2.set_ylabel('Y')
    ax2.set_ylabel('Y')
    ax2.set_ylabel('Y')
    ax2.set_ylabel('Y')
    ax2.set_ylabel('Y')
    ax2.set_ylabel('Y')
    ax2.set_ylabel('Y')
    ax2.set_ylabel('Y')
    ax2.set_ylabel('Y')
    ax2.set_ylabel('Y')
    ax2.set_ylabel('Y')
    ax2.set_ylabel('Y')
    ax2.set_ylabel('Y')
    ax2.set_ylabel('Y')
    ax2.set_ylabel('Y')
    ax2.set_ylabel('Y')
    ax2.set_ylabel('Y')
    ax2.set_ylabel('Y')
    ax2.set_ylabel('Y')
    ax2.set_ylabel('Y')
    ax2.set_ylabel('Y')
    ax2.set_ylabel('Y')
    ax2.set_ylabel('Y')
    ax2.set_ylabel('Y')
    ax2.set_ylabel('Y')
    ax2.set_ylabel('Y')
    ax2.set_zlabel('Z')
    ax2.set_zlabel('Z')
    ax2.set_zlabel('Z')
    ax2.set_zlabel('Z')
    ax2.set_zlabel('Z')
    ax2.set_zlabel('Z')
    ax2.set_zlabel('Z')
    ax2.set_zlabel('Z')
    ax2.set_zlabel('Z')
    ax2.set_zlabel('Z')
    ax2.set_zlabel('Z')
    ax2.set_zlabel('Z')
    ax2.set_zlabel('Z')
    ax2.set_zlabel('Z')
    ax2.set_zlabel('Z')
    ax2.set_zlabel('Z')
    ax2.set_zlabel('Z')
    ax2.set_zlabel('Z')
    ax2.set_zlabel('Z')
    ax2.set_zlabel('Z')
    ax2.set_zlabel('Z')
    ax2.set_zlabel('Z')
    ax2.set_zlabel('Z')
    ax2.set_zlabel('Z')
    ax2.set_zlabel('Z')
    ax2.set_zlabel('Z')
    ax2.set_zlabel('Z')
    ax2.set_zlabel('Z')
    ax2.set_zlabel('Z')
    ax2.set_zlabel('Z')
    ax2.set_zlabel('Z')
    ax2.set_zlabel('Z')
    ax2.set_zlabel('Z')
    ax2.set_zlabel('Z')
    ax2.set_zlabel('Z')
    ax2.set_zlabel('Z')
    ax2.set_zlabel('Z')
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    # Plot 3: comparison
    # Plot 3: comparison
    # Plot 3: comparison
    # Plot 3: comparison
    # Plot 3: comparison
    # Plot 3: comparison
    # Plot 3: comparison
    # Plot 3: comparison
    # Plot 3: comparison
    # Plot 3: comparison
    # Plot 3: comparison
    # Plot 3: comparison
    # Plot 3: comparison
    # Plot 3: comparison
    # Plot 3: comparison
    # Plot 3: comparison
    # Plot 3: comparison
    # Plot 3: comparison
    # Plot 3: comparison
    # Plot 3: comparison
    # Plot 3: comparison
    # Plot 3: comparison
    # Plot 3: comparison
    # Plot 3: comparison
    # Plot 3: comparison
    # Plot 3: comparison
    # Plot 3: comparison
    # Plot 3: comparison
    # Plot 3: comparison
    # Plot 3: comparison
    # Plot 3: comparison
    # Plot 3: comparison
    # Plot 3: comparison
    # Plot 3: comparison
    # Plot 3: comparison
    # Plot 3: comparison
    # Plot 3: comparison
    ax3 = fig.add_subplot(233, projection='3d')
    ax3 = fig.add_subplot(233, projection='3d')
    ax3 = fig.add_subplot(233, projection='3d')
    ax3 = fig.add_subplot(233, projection='3d')
    ax3 = fig.add_subplot(233, projection='3d')
    ax3 = fig.add_subplot(233, projection='3d')
    ax3 = fig.add_subplot(233, projection='3d')
    ax3 = fig.add_subplot(233, projection='3d')
    ax3 = fig.add_subplot(233, projection='3d')
    ax3 = fig.add_subplot(233, projection='3d')
    ax3 = fig.add_subplot(233, projection='3d')
    ax3 = fig.add_subplot(233, projection='3d')
    ax3 = fig.add_subplot(233, projection='3d')
    ax3 = fig.add_subplot(233, projection='3d')
    ax3 = fig.add_subplot(233, projection='3d')
    ax3 = fig.add_subplot(233, projection='3d')
    ax3 = fig.add_subplot(233, projection='3d')
    ax3 = fig.add_subplot(233, projection='3d')
    ax3 = fig.add_subplot(233, projection='3d')
    ax3 = fig.add_subplot(233, projection='3d')
    ax3 = fig.add_subplot(233, projection='3d')
    ax3 = fig.add_subplot(233, projection='3d')
    ax3 = fig.add_subplot(233, projection='3d')
    ax3 = fig.add_subplot(233, projection='3d')
    ax3 = fig.add_subplot(233, projection='3d')
    ax3 = fig.add_subplot(233, projection='3d')
    ax3 = fig.add_subplot(233, projection='3d')
    ax3 = fig.add_subplot(233, projection='3d')
    ax3 = fig.add_subplot(233, projection='3d')
    ax3 = fig.add_subplot(233, projection='3d')
    ax3 = fig.add_subplot(233, projection='3d')
    ax3 = fig.add_subplot(233, projection='3d')
    ax3 = fig.add_subplot(233, projection='3d')
    ax3 = fig.add_subplot(233, projection='3d')
    ax3 = fig.add_subplot(233, projection='3d')
    ax3 = fig.add_subplot(233, projection='3d')
    ax3 = fig.add_subplot(233, projection='3d')
    ax3.scatter(original_points[:, 0], original_points[:, 1], original_points[:, 2], 
    ax3.scatter(original_points[:, 0], original_points[:, 1], original_points[:, 2], 
    ax3.scatter(original_points[:, 0], original_points[:, 1], original_points[:, 2], 
    ax3.scatter(original_points[:, 0], original_points[:, 1], original_points[:, 2], 
    ax3.scatter(original_points[:, 0], original_points[:, 1], original_points[:, 2], 
    ax3.scatter(original_points[:, 0], original_points[:, 1], original_points[:, 2], 
    ax3.scatter(original_points[:, 0], original_points[:, 1], original_points[:, 2], 
    ax3.scatter(original_points[:, 0], original_points[:, 1], original_points[:, 2], 
    ax3.scatter(original_points[:, 0], original_points[:, 1], original_points[:, 2], 
    ax3.scatter(original_points[:, 0], original_points[:, 1], original_points[:, 2], 
    ax3.scatter(original_points[:, 0], original_points[:, 1], original_points[:, 2], 
    ax3.scatter(original_points[:, 0], original_points[:, 1], original_points[:, 2], 
    ax3.scatter(original_points[:, 0], original_points[:, 1], original_points[:, 2], 
    ax3.scatter(original_points[:, 0], original_points[:, 1], original_points[:, 2], 
    ax3.scatter(original_points[:, 0], original_points[:, 1], original_points[:, 2], 
    ax3.scatter(original_points[:, 0], original_points[:, 1], original_points[:, 2], 
    ax3.scatter(original_points[:, 0], original_points[:, 1], original_points[:, 2], 
    ax3.scatter(original_points[:, 0], original_points[:, 1], original_points[:, 2], 
    ax3.scatter(original_points[:, 0], original_points[:, 1], original_points[:, 2], 
    ax3.scatter(original_points[:, 0], original_points[:, 1], original_points[:, 2], 
    ax3.scatter(original_points[:, 0], original_points[:, 1], original_points[:, 2], 
    ax3.scatter(original_points[:, 0], original_points[:, 1], original_points[:, 2], 
    ax3.scatter(original_points[:, 0], original_points[:, 1], original_points[:, 2], 
    ax3.scatter(original_points[:, 0], original_points[:, 1], original_points[:, 2], 
    ax3.scatter(original_points[:, 0], original_points[:, 1], original_points[:, 2], 
    ax3.scatter(original_points[:, 0], original_points[:, 1], original_points[:, 2], 
    ax3.scatter(original_points[:, 0], original_points[:, 1], original_points[:, 2], 
    ax3.scatter(original_points[:, 0], original_points[:, 1], original_points[:, 2], 
    ax3.scatter(original_points[:, 0], original_points[:, 1], original_points[:, 2], 
    ax3.scatter(original_points[:, 0], original_points[:, 1], original_points[:, 2], 
    ax3.scatter(original_points[:, 0], original_points[:, 1], original_points[:, 2], 
    ax3.scatter(original_points[:, 0], original_points[:, 1], original_points[:, 2], 
    ax3.scatter(original_points[:, 0], original_points[:, 1], original_points[:, 2], 
    ax3.scatter(original_points[:, 0], original_points[:, 1], original_points[:, 2], 
    ax3.scatter(original_points[:, 0], original_points[:, 1], original_points[:, 2], 
    ax3.scatter(original_points[:, 0], original_points[:, 1], original_points[:, 2], 
    ax3.scatter(original_points[:, 0], original_points[:, 1], original_points[:, 2], 
                alpha=0.2, s=1, c='red', label='Removed')
                alpha=0.2, s=1, c='red', label='Removed')
                alpha=0.2, s=1, c='red', label='Removed')
                alpha=0.2, s=1, c='red', label='Removed')
                alpha=0.2, s=1, c='red', label='Removed')
                alpha=0.2, s=1, c='red', label='Removed')
                alpha=0.2, s=1, c='red', label='Removed')
                alpha=0.2, s=1, c='red', label='Removed')
                alpha=0.2, s=1, c='red', label='Removed')
                alpha=0.2, s=1, c='red', label='Removed')
                alpha=0.2, s=1, c='red', label='Removed')
                alpha=0.2, s=1, c='red', label='Removed')
                alpha=0.2, s=1, c='red', label='Removed')
                alpha=0.2, s=1, c='red', label='Removed')
                alpha=0.2, s=1, c='red', label='Removed')
                alpha=0.2, s=1, c='red', label='Removed')
                alpha=0.2, s=1, c='red', label='Removed')
                alpha=0.2, s=1, c='red', label='Removed')
                alpha=0.2, s=1, c='red', label='Removed')
                alpha=0.2, s=1, c='red', label='Removed')
                alpha=0.2, s=1, c='red', label='Removed')
                alpha=0.2, s=1, c='red', label='Removed')
                alpha=0.2, s=1, c='red', label='Removed')
                alpha=0.2, s=1, c='red', label='Removed')
                alpha=0.2, s=1, c='red', label='Removed')
                alpha=0.2, s=1, c='red', label='Removed')
                alpha=0.2, s=1, c='red', label='Removed')
                alpha=0.2, s=1, c='red', label='Removed')
                alpha=0.2, s=1, c='red', label='Removed')
                alpha=0.2, s=1, c='red', label='Removed')
                alpha=0.2, s=1, c='red', label='Removed')
                alpha=0.2, s=1, c='red', label='Removed')
                alpha=0.2, s=1, c='red', label='Removed')
                alpha=0.2, s=1, c='red', label='Removed')
                alpha=0.2, s=1, c='red', label='Removed')
                alpha=0.2, s=1, c='red', label='Removed')
                alpha=0.2, s=1, c='red', label='Removed')
    ax3.scatter(filtered_points[:, 0], filtered_points[:, 1], filtered_points[:, 2], 
    ax3.scatter(filtered_points[:, 0], filtered_points[:, 1], filtered_points[:, 2], 
    ax3.scatter(filtered_points[:, 0], filtered_points[:, 1], filtered_points[:, 2], 
    ax3.scatter(filtered_points[:, 0], filtered_points[:, 1], filtered_points[:, 2], 
    ax3.scatter(filtered_points[:, 0], filtered_points[:, 1], filtered_points[:, 2], 
    ax3.scatter(filtered_points[:, 0], filtered_points[:, 1], filtered_points[:, 2], 
    ax3.scatter(filtered_points[:, 0], filtered_points[:, 1], filtered_points[:, 2], 
    ax3.scatter(filtered_points[:, 0], filtered_points[:, 1], filtered_points[:, 2], 
    ax3.scatter(filtered_points[:, 0], filtered_points[:, 1], filtered_points[:, 2], 
    ax3.scatter(filtered_points[:, 0], filtered_points[:, 1], filtered_points[:, 2], 
    ax3.scatter(filtered_points[:, 0], filtered_points[:, 1], filtered_points[:, 2], 
    ax3.scatter(filtered_points[:, 0], filtered_points[:, 1], filtered_points[:, 2], 
    ax3.scatter(filtered_points[:, 0], filtered_points[:, 1], filtered_points[:, 2], 
    ax3.scatter(filtered_points[:, 0], filtered_points[:, 1], filtered_points[:, 2], 
    ax3.scatter(filtered_points[:, 0], filtered_points[:, 1], filtered_points[:, 2], 
    ax3.scatter(filtered_points[:, 0], filtered_points[:, 1], filtered_points[:, 2], 
    ax3.scatter(filtered_points[:, 0], filtered_points[:, 1], filtered_points[:, 2], 
    ax3.scatter(filtered_points[:, 0], filtered_points[:, 1], filtered_points[:, 2], 
    ax3.scatter(filtered_points[:, 0], filtered_points[:, 1], filtered_points[:, 2], 
    ax3.scatter(filtered_points[:, 0], filtered_points[:, 1], filtered_points[:, 2], 
    ax3.scatter(filtered_points[:, 0], filtered_points[:, 1], filtered_points[:, 2], 
    ax3.scatter(filtered_points[:, 0], filtered_points[:, 1], filtered_points[:, 2], 
    ax3.scatter(filtered_points[:, 0], filtered_points[:, 1], filtered_points[:, 2], 
    ax3.scatter(filtered_points[:, 0], filtered_points[:, 1], filtered_points[:, 2], 
    ax3.scatter(filtered_points[:, 0], filtered_points[:, 1], filtered_points[:, 2], 
    ax3.scatter(filtered_points[:, 0], filtered_points[:, 1], filtered_points[:, 2], 
    ax3.scatter(filtered_points[:, 0], filtered_points[:, 1], filtered_points[:, 2], 
    ax3.scatter(filtered_points[:, 0], filtered_points[:, 1], filtered_points[:, 2], 
    ax3.scatter(filtered_points[:, 0], filtered_points[:, 1], filtered_points[:, 2], 
    ax3.scatter(filtered_points[:, 0], filtered_points[:, 1], filtered_points[:, 2], 
    ax3.scatter(filtered_points[:, 0], filtered_points[:, 1], filtered_points[:, 2], 
    ax3.scatter(filtered_points[:, 0], filtered_points[:, 1], filtered_points[:, 2], 
    ax3.scatter(filtered_points[:, 0], filtered_points[:, 1], filtered_points[:, 2], 
    ax3.scatter(filtered_points[:, 0], filtered_points[:, 1], filtered_points[:, 2], 
    ax3.scatter(filtered_points[:, 0], filtered_points[:, 1], filtered_points[:, 2], 
    ax3.scatter(filtered_points[:, 0], filtered_points[:, 1], filtered_points[:, 2], 
    ax3.scatter(filtered_points[:, 0], filtered_points[:, 1], filtered_points[:, 2], 
                alpha=0.7, s=2, c='green', label='Kept')
                alpha=0.7, s=2, c='green', label='Kept')
                alpha=0.7, s=2, c='green', label='Kept')
                alpha=0.7, s=2, c='green', label='Kept')
                alpha=0.7, s=2, c='green', label='Kept')
                alpha=0.7, s=2, c='green', label='Kept')
                alpha=0.7, s=2, c='green', label='Kept')
                alpha=0.7, s=2, c='green', label='Kept')
                alpha=0.7, s=2, c='green', label='Kept')
                alpha=0.7, s=2, c='green', label='Kept')
                alpha=0.7, s=2, c='green', label='Kept')
                alpha=0.7, s=2, c='green', label='Kept')
                alpha=0.7, s=2, c='green', label='Kept')
                alpha=0.7, s=2, c='green', label='Kept')
                alpha=0.7, s=2, c='green', label='Kept')
                alpha=0.7, s=2, c='green', label='Kept')
                alpha=0.7, s=2, c='green', label='Kept')
                alpha=0.7, s=2, c='green', label='Kept')
                alpha=0.7, s=2, c='green', label='Kept')
                alpha=0.7, s=2, c='green', label='Kept')
                alpha=0.7, s=2, c='green', label='Kept')
                alpha=0.7, s=2, c='green', label='Kept')
                alpha=0.7, s=2, c='green', label='Kept')
                alpha=0.7, s=2, c='green', label='Kept')
                alpha=0.7, s=2, c='green', label='Kept')
                alpha=0.7, s=2, c='green', label='Kept')
                alpha=0.7, s=2, c='green', label='Kept')
                alpha=0.7, s=2, c='green', label='Kept')
                alpha=0.7, s=2, c='green', label='Kept')
                alpha=0.7, s=2, c='green', label='Kept')
                alpha=0.7, s=2, c='green', label='Kept')
                alpha=0.7, s=2, c='green', label='Kept')
                alpha=0.7, s=2, c='green', label='Kept')
                alpha=0.7, s=2, c='green', label='Kept')
                alpha=0.7, s=2, c='green', label='Kept')
                alpha=0.7, s=2, c='green', label='Kept')
                alpha=0.7, s=2, c='green', label='Kept')
    ax3.set_title('Comparison: Red=Removed, Green=Kept')
    ax3.set_title('Comparison: Red=Removed, Green=Kept')
    ax3.set_title('Comparison: Red=Removed, Green=Kept')
    ax3.set_title('Comparison: Red=Removed, Green=Kept')
    ax3.set_title('Comparison: Red=Removed, Green=Kept')
    ax3.set_title('Comparison: Red=Removed, Green=Kept')
    ax3.set_title('Comparison: Red=Removed, Green=Kept')
    ax3.set_title('Comparison: Red=Removed, Green=Kept')
    ax3.set_title('Comparison: Red=Removed, Green=Kept')
    ax3.set_title('Comparison: Red=Removed, Green=Kept')
    ax3.set_title('Comparison: Red=Removed, Green=Kept')
    ax3.set_title('Comparison: Red=Removed, Green=Kept')
    ax3.set_title('Comparison: Red=Removed, Green=Kept')
    ax3.set_title('Comparison: Red=Removed, Green=Kept')
    ax3.set_title('Comparison: Red=Removed, Green=Kept')
    ax3.set_title('Comparison: Red=Removed, Green=Kept')
    ax3.set_title('Comparison: Red=Removed, Green=Kept')
    ax3.set_title('Comparison: Red=Removed, Green=Kept')
    ax3.set_title('Comparison: Red=Removed, Green=Kept')
    ax3.set_title('Comparison: Red=Removed, Green=Kept')
    ax3.set_title('Comparison: Red=Removed, Green=Kept')
    ax3.set_title('Comparison: Red=Removed, Green=Kept')
    ax3.set_title('Comparison: Red=Removed, Green=Kept')
    ax3.set_title('Comparison: Red=Removed, Green=Kept')
    ax3.set_title('Comparison: Red=Removed, Green=Kept')
    ax3.set_title('Comparison: Red=Removed, Green=Kept')
    ax3.set_title('Comparison: Red=Removed, Green=Kept')
    ax3.set_title('Comparison: Red=Removed, Green=Kept')
    ax3.set_title('Comparison: Red=Removed, Green=Kept')
    ax3.set_title('Comparison: Red=Removed, Green=Kept')
    ax3.set_title('Comparison: Red=Removed, Green=Kept')
    ax3.set_title('Comparison: Red=Removed, Green=Kept')
    ax3.set_title('Comparison: Red=Removed, Green=Kept')
    ax3.set_title('Comparison: Red=Removed, Green=Kept')
    ax3.set_title('Comparison: Red=Removed, Green=Kept')
    ax3.set_title('Comparison: Red=Removed, Green=Kept')
    ax3.set_title('Comparison: Red=Removed, Green=Kept')
    ax3.legend()
    ax3.legend()
    ax3.legend()
    ax3.legend()
    ax3.legend()
    ax3.legend()
    ax3.legend()
    ax3.legend()
    ax3.legend()
    ax3.legend()
    ax3.legend()
    ax3.legend()
    ax3.legend()
    ax3.legend()
    ax3.legend()
    ax3.legend()
    ax3.legend()
    ax3.legend()
    ax3.legend()
    ax3.legend()
    ax3.legend()
    ax3.legend()
    ax3.legend()
    ax3.legend()
    ax3.legend()
    ax3.legend()
    ax3.legend()
    ax3.legend()
    ax3.legend()
    ax3.legend()
    ax3.legend()
    ax3.legend()
    ax3.legend()
    ax3.legend()
    ax3.legend()
    ax3.legend()
    ax3.legend()
    ax3.set_xlabel('X')
    ax3.set_xlabel('X')
    ax3.set_xlabel('X')
    ax3.set_xlabel('X')
    ax3.set_xlabel('X')
    ax3.set_xlabel('X')
    ax3.set_xlabel('X')
    ax3.set_xlabel('X')
    ax3.set_xlabel('X')
    ax3.set_xlabel('X')
    ax3.set_xlabel('X')
    ax3.set_xlabel('X')
    ax3.set_xlabel('X')
    ax3.set_xlabel('X')
    ax3.set_xlabel('X')
    ax3.set_xlabel('X')
    ax3.set_xlabel('X')
    ax3.set_xlabel('X')
    ax3.set_xlabel('X')
    ax3.set_xlabel('X')
    ax3.set_xlabel('X')
    ax3.set_xlabel('X')
    ax3.set_xlabel('X')
    ax3.set_xlabel('X')
    ax3.set_xlabel('X')
    ax3.set_xlabel('X')
    ax3.set_xlabel('X')
    ax3.set_xlabel('X')
    ax3.set_xlabel('X')
    ax3.set_xlabel('X')
    ax3.set_xlabel('X')
    ax3.set_xlabel('X')
    ax3.set_xlabel('X')
    ax3.set_xlabel('X')
    ax3.set_xlabel('X')
    ax3.set_xlabel('X')
    ax3.set_xlabel('X')
    ax3.set_ylabel('Y')
    ax3.set_ylabel('Y')
    ax3.set_ylabel('Y')
    ax3.set_ylabel('Y')
    ax3.set_ylabel('Y')
    ax3.set_ylabel('Y')
    ax3.set_ylabel('Y')
    ax3.set_ylabel('Y')
    ax3.set_ylabel('Y')
    ax3.set_ylabel('Y')
    ax3.set_ylabel('Y')
    ax3.set_ylabel('Y')
    ax3.set_ylabel('Y')
    ax3.set_ylabel('Y')
    ax3.set_ylabel('Y')
    ax3.set_ylabel('Y')
    ax3.set_ylabel('Y')
    ax3.set_ylabel('Y')
    ax3.set_ylabel('Y')
    ax3.set_ylabel('Y')
    ax3.set_ylabel('Y')
    ax3.set_ylabel('Y')
    ax3.set_ylabel('Y')
    ax3.set_ylabel('Y')
    ax3.set_ylabel('Y')
    ax3.set_ylabel('Y')
    ax3.set_ylabel('Y')
    ax3.set_ylabel('Y')
    ax3.set_ylabel('Y')
    ax3.set_ylabel('Y')
    ax3.set_ylabel('Y')
    ax3.set_ylabel('Y')
    ax3.set_ylabel('Y')
    ax3.set_ylabel('Y')
    ax3.set_ylabel('Y')
    ax3.set_ylabel('Y')
    ax3.set_ylabel('Y')
    ax3.set_zlabel('Z')
    ax3.set_zlabel('Z')
    ax3.set_zlabel('Z')
    ax3.set_zlabel('Z')
    ax3.set_zlabel('Z')
    ax3.set_zlabel('Z')
    ax3.set_zlabel('Z')
    ax3.set_zlabel('Z')
    ax3.set_zlabel('Z')
    ax3.set_zlabel('Z')
    ax3.set_zlabel('Z')
    ax3.set_zlabel('Z')
    ax3.set_zlabel('Z')
    ax3.set_zlabel('Z')
    ax3.set_zlabel('Z')
    ax3.set_zlabel('Z')
    ax3.set_zlabel('Z')
    ax3.set_zlabel('Z')
    ax3.set_zlabel('Z')
    ax3.set_zlabel('Z')
    ax3.set_zlabel('Z')
    ax3.set_zlabel('Z')
    ax3.set_zlabel('Z')
    ax3.set_zlabel('Z')
    ax3.set_zlabel('Z')
    ax3.set_zlabel('Z')
    ax3.set_zlabel('Z')
    ax3.set_zlabel('Z')
    ax3.set_zlabel('Z')
    ax3.set_zlabel('Z')
    ax3.set_zlabel('Z')
    ax3.set_zlabel('Z')
    ax3.set_zlabel('Z')
    ax3.set_zlabel('Z')
    ax3.set_zlabel('Z')
    ax3.set_zlabel('Z')
    ax3.set_zlabel('Z')
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    # Plot 4: Z distribution
    # Plot 4: Z distribution
    # Plot 4: Z distribution
    # Plot 4: Z distribution
    # Plot 4: Z distribution
    # Plot 4: Z distribution
    # Plot 4: Z distribution
    # Plot 4: Z distribution
    # Plot 4: Z distribution
    # Plot 4: Z distribution
    # Plot 4: Z distribution
    # Plot 4: Z distribution
    # Plot 4: Z distribution
    # Plot 4: Z distribution
    # Plot 4: Z distribution
    # Plot 4: Z distribution
    # Plot 4: Z distribution
    # Plot 4: Z distribution
    # Plot 4: Z distribution
    # Plot 4: Z distribution
    # Plot 4: Z distribution
    # Plot 4: Z distribution
    # Plot 4: Z distribution
    # Plot 4: Z distribution
    # Plot 4: Z distribution
    # Plot 4: Z distribution
    # Plot 4: Z distribution
    # Plot 4: Z distribution
    # Plot 4: Z distribution
    # Plot 4: Z distribution
    # Plot 4: Z distribution
    # Plot 4: Z distribution
    # Plot 4: Z distribution
    # Plot 4: Z distribution
    # Plot 4: Z distribution
    # Plot 4: Z distribution
    # Plot 4: Z distribution
    ax4 = fig.add_subplot(234)
    ax4 = fig.add_subplot(234)
    ax4 = fig.add_subplot(234)
    ax4 = fig.add_subplot(234)
    ax4 = fig.add_subplot(234)
    ax4 = fig.add_subplot(234)
    ax4 = fig.add_subplot(234)
    ax4 = fig.add_subplot(234)
    ax4 = fig.add_subplot(234)
    ax4 = fig.add_subplot(234)
    ax4 = fig.add_subplot(234)
    ax4 = fig.add_subplot(234)
    ax4 = fig.add_subplot(234)
    ax4 = fig.add_subplot(234)
    ax4 = fig.add_subplot(234)
    ax4 = fig.add_subplot(234)
    ax4 = fig.add_subplot(234)
    ax4 = fig.add_subplot(234)
    ax4 = fig.add_subplot(234)
    ax4 = fig.add_subplot(234)
    ax4 = fig.add_subplot(234)
    ax4 = fig.add_subplot(234)
    ax4 = fig.add_subplot(234)
    ax4 = fig.add_subplot(234)
    ax4 = fig.add_subplot(234)
    ax4 = fig.add_subplot(234)
    ax4 = fig.add_subplot(234)
    ax4 = fig.add_subplot(234)
    ax4 = fig.add_subplot(234)
    ax4 = fig.add_subplot(234)
    ax4 = fig.add_subplot(234)
    ax4 = fig.add_subplot(234)
    ax4 = fig.add_subplot(234)
    ax4 = fig.add_subplot(234)
    ax4 = fig.add_subplot(234)
    ax4 = fig.add_subplot(234)
    ax4 = fig.add_subplot(234)
    ax4.hist(original_points[:, 2], bins=50, alpha=0.6, color='blue', label='Original')
    ax4.hist(original_points[:, 2], bins=50, alpha=0.6, color='blue', label='Original')
    ax4.hist(original_points[:, 2], bins=50, alpha=0.6, color='blue', label='Original')
    ax4.hist(original_points[:, 2], bins=50, alpha=0.6, color='blue', label='Original')
    ax4.hist(original_points[:, 2], bins=50, alpha=0.6, color='blue', label='Original')
    ax4.hist(original_points[:, 2], bins=50, alpha=0.6, color='blue', label='Original')
    ax4.hist(original_points[:, 2], bins=50, alpha=0.6, color='blue', label='Original')
    ax4.hist(original_points[:, 2], bins=50, alpha=0.6, color='blue', label='Original')
    ax4.hist(original_points[:, 2], bins=50, alpha=0.6, color='blue', label='Original')
    ax4.hist(original_points[:, 2], bins=50, alpha=0.6, color='blue', label='Original')
    ax4.hist(original_points[:, 2], bins=50, alpha=0.6, color='blue', label='Original')
    ax4.hist(original_points[:, 2], bins=50, alpha=0.6, color='blue', label='Original')
    ax4.hist(original_points[:, 2], bins=50, alpha=0.6, color='blue', label='Original')
    ax4.hist(original_points[:, 2], bins=50, alpha=0.6, color='blue', label='Original')
    ax4.hist(original_points[:, 2], bins=50, alpha=0.6, color='blue', label='Original')
    ax4.hist(original_points[:, 2], bins=50, alpha=0.6, color='blue', label='Original')
    ax4.hist(original_points[:, 2], bins=50, alpha=0.6, color='blue', label='Original')
    ax4.hist(original_points[:, 2], bins=50, alpha=0.6, color='blue', label='Original')
    ax4.hist(original_points[:, 2], bins=50, alpha=0.6, color='blue', label='Original')
    ax4.hist(original_points[:, 2], bins=50, alpha=0.6, color='blue', label='Original')
    ax4.hist(original_points[:, 2], bins=50, alpha=0.6, color='blue', label='Original')
    ax4.hist(original_points[:, 2], bins=50, alpha=0.6, color='blue', label='Original')
    ax4.hist(original_points[:, 2], bins=50, alpha=0.6, color='blue', label='Original')
    ax4.hist(original_points[:, 2], bins=50, alpha=0.6, color='blue', label='Original')
    ax4.hist(original_points[:, 2], bins=50, alpha=0.6, color='blue', label='Original')
    ax4.hist(original_points[:, 2], bins=50, alpha=0.6, color='blue', label='Original')
    ax4.hist(original_points[:, 2], bins=50, alpha=0.6, color='blue', label='Original')
    ax4.hist(original_points[:, 2], bins=50, alpha=0.6, color='blue', label='Original')
    ax4.hist(original_points[:, 2], bins=50, alpha=0.6, color='blue', label='Original')
    ax4.hist(original_points[:, 2], bins=50, alpha=0.6, color='blue', label='Original')
    ax4.hist(original_points[:, 2], bins=50, alpha=0.6, color='blue', label='Original')
    ax4.hist(original_points[:, 2], bins=50, alpha=0.6, color='blue', label='Original')
    ax4.hist(original_points[:, 2], bins=50, alpha=0.6, color='blue', label='Original')
    ax4.hist(original_points[:, 2], bins=50, alpha=0.6, color='blue', label='Original')
    ax4.hist(original_points[:, 2], bins=50, alpha=0.6, color='blue', label='Original')
    ax4.hist(original_points[:, 2], bins=50, alpha=0.6, color='blue', label='Original')
    ax4.hist(original_points[:, 2], bins=50, alpha=0.6, color='blue', label='Original')
    ax4.hist(filtered_points[:, 2], bins=50, alpha=0.6, color='green', label='Filtered')
    ax4.hist(filtered_points[:, 2], bins=50, alpha=0.6, color='green', label='Filtered')
    ax4.hist(filtered_points[:, 2], bins=50, alpha=0.6, color='green', label='Filtered')
    ax4.hist(filtered_points[:, 2], bins=50, alpha=0.6, color='green', label='Filtered')
    ax4.hist(filtered_points[:, 2], bins=50, alpha=0.6, color='green', label='Filtered')
    ax4.hist(filtered_points[:, 2], bins=50, alpha=0.6, color='green', label='Filtered')
    ax4.hist(filtered_points[:, 2], bins=50, alpha=0.6, color='green', label='Filtered')
    ax4.hist(filtered_points[:, 2], bins=50, alpha=0.6, color='green', label='Filtered')
    ax4.hist(filtered_points[:, 2], bins=50, alpha=0.6, color='green', label='Filtered')
    ax4.hist(filtered_points[:, 2], bins=50, alpha=0.6, color='green', label='Filtered')
    ax4.hist(filtered_points[:, 2], bins=50, alpha=0.6, color='green', label='Filtered')
    ax4.hist(filtered_points[:, 2], bins=50, alpha=0.6, color='green', label='Filtered')
    ax4.hist(filtered_points[:, 2], bins=50, alpha=0.6, color='green', label='Filtered')
    ax4.hist(filtered_points[:, 2], bins=50, alpha=0.6, color='green', label='Filtered')
    ax4.hist(filtered_points[:, 2], bins=50, alpha=0.6, color='green', label='Filtered')
    ax4.hist(filtered_points[:, 2], bins=50, alpha=0.6, color='green', label='Filtered')
    ax4.hist(filtered_points[:, 2], bins=50, alpha=0.6, color='green', label='Filtered')
    ax4.hist(filtered_points[:, 2], bins=50, alpha=0.6, color='green', label='Filtered')
    ax4.hist(filtered_points[:, 2], bins=50, alpha=0.6, color='green', label='Filtered')
    ax4.hist(filtered_points[:, 2], bins=50, alpha=0.6, color='green', label='Filtered')
    ax4.hist(filtered_points[:, 2], bins=50, alpha=0.6, color='green', label='Filtered')
    ax4.hist(filtered_points[:, 2], bins=50, alpha=0.6, color='green', label='Filtered')
    ax4.hist(filtered_points[:, 2], bins=50, alpha=0.6, color='green', label='Filtered')
    ax4.hist(filtered_points[:, 2], bins=50, alpha=0.6, color='green', label='Filtered')
    ax4.hist(filtered_points[:, 2], bins=50, alpha=0.6, color='green', label='Filtered')
    ax4.hist(filtered_points[:, 2], bins=50, alpha=0.6, color='green', label='Filtered')
    ax4.hist(filtered_points[:, 2], bins=50, alpha=0.6, color='green', label='Filtered')
    ax4.hist(filtered_points[:, 2], bins=50, alpha=0.6, color='green', label='Filtered')
    ax4.hist(filtered_points[:, 2], bins=50, alpha=0.6, color='green', label='Filtered')
    ax4.hist(filtered_points[:, 2], bins=50, alpha=0.6, color='green', label='Filtered')
    ax4.hist(filtered_points[:, 2], bins=50, alpha=0.6, color='green', label='Filtered')
    ax4.hist(filtered_points[:, 2], bins=50, alpha=0.6, color='green', label='Filtered')
    ax4.hist(filtered_points[:, 2], bins=50, alpha=0.6, color='green', label='Filtered')
    ax4.hist(filtered_points[:, 2], bins=50, alpha=0.6, color='green', label='Filtered')
    ax4.hist(filtered_points[:, 2], bins=50, alpha=0.6, color='green', label='Filtered')
    ax4.hist(filtered_points[:, 2], bins=50, alpha=0.6, color='green', label='Filtered')
    ax4.hist(filtered_points[:, 2], bins=50, alpha=0.6, color='green', label='Filtered')
    ax4.set_xlabel('Z coordinate')
    ax4.set_xlabel('Z coordinate')
    ax4.set_xlabel('Z coordinate')
    ax4.set_xlabel('Z coordinate')
    ax4.set_xlabel('Z coordinate')
    ax4.set_xlabel('Z coordinate')
    ax4.set_xlabel('Z coordinate')
    ax4.set_xlabel('Z coordinate')
    ax4.set_xlabel('Z coordinate')
    ax4.set_xlabel('Z coordinate')
    ax4.set_xlabel('Z coordinate')
    ax4.set_xlabel('Z coordinate')
    ax4.set_xlabel('Z coordinate')
    ax4.set_xlabel('Z coordinate')
    ax4.set_xlabel('Z coordinate')
    ax4.set_xlabel('Z coordinate')
    ax4.set_xlabel('Z coordinate')
    ax4.set_xlabel('Z coordinate')
    ax4.set_xlabel('Z coordinate')
    ax4.set_xlabel('Z coordinate')
    ax4.set_xlabel('Z coordinate')
    ax4.set_xlabel('Z coordinate')
    ax4.set_xlabel('Z coordinate')
    ax4.set_xlabel('Z coordinate')
    ax4.set_xlabel('Z coordinate')
    ax4.set_xlabel('Z coordinate')
    ax4.set_xlabel('Z coordinate')
    ax4.set_xlabel('Z coordinate')
    ax4.set_xlabel('Z coordinate')
    ax4.set_xlabel('Z coordinate')
    ax4.set_xlabel('Z coordinate')
    ax4.set_xlabel('Z coordinate')
    ax4.set_xlabel('Z coordinate')
    ax4.set_xlabel('Z coordinate')
    ax4.set_xlabel('Z coordinate')
    ax4.set_xlabel('Z coordinate')
    ax4.set_xlabel('Z coordinate')
    ax4.set_ylabel('Frequency')
    ax4.set_ylabel('Frequency')
    ax4.set_ylabel('Frequency')
    ax4.set_ylabel('Frequency')
    ax4.set_ylabel('Frequency')
    ax4.set_ylabel('Frequency')
    ax4.set_ylabel('Frequency')
    ax4.set_ylabel('Frequency')
    ax4.set_ylabel('Frequency')
    ax4.set_ylabel('Frequency')
    ax4.set_ylabel('Frequency')
    ax4.set_ylabel('Frequency')
    ax4.set_ylabel('Frequency')
    ax4.set_ylabel('Frequency')
    ax4.set_ylabel('Frequency')
    ax4.set_ylabel('Frequency')
    ax4.set_ylabel('Frequency')
    ax4.set_ylabel('Frequency')
    ax4.set_ylabel('Frequency')
    ax4.set_ylabel('Frequency')
    ax4.set_ylabel('Frequency')
    ax4.set_ylabel('Frequency')
    ax4.set_ylabel('Frequency')
    ax4.set_ylabel('Frequency')
    ax4.set_ylabel('Frequency')
    ax4.set_ylabel('Frequency')
    ax4.set_ylabel('Frequency')
    ax4.set_ylabel('Frequency')
    ax4.set_ylabel('Frequency')
    ax4.set_ylabel('Frequency')
    ax4.set_ylabel('Frequency')
    ax4.set_ylabel('Frequency')
    ax4.set_ylabel('Frequency')
    ax4.set_ylabel('Frequency')
    ax4.set_ylabel('Frequency')
    ax4.set_ylabel('Frequency')
    ax4.set_ylabel('Frequency')
    ax4.set_title('Z-coordinate Distribution')
    ax4.set_title('Z-coordinate Distribution')
    ax4.set_title('Z-coordinate Distribution')
    ax4.set_title('Z-coordinate Distribution')
    ax4.set_title('Z-coordinate Distribution')
    ax4.set_title('Z-coordinate Distribution')
    ax4.set_title('Z-coordinate Distribution')
    ax4.set_title('Z-coordinate Distribution')
    ax4.set_title('Z-coordinate Distribution')
    ax4.set_title('Z-coordinate Distribution')
    ax4.set_title('Z-coordinate Distribution')
    ax4.set_title('Z-coordinate Distribution')
    ax4.set_title('Z-coordinate Distribution')
    ax4.set_title('Z-coordinate Distribution')
    ax4.set_title('Z-coordinate Distribution')
    ax4.set_title('Z-coordinate Distribution')
    ax4.set_title('Z-coordinate Distribution')
    ax4.set_title('Z-coordinate Distribution')
    ax4.set_title('Z-coordinate Distribution')
    ax4.set_title('Z-coordinate Distribution')
    ax4.set_title('Z-coordinate Distribution')
    ax4.set_title('Z-coordinate Distribution')
    ax4.set_title('Z-coordinate Distribution')
    ax4.set_title('Z-coordinate Distribution')
    ax4.set_title('Z-coordinate Distribution')
    ax4.set_title('Z-coordinate Distribution')
    ax4.set_title('Z-coordinate Distribution')
    ax4.set_title('Z-coordinate Distribution')
    ax4.set_title('Z-coordinate Distribution')
    ax4.set_title('Z-coordinate Distribution')
    ax4.set_title('Z-coordinate Distribution')
    ax4.set_title('Z-coordinate Distribution')
    ax4.set_title('Z-coordinate Distribution')
    ax4.set_title('Z-coordinate Distribution')
    ax4.set_title('Z-coordinate Distribution')
    ax4.set_title('Z-coordinate Distribution')
    ax4.set_title('Z-coordinate Distribution')
    ax4.legend()
    ax4.legend()
    ax4.legend()
    ax4.legend()
    ax4.legend()
    ax4.legend()
    ax4.legend()
    ax4.legend()
    ax4.legend()
    ax4.legend()
    ax4.legend()
    ax4.legend()
    ax4.legend()
    ax4.legend()
    ax4.legend()
    ax4.legend()
    ax4.legend()
    ax4.legend()
    ax4.legend()
    ax4.legend()
    ax4.legend()
    ax4.legend()
    ax4.legend()
    ax4.legend()
    ax4.legend()
    ax4.legend()
    ax4.legend()
    ax4.legend()
    ax4.legend()
    ax4.legend()
    ax4.legend()
    ax4.legend()
    ax4.legend()
    ax4.legend()
    ax4.legend()
    ax4.legend()
    ax4.legend()
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    # Plot 5: statistics
    # Plot 5: statistics
    # Plot 5: statistics
    # Plot 5: statistics
    # Plot 5: statistics
    # Plot 5: statistics
    # Plot 5: statistics
    # Plot 5: statistics
    # Plot 5: statistics
    # Plot 5: statistics
    # Plot 5: statistics
    # Plot 5: statistics
    # Plot 5: statistics
    # Plot 5: statistics
    # Plot 5: statistics
    # Plot 5: statistics
    # Plot 5: statistics
    # Plot 5: statistics
    # Plot 5: statistics
    # Plot 5: statistics
    # Plot 5: statistics
    # Plot 5: statistics
    # Plot 5: statistics
    # Plot 5: statistics
    # Plot 5: statistics
    # Plot 5: statistics
    # Plot 5: statistics
    # Plot 5: statistics
    # Plot 5: statistics
    # Plot 5: statistics
    # Plot 5: statistics
    # Plot 5: statistics
    # Plot 5: statistics
    # Plot 5: statistics
    # Plot 5: statistics
    # Plot 5: statistics
    # Plot 5: statistics
    ax5 = fig.add_subplot(235)
    ax5 = fig.add_subplot(235)
    ax5 = fig.add_subplot(235)
    ax5 = fig.add_subplot(235)
    ax5 = fig.add_subplot(235)
    ax5 = fig.add_subplot(235)
    ax5 = fig.add_subplot(235)
    ax5 = fig.add_subplot(235)
    ax5 = fig.add_subplot(235)
    ax5 = fig.add_subplot(235)
    ax5 = fig.add_subplot(235)
    ax5 = fig.add_subplot(235)
    ax5 = fig.add_subplot(235)
    ax5 = fig.add_subplot(235)
    ax5 = fig.add_subplot(235)
    ax5 = fig.add_subplot(235)
    ax5 = fig.add_subplot(235)
    ax5 = fig.add_subplot(235)
    ax5 = fig.add_subplot(235)
    ax5 = fig.add_subplot(235)
    ax5 = fig.add_subplot(235)
    ax5 = fig.add_subplot(235)
    ax5 = fig.add_subplot(235)
    ax5 = fig.add_subplot(235)
    ax5 = fig.add_subplot(235)
    ax5 = fig.add_subplot(235)
    ax5 = fig.add_subplot(235)
    ax5 = fig.add_subplot(235)
    ax5 = fig.add_subplot(235)
    ax5 = fig.add_subplot(235)
    ax5 = fig.add_subplot(235)
    ax5 = fig.add_subplot(235)
    ax5 = fig.add_subplot(235)
    ax5 = fig.add_subplot(235)
    ax5 = fig.add_subplot(235)
    ax5 = fig.add_subplot(235)
    ax5 = fig.add_subplot(235)
    ax5.axis('off')
    ax5.axis('off')
    ax5.axis('off')
    ax5.axis('off')
    ax5.axis('off')
    ax5.axis('off')
    ax5.axis('off')
    ax5.axis('off')
    ax5.axis('off')
    ax5.axis('off')
    ax5.axis('off')
    ax5.axis('off')
    ax5.axis('off')
    ax5.axis('off')
    ax5.axis('off')
    ax5.axis('off')
    ax5.axis('off')
    ax5.axis('off')
    ax5.axis('off')
    ax5.axis('off')
    ax5.axis('off')
    ax5.axis('off')
    ax5.axis('off')
    ax5.axis('off')
    ax5.axis('off')
    ax5.axis('off')
    ax5.axis('off')
    ax5.axis('off')
    ax5.axis('off')
    ax5.axis('off')
    ax5.axis('off')
    ax5.axis('off')
    ax5.axis('off')
    ax5.axis('off')
    ax5.axis('off')
    ax5.axis('off')
    ax5.axis('off')
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    stats_text = f"""Processing Statistics:
    stats_text = f"""Processing Statistics:
    stats_text = f"""Processing Statistics:
    stats_text = f"""Processing Statistics:
    stats_text = f"""Processing Statistics:
    stats_text = f"""Processing Statistics:
    stats_text = f"""Processing Statistics:
    stats_text = f"""Processing Statistics:
    stats_text = f"""Processing Statistics:
    stats_text = f"""Processing Statistics:
    stats_text = f"""Processing Statistics:
    stats_text = f"""Processing Statistics:
    stats_text = f"""Processing Statistics:
    stats_text = f"""Processing Statistics:
    stats_text = f"""Processing Statistics:
    stats_text = f"""Processing Statistics:
    stats_text = f"""Processing Statistics:
    stats_text = f"""Processing Statistics:
    stats_text = f"""Processing Statistics:
    stats_text = f"""Processing Statistics:
    stats_text = f"""Processing Statistics:
    stats_text = f"""Processing Statistics:
    stats_text = f"""Processing Statistics:
    stats_text = f"""Processing Statistics:
    stats_text = f"""Processing Statistics:
    stats_text = f"""Processing Statistics:
    stats_text = f"""Processing Statistics:
    stats_text = f"""Processing Statistics:
    stats_text = f"""Processing Statistics:
    stats_text = f"""Processing Statistics:
    stats_text = f"""Processing Statistics:
    stats_text = f"""Processing Statistics:
    stats_text = f"""Processing Statistics:
    stats_text = f"""Processing Statistics:
    stats_text = f"""Processing Statistics:
    stats_text = f"""Processing Statistics:
    stats_text = f"""Processing Statistics:
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
Original Points: {stats['n_input']:,}
Original Points: {stats['n_input']:,}
Original Points: {stats['n_input']:,}
Original Points: {stats['n_input']:,}
Original Points: {stats['n_input']:,}
Original Points: {stats['n_input']:,}
Original Points: {stats['n_input']:,}
Original Points: {stats['n_input']:,}
Original Points: {stats['n_input']:,}
Original Points: {stats['n_input']:,}
Original Points: {stats['n_input']:,}
Original Points: {stats['n_input']:,}
Original Points: {stats['n_input']:,}
Original Points: {stats['n_input']:,}
Original Points: {stats['n_input']:,}
Original Points: {stats['n_input']:,}
Original Points: {stats['n_input']:,}
Original Points: {stats['n_input']:,}
Original Points: {stats['n_input']:,}
Original Points: {stats['n_input']:,}
Original Points: {stats['n_input']:,}
Original Points: {stats['n_input']:,}
Original Points: {stats['n_input']:,}
Original Points: {stats['n_input']:,}
Original Points: {stats['n_input']:,}
Original Points: {stats['n_input']:,}
Original Points: {stats['n_input']:,}
Original Points: {stats['n_input']:,}
Original Points: {stats['n_input']:,}
Original Points: {stats['n_input']:,}
Original Points: {stats['n_input']:,}
Original Points: {stats['n_input']:,}
Original Points: {stats['n_input']:,}
Original Points: {stats['n_input']:,}
Original Points: {stats['n_input']:,}
Original Points: {stats['n_input']:,}
Original Points: {stats['n_input']:,}
Final Points: {stats['n_final']:,}
Final Points: {stats['n_final']:,}
Final Points: {stats['n_final']:,}
Final Points: {stats['n_final']:,}
Final Points: {stats['n_final']:,}
Final Points: {stats['n_final']:,}
Final Points: {stats['n_final']:,}
Final Points: {stats['n_final']:,}
Final Points: {stats['n_final']:,}
Final Points: {stats['n_final']:,}
Final Points: {stats['n_final']:,}
Final Points: {stats['n_final']:,}
Final Points: {stats['n_final']:,}
Final Points: {stats['n_final']:,}
Final Points: {stats['n_final']:,}
Final Points: {stats['n_final']:,}
Final Points: {stats['n_final']:,}
Final Points: {stats['n_final']:,}
Final Points: {stats['n_final']:,}
Final Points: {stats['n_final']:,}
Final Points: {stats['n_final']:,}
Final Points: {stats['n_final']:,}
Final Points: {stats['n_final']:,}
Final Points: {stats['n_final']:,}
Final Points: {stats['n_final']:,}
Final Points: {stats['n_final']:,}
Final Points: {stats['n_final']:,}
Final Points: {stats['n_final']:,}
Final Points: {stats['n_final']:,}
Final Points: {stats['n_final']:,}
Final Points: {stats['n_final']:,}
Final Points: {stats['n_final']:,}
Final Points: {stats['n_final']:,}
Final Points: {stats['n_final']:,}
Final Points: {stats['n_final']:,}
Final Points: {stats['n_final']:,}
Final Points: {stats['n_final']:,}
Removed Points: {stats['n_removed']:,}
Removed Points: {stats['n_removed']:,}
Removed Points: {stats['n_removed']:,}
Removed Points: {stats['n_removed']:,}
Removed Points: {stats['n_removed']:,}
Removed Points: {stats['n_removed']:,}
Removed Points: {stats['n_removed']:,}
Removed Points: {stats['n_removed']:,}
Removed Points: {stats['n_removed']:,}
Removed Points: {stats['n_removed']:,}
Removed Points: {stats['n_removed']:,}
Removed Points: {stats['n_removed']:,}
Removed Points: {stats['n_removed']:,}
Removed Points: {stats['n_removed']:,}
Removed Points: {stats['n_removed']:,}
Removed Points: {stats['n_removed']:,}
Removed Points: {stats['n_removed']:,}
Removed Points: {stats['n_removed']:,}
Removed Points: {stats['n_removed']:,}
Removed Points: {stats['n_removed']:,}
Removed Points: {stats['n_removed']:,}
Removed Points: {stats['n_removed']:,}
Removed Points: {stats['n_removed']:,}
Removed Points: {stats['n_removed']:,}
Removed Points: {stats['n_removed']:,}
Removed Points: {stats['n_removed']:,}
Removed Points: {stats['n_removed']:,}
Removed Points: {stats['n_removed']:,}
Removed Points: {stats['n_removed']:,}
Removed Points: {stats['n_removed']:,}
Removed Points: {stats['n_removed']:,}
Removed Points: {stats['n_removed']:,}
Removed Points: {stats['n_removed']:,}
Removed Points: {stats['n_removed']:,}
Removed Points: {stats['n_removed']:,}
Removed Points: {stats['n_removed']:,}
Removed Points: {stats['n_removed']:,}
Removal Rate: {stats['n_removed']/stats['n_input']*100:.1f}%
Removal Rate: {stats['n_removed']/stats['n_input']*100:.1f}%
Removal Rate: {stats['n_removed']/stats['n_input']*100:.1f}%
Removal Rate: {stats['n_removed']/stats['n_input']*100:.1f}%
Removal Rate: {stats['n_removed']/stats['n_input']*100:.1f}%
Removal Rate: {stats['n_removed']/stats['n_input']*100:.1f}%
Removal Rate: {stats['n_removed']/stats['n_input']*100:.1f}%
Removal Rate: {stats['n_removed']/stats['n_input']*100:.1f}%
Removal Rate: {stats['n_removed']/stats['n_input']*100:.1f}%
Removal Rate: {stats['n_removed']/stats['n_input']*100:.1f}%
Removal Rate: {stats['n_removed']/stats['n_input']*100:.1f}%
Removal Rate: {stats['n_removed']/stats['n_input']*100:.1f}%
Removal Rate: {stats['n_removed']/stats['n_input']*100:.1f}%
Removal Rate: {stats['n_removed']/stats['n_input']*100:.1f}%
Removal Rate: {stats['n_removed']/stats['n_input']*100:.1f}%
Removal Rate: {stats['n_removed']/stats['n_input']*100:.1f}%
Removal Rate: {stats['n_removed']/stats['n_input']*100:.1f}%
Removal Rate: {stats['n_removed']/stats['n_input']*100:.1f}%
Removal Rate: {stats['n_removed']/stats['n_input']*100:.1f}%
Removal Rate: {stats['n_removed']/stats['n_input']*100:.1f}%
Removal Rate: {stats['n_removed']/stats['n_input']*100:.1f}%
Removal Rate: {stats['n_removed']/stats['n_input']*100:.1f}%
Removal Rate: {stats['n_removed']/stats['n_input']*100:.1f}%
Removal Rate: {stats['n_removed']/stats['n_input']*100:.1f}%
Removal Rate: {stats['n_removed']/stats['n_input']*100:.1f}%
Removal Rate: {stats['n_removed']/stats['n_input']*100:.1f}%
Removal Rate: {stats['n_removed']/stats['n_input']*100:.1f}%
Removal Rate: {stats['n_removed']/stats['n_input']*100:.1f}%
Removal Rate: {stats['n_removed']/stats['n_input']*100:.1f}%
Removal Rate: {stats['n_removed']/stats['n_input']*100:.1f}%
Removal Rate: {stats['n_removed']/stats['n_input']*100:.1f}%
Removal Rate: {stats['n_removed']/stats['n_input']*100:.1f}%
Removal Rate: {stats['n_removed']/stats['n_input']*100:.1f}%
Removal Rate: {stats['n_removed']/stats['n_input']*100:.1f}%
Removal Rate: {stats['n_removed']/stats['n_input']*100:.1f}%
Removal Rate: {stats['n_removed']/stats['n_input']*100:.1f}%
Removal Rate: {stats['n_removed']/stats['n_input']*100:.1f}%
Processing Time: {stats['time_s']:.2f}s
Processing Time: {stats['time_s']:.2f}s
Processing Time: {stats['time_s']:.2f}s
Processing Time: {stats['time_s']:.2f}s
Processing Time: {stats['time_s']:.2f}s
Processing Time: {stats['time_s']:.2f}s
Processing Time: {stats['time_s']:.2f}s
Processing Time: {stats['time_s']:.2f}s
Processing Time: {stats['time_s']:.2f}s
Processing Time: {stats['time_s']:.2f}s
Processing Time: {stats['time_s']:.2f}s
Processing Time: {stats['time_s']:.2f}s
Processing Time: {stats['time_s']:.2f}s
Processing Time: {stats['time_s']:.2f}s
Processing Time: {stats['time_s']:.2f}s
Processing Time: {stats['time_s']:.2f}s
Processing Time: {stats['time_s']:.2f}s
Processing Time: {stats['time_s']:.2f}s
Processing Time: {stats['time_s']:.2f}s
Processing Time: {stats['time_s']:.2f}s
Processing Time: {stats['time_s']:.2f}s
Processing Time: {stats['time_s']:.2f}s
Processing Time: {stats['time_s']:.2f}s
Processing Time: {stats['time_s']:.2f}s
Processing Time: {stats['time_s']:.2f}s
Processing Time: {stats['time_s']:.2f}s
Processing Time: {stats['time_s']:.2f}s
Processing Time: {stats['time_s']:.2f}s
Processing Time: {stats['time_s']:.2f}s
Processing Time: {stats['time_s']:.2f}s
Processing Time: {stats['time_s']:.2f}s
Processing Time: {stats['time_s']:.2f}s
Processing Time: {stats['time_s']:.2f}s
Processing Time: {stats['time_s']:.2f}s
Processing Time: {stats['time_s']:.2f}s
Processing Time: {stats['time_s']:.2f}s
Processing Time: {stats['time_s']:.2f}s





































Layers Processed: {len(stats['per_slice'])}
Layers Processed: {len(stats['per_slice'])}
Layers Processed: {len(stats['per_slice'])}
Layers Processed: {len(stats['per_slice'])}
Layers Processed: {len(stats['per_slice'])}
Layers Processed: {len(stats['per_slice'])}
Layers Processed: {len(stats['per_slice'])}
Layers Processed: {len(stats['per_slice'])}
Layers Processed: {len(stats['per_slice'])}
Layers Processed: {len(stats['per_slice'])}
Layers Processed: {len(stats['per_slice'])}
Layers Processed: {len(stats['per_slice'])}
Layers Processed: {len(stats['per_slice'])}
Layers Processed: {len(stats['per_slice'])}
Layers Processed: {len(stats['per_slice'])}
Layers Processed: {len(stats['per_slice'])}
Layers Processed: {len(stats['per_slice'])}
Layers Processed: {len(stats['per_slice'])}
Layers Processed: {len(stats['per_slice'])}
Layers Processed: {len(stats['per_slice'])}
Layers Processed: {len(stats['per_slice'])}
Layers Processed: {len(stats['per_slice'])}
Layers Processed: {len(stats['per_slice'])}
Layers Processed: {len(stats['per_slice'])}
Layers Processed: {len(stats['per_slice'])}
Layers Processed: {len(stats['per_slice'])}
Layers Processed: {len(stats['per_slice'])}
Layers Processed: {len(stats['per_slice'])}
Layers Processed: {len(stats['per_slice'])}
Layers Processed: {len(stats['per_slice'])}
Layers Processed: {len(stats['per_slice'])}
Layers Processed: {len(stats['per_slice'])}
Layers Processed: {len(stats['per_slice'])}
Layers Processed: {len(stats['per_slice'])}
Layers Processed: {len(stats['per_slice'])}
Layers Processed: {len(stats['per_slice'])}
Layers Processed: {len(stats['per_slice'])}
Clusters Kept: {stats['cluster_info']['n_clusters_kept']}"""
Clusters Kept: {stats['cluster_info']['n_clusters_kept']}"""
Clusters Kept: {stats['cluster_info']['n_clusters_kept']}"""
Clusters Kept: {stats['cluster_info']['n_clusters_kept']}"""
Clusters Kept: {stats['cluster_info']['n_clusters_kept']}"""
Clusters Kept: {stats['cluster_info']['n_clusters_kept']}"""
Clusters Kept: {stats['cluster_info']['n_clusters_kept']}"""
Clusters Kept: {stats['cluster_info']['n_clusters_kept']}"""
Clusters Kept: {stats['cluster_info']['n_clusters_kept']}"""
Clusters Kept: {stats['cluster_info']['n_clusters_kept']}"""
Clusters Kept: {stats['cluster_info']['n_clusters_kept']}"""
Clusters Kept: {stats['cluster_info']['n_clusters_kept']}"""
Clusters Kept: {stats['cluster_info']['n_clusters_kept']}"""
Clusters Kept: {stats['cluster_info']['n_clusters_kept']}"""
Clusters Kept: {stats['cluster_info']['n_clusters_kept']}"""
Clusters Kept: {stats['cluster_info']['n_clusters_kept']}"""
Clusters Kept: {stats['cluster_info']['n_clusters_kept']}"""
Clusters Kept: {stats['cluster_info']['n_clusters_kept']}"""
Clusters Kept: {stats['cluster_info']['n_clusters_kept']}"""
Clusters Kept: {stats['cluster_info']['n_clusters_kept']}"""
Clusters Kept: {stats['cluster_info']['n_clusters_kept']}"""
Clusters Kept: {stats['cluster_info']['n_clusters_kept']}"""
Clusters Kept: {stats['cluster_info']['n_clusters_kept']}"""
Clusters Kept: {stats['cluster_info']['n_clusters_kept']}"""
Clusters Kept: {stats['cluster_info']['n_clusters_kept']}"""
Clusters Kept: {stats['cluster_info']['n_clusters_kept']}"""
Clusters Kept: {stats['cluster_info']['n_clusters_kept']}"""
Clusters Kept: {stats['cluster_info']['n_clusters_kept']}"""
Clusters Kept: {stats['cluster_info']['n_clusters_kept']}"""
Clusters Kept: {stats['cluster_info']['n_clusters_kept']}"""
Clusters Kept: {stats['cluster_info']['n_clusters_kept']}"""
Clusters Kept: {stats['cluster_info']['n_clusters_kept']}"""
Clusters Kept: {stats['cluster_info']['n_clusters_kept']}"""
Clusters Kept: {stats['cluster_info']['n_clusters_kept']}"""
Clusters Kept: {stats['cluster_info']['n_clusters_kept']}"""
Clusters Kept: {stats['cluster_info']['n_clusters_kept']}"""
Clusters Kept: {stats['cluster_info']['n_clusters_kept']}"""
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    ax5.text(0.1, 0.9, stats_text, transform=ax5.transAxes, fontfamily='monospace',
    ax5.text(0.1, 0.9, stats_text, transform=ax5.transAxes, fontfamily='monospace',
    ax5.text(0.1, 0.9, stats_text, transform=ax5.transAxes, fontfamily='monospace',
    ax5.text(0.1, 0.9, stats_text, transform=ax5.transAxes, fontfamily='monospace',
    ax5.text(0.1, 0.9, stats_text, transform=ax5.transAxes, fontfamily='monospace',
    ax5.text(0.1, 0.9, stats_text, transform=ax5.transAxes, fontfamily='monospace',
    ax5.text(0.1, 0.9, stats_text, transform=ax5.transAxes, fontfamily='monospace',
    ax5.text(0.1, 0.9, stats_text, transform=ax5.transAxes, fontfamily='monospace',
    ax5.text(0.1, 0.9, stats_text, transform=ax5.transAxes, fontfamily='monospace',
    ax5.text(0.1, 0.9, stats_text, transform=ax5.transAxes, fontfamily='monospace',
    ax5.text(0.1, 0.9, stats_text, transform=ax5.transAxes, fontfamily='monospace',
    ax5.text(0.1, 0.9, stats_text, transform=ax5.transAxes, fontfamily='monospace',
    ax5.text(0.1, 0.9, stats_text, transform=ax5.transAxes, fontfamily='monospace',
    ax5.text(0.1, 0.9, stats_text, transform=ax5.transAxes, fontfamily='monospace',
    ax5.text(0.1, 0.9, stats_text, transform=ax5.transAxes, fontfamily='monospace',
    ax5.text(0.1, 0.9, stats_text, transform=ax5.transAxes, fontfamily='monospace',
    ax5.text(0.1, 0.9, stats_text, transform=ax5.transAxes, fontfamily='monospace',
    ax5.text(0.1, 0.9, stats_text, transform=ax5.transAxes, fontfamily='monospace',
    ax5.text(0.1, 0.9, stats_text, transform=ax5.transAxes, fontfamily='monospace',
    ax5.text(0.1, 0.9, stats_text, transform=ax5.transAxes, fontfamily='monospace',
    ax5.text(0.1, 0.9, stats_text, transform=ax5.transAxes, fontfamily='monospace',
    ax5.text(0.1, 0.9, stats_text, transform=ax5.transAxes, fontfamily='monospace',
    ax5.text(0.1, 0.9, stats_text, transform=ax5.transAxes, fontfamily='monospace',
    ax5.text(0.1, 0.9, stats_text, transform=ax5.transAxes, fontfamily='monospace',
    ax5.text(0.1, 0.9, stats_text, transform=ax5.transAxes, fontfamily='monospace',
    ax5.text(0.1, 0.9, stats_text, transform=ax5.transAxes, fontfamily='monospace',
    ax5.text(0.1, 0.9, stats_text, transform=ax5.transAxes, fontfamily='monospace',
    ax5.text(0.1, 0.9, stats_text, transform=ax5.transAxes, fontfamily='monospace',
    ax5.text(0.1, 0.9, stats_text, transform=ax5.transAxes, fontfamily='monospace',
    ax5.text(0.1, 0.9, stats_text, transform=ax5.transAxes, fontfamily='monospace',
    ax5.text(0.1, 0.9, stats_text, transform=ax5.transAxes, fontfamily='monospace',
    ax5.text(0.1, 0.9, stats_text, transform=ax5.transAxes, fontfamily='monospace',
    ax5.text(0.1, 0.9, stats_text, transform=ax5.transAxes, fontfamily='monospace',
    ax5.text(0.1, 0.9, stats_text, transform=ax5.transAxes, fontfamily='monospace',
    ax5.text(0.1, 0.9, stats_text, transform=ax5.transAxes, fontfamily='monospace',
    ax5.text(0.1, 0.9, stats_text, transform=ax5.transAxes, fontfamily='monospace',
    ax5.text(0.1, 0.9, stats_text, transform=ax5.transAxes, fontfamily='monospace',
             verticalalignment='top', fontsize=12,
             verticalalignment='top', fontsize=12,
             verticalalignment='top', fontsize=12,
             verticalalignment='top', fontsize=12,
             verticalalignment='top', fontsize=12,
             verticalalignment='top', fontsize=12,
             verticalalignment='top', fontsize=12,
             verticalalignment='top', fontsize=12,
             verticalalignment='top', fontsize=12,
             verticalalignment='top', fontsize=12,
             verticalalignment='top', fontsize=12,
             verticalalignment='top', fontsize=12,
             verticalalignment='top', fontsize=12,
             verticalalignment='top', fontsize=12,
             verticalalignment='top', fontsize=12,
             verticalalignment='top', fontsize=12,
             verticalalignment='top', fontsize=12,
             verticalalignment='top', fontsize=12,
             verticalalignment='top', fontsize=12,
             verticalalignment='top', fontsize=12,
             verticalalignment='top', fontsize=12,
             verticalalignment='top', fontsize=12,
             verticalalignment='top', fontsize=12,
             verticalalignment='top', fontsize=12,
             verticalalignment='top', fontsize=12,
             verticalalignment='top', fontsize=12,
             verticalalignment='top', fontsize=12,
             verticalalignment='top', fontsize=12,
             verticalalignment='top', fontsize=12,
             verticalalignment='top', fontsize=12,
             verticalalignment='top', fontsize=12,
             verticalalignment='top', fontsize=12,
             verticalalignment='top', fontsize=12,
             verticalalignment='top', fontsize=12,
             verticalalignment='top', fontsize=12,
             verticalalignment='top', fontsize=12,
             verticalalignment='top', fontsize=12,
             bbox=dict(boxstyle='round', facecolor='lightblue', alpha=0.8))
             bbox=dict(boxstyle='round', facecolor='lightblue', alpha=0.8))
             bbox=dict(boxstyle='round', facecolor='lightblue', alpha=0.8))
             bbox=dict(boxstyle='round', facecolor='lightblue', alpha=0.8))
             bbox=dict(boxstyle='round', facecolor='lightblue', alpha=0.8))
             bbox=dict(boxstyle='round', facecolor='lightblue', alpha=0.8))
             bbox=dict(boxstyle='round', facecolor='lightblue', alpha=0.8))
             bbox=dict(boxstyle='round', facecolor='lightblue', alpha=0.8))
             bbox=dict(boxstyle='round', facecolor='lightblue', alpha=0.8))
             bbox=dict(boxstyle='round', facecolor='lightblue', alpha=0.8))
             bbox=dict(boxstyle='round', facecolor='lightblue', alpha=0.8))
             bbox=dict(boxstyle='round', facecolor='lightblue', alpha=0.8))
             bbox=dict(boxstyle='round', facecolor='lightblue', alpha=0.8))
             bbox=dict(boxstyle='round', facecolor='lightblue', alpha=0.8))
             bbox=dict(boxstyle='round', facecolor='lightblue', alpha=0.8))
             bbox=dict(boxstyle='round', facecolor='lightblue', alpha=0.8))
             bbox=dict(boxstyle='round', facecolor='lightblue', alpha=0.8))
             bbox=dict(boxstyle='round', facecolor='lightblue', alpha=0.8))
             bbox=dict(boxstyle='round', facecolor='lightblue', alpha=0.8))
             bbox=dict(boxstyle='round', facecolor='lightblue', alpha=0.8))
             bbox=dict(boxstyle='round', facecolor='lightblue', alpha=0.8))
             bbox=dict(boxstyle='round', facecolor='lightblue', alpha=0.8))
             bbox=dict(boxstyle='round', facecolor='lightblue', alpha=0.8))
             bbox=dict(boxstyle='round', facecolor='lightblue', alpha=0.8))
             bbox=dict(boxstyle='round', facecolor='lightblue', alpha=0.8))
             bbox=dict(boxstyle='round', facecolor='lightblue', alpha=0.8))
             bbox=dict(boxstyle='round', facecolor='lightblue', alpha=0.8))
             bbox=dict(boxstyle='round', facecolor='lightblue', alpha=0.8))
             bbox=dict(boxstyle='round', facecolor='lightblue', alpha=0.8))
             bbox=dict(boxstyle='round', facecolor='lightblue', alpha=0.8))
             bbox=dict(boxstyle='round', facecolor='lightblue', alpha=0.8))
             bbox=dict(boxstyle='round', facecolor='lightblue', alpha=0.8))
             bbox=dict(boxstyle='round', facecolor='lightblue', alpha=0.8))
             bbox=dict(boxstyle='round', facecolor='lightblue', alpha=0.8))
             bbox=dict(boxstyle='round', facecolor='lightblue', alpha=0.8))
             bbox=dict(boxstyle='round', facecolor='lightblue', alpha=0.8))
             bbox=dict(boxstyle='round', facecolor='lightblue', alpha=0.8))
    ax5.set_title('Processing Summary')
    ax5.set_title('Processing Summary')
    ax5.set_title('Processing Summary')
    ax5.set_title('Processing Summary')
    ax5.set_title('Processing Summary')
    ax5.set_title('Processing Summary')
    ax5.set_title('Processing Summary')
    ax5.set_title('Processing Summary')
    ax5.set_title('Processing Summary')
    ax5.set_title('Processing Summary')
    ax5.set_title('Processing Summary')
    ax5.set_title('Processing Summary')
    ax5.set_title('Processing Summary')
    ax5.set_title('Processing Summary')
    ax5.set_title('Processing Summary')
    ax5.set_title('Processing Summary')
    ax5.set_title('Processing Summary')
    ax5.set_title('Processing Summary')
    ax5.set_title('Processing Summary')
    ax5.set_title('Processing Summary')
    ax5.set_title('Processing Summary')
    ax5.set_title('Processing Summary')
    ax5.set_title('Processing Summary')
    ax5.set_title('Processing Summary')
    ax5.set_title('Processing Summary')
    ax5.set_title('Processing Summary')
    ax5.set_title('Processing Summary')
    ax5.set_title('Processing Summary')
    ax5.set_title('Processing Summary')
    ax5.set_title('Processing Summary')
    ax5.set_title('Processing Summary')
    ax5.set_title('Processing Summary')
    ax5.set_title('Processing Summary')
    ax5.set_title('Processing Summary')
    ax5.set_title('Processing Summary')
    ax5.set_title('Processing Summary')
    ax5.set_title('Processing Summary')
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    # Plot 6: per-slice performance
    # Plot 6: per-slice performance
    # Plot 6: per-slice performance
    # Plot 6: per-slice performance
    # Plot 6: per-slice performance
    # Plot 6: per-slice performance
    # Plot 6: per-slice performance
    # Plot 6: per-slice performance
    # Plot 6: per-slice performance
    # Plot 6: per-slice performance
    # Plot 6: per-slice performance
    # Plot 6: per-slice performance
    # Plot 6: per-slice performance
    # Plot 6: per-slice performance
    # Plot 6: per-slice performance
    # Plot 6: per-slice performance
    # Plot 6: per-slice performance
    # Plot 6: per-slice performance
    # Plot 6: per-slice performance
    # Plot 6: per-slice performance
    # Plot 6: per-slice performance
    # Plot 6: per-slice performance
    # Plot 6: per-slice performance
    # Plot 6: per-slice performance
    # Plot 6: per-slice performance
    # Plot 6: per-slice performance
    # Plot 6: per-slice performance
    # Plot 6: per-slice performance
    # Plot 6: per-slice performance
    # Plot 6: per-slice performance
    # Plot 6: per-slice performance
    # Plot 6: per-slice performance
    # Plot 6: per-slice performance
    # Plot 6: per-slice performance
    # Plot 6: per-slice performance
    # Plot 6: per-slice performance
    # Plot 6: per-slice performance
    ax6 = fig.add_subplot(236)
    ax6 = fig.add_subplot(236)
    ax6 = fig.add_subplot(236)
    ax6 = fig.add_subplot(236)
    ax6 = fig.add_subplot(236)
    ax6 = fig.add_subplot(236)
    ax6 = fig.add_subplot(236)
    ax6 = fig.add_subplot(236)
    ax6 = fig.add_subplot(236)
    ax6 = fig.add_subplot(236)
    ax6 = fig.add_subplot(236)
    ax6 = fig.add_subplot(236)
    ax6 = fig.add_subplot(236)
    ax6 = fig.add_subplot(236)
    ax6 = fig.add_subplot(236)
    ax6 = fig.add_subplot(236)
    ax6 = fig.add_subplot(236)
    ax6 = fig.add_subplot(236)
    ax6 = fig.add_subplot(236)
    ax6 = fig.add_subplot(236)
    ax6 = fig.add_subplot(236)
    ax6 = fig.add_subplot(236)
    ax6 = fig.add_subplot(236)
    ax6 = fig.add_subplot(236)
    ax6 = fig.add_subplot(236)
    ax6 = fig.add_subplot(236)
    ax6 = fig.add_subplot(236)
    ax6 = fig.add_subplot(236)
    ax6 = fig.add_subplot(236)
    ax6 = fig.add_subplot(236)
    ax6 = fig.add_subplot(236)
    ax6 = fig.add_subplot(236)
    ax6 = fig.add_subplot(236)
    ax6 = fig.add_subplot(236)
    ax6 = fig.add_subplot(236)
    ax6 = fig.add_subplot(236)
    ax6 = fig.add_subplot(236)
    if stats['per_slice']:
    if stats['per_slice']:
    if stats['per_slice']:
    if stats['per_slice']:
    if stats['per_slice']:
    if stats['per_slice']:
    if stats['per_slice']:
    if stats['per_slice']:
    if stats['per_slice']:
    if stats['per_slice']:
    if stats['per_slice']:
    if stats['per_slice']:
    if stats['per_slice']:
    if stats['per_slice']:
    if stats['per_slice']:
    if stats['per_slice']:
    if stats['per_slice']:
    if stats['per_slice']:
    if stats['per_slice']:
    if stats['per_slice']:
    if stats['per_slice']:
    if stats['per_slice']:
    if stats['per_slice']:
    if stats['per_slice']:
    if stats['per_slice']:
    if stats['per_slice']:
    if stats['per_slice']:
    if stats['per_slice']:
    if stats['per_slice']:
    if stats['per_slice']:
    if stats['per_slice']:
    if stats['per_slice']:
    if stats['per_slice']:
    if stats['per_slice']:
    if stats['per_slice']:
    if stats['per_slice']:
    if stats['per_slice']:
        layers = [f'L{i+1}' for i in range(len(stats['per_slice']))]
        layers = [f'L{i+1}' for i in range(len(stats['per_slice']))]
        layers = [f'L{i+1}' for i in range(len(stats['per_slice']))]
        layers = [f'L{i+1}' for i in range(len(stats['per_slice']))]
        layers = [f'L{i+1}' for i in range(len(stats['per_slice']))]
        layers = [f'L{i+1}' for i in range(len(stats['per_slice']))]
        layers = [f'L{i+1}' for i in range(len(stats['per_slice']))]
        layers = [f'L{i+1}' for i in range(len(stats['per_slice']))]
        layers = [f'L{i+1}' for i in range(len(stats['per_slice']))]
        layers = [f'L{i+1}' for i in range(len(stats['per_slice']))]
        layers = [f'L{i+1}' for i in range(len(stats['per_slice']))]
        layers = [f'L{i+1}' for i in range(len(stats['per_slice']))]
        layers = [f'L{i+1}' for i in range(len(stats['per_slice']))]
        layers = [f'L{i+1}' for i in range(len(stats['per_slice']))]
        layers = [f'L{i+1}' for i in range(len(stats['per_slice']))]
        layers = [f'L{i+1}' for i in range(len(stats['per_slice']))]
        layers = [f'L{i+1}' for i in range(len(stats['per_slice']))]
        layers = [f'L{i+1}' for i in range(len(stats['per_slice']))]
        layers = [f'L{i+1}' for i in range(len(stats['per_slice']))]
        layers = [f'L{i+1}' for i in range(len(stats['per_slice']))]
        layers = [f'L{i+1}' for i in range(len(stats['per_slice']))]
        layers = [f'L{i+1}' for i in range(len(stats['per_slice']))]
        layers = [f'L{i+1}' for i in range(len(stats['per_slice']))]
        layers = [f'L{i+1}' for i in range(len(stats['per_slice']))]
        layers = [f'L{i+1}' for i in range(len(stats['per_slice']))]
        layers = [f'L{i+1}' for i in range(len(stats['per_slice']))]
        layers = [f'L{i+1}' for i in range(len(stats['per_slice']))]
        layers = [f'L{i+1}' for i in range(len(stats['per_slice']))]
        layers = [f'L{i+1}' for i in range(len(stats['per_slice']))]
        layers = [f'L{i+1}' for i in range(len(stats['per_slice']))]
        layers = [f'L{i+1}' for i in range(len(stats['per_slice']))]
        layers = [f'L{i+1}' for i in range(len(stats['per_slice']))]
        layers = [f'L{i+1}' for i in range(len(stats['per_slice']))]
        layers = [f'L{i+1}' for i in range(len(stats['per_slice']))]
        layers = [f'L{i+1}' for i in range(len(stats['per_slice']))]
        layers = [f'L{i+1}' for i in range(len(stats['per_slice']))]
        layers = [f'L{i+1}' for i in range(len(stats['per_slice']))]
        original_counts = []
        original_counts = []
        original_counts = []
        original_counts = []
        original_counts = []
        original_counts = []
        original_counts = []
        original_counts = []
        original_counts = []
        original_counts = []
        original_counts = []
        original_counts = []
        original_counts = []
        original_counts = []
        original_counts = []
        original_counts = []
        original_counts = []
        original_counts = []
        original_counts = []
        original_counts = []
        original_counts = []
        original_counts = []
        original_counts = []
        original_counts = []
        original_counts = []
        original_counts = []
        original_counts = []
        original_counts = []
        original_counts = []
        original_counts = []
        original_counts = []
        original_counts = []
        original_counts = []
        original_counts = []
        original_counts = []
        original_counts = []
        original_counts = []
        kept_counts = []
        kept_counts = []
        kept_counts = []
        kept_counts = []
        kept_counts = []
        kept_counts = []
        kept_counts = []
        kept_counts = []
        kept_counts = []
        kept_counts = []
        kept_counts = []
        kept_counts = []
        kept_counts = []
        kept_counts = []
        kept_counts = []
        kept_counts = []
        kept_counts = []
        kept_counts = []
        kept_counts = []
        kept_counts = []
        kept_counts = []
        kept_counts = []
        kept_counts = []
        kept_counts = []
        kept_counts = []
        kept_counts = []
        kept_counts = []
        kept_counts = []
        kept_counts = []
        kept_counts = []
        kept_counts = []
        kept_counts = []
        kept_counts = []
        kept_counts = []
        kept_counts = []
        kept_counts = []
        kept_counts = []
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        for s in stats['per_slice']:
        for s in stats['per_slice']:
        for s in stats['per_slice']:
        for s in stats['per_slice']:
        for s in stats['per_slice']:
        for s in stats['per_slice']:
        for s in stats['per_slice']:
        for s in stats['per_slice']:
        for s in stats['per_slice']:
        for s in stats['per_slice']:
        for s in stats['per_slice']:
        for s in stats['per_slice']:
        for s in stats['per_slice']:
        for s in stats['per_slice']:
        for s in stats['per_slice']:
        for s in stats['per_slice']:
        for s in stats['per_slice']:
        for s in stats['per_slice']:
        for s in stats['per_slice']:
        for s in stats['per_slice']:
        for s in stats['per_slice']:
        for s in stats['per_slice']:
        for s in stats['per_slice']:
        for s in stats['per_slice']:
        for s in stats['per_slice']:
        for s in stats['per_slice']:
        for s in stats['per_slice']:
        for s in stats['per_slice']:
        for s in stats['per_slice']:
        for s in stats['per_slice']:
        for s in stats['per_slice']:
        for s in stats['per_slice']:
        for s in stats['per_slice']:
        for s in stats['per_slice']:
        for s in stats['per_slice']:
        for s in stats['per_slice']:
        for s in stats['per_slice']:
            original_counts.append(s['n_in_slice'])
            original_counts.append(s['n_in_slice'])
            original_counts.append(s['n_in_slice'])
            original_counts.append(s['n_in_slice'])
            original_counts.append(s['n_in_slice'])
            original_counts.append(s['n_in_slice'])
            original_counts.append(s['n_in_slice'])
            original_counts.append(s['n_in_slice'])
            original_counts.append(s['n_in_slice'])
            original_counts.append(s['n_in_slice'])
            original_counts.append(s['n_in_slice'])
            original_counts.append(s['n_in_slice'])
            original_counts.append(s['n_in_slice'])
            original_counts.append(s['n_in_slice'])
            original_counts.append(s['n_in_slice'])
            original_counts.append(s['n_in_slice'])
            original_counts.append(s['n_in_slice'])
            original_counts.append(s['n_in_slice'])
            original_counts.append(s['n_in_slice'])
            original_counts.append(s['n_in_slice'])
            original_counts.append(s['n_in_slice'])
            original_counts.append(s['n_in_slice'])
            original_counts.append(s['n_in_slice'])
            original_counts.append(s['n_in_slice'])
            original_counts.append(s['n_in_slice'])
            original_counts.append(s['n_in_slice'])
            original_counts.append(s['n_in_slice'])
            original_counts.append(s['n_in_slice'])
            original_counts.append(s['n_in_slice'])
            original_counts.append(s['n_in_slice'])
            original_counts.append(s['n_in_slice'])
            original_counts.append(s['n_in_slice'])
            original_counts.append(s['n_in_slice'])
            original_counts.append(s['n_in_slice'])
            original_counts.append(s['n_in_slice'])
            original_counts.append(s['n_in_slice'])
            original_counts.append(s['n_in_slice'])
            # use .get() to avoid KeyError
            # use .get() to avoid KeyError
            # use .get() to avoid KeyError
            # use .get() to avoid KeyError
            # use .get() to avoid KeyError
            # use .get() to avoid KeyError
            # use .get() to avoid KeyError
            # use .get() to avoid KeyError
            # use .get() to avoid KeyError
            # use .get() to avoid KeyError
            # use .get() to avoid KeyError
            # use .get() to avoid KeyError
            # use .get() to avoid KeyError
            # use .get() to avoid KeyError
            # use .get() to avoid KeyError
            # use .get() to avoid KeyError
            # use .get() to avoid KeyError
            # use .get() to avoid KeyError
            # use .get() to avoid KeyError
            # use .get() to avoid KeyError
            # use .get() to avoid KeyError
            # use .get() to avoid KeyError
            # use .get() to avoid KeyError
            # use .get() to avoid KeyError
            # use .get() to avoid KeyError
            # use .get() to avoid KeyError
            # use .get() to avoid KeyError
            # use .get() to avoid KeyError
            # use .get() to avoid KeyError
            # use .get() to avoid KeyError
            # use .get() to avoid KeyError
            # use .get() to avoid KeyError
            # use .get() to avoid KeyError
            # use .get() to avoid KeyError
            # use .get() to avoid KeyError
            # use .get() to avoid KeyError
            # use .get() to avoid KeyError
            kept_counts.append(s.get('kept', s['n_in_slice']))  # fallback to n_in_slice if 'kept' key is missing
            kept_counts.append(s.get('kept', s['n_in_slice']))  # fallback to n_in_slice if 'kept' key is missing
            kept_counts.append(s.get('kept', s['n_in_slice']))  # fallback to n_in_slice if 'kept' key is missing
            kept_counts.append(s.get('kept', s['n_in_slice']))  # fallback to n_in_slice if 'kept' key is missing
            kept_counts.append(s.get('kept', s['n_in_slice']))  # fallback to n_in_slice if 'kept' key is missing
            kept_counts.append(s.get('kept', s['n_in_slice']))  # fallback to n_in_slice if 'kept' key is missing
            kept_counts.append(s.get('kept', s['n_in_slice']))  # fallback to n_in_slice if 'kept' key is missing
            kept_counts.append(s.get('kept', s['n_in_slice']))  # fallback to n_in_slice if 'kept' key is missing
            kept_counts.append(s.get('kept', s['n_in_slice']))  # fallback to n_in_slice if 'kept' key is missing
            kept_counts.append(s.get('kept', s['n_in_slice']))  # fallback to n_in_slice if 'kept' key is missing
            kept_counts.append(s.get('kept', s['n_in_slice']))  # fallback to n_in_slice if 'kept' key is missing
            kept_counts.append(s.get('kept', s['n_in_slice']))  # fallback to n_in_slice if 'kept' key is missing
            kept_counts.append(s.get('kept', s['n_in_slice']))  # fallback to n_in_slice if 'kept' key is missing
            kept_counts.append(s.get('kept', s['n_in_slice']))  # fallback to n_in_slice if 'kept' key is missing
            kept_counts.append(s.get('kept', s['n_in_slice']))  # fallback to n_in_slice if 'kept' key is missing
            kept_counts.append(s.get('kept', s['n_in_slice']))  # fallback to n_in_slice if 'kept' key is missing
            kept_counts.append(s.get('kept', s['n_in_slice']))  # fallback to n_in_slice if 'kept' key is missing
            kept_counts.append(s.get('kept', s['n_in_slice']))  # fallback to n_in_slice if 'kept' key is missing
            kept_counts.append(s.get('kept', s['n_in_slice']))  # fallback to n_in_slice if 'kept' key is missing
            kept_counts.append(s.get('kept', s['n_in_slice']))  # fallback to n_in_slice if 'kept' key is missing
            kept_counts.append(s.get('kept', s['n_in_slice']))  # fallback to n_in_slice if 'kept' key is missing
            kept_counts.append(s.get('kept', s['n_in_slice']))  # fallback to n_in_slice if 'kept' key is missing
            kept_counts.append(s.get('kept', s['n_in_slice']))  # fallback to n_in_slice if 'kept' key is missing
            kept_counts.append(s.get('kept', s['n_in_slice']))  # fallback to n_in_slice if 'kept' key is missing
            kept_counts.append(s.get('kept', s['n_in_slice']))  # fallback to n_in_slice if 'kept' key is missing
            kept_counts.append(s.get('kept', s['n_in_slice']))  # fallback to n_in_slice if 'kept' key is missing
            kept_counts.append(s.get('kept', s['n_in_slice']))  # fallback to n_in_slice if 'kept' key is missing
            kept_counts.append(s.get('kept', s['n_in_slice']))  # fallback to n_in_slice if 'kept' key is missing
            kept_counts.append(s.get('kept', s['n_in_slice']))  # fallback to n_in_slice if 'kept' key is missing
            kept_counts.append(s.get('kept', s['n_in_slice']))  # fallback to n_in_slice if 'kept' key is missing
            kept_counts.append(s.get('kept', s['n_in_slice']))  # fallback to n_in_slice if 'kept' key is missing
            kept_counts.append(s.get('kept', s['n_in_slice']))  # fallback to n_in_slice if 'kept' key is missing
            kept_counts.append(s.get('kept', s['n_in_slice']))  # fallback to n_in_slice if 'kept' key is missing
            kept_counts.append(s.get('kept', s['n_in_slice']))  # fallback to n_in_slice if 'kept' key is missing
            kept_counts.append(s.get('kept', s['n_in_slice']))  # fallback to n_in_slice if 'kept' key is missing
            kept_counts.append(s.get('kept', s['n_in_slice']))  # fallback to n_in_slice if 'kept' key is missing
            kept_counts.append(s.get('kept', s['n_in_slice']))  # fallback to n_in_slice if 'kept' key is missing
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        x = np.arange(len(layers))
        x = np.arange(len(layers))
        x = np.arange(len(layers))
        x = np.arange(len(layers))
        x = np.arange(len(layers))
        x = np.arange(len(layers))
        x = np.arange(len(layers))
        x = np.arange(len(layers))
        x = np.arange(len(layers))
        x = np.arange(len(layers))
        x = np.arange(len(layers))
        x = np.arange(len(layers))
        x = np.arange(len(layers))
        x = np.arange(len(layers))
        x = np.arange(len(layers))
        x = np.arange(len(layers))
        x = np.arange(len(layers))
        x = np.arange(len(layers))
        x = np.arange(len(layers))
        x = np.arange(len(layers))
        x = np.arange(len(layers))
        x = np.arange(len(layers))
        x = np.arange(len(layers))
        x = np.arange(len(layers))
        x = np.arange(len(layers))
        x = np.arange(len(layers))
        x = np.arange(len(layers))
        x = np.arange(len(layers))
        x = np.arange(len(layers))
        x = np.arange(len(layers))
        x = np.arange(len(layers))
        x = np.arange(len(layers))
        x = np.arange(len(layers))
        x = np.arange(len(layers))
        x = np.arange(len(layers))
        x = np.arange(len(layers))
        x = np.arange(len(layers))
        width = 0.35
        width = 0.35
        width = 0.35
        width = 0.35
        width = 0.35
        width = 0.35
        width = 0.35
        width = 0.35
        width = 0.35
        width = 0.35
        width = 0.35
        width = 0.35
        width = 0.35
        width = 0.35
        width = 0.35
        width = 0.35
        width = 0.35
        width = 0.35
        width = 0.35
        width = 0.35
        width = 0.35
        width = 0.35
        width = 0.35
        width = 0.35
        width = 0.35
        width = 0.35
        width = 0.35
        width = 0.35
        width = 0.35
        width = 0.35
        width = 0.35
        width = 0.35
        width = 0.35
        width = 0.35
        width = 0.35
        width = 0.35
        width = 0.35
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        ax6.bar(x - width/2, original_counts, width, label='Original', alpha=0.7)
        ax6.bar(x - width/2, original_counts, width, label='Original', alpha=0.7)
        ax6.bar(x - width/2, original_counts, width, label='Original', alpha=0.7)
        ax6.bar(x - width/2, original_counts, width, label='Original', alpha=0.7)
        ax6.bar(x - width/2, original_counts, width, label='Original', alpha=0.7)
        ax6.bar(x - width/2, original_counts, width, label='Original', alpha=0.7)
        ax6.bar(x - width/2, original_counts, width, label='Original', alpha=0.7)
        ax6.bar(x - width/2, original_counts, width, label='Original', alpha=0.7)
        ax6.bar(x - width/2, original_counts, width, label='Original', alpha=0.7)
        ax6.bar(x - width/2, original_counts, width, label='Original', alpha=0.7)
        ax6.bar(x - width/2, original_counts, width, label='Original', alpha=0.7)
        ax6.bar(x - width/2, original_counts, width, label='Original', alpha=0.7)
        ax6.bar(x - width/2, original_counts, width, label='Original', alpha=0.7)
        ax6.bar(x - width/2, original_counts, width, label='Original', alpha=0.7)
        ax6.bar(x - width/2, original_counts, width, label='Original', alpha=0.7)
        ax6.bar(x - width/2, original_counts, width, label='Original', alpha=0.7)
        ax6.bar(x - width/2, original_counts, width, label='Original', alpha=0.7)
        ax6.bar(x - width/2, original_counts, width, label='Original', alpha=0.7)
        ax6.bar(x - width/2, original_counts, width, label='Original', alpha=0.7)
        ax6.bar(x - width/2, original_counts, width, label='Original', alpha=0.7)
        ax6.bar(x - width/2, original_counts, width, label='Original', alpha=0.7)
        ax6.bar(x - width/2, original_counts, width, label='Original', alpha=0.7)
        ax6.bar(x - width/2, original_counts, width, label='Original', alpha=0.7)
        ax6.bar(x - width/2, original_counts, width, label='Original', alpha=0.7)
        ax6.bar(x - width/2, original_counts, width, label='Original', alpha=0.7)
        ax6.bar(x - width/2, original_counts, width, label='Original', alpha=0.7)
        ax6.bar(x - width/2, original_counts, width, label='Original', alpha=0.7)
        ax6.bar(x - width/2, original_counts, width, label='Original', alpha=0.7)
        ax6.bar(x - width/2, original_counts, width, label='Original', alpha=0.7)
        ax6.bar(x - width/2, original_counts, width, label='Original', alpha=0.7)
        ax6.bar(x - width/2, original_counts, width, label='Original', alpha=0.7)
        ax6.bar(x - width/2, original_counts, width, label='Original', alpha=0.7)
        ax6.bar(x - width/2, original_counts, width, label='Original', alpha=0.7)
        ax6.bar(x - width/2, original_counts, width, label='Original', alpha=0.7)
        ax6.bar(x - width/2, original_counts, width, label='Original', alpha=0.7)
        ax6.bar(x - width/2, original_counts, width, label='Original', alpha=0.7)
        ax6.bar(x - width/2, original_counts, width, label='Original', alpha=0.7)
        ax6.bar(x + width/2, kept_counts, width, label='Kept', alpha=0.7)
        ax6.bar(x + width/2, kept_counts, width, label='Kept', alpha=0.7)
        ax6.bar(x + width/2, kept_counts, width, label='Kept', alpha=0.7)
        ax6.bar(x + width/2, kept_counts, width, label='Kept', alpha=0.7)
        ax6.bar(x + width/2, kept_counts, width, label='Kept', alpha=0.7)
        ax6.bar(x + width/2, kept_counts, width, label='Kept', alpha=0.7)
        ax6.bar(x + width/2, kept_counts, width, label='Kept', alpha=0.7)
        ax6.bar(x + width/2, kept_counts, width, label='Kept', alpha=0.7)
        ax6.bar(x + width/2, kept_counts, width, label='Kept', alpha=0.7)
        ax6.bar(x + width/2, kept_counts, width, label='Kept', alpha=0.7)
        ax6.bar(x + width/2, kept_counts, width, label='Kept', alpha=0.7)
        ax6.bar(x + width/2, kept_counts, width, label='Kept', alpha=0.7)
        ax6.bar(x + width/2, kept_counts, width, label='Kept', alpha=0.7)
        ax6.bar(x + width/2, kept_counts, width, label='Kept', alpha=0.7)
        ax6.bar(x + width/2, kept_counts, width, label='Kept', alpha=0.7)
        ax6.bar(x + width/2, kept_counts, width, label='Kept', alpha=0.7)
        ax6.bar(x + width/2, kept_counts, width, label='Kept', alpha=0.7)
        ax6.bar(x + width/2, kept_counts, width, label='Kept', alpha=0.7)
        ax6.bar(x + width/2, kept_counts, width, label='Kept', alpha=0.7)
        ax6.bar(x + width/2, kept_counts, width, label='Kept', alpha=0.7)
        ax6.bar(x + width/2, kept_counts, width, label='Kept', alpha=0.7)
        ax6.bar(x + width/2, kept_counts, width, label='Kept', alpha=0.7)
        ax6.bar(x + width/2, kept_counts, width, label='Kept', alpha=0.7)
        ax6.bar(x + width/2, kept_counts, width, label='Kept', alpha=0.7)
        ax6.bar(x + width/2, kept_counts, width, label='Kept', alpha=0.7)
        ax6.bar(x + width/2, kept_counts, width, label='Kept', alpha=0.7)
        ax6.bar(x + width/2, kept_counts, width, label='Kept', alpha=0.7)
        ax6.bar(x + width/2, kept_counts, width, label='Kept', alpha=0.7)
        ax6.bar(x + width/2, kept_counts, width, label='Kept', alpha=0.7)
        ax6.bar(x + width/2, kept_counts, width, label='Kept', alpha=0.7)
        ax6.bar(x + width/2, kept_counts, width, label='Kept', alpha=0.7)
        ax6.bar(x + width/2, kept_counts, width, label='Kept', alpha=0.7)
        ax6.bar(x + width/2, kept_counts, width, label='Kept', alpha=0.7)
        ax6.bar(x + width/2, kept_counts, width, label='Kept', alpha=0.7)
        ax6.bar(x + width/2, kept_counts, width, label='Kept', alpha=0.7)
        ax6.bar(x + width/2, kept_counts, width, label='Kept', alpha=0.7)
        ax6.bar(x + width/2, kept_counts, width, label='Kept', alpha=0.7)
        ax6.set_xlabel('Layers')
        ax6.set_xlabel('Layers')
        ax6.set_xlabel('Layers')
        ax6.set_xlabel('Layers')
        ax6.set_xlabel('Layers')
        ax6.set_xlabel('Layers')
        ax6.set_xlabel('Layers')
        ax6.set_xlabel('Layers')
        ax6.set_xlabel('Layers')
        ax6.set_xlabel('Layers')
        ax6.set_xlabel('Layers')
        ax6.set_xlabel('Layers')
        ax6.set_xlabel('Layers')
        ax6.set_xlabel('Layers')
        ax6.set_xlabel('Layers')
        ax6.set_xlabel('Layers')
        ax6.set_xlabel('Layers')
        ax6.set_xlabel('Layers')
        ax6.set_xlabel('Layers')
        ax6.set_xlabel('Layers')
        ax6.set_xlabel('Layers')
        ax6.set_xlabel('Layers')
        ax6.set_xlabel('Layers')
        ax6.set_xlabel('Layers')
        ax6.set_xlabel('Layers')
        ax6.set_xlabel('Layers')
        ax6.set_xlabel('Layers')
        ax6.set_xlabel('Layers')
        ax6.set_xlabel('Layers')
        ax6.set_xlabel('Layers')
        ax6.set_xlabel('Layers')
        ax6.set_xlabel('Layers')
        ax6.set_xlabel('Layers')
        ax6.set_xlabel('Layers')
        ax6.set_xlabel('Layers')
        ax6.set_xlabel('Layers')
        ax6.set_xlabel('Layers')
        ax6.set_ylabel('Number of Points')
        ax6.set_ylabel('Number of Points')
        ax6.set_ylabel('Number of Points')
        ax6.set_ylabel('Number of Points')
        ax6.set_ylabel('Number of Points')
        ax6.set_ylabel('Number of Points')
        ax6.set_ylabel('Number of Points')
        ax6.set_ylabel('Number of Points')
        ax6.set_ylabel('Number of Points')
        ax6.set_ylabel('Number of Points')
        ax6.set_ylabel('Number of Points')
        ax6.set_ylabel('Number of Points')
        ax6.set_ylabel('Number of Points')
        ax6.set_ylabel('Number of Points')
        ax6.set_ylabel('Number of Points')
        ax6.set_ylabel('Number of Points')
        ax6.set_ylabel('Number of Points')
        ax6.set_ylabel('Number of Points')
        ax6.set_ylabel('Number of Points')
        ax6.set_ylabel('Number of Points')
        ax6.set_ylabel('Number of Points')
        ax6.set_ylabel('Number of Points')
        ax6.set_ylabel('Number of Points')
        ax6.set_ylabel('Number of Points')
        ax6.set_ylabel('Number of Points')
        ax6.set_ylabel('Number of Points')
        ax6.set_ylabel('Number of Points')
        ax6.set_ylabel('Number of Points')
        ax6.set_ylabel('Number of Points')
        ax6.set_ylabel('Number of Points')
        ax6.set_ylabel('Number of Points')
        ax6.set_ylabel('Number of Points')
        ax6.set_ylabel('Number of Points')
        ax6.set_ylabel('Number of Points')
        ax6.set_ylabel('Number of Points')
        ax6.set_ylabel('Number of Points')
        ax6.set_ylabel('Number of Points')
        ax6.set_title('Points Distribution by Layer')
        ax6.set_title('Points Distribution by Layer')
        ax6.set_title('Points Distribution by Layer')
        ax6.set_title('Points Distribution by Layer')
        ax6.set_title('Points Distribution by Layer')
        ax6.set_title('Points Distribution by Layer')
        ax6.set_title('Points Distribution by Layer')
        ax6.set_title('Points Distribution by Layer')
        ax6.set_title('Points Distribution by Layer')
        ax6.set_title('Points Distribution by Layer')
        ax6.set_title('Points Distribution by Layer')
        ax6.set_title('Points Distribution by Layer')
        ax6.set_title('Points Distribution by Layer')
        ax6.set_title('Points Distribution by Layer')
        ax6.set_title('Points Distribution by Layer')
        ax6.set_title('Points Distribution by Layer')
        ax6.set_title('Points Distribution by Layer')
        ax6.set_title('Points Distribution by Layer')
        ax6.set_title('Points Distribution by Layer')
        ax6.set_title('Points Distribution by Layer')
        ax6.set_title('Points Distribution by Layer')
        ax6.set_title('Points Distribution by Layer')
        ax6.set_title('Points Distribution by Layer')
        ax6.set_title('Points Distribution by Layer')
        ax6.set_title('Points Distribution by Layer')
        ax6.set_title('Points Distribution by Layer')
        ax6.set_title('Points Distribution by Layer')
        ax6.set_title('Points Distribution by Layer')
        ax6.set_title('Points Distribution by Layer')
        ax6.set_title('Points Distribution by Layer')
        ax6.set_title('Points Distribution by Layer')
        ax6.set_title('Points Distribution by Layer')
        ax6.set_title('Points Distribution by Layer')
        ax6.set_title('Points Distribution by Layer')
        ax6.set_title('Points Distribution by Layer')
        ax6.set_title('Points Distribution by Layer')
        ax6.set_title('Points Distribution by Layer')
        ax6.legend()
        ax6.legend()
        ax6.legend()
        ax6.legend()
        ax6.legend()
        ax6.legend()
        ax6.legend()
        ax6.legend()
        ax6.legend()
        ax6.legend()
        ax6.legend()
        ax6.legend()
        ax6.legend()
        ax6.legend()
        ax6.legend()
        ax6.legend()
        ax6.legend()
        ax6.legend()
        ax6.legend()
        ax6.legend()
        ax6.legend()
        ax6.legend()
        ax6.legend()
        ax6.legend()
        ax6.legend()
        ax6.legend()
        ax6.legend()
        ax6.legend()
        ax6.legend()
        ax6.legend()
        ax6.legend()
        ax6.legend()
        ax6.legend()
        ax6.legend()
        ax6.legend()
        ax6.legend()
        ax6.legend()
        ax6.tick_params(axis='x', rotation=45)
        ax6.tick_params(axis='x', rotation=45)
        ax6.tick_params(axis='x', rotation=45)
        ax6.tick_params(axis='x', rotation=45)
        ax6.tick_params(axis='x', rotation=45)
        ax6.tick_params(axis='x', rotation=45)
        ax6.tick_params(axis='x', rotation=45)
        ax6.tick_params(axis='x', rotation=45)
        ax6.tick_params(axis='x', rotation=45)
        ax6.tick_params(axis='x', rotation=45)
        ax6.tick_params(axis='x', rotation=45)
        ax6.tick_params(axis='x', rotation=45)
        ax6.tick_params(axis='x', rotation=45)
        ax6.tick_params(axis='x', rotation=45)
        ax6.tick_params(axis='x', rotation=45)
        ax6.tick_params(axis='x', rotation=45)
        ax6.tick_params(axis='x', rotation=45)
        ax6.tick_params(axis='x', rotation=45)
        ax6.tick_params(axis='x', rotation=45)
        ax6.tick_params(axis='x', rotation=45)
        ax6.tick_params(axis='x', rotation=45)
        ax6.tick_params(axis='x', rotation=45)
        ax6.tick_params(axis='x', rotation=45)
        ax6.tick_params(axis='x', rotation=45)
        ax6.tick_params(axis='x', rotation=45)
        ax6.tick_params(axis='x', rotation=45)
        ax6.tick_params(axis='x', rotation=45)
        ax6.tick_params(axis='x', rotation=45)
        ax6.tick_params(axis='x', rotation=45)
        ax6.tick_params(axis='x', rotation=45)
        ax6.tick_params(axis='x', rotation=45)
        ax6.tick_params(axis='x', rotation=45)
        ax6.tick_params(axis='x', rotation=45)
        ax6.tick_params(axis='x', rotation=45)
        ax6.tick_params(axis='x', rotation=45)
        ax6.tick_params(axis='x', rotation=45)
        ax6.tick_params(axis='x', rotation=45)
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    plt.tight_layout()
    plt.tight_layout()
    plt.tight_layout()
    plt.tight_layout()
    plt.tight_layout()
    plt.tight_layout()
    plt.tight_layout()
    plt.tight_layout()
    plt.tight_layout()
    plt.tight_layout()
    plt.tight_layout()
    plt.tight_layout()
    plt.tight_layout()
    plt.tight_layout()
    plt.tight_layout()
    plt.tight_layout()
    plt.tight_layout()
    plt.tight_layout()
    plt.tight_layout()
    plt.tight_layout()
    plt.tight_layout()
    plt.tight_layout()
    plt.tight_layout()
    plt.tight_layout()
    plt.tight_layout()
    plt.tight_layout()
    plt.tight_layout()
    plt.tight_layout()
    plt.tight_layout()
    plt.tight_layout()
    plt.tight_layout()
    plt.tight_layout()
    plt.tight_layout()
    plt.tight_layout()
    plt.tight_layout()
    plt.tight_layout()
    plt.tight_layout()
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
        # save plot
        # save plot
        # save plot
        # save plot
        # save plot
        # save plot
        # save plot
        # save plot
        # save plot
        # save plot
        # save plot
        # save plot
        # save plot
        # save plot
        # save plot
        # save plot
        # save plot
        # save plot
        # save plot
        # save plot
        # save plot
        # save plot
        # save plot
        # save plot
        # save plot
        # save plot
        # save plot
        # save plot
        # save plot
        # save plot
        # save plot
        # save plot
        # save plot
        # save plot
        # save plot
        # save plot
        # save plot
    plot_path = os.path.join(output_dir, "processing_visualization.png")
    plot_path = os.path.join(output_dir, "processing_visualization.png")
    plot_path = os.path.join(output_dir, "processing_visualization.png")
    plot_path = os.path.join(output_dir, "processing_visualization.png")
    plot_path = os.path.join(output_dir, "processing_visualization.png")
    plot_path = os.path.join(output_dir, "processing_visualization.png")
    plot_path = os.path.join(output_dir, "processing_visualization.png")
    plot_path = os.path.join(output_dir, "processing_visualization.png")
    plot_path = os.path.join(output_dir, "processing_visualization.png")
    plot_path = os.path.join(output_dir, "processing_visualization.png")
    plot_path = os.path.join(output_dir, "processing_visualization.png")
    plot_path = os.path.join(output_dir, "processing_visualization.png")
    plot_path = os.path.join(output_dir, "processing_visualization.png")
    plot_path = os.path.join(output_dir, "processing_visualization.png")
    plot_path = os.path.join(output_dir, "processing_visualization.png")
    plot_path = os.path.join(output_dir, "processing_visualization.png")
    plot_path = os.path.join(output_dir, "processing_visualization.png")
    plot_path = os.path.join(output_dir, "processing_visualization.png")
    plot_path = os.path.join(output_dir, "processing_visualization.png")
    plot_path = os.path.join(output_dir, "processing_visualization.png")
    plot_path = os.path.join(output_dir, "processing_visualization.png")
    plot_path = os.path.join(output_dir, "processing_visualization.png")
    plot_path = os.path.join(output_dir, "processing_visualization.png")
    plot_path = os.path.join(output_dir, "processing_visualization.png")
    plot_path = os.path.join(output_dir, "processing_visualization.png")
    plot_path = os.path.join(output_dir, "processing_visualization.png")
    plot_path = os.path.join(output_dir, "processing_visualization.png")
    plot_path = os.path.join(output_dir, "processing_visualization.png")
    plot_path = os.path.join(output_dir, "processing_visualization.png")
    plot_path = os.path.join(output_dir, "processing_visualization.png")
    plot_path = os.path.join(output_dir, "processing_visualization.png")
    plot_path = os.path.join(output_dir, "processing_visualization.png")
    plot_path = os.path.join(output_dir, "processing_visualization.png")
    plot_path = os.path.join(output_dir, "processing_visualization.png")
    plot_path = os.path.join(output_dir, "processing_visualization.png")
    plot_path = os.path.join(output_dir, "processing_visualization.png")
    plot_path = os.path.join(output_dir, "processing_visualization.png")
    plt.savefig(plot_path, dpi=300, bbox_inches='tight')
    plt.savefig(plot_path, dpi=300, bbox_inches='tight')
    plt.savefig(plot_path, dpi=300, bbox_inches='tight')
    plt.savefig(plot_path, dpi=300, bbox_inches='tight')
    plt.savefig(plot_path, dpi=300, bbox_inches='tight')
    plt.savefig(plot_path, dpi=300, bbox_inches='tight')
    plt.savefig(plot_path, dpi=300, bbox_inches='tight')
    plt.savefig(plot_path, dpi=300, bbox_inches='tight')
    plt.savefig(plot_path, dpi=300, bbox_inches='tight')
    plt.savefig(plot_path, dpi=300, bbox_inches='tight')
    plt.savefig(plot_path, dpi=300, bbox_inches='tight')
    plt.savefig(plot_path, dpi=300, bbox_inches='tight')
    plt.savefig(plot_path, dpi=300, bbox_inches='tight')
    plt.savefig(plot_path, dpi=300, bbox_inches='tight')
    plt.savefig(plot_path, dpi=300, bbox_inches='tight')
    plt.savefig(plot_path, dpi=300, bbox_inches='tight')
    plt.savefig(plot_path, dpi=300, bbox_inches='tight')
    plt.savefig(plot_path, dpi=300, bbox_inches='tight')
    plt.savefig(plot_path, dpi=300, bbox_inches='tight')
    plt.savefig(plot_path, dpi=300, bbox_inches='tight')
    plt.savefig(plot_path, dpi=300, bbox_inches='tight')
    plt.savefig(plot_path, dpi=300, bbox_inches='tight')
    plt.savefig(plot_path, dpi=300, bbox_inches='tight')
    plt.savefig(plot_path, dpi=300, bbox_inches='tight')
    plt.savefig(plot_path, dpi=300, bbox_inches='tight')
    plt.savefig(plot_path, dpi=300, bbox_inches='tight')
    plt.savefig(plot_path, dpi=300, bbox_inches='tight')
    plt.savefig(plot_path, dpi=300, bbox_inches='tight')
    plt.savefig(plot_path, dpi=300, bbox_inches='tight')
    plt.savefig(plot_path, dpi=300, bbox_inches='tight')
    plt.savefig(plot_path, dpi=300, bbox_inches='tight')
    plt.savefig(plot_path, dpi=300, bbox_inches='tight')
    plt.savefig(plot_path, dpi=300, bbox_inches='tight')
    plt.savefig(plot_path, dpi=300, bbox_inches='tight')
    plt.savefig(plot_path, dpi=300, bbox_inches='tight')
    plt.savefig(plot_path, dpi=300, bbox_inches='tight')
    plt.savefig(plot_path, dpi=300, bbox_inches='tight')
    plt.show()
    plt.show()
    plt.show()
    plt.show()
    plt.show()
    plt.show()
    plt.show()
    plt.show()
    plt.show()
    plt.show()
    plt.show()
    plt.show()
    plt.show()
    plt.show()
    plt.show()
    plt.show()
    plt.show()
    plt.show()
    plt.show()
    plt.show()
    plt.show()
    plt.show()
    plt.show()
    plt.show()
    plt.show()
    plt.show()
    plt.show()
    plt.show()
    plt.show()
    plt.show()
    plt.show()
    plt.show()
    plt.show()
    plt.show()
    plt.show()
    plt.show()
    plt.show()
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    print(f"✓ Visualization saved: {plot_path}")
    print(f"✓ Visualization saved: {plot_path}")
    print(f"✓ Visualization saved: {plot_path}")
    print(f"✓ Visualization saved: {plot_path}")
    print(f"✓ Visualization saved: {plot_path}")
    print(f"✓ Visualization saved: {plot_path}")
    print(f"✓ Visualization saved: {plot_path}")
    print(f"✓ Visualization saved: {plot_path}")
    print(f"✓ Visualization saved: {plot_path}")
    print(f"✓ Visualization saved: {plot_path}")
    print(f"✓ Visualization saved: {plot_path}")
    print(f"✓ Visualization saved: {plot_path}")
    print(f"✓ Visualization saved: {plot_path}")
    print(f"✓ Visualization saved: {plot_path}")
    print(f"✓ Visualization saved: {plot_path}")
    print(f"✓ Visualization saved: {plot_path}")
    print(f"✓ Visualization saved: {plot_path}")
    print(f"✓ Visualization saved: {plot_path}")
    print(f"✓ Visualization saved: {plot_path}")
    print(f"✓ Visualization saved: {plot_path}")
    print(f"✓ Visualization saved: {plot_path}")
    print(f"✓ Visualization saved: {plot_path}")
    print(f"✓ Visualization saved: {plot_path}")
    print(f"✓ Visualization saved: {plot_path}")
    print(f"✓ Visualization saved: {plot_path}")
    print(f"✓ Visualization saved: {plot_path}")
    print(f"✓ Visualization saved: {plot_path}")
    print(f"✓ Visualization saved: {plot_path}")
    print(f"✓ Visualization saved: {plot_path}")
    print(f"✓ Visualization saved: {plot_path}")
    print(f"✓ Visualization saved: {plot_path}")
    print(f"✓ Visualization saved: {plot_path}")
    print(f"✓ Visualization saved: {plot_path}")
    print(f"✓ Visualization saved: {plot_path}")
    print(f"✓ Visualization saved: {plot_path}")
    print(f"✓ Visualization saved: {plot_path}")
    print(f"✓ Visualization saved: {plot_path}")

# %% [markdown]
# # ---------- Full pipeline execution ----------
# # ---------- Full pipeline execution ----------
# # ---------- Full pipeline execution ----------
# # ---------- Full pipeline execution ----------
# # ---------- Full pipeline execution ----------
# # ---------- Full pipeline execution ----------
# # ---------- Full pipeline execution ----------
# # ---------- Full pipeline execution ----------
# # ---------- Full pipeline execution ----------
# # ---------- Full pipeline execution ----------
# # ---------- Full pipeline execution ----------
# # ---------- Full pipeline execution ----------
# # ---------- Full pipeline execution ----------
# # ---------- Full pipeline execution ----------
# # ---------- Full pipeline execution ----------
# # ---------- Full pipeline execution ----------
# # ---------- Full pipeline execution ----------
# # ---------- Full pipeline execution ----------
# # ---------- Full pipeline execution ----------
# # ---------- Full pipeline execution ----------
# # ---------- Full pipeline execution ----------
# # ---------- Full pipeline execution ----------
# # ---------- Full pipeline execution ----------
# # ---------- Full pipeline execution ----------
# # ---------- Full pipeline execution ----------
# # ---------- Full pipeline execution ----------
# # ---------- Full pipeline execution ----------
# # ---------- Full pipeline execution ----------
# # ---------- Full pipeline execution ----------
# # ---------- Full pipeline execution ----------
# # ---------- Full pipeline execution ----------
# # ---------- Full pipeline execution ----------
# # ---------- Full pipeline execution ----------
# # ---------- Full pipeline execution ----------
# # ---------- Full pipeline execution ----------
# # ---------- Full pipeline execution ----------
# # ---------- Full pipeline execution ----------

# %%
def run_remove_outliers(input_csv=INPUT_CSV, outdir=OUTDIR, outfile=OUTFILE):
def run_remove_outliers(input_csv=INPUT_CSV, outdir=OUTDIR, outfile=OUTFILE):
def run_remove_outliers(input_csv=INPUT_CSV, outdir=OUTDIR, outfile=OUTFILE):
def run_remove_outliers(input_csv=INPUT_CSV, outdir=OUTDIR, outfile=OUTFILE):
def run_remove_outliers(input_csv=INPUT_CSV, outdir=OUTDIR, outfile=OUTFILE):
def run_remove_outliers(input_csv=INPUT_CSV, outdir=OUTDIR, outfile=OUTFILE):
def run_remove_outliers(input_csv=INPUT_CSV, outdir=OUTDIR, outfile=OUTFILE):
def run_remove_outliers(input_csv=INPUT_CSV, outdir=OUTDIR, outfile=OUTFILE):
def run_remove_outliers(input_csv=INPUT_CSV, outdir=OUTDIR, outfile=OUTFILE):
def run_remove_outliers(input_csv=INPUT_CSV, outdir=OUTDIR, outfile=OUTFILE):
def run_remove_outliers(input_csv=INPUT_CSV, outdir=OUTDIR, outfile=OUTFILE):
def run_remove_outliers(input_csv=INPUT_CSV, outdir=OUTDIR, outfile=OUTFILE):
def run_remove_outliers(input_csv=INPUT_CSV, outdir=OUTDIR, outfile=OUTFILE):
def run_remove_outliers(input_csv=INPUT_CSV, outdir=OUTDIR, outfile=OUTFILE):
def run_remove_outliers(input_csv=INPUT_CSV, outdir=OUTDIR, outfile=OUTFILE):
def run_remove_outliers(input_csv=INPUT_CSV, outdir=OUTDIR, outfile=OUTFILE):
def run_remove_outliers(input_csv=INPUT_CSV, outdir=OUTDIR, outfile=OUTFILE):
def run_remove_outliers(input_csv=INPUT_CSV, outdir=OUTDIR, outfile=OUTFILE):
def run_remove_outliers(input_csv=INPUT_CSV, outdir=OUTDIR, outfile=OUTFILE):
def run_remove_outliers(input_csv=INPUT_CSV, outdir=OUTDIR, outfile=OUTFILE):
def run_remove_outliers(input_csv=INPUT_CSV, outdir=OUTDIR, outfile=OUTFILE):
def run_remove_outliers(input_csv=INPUT_CSV, outdir=OUTDIR, outfile=OUTFILE):
def run_remove_outliers(input_csv=INPUT_CSV, outdir=OUTDIR, outfile=OUTFILE):
def run_remove_outliers(input_csv=INPUT_CSV, outdir=OUTDIR, outfile=OUTFILE):
def run_remove_outliers(input_csv=INPUT_CSV, outdir=OUTDIR, outfile=OUTFILE):
def run_remove_outliers(input_csv=INPUT_CSV, outdir=OUTDIR, outfile=OUTFILE):
def run_remove_outliers(input_csv=INPUT_CSV, outdir=OUTDIR, outfile=OUTFILE):
def run_remove_outliers(input_csv=INPUT_CSV, outdir=OUTDIR, outfile=OUTFILE):
def run_remove_outliers(input_csv=INPUT_CSV, outdir=OUTDIR, outfile=OUTFILE):
def run_remove_outliers(input_csv=INPUT_CSV, outdir=OUTDIR, outfile=OUTFILE):
def run_remove_outliers(input_csv=INPUT_CSV, outdir=OUTDIR, outfile=OUTFILE):
def run_remove_outliers(input_csv=INPUT_CSV, outdir=OUTDIR, outfile=OUTFILE):
def run_remove_outliers(input_csv=INPUT_CSV, outdir=OUTDIR, outfile=OUTFILE):
def run_remove_outliers(input_csv=INPUT_CSV, outdir=OUTDIR, outfile=OUTFILE):
def run_remove_outliers(input_csv=INPUT_CSV, outdir=OUTDIR, outfile=OUTFILE):
def run_remove_outliers(input_csv=INPUT_CSV, outdir=OUTDIR, outfile=OUTFILE):
def run_remove_outliers(input_csv=INPUT_CSV, outdir=OUTDIR, outfile=OUTFILE):
    t0 = time.time()
    t0 = time.time()
    t0 = time.time()
    t0 = time.time()
    t0 = time.time()
    t0 = time.time()
    t0 = time.time()
    t0 = time.time()
    t0 = time.time()
    t0 = time.time()
    t0 = time.time()
    t0 = time.time()
    t0 = time.time()
    t0 = time.time()
    t0 = time.time()
    t0 = time.time()
    t0 = time.time()
    t0 = time.time()
    t0 = time.time()
    t0 = time.time()
    t0 = time.time()
    t0 = time.time()
    t0 = time.time()
    t0 = time.time()
    t0 = time.time()
    t0 = time.time()
    t0 = time.time()
    t0 = time.time()
    t0 = time.time()
    t0 = time.time()
    t0 = time.time()
    t0 = time.time()
    t0 = time.time()
    t0 = time.time()
    t0 = time.time()
    t0 = time.time()
    t0 = time.time()
    pts, df = load_csv_xyz(input_csv)
    pts, df = load_csv_xyz(input_csv)
    pts, df = load_csv_xyz(input_csv)
    pts, df = load_csv_xyz(input_csv)
    pts, df = load_csv_xyz(input_csv)
    pts, df = load_csv_xyz(input_csv)
    pts, df = load_csv_xyz(input_csv)
    pts, df = load_csv_xyz(input_csv)
    pts, df = load_csv_xyz(input_csv)
    pts, df = load_csv_xyz(input_csv)
    pts, df = load_csv_xyz(input_csv)
    pts, df = load_csv_xyz(input_csv)
    pts, df = load_csv_xyz(input_csv)
    pts, df = load_csv_xyz(input_csv)
    pts, df = load_csv_xyz(input_csv)
    pts, df = load_csv_xyz(input_csv)
    pts, df = load_csv_xyz(input_csv)
    pts, df = load_csv_xyz(input_csv)
    pts, df = load_csv_xyz(input_csv)
    pts, df = load_csv_xyz(input_csv)
    pts, df = load_csv_xyz(input_csv)
    pts, df = load_csv_xyz(input_csv)
    pts, df = load_csv_xyz(input_csv)
    pts, df = load_csv_xyz(input_csv)
    pts, df = load_csv_xyz(input_csv)
    pts, df = load_csv_xyz(input_csv)
    pts, df = load_csv_xyz(input_csv)
    pts, df = load_csv_xyz(input_csv)
    pts, df = load_csv_xyz(input_csv)
    pts, df = load_csv_xyz(input_csv)
    pts, df = load_csv_xyz(input_csv)
    pts, df = load_csv_xyz(input_csv)
    pts, df = load_csv_xyz(input_csv)
    pts, df = load_csv_xyz(input_csv)
    pts, df = load_csv_xyz(input_csv)
    pts, df = load_csv_xyz(input_csv)
    pts, df = load_csv_xyz(input_csv)
    n0 = pts.shape[0]
    n0 = pts.shape[0]
    n0 = pts.shape[0]
    n0 = pts.shape[0]
    n0 = pts.shape[0]
    n0 = pts.shape[0]
    n0 = pts.shape[0]
    n0 = pts.shape[0]
    n0 = pts.shape[0]
    n0 = pts.shape[0]
    n0 = pts.shape[0]
    n0 = pts.shape[0]
    n0 = pts.shape[0]
    n0 = pts.shape[0]
    n0 = pts.shape[0]
    n0 = pts.shape[0]
    n0 = pts.shape[0]
    n0 = pts.shape[0]
    n0 = pts.shape[0]
    n0 = pts.shape[0]
    n0 = pts.shape[0]
    n0 = pts.shape[0]
    n0 = pts.shape[0]
    n0 = pts.shape[0]
    n0 = pts.shape[0]
    n0 = pts.shape[0]
    n0 = pts.shape[0]
    n0 = pts.shape[0]
    n0 = pts.shape[0]
    n0 = pts.shape[0]
    n0 = pts.shape[0]
    n0 = pts.shape[0]
    n0 = pts.shape[0]
    n0 = pts.shape[0]
    n0 = pts.shape[0]
    n0 = pts.shape[0]
    n0 = pts.shape[0]
    if VERBOSE: print(f"[RUN] loaded {n0} points from '{input_csv}'")
    if VERBOSE: print(f"[RUN] loaded {n0} points from '{input_csv}'")
    if VERBOSE: print(f"[RUN] loaded {n0} points from '{input_csv}'")
    if VERBOSE: print(f"[RUN] loaded {n0} points from '{input_csv}'")
    if VERBOSE: print(f"[RUN] loaded {n0} points from '{input_csv}'")
    if VERBOSE: print(f"[RUN] loaded {n0} points from '{input_csv}'")
    if VERBOSE: print(f"[RUN] loaded {n0} points from '{input_csv}'")
    if VERBOSE: print(f"[RUN] loaded {n0} points from '{input_csv}'")
    if VERBOSE: print(f"[RUN] loaded {n0} points from '{input_csv}'")
    if VERBOSE: print(f"[RUN] loaded {n0} points from '{input_csv}'")
    if VERBOSE: print(f"[RUN] loaded {n0} points from '{input_csv}'")
    if VERBOSE: print(f"[RUN] loaded {n0} points from '{input_csv}'")
    if VERBOSE: print(f"[RUN] loaded {n0} points from '{input_csv}'")
    if VERBOSE: print(f"[RUN] loaded {n0} points from '{input_csv}'")
    if VERBOSE: print(f"[RUN] loaded {n0} points from '{input_csv}'")
    if VERBOSE: print(f"[RUN] loaded {n0} points from '{input_csv}'")
    if VERBOSE: print(f"[RUN] loaded {n0} points from '{input_csv}'")
    if VERBOSE: print(f"[RUN] loaded {n0} points from '{input_csv}'")
    if VERBOSE: print(f"[RUN] loaded {n0} points from '{input_csv}'")
    if VERBOSE: print(f"[RUN] loaded {n0} points from '{input_csv}'")
    if VERBOSE: print(f"[RUN] loaded {n0} points from '{input_csv}'")
    if VERBOSE: print(f"[RUN] loaded {n0} points from '{input_csv}'")
    if VERBOSE: print(f"[RUN] loaded {n0} points from '{input_csv}'")
    if VERBOSE: print(f"[RUN] loaded {n0} points from '{input_csv}'")
    if VERBOSE: print(f"[RUN] loaded {n0} points from '{input_csv}'")
    if VERBOSE: print(f"[RUN] loaded {n0} points from '{input_csv}'")
    if VERBOSE: print(f"[RUN] loaded {n0} points from '{input_csv}'")
    if VERBOSE: print(f"[RUN] loaded {n0} points from '{input_csv}'")
    if VERBOSE: print(f"[RUN] loaded {n0} points from '{input_csv}'")
    if VERBOSE: print(f"[RUN] loaded {n0} points from '{input_csv}'")
    if VERBOSE: print(f"[RUN] loaded {n0} points from '{input_csv}'")
    if VERBOSE: print(f"[RUN] loaded {n0} points from '{input_csv}'")
    if VERBOSE: print(f"[RUN] loaded {n0} points from '{input_csv}'")
    if VERBOSE: print(f"[RUN] loaded {n0} points from '{input_csv}'")
    if VERBOSE: print(f"[RUN] loaded {n0} points from '{input_csv}'")
    if VERBOSE: print(f"[RUN] loaded {n0} points from '{input_csv}'")
    if VERBOSE: print(f"[RUN] loaded {n0} points from '{input_csv}'")
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    # store original data for plotting
    # store original data for plotting
    # store original data for plotting
    # store original data for plotting
    # store original data for plotting
    # store original data for plotting
    # store original data for plotting
    # store original data for plotting
    # store original data for plotting
    # store original data for plotting
    # store original data for plotting
    # store original data for plotting
    # store original data for plotting
    # store original data for plotting
    # store original data for plotting
    # store original data for plotting
    # store original data for plotting
    # store original data for plotting
    # store original data for plotting
    # store original data for plotting
    # store original data for plotting
    # store original data for plotting
    # store original data for plotting
    # store original data for plotting
    # store original data for plotting
    # store original data for plotting
    # store original data for plotting
    # store original data for plotting
    # store original data for plotting
    # store original data for plotting
    # store original data for plotting
    # store original data for plotting
    # store original data for plotting
    # store original data for plotting
    # store original data for plotting
    # store original data for plotting
    # store original data for plotting
    original_points = pts.copy()
    original_points = pts.copy()
    original_points = pts.copy()
    original_points = pts.copy()
    original_points = pts.copy()
    original_points = pts.copy()
    original_points = pts.copy()
    original_points = pts.copy()
    original_points = pts.copy()
    original_points = pts.copy()
    original_points = pts.copy()
    original_points = pts.copy()
    original_points = pts.copy()
    original_points = pts.copy()
    original_points = pts.copy()
    original_points = pts.copy()
    original_points = pts.copy()
    original_points = pts.copy()
    original_points = pts.copy()
    original_points = pts.copy()
    original_points = pts.copy()
    original_points = pts.copy()
    original_points = pts.copy()
    original_points = pts.copy()
    original_points = pts.copy()
    original_points = pts.copy()
    original_points = pts.copy()
    original_points = pts.copy()
    original_points = pts.copy()
    original_points = pts.copy()
    original_points = pts.copy()
    original_points = pts.copy()
    original_points = pts.copy()
    original_points = pts.copy()
    original_points = pts.copy()
    original_points = pts.copy()
    original_points = pts.copy()
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    # slicing
    # slicing
    # slicing
    # slicing
    # slicing
    # slicing
    # slicing
    # slicing
    # slicing
    # slicing
    # slicing
    # slicing
    # slicing
    # slicing
    # slicing
    # slicing
    # slicing
    # slicing
    # slicing
    # slicing
    # slicing
    # slicing
    # slicing
    # slicing
    # slicing
    # slicing
    # slicing
    # slicing
    # slicing
    # slicing
    # slicing
    # slicing
    # slicing
    # slicing
    # slicing
    # slicing
    # slicing
    slices = adaptive_slicing_indices(pts, axis=BUILD_AXIS)
    slices = adaptive_slicing_indices(pts, axis=BUILD_AXIS)
    slices = adaptive_slicing_indices(pts, axis=BUILD_AXIS)
    slices = adaptive_slicing_indices(pts, axis=BUILD_AXIS)
    slices = adaptive_slicing_indices(pts, axis=BUILD_AXIS)
    slices = adaptive_slicing_indices(pts, axis=BUILD_AXIS)
    slices = adaptive_slicing_indices(pts, axis=BUILD_AXIS)
    slices = adaptive_slicing_indices(pts, axis=BUILD_AXIS)
    slices = adaptive_slicing_indices(pts, axis=BUILD_AXIS)
    slices = adaptive_slicing_indices(pts, axis=BUILD_AXIS)
    slices = adaptive_slicing_indices(pts, axis=BUILD_AXIS)
    slices = adaptive_slicing_indices(pts, axis=BUILD_AXIS)
    slices = adaptive_slicing_indices(pts, axis=BUILD_AXIS)
    slices = adaptive_slicing_indices(pts, axis=BUILD_AXIS)
    slices = adaptive_slicing_indices(pts, axis=BUILD_AXIS)
    slices = adaptive_slicing_indices(pts, axis=BUILD_AXIS)
    slices = adaptive_slicing_indices(pts, axis=BUILD_AXIS)
    slices = adaptive_slicing_indices(pts, axis=BUILD_AXIS)
    slices = adaptive_slicing_indices(pts, axis=BUILD_AXIS)
    slices = adaptive_slicing_indices(pts, axis=BUILD_AXIS)
    slices = adaptive_slicing_indices(pts, axis=BUILD_AXIS)
    slices = adaptive_slicing_indices(pts, axis=BUILD_AXIS)
    slices = adaptive_slicing_indices(pts, axis=BUILD_AXIS)
    slices = adaptive_slicing_indices(pts, axis=BUILD_AXIS)
    slices = adaptive_slicing_indices(pts, axis=BUILD_AXIS)
    slices = adaptive_slicing_indices(pts, axis=BUILD_AXIS)
    slices = adaptive_slicing_indices(pts, axis=BUILD_AXIS)
    slices = adaptive_slicing_indices(pts, axis=BUILD_AXIS)
    slices = adaptive_slicing_indices(pts, axis=BUILD_AXIS)
    slices = adaptive_slicing_indices(pts, axis=BUILD_AXIS)
    slices = adaptive_slicing_indices(pts, axis=BUILD_AXIS)
    slices = adaptive_slicing_indices(pts, axis=BUILD_AXIS)
    slices = adaptive_slicing_indices(pts, axis=BUILD_AXIS)
    slices = adaptive_slicing_indices(pts, axis=BUILD_AXIS)
    slices = adaptive_slicing_indices(pts, axis=BUILD_AXIS)
    slices = adaptive_slicing_indices(pts, axis=BUILD_AXIS)
    slices = adaptive_slicing_indices(pts, axis=BUILD_AXIS)
    if VERBOSE: print(f"[SLICES] generated {len(slices)} layers")
    if VERBOSE: print(f"[SLICES] generated {len(slices)} layers")
    if VERBOSE: print(f"[SLICES] generated {len(slices)} layers")
    if VERBOSE: print(f"[SLICES] generated {len(slices)} layers")
    if VERBOSE: print(f"[SLICES] generated {len(slices)} layers")
    if VERBOSE: print(f"[SLICES] generated {len(slices)} layers")
    if VERBOSE: print(f"[SLICES] generated {len(slices)} layers")
    if VERBOSE: print(f"[SLICES] generated {len(slices)} layers")
    if VERBOSE: print(f"[SLICES] generated {len(slices)} layers")
    if VERBOSE: print(f"[SLICES] generated {len(slices)} layers")
    if VERBOSE: print(f"[SLICES] generated {len(slices)} layers")
    if VERBOSE: print(f"[SLICES] generated {len(slices)} layers")
    if VERBOSE: print(f"[SLICES] generated {len(slices)} layers")
    if VERBOSE: print(f"[SLICES] generated {len(slices)} layers")
    if VERBOSE: print(f"[SLICES] generated {len(slices)} layers")
    if VERBOSE: print(f"[SLICES] generated {len(slices)} layers")
    if VERBOSE: print(f"[SLICES] generated {len(slices)} layers")
    if VERBOSE: print(f"[SLICES] generated {len(slices)} layers")
    if VERBOSE: print(f"[SLICES] generated {len(slices)} layers")
    if VERBOSE: print(f"[SLICES] generated {len(slices)} layers")
    if VERBOSE: print(f"[SLICES] generated {len(slices)} layers")
    if VERBOSE: print(f"[SLICES] generated {len(slices)} layers")
    if VERBOSE: print(f"[SLICES] generated {len(slices)} layers")
    if VERBOSE: print(f"[SLICES] generated {len(slices)} layers")
    if VERBOSE: print(f"[SLICES] generated {len(slices)} layers")
    if VERBOSE: print(f"[SLICES] generated {len(slices)} layers")
    if VERBOSE: print(f"[SLICES] generated {len(slices)} layers")
    if VERBOSE: print(f"[SLICES] generated {len(slices)} layers")
    if VERBOSE: print(f"[SLICES] generated {len(slices)} layers")
    if VERBOSE: print(f"[SLICES] generated {len(slices)} layers")
    if VERBOSE: print(f"[SLICES] generated {len(slices)} layers")
    if VERBOSE: print(f"[SLICES] generated {len(slices)} layers")
    if VERBOSE: print(f"[SLICES] generated {len(slices)} layers")
    if VERBOSE: print(f"[SLICES] generated {len(slices)} layers")
    if VERBOSE: print(f"[SLICES] generated {len(slices)} layers")
    if VERBOSE: print(f"[SLICES] generated {len(slices)} layers")
    if VERBOSE: print(f"[SLICES] generated {len(slices)} layers")
    kept_global_mask = np.zeros(n0, dtype=bool)
    kept_global_mask = np.zeros(n0, dtype=bool)
    kept_global_mask = np.zeros(n0, dtype=bool)
    kept_global_mask = np.zeros(n0, dtype=bool)
    kept_global_mask = np.zeros(n0, dtype=bool)
    kept_global_mask = np.zeros(n0, dtype=bool)
    kept_global_mask = np.zeros(n0, dtype=bool)
    kept_global_mask = np.zeros(n0, dtype=bool)
    kept_global_mask = np.zeros(n0, dtype=bool)
    kept_global_mask = np.zeros(n0, dtype=bool)
    kept_global_mask = np.zeros(n0, dtype=bool)
    kept_global_mask = np.zeros(n0, dtype=bool)
    kept_global_mask = np.zeros(n0, dtype=bool)
    kept_global_mask = np.zeros(n0, dtype=bool)
    kept_global_mask = np.zeros(n0, dtype=bool)
    kept_global_mask = np.zeros(n0, dtype=bool)
    kept_global_mask = np.zeros(n0, dtype=bool)
    kept_global_mask = np.zeros(n0, dtype=bool)
    kept_global_mask = np.zeros(n0, dtype=bool)
    kept_global_mask = np.zeros(n0, dtype=bool)
    kept_global_mask = np.zeros(n0, dtype=bool)
    kept_global_mask = np.zeros(n0, dtype=bool)
    kept_global_mask = np.zeros(n0, dtype=bool)
    kept_global_mask = np.zeros(n0, dtype=bool)
    kept_global_mask = np.zeros(n0, dtype=bool)
    kept_global_mask = np.zeros(n0, dtype=bool)
    kept_global_mask = np.zeros(n0, dtype=bool)
    kept_global_mask = np.zeros(n0, dtype=bool)
    kept_global_mask = np.zeros(n0, dtype=bool)
    kept_global_mask = np.zeros(n0, dtype=bool)
    kept_global_mask = np.zeros(n0, dtype=bool)
    kept_global_mask = np.zeros(n0, dtype=bool)
    kept_global_mask = np.zeros(n0, dtype=bool)
    kept_global_mask = np.zeros(n0, dtype=bool)
    kept_global_mask = np.zeros(n0, dtype=bool)
    kept_global_mask = np.zeros(n0, dtype=bool)
    kept_global_mask = np.zeros(n0, dtype=bool)
    per_slice = []
    per_slice = []
    per_slice = []
    per_slice = []
    per_slice = []
    per_slice = []
    per_slice = []
    per_slice = []
    per_slice = []
    per_slice = []
    per_slice = []
    per_slice = []
    per_slice = []
    per_slice = []
    per_slice = []
    per_slice = []
    per_slice = []
    per_slice = []
    per_slice = []
    per_slice = []
    per_slice = []
    per_slice = []
    per_slice = []
    per_slice = []
    per_slice = []
    per_slice = []
    per_slice = []
    per_slice = []
    per_slice = []
    per_slice = []
    per_slice = []
    per_slice = []
    per_slice = []
    per_slice = []
    per_slice = []
    per_slice = []
    per_slice = []
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    # process each slice: collect kept indices
    # process each slice: collect kept indices
    # process each slice: collect kept indices
    # process each slice: collect kept indices
    # process each slice: collect kept indices
    # process each slice: collect kept indices
    # process each slice: collect kept indices
    # process each slice: collect kept indices
    # process each slice: collect kept indices
    # process each slice: collect kept indices
    # process each slice: collect kept indices
    # process each slice: collect kept indices
    # process each slice: collect kept indices
    # process each slice: collect kept indices
    # process each slice: collect kept indices
    # process each slice: collect kept indices
    # process each slice: collect kept indices
    # process each slice: collect kept indices
    # process each slice: collect kept indices
    # process each slice: collect kept indices
    # process each slice: collect kept indices
    # process each slice: collect kept indices
    # process each slice: collect kept indices
    # process each slice: collect kept indices
    # process each slice: collect kept indices
    # process each slice: collect kept indices
    # process each slice: collect kept indices
    # process each slice: collect kept indices
    # process each slice: collect kept indices
    # process each slice: collect kept indices
    # process each slice: collect kept indices
    # process each slice: collect kept indices
    # process each slice: collect kept indices
    # process each slice: collect kept indices
    # process each slice: collect kept indices
    # process each slice: collect kept indices
    # process each slice: collect kept indices
    for i,(idxs, mid) in enumerate(slices, start=1):
    for i,(idxs, mid) in enumerate(slices, start=1):
    for i,(idxs, mid) in enumerate(slices, start=1):
    for i,(idxs, mid) in enumerate(slices, start=1):
    for i,(idxs, mid) in enumerate(slices, start=1):
    for i,(idxs, mid) in enumerate(slices, start=1):
    for i,(idxs, mid) in enumerate(slices, start=1):
    for i,(idxs, mid) in enumerate(slices, start=1):
    for i,(idxs, mid) in enumerate(slices, start=1):
    for i,(idxs, mid) in enumerate(slices, start=1):
    for i,(idxs, mid) in enumerate(slices, start=1):
    for i,(idxs, mid) in enumerate(slices, start=1):
    for i,(idxs, mid) in enumerate(slices, start=1):
    for i,(idxs, mid) in enumerate(slices, start=1):
    for i,(idxs, mid) in enumerate(slices, start=1):
    for i,(idxs, mid) in enumerate(slices, start=1):
    for i,(idxs, mid) in enumerate(slices, start=1):
    for i,(idxs, mid) in enumerate(slices, start=1):
    for i,(idxs, mid) in enumerate(slices, start=1):
    for i,(idxs, mid) in enumerate(slices, start=1):
    for i,(idxs, mid) in enumerate(slices, start=1):
    for i,(idxs, mid) in enumerate(slices, start=1):
    for i,(idxs, mid) in enumerate(slices, start=1):
    for i,(idxs, mid) in enumerate(slices, start=1):
    for i,(idxs, mid) in enumerate(slices, start=1):
    for i,(idxs, mid) in enumerate(slices, start=1):
    for i,(idxs, mid) in enumerate(slices, start=1):
    for i,(idxs, mid) in enumerate(slices, start=1):
    for i,(idxs, mid) in enumerate(slices, start=1):
    for i,(idxs, mid) in enumerate(slices, start=1):
    for i,(idxs, mid) in enumerate(slices, start=1):
    for i,(idxs, mid) in enumerate(slices, start=1):
    for i,(idxs, mid) in enumerate(slices, start=1):
    for i,(idxs, mid) in enumerate(slices, start=1):
    for i,(idxs, mid) in enumerate(slices, start=1):
    for i,(idxs, mid) in enumerate(slices, start=1):
    for i,(idxs, mid) in enumerate(slices, start=1):
        kept_idxs, info = process_slice_keep_indices(idxs, pts, BUILD_AXIS, mid)
        kept_idxs, info = process_slice_keep_indices(idxs, pts, BUILD_AXIS, mid)
        kept_idxs, info = process_slice_keep_indices(idxs, pts, BUILD_AXIS, mid)
        kept_idxs, info = process_slice_keep_indices(idxs, pts, BUILD_AXIS, mid)
        kept_idxs, info = process_slice_keep_indices(idxs, pts, BUILD_AXIS, mid)
        kept_idxs, info = process_slice_keep_indices(idxs, pts, BUILD_AXIS, mid)
        kept_idxs, info = process_slice_keep_indices(idxs, pts, BUILD_AXIS, mid)
        kept_idxs, info = process_slice_keep_indices(idxs, pts, BUILD_AXIS, mid)
        kept_idxs, info = process_slice_keep_indices(idxs, pts, BUILD_AXIS, mid)
        kept_idxs, info = process_slice_keep_indices(idxs, pts, BUILD_AXIS, mid)
        kept_idxs, info = process_slice_keep_indices(idxs, pts, BUILD_AXIS, mid)
        kept_idxs, info = process_slice_keep_indices(idxs, pts, BUILD_AXIS, mid)
        kept_idxs, info = process_slice_keep_indices(idxs, pts, BUILD_AXIS, mid)
        kept_idxs, info = process_slice_keep_indices(idxs, pts, BUILD_AXIS, mid)
        kept_idxs, info = process_slice_keep_indices(idxs, pts, BUILD_AXIS, mid)
        kept_idxs, info = process_slice_keep_indices(idxs, pts, BUILD_AXIS, mid)
        kept_idxs, info = process_slice_keep_indices(idxs, pts, BUILD_AXIS, mid)
        kept_idxs, info = process_slice_keep_indices(idxs, pts, BUILD_AXIS, mid)
        kept_idxs, info = process_slice_keep_indices(idxs, pts, BUILD_AXIS, mid)
        kept_idxs, info = process_slice_keep_indices(idxs, pts, BUILD_AXIS, mid)
        kept_idxs, info = process_slice_keep_indices(idxs, pts, BUILD_AXIS, mid)
        kept_idxs, info = process_slice_keep_indices(idxs, pts, BUILD_AXIS, mid)
        kept_idxs, info = process_slice_keep_indices(idxs, pts, BUILD_AXIS, mid)
        kept_idxs, info = process_slice_keep_indices(idxs, pts, BUILD_AXIS, mid)
        kept_idxs, info = process_slice_keep_indices(idxs, pts, BUILD_AXIS, mid)
        kept_idxs, info = process_slice_keep_indices(idxs, pts, BUILD_AXIS, mid)
        kept_idxs, info = process_slice_keep_indices(idxs, pts, BUILD_AXIS, mid)
        kept_idxs, info = process_slice_keep_indices(idxs, pts, BUILD_AXIS, mid)
        kept_idxs, info = process_slice_keep_indices(idxs, pts, BUILD_AXIS, mid)
        kept_idxs, info = process_slice_keep_indices(idxs, pts, BUILD_AXIS, mid)
        kept_idxs, info = process_slice_keep_indices(idxs, pts, BUILD_AXIS, mid)
        kept_idxs, info = process_slice_keep_indices(idxs, pts, BUILD_AXIS, mid)
        kept_idxs, info = process_slice_keep_indices(idxs, pts, BUILD_AXIS, mid)
        kept_idxs, info = process_slice_keep_indices(idxs, pts, BUILD_AXIS, mid)
        kept_idxs, info = process_slice_keep_indices(idxs, pts, BUILD_AXIS, mid)
        kept_idxs, info = process_slice_keep_indices(idxs, pts, BUILD_AXIS, mid)
        kept_idxs, info = process_slice_keep_indices(idxs, pts, BUILD_AXIS, mid)
        kept_global_mask[kept_idxs] = True
        kept_global_mask[kept_idxs] = True
        kept_global_mask[kept_idxs] = True
        kept_global_mask[kept_idxs] = True
        kept_global_mask[kept_idxs] = True
        kept_global_mask[kept_idxs] = True
        kept_global_mask[kept_idxs] = True
        kept_global_mask[kept_idxs] = True
        kept_global_mask[kept_idxs] = True
        kept_global_mask[kept_idxs] = True
        kept_global_mask[kept_idxs] = True
        kept_global_mask[kept_idxs] = True
        kept_global_mask[kept_idxs] = True
        kept_global_mask[kept_idxs] = True
        kept_global_mask[kept_idxs] = True
        kept_global_mask[kept_idxs] = True
        kept_global_mask[kept_idxs] = True
        kept_global_mask[kept_idxs] = True
        kept_global_mask[kept_idxs] = True
        kept_global_mask[kept_idxs] = True
        kept_global_mask[kept_idxs] = True
        kept_global_mask[kept_idxs] = True
        kept_global_mask[kept_idxs] = True
        kept_global_mask[kept_idxs] = True
        kept_global_mask[kept_idxs] = True
        kept_global_mask[kept_idxs] = True
        kept_global_mask[kept_idxs] = True
        kept_global_mask[kept_idxs] = True
        kept_global_mask[kept_idxs] = True
        kept_global_mask[kept_idxs] = True
        kept_global_mask[kept_idxs] = True
        kept_global_mask[kept_idxs] = True
        kept_global_mask[kept_idxs] = True
        kept_global_mask[kept_idxs] = True
        kept_global_mask[kept_idxs] = True
        kept_global_mask[kept_idxs] = True
        kept_global_mask[kept_idxs] = True
        info['slice_idx'] = i
        info['slice_idx'] = i
        info['slice_idx'] = i
        info['slice_idx'] = i
        info['slice_idx'] = i
        info['slice_idx'] = i
        info['slice_idx'] = i
        info['slice_idx'] = i
        info['slice_idx'] = i
        info['slice_idx'] = i
        info['slice_idx'] = i
        info['slice_idx'] = i
        info['slice_idx'] = i
        info['slice_idx'] = i
        info['slice_idx'] = i
        info['slice_idx'] = i
        info['slice_idx'] = i
        info['slice_idx'] = i
        info['slice_idx'] = i
        info['slice_idx'] = i
        info['slice_idx'] = i
        info['slice_idx'] = i
        info['slice_idx'] = i
        info['slice_idx'] = i
        info['slice_idx'] = i
        info['slice_idx'] = i
        info['slice_idx'] = i
        info['slice_idx'] = i
        info['slice_idx'] = i
        info['slice_idx'] = i
        info['slice_idx'] = i
        info['slice_idx'] = i
        info['slice_idx'] = i
        info['slice_idx'] = i
        info['slice_idx'] = i
        info['slice_idx'] = i
        info['slice_idx'] = i
        info['n_in_slice'] = int(len(idxs))
        info['n_in_slice'] = int(len(idxs))
        info['n_in_slice'] = int(len(idxs))
        info['n_in_slice'] = int(len(idxs))
        info['n_in_slice'] = int(len(idxs))
        info['n_in_slice'] = int(len(idxs))
        info['n_in_slice'] = int(len(idxs))
        info['n_in_slice'] = int(len(idxs))
        info['n_in_slice'] = int(len(idxs))
        info['n_in_slice'] = int(len(idxs))
        info['n_in_slice'] = int(len(idxs))
        info['n_in_slice'] = int(len(idxs))
        info['n_in_slice'] = int(len(idxs))
        info['n_in_slice'] = int(len(idxs))
        info['n_in_slice'] = int(len(idxs))
        info['n_in_slice'] = int(len(idxs))
        info['n_in_slice'] = int(len(idxs))
        info['n_in_slice'] = int(len(idxs))
        info['n_in_slice'] = int(len(idxs))
        info['n_in_slice'] = int(len(idxs))
        info['n_in_slice'] = int(len(idxs))
        info['n_in_slice'] = int(len(idxs))
        info['n_in_slice'] = int(len(idxs))
        info['n_in_slice'] = int(len(idxs))
        info['n_in_slice'] = int(len(idxs))
        info['n_in_slice'] = int(len(idxs))
        info['n_in_slice'] = int(len(idxs))
        info['n_in_slice'] = int(len(idxs))
        info['n_in_slice'] = int(len(idxs))
        info['n_in_slice'] = int(len(idxs))
        info['n_in_slice'] = int(len(idxs))
        info['n_in_slice'] = int(len(idxs))
        info['n_in_slice'] = int(len(idxs))
        info['n_in_slice'] = int(len(idxs))
        info['n_in_slice'] = int(len(idxs))
        info['n_in_slice'] = int(len(idxs))
        info['n_in_slice'] = int(len(idxs))
        # verify required keys exist
        # verify required keys exist
        # verify required keys exist
        # verify required keys exist
        # verify required keys exist
        # verify required keys exist
        # verify required keys exist
        # verify required keys exist
        # verify required keys exist
        # verify required keys exist
        # verify required keys exist
        # verify required keys exist
        # verify required keys exist
        # verify required keys exist
        # verify required keys exist
        # verify required keys exist
        # verify required keys exist
        # verify required keys exist
        # verify required keys exist
        # verify required keys exist
        # verify required keys exist
        # verify required keys exist
        # verify required keys exist
        # verify required keys exist
        # verify required keys exist
        # verify required keys exist
        # verify required keys exist
        # verify required keys exist
        # verify required keys exist
        # verify required keys exist
        # verify required keys exist
        # verify required keys exist
        # verify required keys exist
        # verify required keys exist
        # verify required keys exist
        # verify required keys exist
        # verify required keys exist
        if 'kept' not in info:
        if 'kept' not in info:
        if 'kept' not in info:
        if 'kept' not in info:
        if 'kept' not in info:
        if 'kept' not in info:
        if 'kept' not in info:
        if 'kept' not in info:
        if 'kept' not in info:
        if 'kept' not in info:
        if 'kept' not in info:
        if 'kept' not in info:
        if 'kept' not in info:
        if 'kept' not in info:
        if 'kept' not in info:
        if 'kept' not in info:
        if 'kept' not in info:
        if 'kept' not in info:
        if 'kept' not in info:
        if 'kept' not in info:
        if 'kept' not in info:
        if 'kept' not in info:
        if 'kept' not in info:
        if 'kept' not in info:
        if 'kept' not in info:
        if 'kept' not in info:
        if 'kept' not in info:
        if 'kept' not in info:
        if 'kept' not in info:
        if 'kept' not in info:
        if 'kept' not in info:
        if 'kept' not in info:
        if 'kept' not in info:
        if 'kept' not in info:
        if 'kept' not in info:
        if 'kept' not in info:
        if 'kept' not in info:
            info['kept'] = len(kept_idxs)
            info['kept'] = len(kept_idxs)
            info['kept'] = len(kept_idxs)
            info['kept'] = len(kept_idxs)
            info['kept'] = len(kept_idxs)
            info['kept'] = len(kept_idxs)
            info['kept'] = len(kept_idxs)
            info['kept'] = len(kept_idxs)
            info['kept'] = len(kept_idxs)
            info['kept'] = len(kept_idxs)
            info['kept'] = len(kept_idxs)
            info['kept'] = len(kept_idxs)
            info['kept'] = len(kept_idxs)
            info['kept'] = len(kept_idxs)
            info['kept'] = len(kept_idxs)
            info['kept'] = len(kept_idxs)
            info['kept'] = len(kept_idxs)
            info['kept'] = len(kept_idxs)
            info['kept'] = len(kept_idxs)
            info['kept'] = len(kept_idxs)
            info['kept'] = len(kept_idxs)
            info['kept'] = len(kept_idxs)
            info['kept'] = len(kept_idxs)
            info['kept'] = len(kept_idxs)
            info['kept'] = len(kept_idxs)
            info['kept'] = len(kept_idxs)
            info['kept'] = len(kept_idxs)
            info['kept'] = len(kept_idxs)
            info['kept'] = len(kept_idxs)
            info['kept'] = len(kept_idxs)
            info['kept'] = len(kept_idxs)
            info['kept'] = len(kept_idxs)
            info['kept'] = len(kept_idxs)
            info['kept'] = len(kept_idxs)
            info['kept'] = len(kept_idxs)
            info['kept'] = len(kept_idxs)
            info['kept'] = len(kept_idxs)
        if 'removed' not in info:
        if 'removed' not in info:
        if 'removed' not in info:
        if 'removed' not in info:
        if 'removed' not in info:
        if 'removed' not in info:
        if 'removed' not in info:
        if 'removed' not in info:
        if 'removed' not in info:
        if 'removed' not in info:
        if 'removed' not in info:
        if 'removed' not in info:
        if 'removed' not in info:
        if 'removed' not in info:
        if 'removed' not in info:
        if 'removed' not in info:
        if 'removed' not in info:
        if 'removed' not in info:
        if 'removed' not in info:
        if 'removed' not in info:
        if 'removed' not in info:
        if 'removed' not in info:
        if 'removed' not in info:
        if 'removed' not in info:
        if 'removed' not in info:
        if 'removed' not in info:
        if 'removed' not in info:
        if 'removed' not in info:
        if 'removed' not in info:
        if 'removed' not in info:
        if 'removed' not in info:
        if 'removed' not in info:
        if 'removed' not in info:
        if 'removed' not in info:
        if 'removed' not in info:
        if 'removed' not in info:
        if 'removed' not in info:
            info['removed'] = info['n_in_slice'] - info['kept']
            info['removed'] = info['n_in_slice'] - info['kept']
            info['removed'] = info['n_in_slice'] - info['kept']
            info['removed'] = info['n_in_slice'] - info['kept']
            info['removed'] = info['n_in_slice'] - info['kept']
            info['removed'] = info['n_in_slice'] - info['kept']
            info['removed'] = info['n_in_slice'] - info['kept']
            info['removed'] = info['n_in_slice'] - info['kept']
            info['removed'] = info['n_in_slice'] - info['kept']
            info['removed'] = info['n_in_slice'] - info['kept']
            info['removed'] = info['n_in_slice'] - info['kept']
            info['removed'] = info['n_in_slice'] - info['kept']
            info['removed'] = info['n_in_slice'] - info['kept']
            info['removed'] = info['n_in_slice'] - info['kept']
            info['removed'] = info['n_in_slice'] - info['kept']
            info['removed'] = info['n_in_slice'] - info['kept']
            info['removed'] = info['n_in_slice'] - info['kept']
            info['removed'] = info['n_in_slice'] - info['kept']
            info['removed'] = info['n_in_slice'] - info['kept']
            info['removed'] = info['n_in_slice'] - info['kept']
            info['removed'] = info['n_in_slice'] - info['kept']
            info['removed'] = info['n_in_slice'] - info['kept']
            info['removed'] = info['n_in_slice'] - info['kept']
            info['removed'] = info['n_in_slice'] - info['kept']
            info['removed'] = info['n_in_slice'] - info['kept']
            info['removed'] = info['n_in_slice'] - info['kept']
            info['removed'] = info['n_in_slice'] - info['kept']
            info['removed'] = info['n_in_slice'] - info['kept']
            info['removed'] = info['n_in_slice'] - info['kept']
            info['removed'] = info['n_in_slice'] - info['kept']
            info['removed'] = info['n_in_slice'] - info['kept']
            info['removed'] = info['n_in_slice'] - info['kept']
            info['removed'] = info['n_in_slice'] - info['kept']
            info['removed'] = info['n_in_slice'] - info['kept']
            info['removed'] = info['n_in_slice'] - info['kept']
            info['removed'] = info['n_in_slice'] - info['kept']
            info['removed'] = info['n_in_slice'] - info['kept']
        per_slice.append(info)
        per_slice.append(info)
        per_slice.append(info)
        per_slice.append(info)
        per_slice.append(info)
        per_slice.append(info)
        per_slice.append(info)
        per_slice.append(info)
        per_slice.append(info)
        per_slice.append(info)
        per_slice.append(info)
        per_slice.append(info)
        per_slice.append(info)
        per_slice.append(info)
        per_slice.append(info)
        per_slice.append(info)
        per_slice.append(info)
        per_slice.append(info)
        per_slice.append(info)
        per_slice.append(info)
        per_slice.append(info)
        per_slice.append(info)
        per_slice.append(info)
        per_slice.append(info)
        per_slice.append(info)
        per_slice.append(info)
        per_slice.append(info)
        per_slice.append(info)
        per_slice.append(info)
        per_slice.append(info)
        per_slice.append(info)
        per_slice.append(info)
        per_slice.append(info)
        per_slice.append(info)
        per_slice.append(info)
        per_slice.append(info)
        per_slice.append(info)
        if VERBOSE:
        if VERBOSE:
        if VERBOSE:
        if VERBOSE:
        if VERBOSE:
        if VERBOSE:
        if VERBOSE:
        if VERBOSE:
        if VERBOSE:
        if VERBOSE:
        if VERBOSE:
        if VERBOSE:
        if VERBOSE:
        if VERBOSE:
        if VERBOSE:
        if VERBOSE:
        if VERBOSE:
        if VERBOSE:
        if VERBOSE:
        if VERBOSE:
        if VERBOSE:
        if VERBOSE:
        if VERBOSE:
        if VERBOSE:
        if VERBOSE:
        if VERBOSE:
        if VERBOSE:
        if VERBOSE:
        if VERBOSE:
        if VERBOSE:
        if VERBOSE:
        if VERBOSE:
        if VERBOSE:
        if VERBOSE:
        if VERBOSE:
        if VERBOSE:
        if VERBOSE:
            print(f"[SLICE {i}] in={len(idxs):4d} kept={info.get('kept', len(kept_idxs)):4d} removed={info.get('removed', 0):4d} bw={info.get('band_width', 0):.4g}")
            print(f"[SLICE {i}] in={len(idxs):4d} kept={info.get('kept', len(kept_idxs)):4d} removed={info.get('removed', 0):4d} bw={info.get('band_width', 0):.4g}")
            print(f"[SLICE {i}] in={len(idxs):4d} kept={info.get('kept', len(kept_idxs)):4d} removed={info.get('removed', 0):4d} bw={info.get('band_width', 0):.4g}")
            print(f"[SLICE {i}] in={len(idxs):4d} kept={info.get('kept', len(kept_idxs)):4d} removed={info.get('removed', 0):4d} bw={info.get('band_width', 0):.4g}")
            print(f"[SLICE {i}] in={len(idxs):4d} kept={info.get('kept', len(kept_idxs)):4d} removed={info.get('removed', 0):4d} bw={info.get('band_width', 0):.4g}")
            print(f"[SLICE {i}] in={len(idxs):4d} kept={info.get('kept', len(kept_idxs)):4d} removed={info.get('removed', 0):4d} bw={info.get('band_width', 0):.4g}")
            print(f"[SLICE {i}] in={len(idxs):4d} kept={info.get('kept', len(kept_idxs)):4d} removed={info.get('removed', 0):4d} bw={info.get('band_width', 0):.4g}")
            print(f"[SLICE {i}] in={len(idxs):4d} kept={info.get('kept', len(kept_idxs)):4d} removed={info.get('removed', 0):4d} bw={info.get('band_width', 0):.4g}")
            print(f"[SLICE {i}] in={len(idxs):4d} kept={info.get('kept', len(kept_idxs)):4d} removed={info.get('removed', 0):4d} bw={info.get('band_width', 0):.4g}")
            print(f"[SLICE {i}] in={len(idxs):4d} kept={info.get('kept', len(kept_idxs)):4d} removed={info.get('removed', 0):4d} bw={info.get('band_width', 0):.4g}")
            print(f"[SLICE {i}] in={len(idxs):4d} kept={info.get('kept', len(kept_idxs)):4d} removed={info.get('removed', 0):4d} bw={info.get('band_width', 0):.4g}")
            print(f"[SLICE {i}] in={len(idxs):4d} kept={info.get('kept', len(kept_idxs)):4d} removed={info.get('removed', 0):4d} bw={info.get('band_width', 0):.4g}")
            print(f"[SLICE {i}] in={len(idxs):4d} kept={info.get('kept', len(kept_idxs)):4d} removed={info.get('removed', 0):4d} bw={info.get('band_width', 0):.4g}")
            print(f"[SLICE {i}] in={len(idxs):4d} kept={info.get('kept', len(kept_idxs)):4d} removed={info.get('removed', 0):4d} bw={info.get('band_width', 0):.4g}")
            print(f"[SLICE {i}] in={len(idxs):4d} kept={info.get('kept', len(kept_idxs)):4d} removed={info.get('removed', 0):4d} bw={info.get('band_width', 0):.4g}")
            print(f"[SLICE {i}] in={len(idxs):4d} kept={info.get('kept', len(kept_idxs)):4d} removed={info.get('removed', 0):4d} bw={info.get('band_width', 0):.4g}")
            print(f"[SLICE {i}] in={len(idxs):4d} kept={info.get('kept', len(kept_idxs)):4d} removed={info.get('removed', 0):4d} bw={info.get('band_width', 0):.4g}")
            print(f"[SLICE {i}] in={len(idxs):4d} kept={info.get('kept', len(kept_idxs)):4d} removed={info.get('removed', 0):4d} bw={info.get('band_width', 0):.4g}")
            print(f"[SLICE {i}] in={len(idxs):4d} kept={info.get('kept', len(kept_idxs)):4d} removed={info.get('removed', 0):4d} bw={info.get('band_width', 0):.4g}")
            print(f"[SLICE {i}] in={len(idxs):4d} kept={info.get('kept', len(kept_idxs)):4d} removed={info.get('removed', 0):4d} bw={info.get('band_width', 0):.4g}")
            print(f"[SLICE {i}] in={len(idxs):4d} kept={info.get('kept', len(kept_idxs)):4d} removed={info.get('removed', 0):4d} bw={info.get('band_width', 0):.4g}")
            print(f"[SLICE {i}] in={len(idxs):4d} kept={info.get('kept', len(kept_idxs)):4d} removed={info.get('removed', 0):4d} bw={info.get('band_width', 0):.4g}")
            print(f"[SLICE {i}] in={len(idxs):4d} kept={info.get('kept', len(kept_idxs)):4d} removed={info.get('removed', 0):4d} bw={info.get('band_width', 0):.4g}")
            print(f"[SLICE {i}] in={len(idxs):4d} kept={info.get('kept', len(kept_idxs)):4d} removed={info.get('removed', 0):4d} bw={info.get('band_width', 0):.4g}")
            print(f"[SLICE {i}] in={len(idxs):4d} kept={info.get('kept', len(kept_idxs)):4d} removed={info.get('removed', 0):4d} bw={info.get('band_width', 0):.4g}")
            print(f"[SLICE {i}] in={len(idxs):4d} kept={info.get('kept', len(kept_idxs)):4d} removed={info.get('removed', 0):4d} bw={info.get('band_width', 0):.4g}")
            print(f"[SLICE {i}] in={len(idxs):4d} kept={info.get('kept', len(kept_idxs)):4d} removed={info.get('removed', 0):4d} bw={info.get('band_width', 0):.4g}")
            print(f"[SLICE {i}] in={len(idxs):4d} kept={info.get('kept', len(kept_idxs)):4d} removed={info.get('removed', 0):4d} bw={info.get('band_width', 0):.4g}")
            print(f"[SLICE {i}] in={len(idxs):4d} kept={info.get('kept', len(kept_idxs)):4d} removed={info.get('removed', 0):4d} bw={info.get('band_width', 0):.4g}")
            print(f"[SLICE {i}] in={len(idxs):4d} kept={info.get('kept', len(kept_idxs)):4d} removed={info.get('removed', 0):4d} bw={info.get('band_width', 0):.4g}")
            print(f"[SLICE {i}] in={len(idxs):4d} kept={info.get('kept', len(kept_idxs)):4d} removed={info.get('removed', 0):4d} bw={info.get('band_width', 0):.4g}")
            print(f"[SLICE {i}] in={len(idxs):4d} kept={info.get('kept', len(kept_idxs)):4d} removed={info.get('removed', 0):4d} bw={info.get('band_width', 0):.4g}")
            print(f"[SLICE {i}] in={len(idxs):4d} kept={info.get('kept', len(kept_idxs)):4d} removed={info.get('removed', 0):4d} bw={info.get('band_width', 0):.4g}")
            print(f"[SLICE {i}] in={len(idxs):4d} kept={info.get('kept', len(kept_idxs)):4d} removed={info.get('removed', 0):4d} bw={info.get('band_width', 0):.4g}")
            print(f"[SLICE {i}] in={len(idxs):4d} kept={info.get('kept', len(kept_idxs)):4d} removed={info.get('removed', 0):4d} bw={info.get('band_width', 0):.4g}")
            print(f"[SLICE {i}] in={len(idxs):4d} kept={info.get('kept', len(kept_idxs)):4d} removed={info.get('removed', 0):4d} bw={info.get('band_width', 0):.4g}")
            print(f"[SLICE {i}] in={len(idxs):4d} kept={info.get('kept', len(kept_idxs)):4d} removed={info.get('removed', 0):4d} bw={info.get('band_width', 0):.4g}")
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    # points not kept in any slice => remove
    # points not kept in any slice => remove
    # points not kept in any slice => remove
    # points not kept in any slice => remove
    # points not kept in any slice => remove
    # points not kept in any slice => remove
    # points not kept in any slice => remove
    # points not kept in any slice => remove
    # points not kept in any slice => remove
    # points not kept in any slice => remove
    # points not kept in any slice => remove
    # points not kept in any slice => remove
    # points not kept in any slice => remove
    # points not kept in any slice => remove
    # points not kept in any slice => remove
    # points not kept in any slice => remove
    # points not kept in any slice => remove
    # points not kept in any slice => remove
    # points not kept in any slice => remove
    # points not kept in any slice => remove
    # points not kept in any slice => remove
    # points not kept in any slice => remove
    # points not kept in any slice => remove
    # points not kept in any slice => remove
    # points not kept in any slice => remove
    # points not kept in any slice => remove
    # points not kept in any slice => remove
    # points not kept in any slice => remove
    # points not kept in any slice => remove
    # points not kept in any slice => remove
    # points not kept in any slice => remove
    # points not kept in any slice => remove
    # points not kept in any slice => remove
    # points not kept in any slice => remove
    # points not kept in any slice => remove
    # points not kept in any slice => remove
    # points not kept in any slice => remove
    kept_indices_initial = np.where(kept_global_mask)[0]
    kept_indices_initial = np.where(kept_global_mask)[0]
    kept_indices_initial = np.where(kept_global_mask)[0]
    kept_indices_initial = np.where(kept_global_mask)[0]
    kept_indices_initial = np.where(kept_global_mask)[0]
    kept_indices_initial = np.where(kept_global_mask)[0]
    kept_indices_initial = np.where(kept_global_mask)[0]
    kept_indices_initial = np.where(kept_global_mask)[0]
    kept_indices_initial = np.where(kept_global_mask)[0]
    kept_indices_initial = np.where(kept_global_mask)[0]
    kept_indices_initial = np.where(kept_global_mask)[0]
    kept_indices_initial = np.where(kept_global_mask)[0]
    kept_indices_initial = np.where(kept_global_mask)[0]
    kept_indices_initial = np.where(kept_global_mask)[0]
    kept_indices_initial = np.where(kept_global_mask)[0]
    kept_indices_initial = np.where(kept_global_mask)[0]
    kept_indices_initial = np.where(kept_global_mask)[0]
    kept_indices_initial = np.where(kept_global_mask)[0]
    kept_indices_initial = np.where(kept_global_mask)[0]
    kept_indices_initial = np.where(kept_global_mask)[0]
    kept_indices_initial = np.where(kept_global_mask)[0]
    kept_indices_initial = np.where(kept_global_mask)[0]
    kept_indices_initial = np.where(kept_global_mask)[0]
    kept_indices_initial = np.where(kept_global_mask)[0]
    kept_indices_initial = np.where(kept_global_mask)[0]
    kept_indices_initial = np.where(kept_global_mask)[0]
    kept_indices_initial = np.where(kept_global_mask)[0]
    kept_indices_initial = np.where(kept_global_mask)[0]
    kept_indices_initial = np.where(kept_global_mask)[0]
    kept_indices_initial = np.where(kept_global_mask)[0]
    kept_indices_initial = np.where(kept_global_mask)[0]
    kept_indices_initial = np.where(kept_global_mask)[0]
    kept_indices_initial = np.where(kept_global_mask)[0]
    kept_indices_initial = np.where(kept_global_mask)[0]
    kept_indices_initial = np.where(kept_global_mask)[0]
    kept_indices_initial = np.where(kept_global_mask)[0]
    kept_indices_initial = np.where(kept_global_mask)[0]
    pts_kept_initial = pts[kept_indices_initial]
    pts_kept_initial = pts[kept_indices_initial]
    pts_kept_initial = pts[kept_indices_initial]
    pts_kept_initial = pts[kept_indices_initial]
    pts_kept_initial = pts[kept_indices_initial]
    pts_kept_initial = pts[kept_indices_initial]
    pts_kept_initial = pts[kept_indices_initial]
    pts_kept_initial = pts[kept_indices_initial]
    pts_kept_initial = pts[kept_indices_initial]
    pts_kept_initial = pts[kept_indices_initial]
    pts_kept_initial = pts[kept_indices_initial]
    pts_kept_initial = pts[kept_indices_initial]
    pts_kept_initial = pts[kept_indices_initial]
    pts_kept_initial = pts[kept_indices_initial]
    pts_kept_initial = pts[kept_indices_initial]
    pts_kept_initial = pts[kept_indices_initial]
    pts_kept_initial = pts[kept_indices_initial]
    pts_kept_initial = pts[kept_indices_initial]
    pts_kept_initial = pts[kept_indices_initial]
    pts_kept_initial = pts[kept_indices_initial]
    pts_kept_initial = pts[kept_indices_initial]
    pts_kept_initial = pts[kept_indices_initial]
    pts_kept_initial = pts[kept_indices_initial]
    pts_kept_initial = pts[kept_indices_initial]
    pts_kept_initial = pts[kept_indices_initial]
    pts_kept_initial = pts[kept_indices_initial]
    pts_kept_initial = pts[kept_indices_initial]
    pts_kept_initial = pts[kept_indices_initial]
    pts_kept_initial = pts[kept_indices_initial]
    pts_kept_initial = pts[kept_indices_initial]
    pts_kept_initial = pts[kept_indices_initial]
    pts_kept_initial = pts[kept_indices_initial]
    pts_kept_initial = pts[kept_indices_initial]
    pts_kept_initial = pts[kept_indices_initial]
    pts_kept_initial = pts[kept_indices_initial]
    pts_kept_initial = pts[kept_indices_initial]
    pts_kept_initial = pts[kept_indices_initial]
    if VERBOSE: print(f"[STEP] kept after per-slice decision: {len(kept_indices_initial)} / {n0}")
    if VERBOSE: print(f"[STEP] kept after per-slice decision: {len(kept_indices_initial)} / {n0}")
    if VERBOSE: print(f"[STEP] kept after per-slice decision: {len(kept_indices_initial)} / {n0}")
    if VERBOSE: print(f"[STEP] kept after per-slice decision: {len(kept_indices_initial)} / {n0}")
    if VERBOSE: print(f"[STEP] kept after per-slice decision: {len(kept_indices_initial)} / {n0}")
    if VERBOSE: print(f"[STEP] kept after per-slice decision: {len(kept_indices_initial)} / {n0}")
    if VERBOSE: print(f"[STEP] kept after per-slice decision: {len(kept_indices_initial)} / {n0}")
    if VERBOSE: print(f"[STEP] kept after per-slice decision: {len(kept_indices_initial)} / {n0}")
    if VERBOSE: print(f"[STEP] kept after per-slice decision: {len(kept_indices_initial)} / {n0}")
    if VERBOSE: print(f"[STEP] kept after per-slice decision: {len(kept_indices_initial)} / {n0}")
    if VERBOSE: print(f"[STEP] kept after per-slice decision: {len(kept_indices_initial)} / {n0}")
    if VERBOSE: print(f"[STEP] kept after per-slice decision: {len(kept_indices_initial)} / {n0}")
    if VERBOSE: print(f"[STEP] kept after per-slice decision: {len(kept_indices_initial)} / {n0}")
    if VERBOSE: print(f"[STEP] kept after per-slice decision: {len(kept_indices_initial)} / {n0}")
    if VERBOSE: print(f"[STEP] kept after per-slice decision: {len(kept_indices_initial)} / {n0}")
    if VERBOSE: print(f"[STEP] kept after per-slice decision: {len(kept_indices_initial)} / {n0}")
    if VERBOSE: print(f"[STEP] kept after per-slice decision: {len(kept_indices_initial)} / {n0}")
    if VERBOSE: print(f"[STEP] kept after per-slice decision: {len(kept_indices_initial)} / {n0}")
    if VERBOSE: print(f"[STEP] kept after per-slice decision: {len(kept_indices_initial)} / {n0}")
    if VERBOSE: print(f"[STEP] kept after per-slice decision: {len(kept_indices_initial)} / {n0}")
    if VERBOSE: print(f"[STEP] kept after per-slice decision: {len(kept_indices_initial)} / {n0}")
    if VERBOSE: print(f"[STEP] kept after per-slice decision: {len(kept_indices_initial)} / {n0}")
    if VERBOSE: print(f"[STEP] kept after per-slice decision: {len(kept_indices_initial)} / {n0}")
    if VERBOSE: print(f"[STEP] kept after per-slice decision: {len(kept_indices_initial)} / {n0}")
    if VERBOSE: print(f"[STEP] kept after per-slice decision: {len(kept_indices_initial)} / {n0}")
    if VERBOSE: print(f"[STEP] kept after per-slice decision: {len(kept_indices_initial)} / {n0}")
    if VERBOSE: print(f"[STEP] kept after per-slice decision: {len(kept_indices_initial)} / {n0}")
    if VERBOSE: print(f"[STEP] kept after per-slice decision: {len(kept_indices_initial)} / {n0}")
    if VERBOSE: print(f"[STEP] kept after per-slice decision: {len(kept_indices_initial)} / {n0}")
    if VERBOSE: print(f"[STEP] kept after per-slice decision: {len(kept_indices_initial)} / {n0}")
    if VERBOSE: print(f"[STEP] kept after per-slice decision: {len(kept_indices_initial)} / {n0}")
    if VERBOSE: print(f"[STEP] kept after per-slice decision: {len(kept_indices_initial)} / {n0}")
    if VERBOSE: print(f"[STEP] kept after per-slice decision: {len(kept_indices_initial)} / {n0}")
    if VERBOSE: print(f"[STEP] kept after per-slice decision: {len(kept_indices_initial)} / {n0}")
    if VERBOSE: print(f"[STEP] kept after per-slice decision: {len(kept_indices_initial)} / {n0}")
    if VERBOSE: print(f"[STEP] kept after per-slice decision: {len(kept_indices_initial)} / {n0}")
    if VERBOSE: print(f"[STEP] kept after per-slice decision: {len(kept_indices_initial)} / {n0}")
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    # final clustering to remove small clusters from kept points
    # final clustering to remove small clusters from kept points
    # final clustering to remove small clusters from kept points
    # final clustering to remove small clusters from kept points
    # final clustering to remove small clusters from kept points
    # final clustering to remove small clusters from kept points
    # final clustering to remove small clusters from kept points
    # final clustering to remove small clusters from kept points
    # final clustering to remove small clusters from kept points
    # final clustering to remove small clusters from kept points
    # final clustering to remove small clusters from kept points
    # final clustering to remove small clusters from kept points
    # final clustering to remove small clusters from kept points
    # final clustering to remove small clusters from kept points
    # final clustering to remove small clusters from kept points
    # final clustering to remove small clusters from kept points
    # final clustering to remove small clusters from kept points
    # final clustering to remove small clusters from kept points
    # final clustering to remove small clusters from kept points
    # final clustering to remove small clusters from kept points
    # final clustering to remove small clusters from kept points
    # final clustering to remove small clusters from kept points
    # final clustering to remove small clusters from kept points
    # final clustering to remove small clusters from kept points
    # final clustering to remove small clusters from kept points
    # final clustering to remove small clusters from kept points
    # final clustering to remove small clusters from kept points
    # final clustering to remove small clusters from kept points
    # final clustering to remove small clusters from kept points
    # final clustering to remove small clusters from kept points
    # final clustering to remove small clusters from kept points
    # final clustering to remove small clusters from kept points
    # final clustering to remove small clusters from kept points
    # final clustering to remove small clusters from kept points
    # final clustering to remove small clusters from kept points
    # final clustering to remove small clusters from kept points
    # final clustering to remove small clusters from kept points
    kept_final_idx, cluster_info = prune_small_clusters(pts_kept_initial, kept_indices_initial)
    kept_final_idx, cluster_info = prune_small_clusters(pts_kept_initial, kept_indices_initial)
    kept_final_idx, cluster_info = prune_small_clusters(pts_kept_initial, kept_indices_initial)
    kept_final_idx, cluster_info = prune_small_clusters(pts_kept_initial, kept_indices_initial)
    kept_final_idx, cluster_info = prune_small_clusters(pts_kept_initial, kept_indices_initial)
    kept_final_idx, cluster_info = prune_small_clusters(pts_kept_initial, kept_indices_initial)
    kept_final_idx, cluster_info = prune_small_clusters(pts_kept_initial, kept_indices_initial)
    kept_final_idx, cluster_info = prune_small_clusters(pts_kept_initial, kept_indices_initial)
    kept_final_idx, cluster_info = prune_small_clusters(pts_kept_initial, kept_indices_initial)
    kept_final_idx, cluster_info = prune_small_clusters(pts_kept_initial, kept_indices_initial)
    kept_final_idx, cluster_info = prune_small_clusters(pts_kept_initial, kept_indices_initial)
    kept_final_idx, cluster_info = prune_small_clusters(pts_kept_initial, kept_indices_initial)
    kept_final_idx, cluster_info = prune_small_clusters(pts_kept_initial, kept_indices_initial)
    kept_final_idx, cluster_info = prune_small_clusters(pts_kept_initial, kept_indices_initial)
    kept_final_idx, cluster_info = prune_small_clusters(pts_kept_initial, kept_indices_initial)
    kept_final_idx, cluster_info = prune_small_clusters(pts_kept_initial, kept_indices_initial)
    kept_final_idx, cluster_info = prune_small_clusters(pts_kept_initial, kept_indices_initial)
    kept_final_idx, cluster_info = prune_small_clusters(pts_kept_initial, kept_indices_initial)
    kept_final_idx, cluster_info = prune_small_clusters(pts_kept_initial, kept_indices_initial)
    kept_final_idx, cluster_info = prune_small_clusters(pts_kept_initial, kept_indices_initial)
    kept_final_idx, cluster_info = prune_small_clusters(pts_kept_initial, kept_indices_initial)
    kept_final_idx, cluster_info = prune_small_clusters(pts_kept_initial, kept_indices_initial)
    kept_final_idx, cluster_info = prune_small_clusters(pts_kept_initial, kept_indices_initial)
    kept_final_idx, cluster_info = prune_small_clusters(pts_kept_initial, kept_indices_initial)
    kept_final_idx, cluster_info = prune_small_clusters(pts_kept_initial, kept_indices_initial)
    kept_final_idx, cluster_info = prune_small_clusters(pts_kept_initial, kept_indices_initial)
    kept_final_idx, cluster_info = prune_small_clusters(pts_kept_initial, kept_indices_initial)
    kept_final_idx, cluster_info = prune_small_clusters(pts_kept_initial, kept_indices_initial)
    kept_final_idx, cluster_info = prune_small_clusters(pts_kept_initial, kept_indices_initial)
    kept_final_idx, cluster_info = prune_small_clusters(pts_kept_initial, kept_indices_initial)
    kept_final_idx, cluster_info = prune_small_clusters(pts_kept_initial, kept_indices_initial)
    kept_final_idx, cluster_info = prune_small_clusters(pts_kept_initial, kept_indices_initial)
    kept_final_idx, cluster_info = prune_small_clusters(pts_kept_initial, kept_indices_initial)
    kept_final_idx, cluster_info = prune_small_clusters(pts_kept_initial, kept_indices_initial)
    kept_final_idx, cluster_info = prune_small_clusters(pts_kept_initial, kept_indices_initial)
    kept_final_idx, cluster_info = prune_small_clusters(pts_kept_initial, kept_indices_initial)
    kept_final_idx, cluster_info = prune_small_clusters(pts_kept_initial, kept_indices_initial)
    pts_final = pts[kept_final_idx]
    pts_final = pts[kept_final_idx]
    pts_final = pts[kept_final_idx]
    pts_final = pts[kept_final_idx]
    pts_final = pts[kept_final_idx]
    pts_final = pts[kept_final_idx]
    pts_final = pts[kept_final_idx]
    pts_final = pts[kept_final_idx]
    pts_final = pts[kept_final_idx]
    pts_final = pts[kept_final_idx]
    pts_final = pts[kept_final_idx]
    pts_final = pts[kept_final_idx]
    pts_final = pts[kept_final_idx]
    pts_final = pts[kept_final_idx]
    pts_final = pts[kept_final_idx]
    pts_final = pts[kept_final_idx]
    pts_final = pts[kept_final_idx]
    pts_final = pts[kept_final_idx]
    pts_final = pts[kept_final_idx]
    pts_final = pts[kept_final_idx]
    pts_final = pts[kept_final_idx]
    pts_final = pts[kept_final_idx]
    pts_final = pts[kept_final_idx]
    pts_final = pts[kept_final_idx]
    pts_final = pts[kept_final_idx]
    pts_final = pts[kept_final_idx]
    pts_final = pts[kept_final_idx]
    pts_final = pts[kept_final_idx]
    pts_final = pts[kept_final_idx]
    pts_final = pts[kept_final_idx]
    pts_final = pts[kept_final_idx]
    pts_final = pts[kept_final_idx]
    pts_final = pts[kept_final_idx]
    pts_final = pts[kept_final_idx]
    pts_final = pts[kept_final_idx]
    pts_final = pts[kept_final_idx]
    pts_final = pts[kept_final_idx]
    n_final = len(pts_final)
    n_final = len(pts_final)
    n_final = len(pts_final)
    n_final = len(pts_final)
    n_final = len(pts_final)
    n_final = len(pts_final)
    n_final = len(pts_final)
    n_final = len(pts_final)
    n_final = len(pts_final)
    n_final = len(pts_final)
    n_final = len(pts_final)
    n_final = len(pts_final)
    n_final = len(pts_final)
    n_final = len(pts_final)
    n_final = len(pts_final)
    n_final = len(pts_final)
    n_final = len(pts_final)
    n_final = len(pts_final)
    n_final = len(pts_final)
    n_final = len(pts_final)
    n_final = len(pts_final)
    n_final = len(pts_final)
    n_final = len(pts_final)
    n_final = len(pts_final)
    n_final = len(pts_final)
    n_final = len(pts_final)
    n_final = len(pts_final)
    n_final = len(pts_final)
    n_final = len(pts_final)
    n_final = len(pts_final)
    n_final = len(pts_final)
    n_final = len(pts_final)
    n_final = len(pts_final)
    n_final = len(pts_final)
    n_final = len(pts_final)
    n_final = len(pts_final)
    n_final = len(pts_final)
    n_removed = n0 - n_final
    n_removed = n0 - n_final
    n_removed = n0 - n_final
    n_removed = n0 - n_final
    n_removed = n0 - n_final
    n_removed = n0 - n_final
    n_removed = n0 - n_final
    n_removed = n0 - n_final
    n_removed = n0 - n_final
    n_removed = n0 - n_final
    n_removed = n0 - n_final
    n_removed = n0 - n_final
    n_removed = n0 - n_final
    n_removed = n0 - n_final
    n_removed = n0 - n_final
    n_removed = n0 - n_final
    n_removed = n0 - n_final
    n_removed = n0 - n_final
    n_removed = n0 - n_final
    n_removed = n0 - n_final
    n_removed = n0 - n_final
    n_removed = n0 - n_final
    n_removed = n0 - n_final
    n_removed = n0 - n_final
    n_removed = n0 - n_final
    n_removed = n0 - n_final
    n_removed = n0 - n_final
    n_removed = n0 - n_final
    n_removed = n0 - n_final
    n_removed = n0 - n_final
    n_removed = n0 - n_final
    n_removed = n0 - n_final
    n_removed = n0 - n_final
    n_removed = n0 - n_final
    n_removed = n0 - n_final
    n_removed = n0 - n_final
    n_removed = n0 - n_final
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    # save output (retained points only)
    # save output (retained points only)
    # save output (retained points only)
    # save output (retained points only)
    # save output (retained points only)
    # save output (retained points only)
    # save output (retained points only)
    # save output (retained points only)
    # save output (retained points only)
    # save output (retained points only)
    # save output (retained points only)
    # save output (retained points only)
    # save output (retained points only)
    # save output (retained points only)
    # save output (retained points only)
    # save output (retained points only)
    # save output (retained points only)
    # save output (retained points only)
    # save output (retained points only)
    # save output (retained points only)
    # save output (retained points only)
    # save output (retained points only)
    # save output (retained points only)
    # save output (retained points only)
    # save output (retained points only)
    # save output (retained points only)
    # save output (retained points only)
    # save output (retained points only)
    # save output (retained points only)
    # save output (retained points only)
    # save output (retained points only)
    # save output (retained points only)
    # save output (retained points only)
    # save output (retained points only)
    # save output (retained points only)
    # save output (retained points only)
    # save output (retained points only)
    os.makedirs(outdir, exist_ok=True)
    os.makedirs(outdir, exist_ok=True)
    os.makedirs(outdir, exist_ok=True)
    os.makedirs(outdir, exist_ok=True)
    os.makedirs(outdir, exist_ok=True)
    os.makedirs(outdir, exist_ok=True)
    os.makedirs(outdir, exist_ok=True)
    os.makedirs(outdir, exist_ok=True)
    os.makedirs(outdir, exist_ok=True)
    os.makedirs(outdir, exist_ok=True)
    os.makedirs(outdir, exist_ok=True)
    os.makedirs(outdir, exist_ok=True)
    os.makedirs(outdir, exist_ok=True)
    os.makedirs(outdir, exist_ok=True)
    os.makedirs(outdir, exist_ok=True)
    os.makedirs(outdir, exist_ok=True)
    os.makedirs(outdir, exist_ok=True)
    os.makedirs(outdir, exist_ok=True)
    os.makedirs(outdir, exist_ok=True)
    os.makedirs(outdir, exist_ok=True)
    os.makedirs(outdir, exist_ok=True)
    os.makedirs(outdir, exist_ok=True)
    os.makedirs(outdir, exist_ok=True)
    os.makedirs(outdir, exist_ok=True)
    os.makedirs(outdir, exist_ok=True)
    os.makedirs(outdir, exist_ok=True)
    os.makedirs(outdir, exist_ok=True)
    os.makedirs(outdir, exist_ok=True)
    os.makedirs(outdir, exist_ok=True)
    os.makedirs(outdir, exist_ok=True)
    os.makedirs(outdir, exist_ok=True)
    os.makedirs(outdir, exist_ok=True)
    os.makedirs(outdir, exist_ok=True)
    os.makedirs(outdir, exist_ok=True)
    os.makedirs(outdir, exist_ok=True)
    os.makedirs(outdir, exist_ok=True)
    os.makedirs(outdir, exist_ok=True)
    outpath = os.path.join(outdir, outfile)
    outpath = os.path.join(outdir, outfile)
    outpath = os.path.join(outdir, outfile)
    outpath = os.path.join(outdir, outfile)
    outpath = os.path.join(outdir, outfile)
    outpath = os.path.join(outdir, outfile)
    outpath = os.path.join(outdir, outfile)
    outpath = os.path.join(outdir, outfile)
    outpath = os.path.join(outdir, outfile)
    outpath = os.path.join(outdir, outfile)
    outpath = os.path.join(outdir, outfile)
    outpath = os.path.join(outdir, outfile)
    outpath = os.path.join(outdir, outfile)
    outpath = os.path.join(outdir, outfile)
    outpath = os.path.join(outdir, outfile)
    outpath = os.path.join(outdir, outfile)
    outpath = os.path.join(outdir, outfile)
    outpath = os.path.join(outdir, outfile)
    outpath = os.path.join(outdir, outfile)
    outpath = os.path.join(outdir, outfile)
    outpath = os.path.join(outdir, outfile)
    outpath = os.path.join(outdir, outfile)
    outpath = os.path.join(outdir, outfile)
    outpath = os.path.join(outdir, outfile)
    outpath = os.path.join(outdir, outfile)
    outpath = os.path.join(outdir, outfile)
    outpath = os.path.join(outdir, outfile)
    outpath = os.path.join(outdir, outfile)
    outpath = os.path.join(outdir, outfile)
    outpath = os.path.join(outdir, outfile)
    outpath = os.path.join(outdir, outfile)
    outpath = os.path.join(outdir, outfile)
    outpath = os.path.join(outdir, outfile)
    outpath = os.path.join(outdir, outfile)
    outpath = os.path.join(outdir, outfile)
    outpath = os.path.join(outdir, outfile)
    outpath = os.path.join(outdir, outfile)
    save_csv_xyz(outpath, pts_final)
    save_csv_xyz(outpath, pts_final)
    save_csv_xyz(outpath, pts_final)
    save_csv_xyz(outpath, pts_final)
    save_csv_xyz(outpath, pts_final)
    save_csv_xyz(outpath, pts_final)
    save_csv_xyz(outpath, pts_final)
    save_csv_xyz(outpath, pts_final)
    save_csv_xyz(outpath, pts_final)
    save_csv_xyz(outpath, pts_final)
    save_csv_xyz(outpath, pts_final)
    save_csv_xyz(outpath, pts_final)
    save_csv_xyz(outpath, pts_final)
    save_csv_xyz(outpath, pts_final)
    save_csv_xyz(outpath, pts_final)
    save_csv_xyz(outpath, pts_final)
    save_csv_xyz(outpath, pts_final)
    save_csv_xyz(outpath, pts_final)
    save_csv_xyz(outpath, pts_final)
    save_csv_xyz(outpath, pts_final)
    save_csv_xyz(outpath, pts_final)
    save_csv_xyz(outpath, pts_final)
    save_csv_xyz(outpath, pts_final)
    save_csv_xyz(outpath, pts_final)
    save_csv_xyz(outpath, pts_final)
    save_csv_xyz(outpath, pts_final)
    save_csv_xyz(outpath, pts_final)
    save_csv_xyz(outpath, pts_final)
    save_csv_xyz(outpath, pts_final)
    save_csv_xyz(outpath, pts_final)
    save_csv_xyz(outpath, pts_final)
    save_csv_xyz(outpath, pts_final)
    save_csv_xyz(outpath, pts_final)
    save_csv_xyz(outpath, pts_final)
    save_csv_xyz(outpath, pts_final)
    save_csv_xyz(outpath, pts_final)
    save_csv_xyz(outpath, pts_final)
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    t1 = time.time()
    t1 = time.time()
    t1 = time.time()
    t1 = time.time()
    t1 = time.time()
    t1 = time.time()
    t1 = time.time()
    t1 = time.time()
    t1 = time.time()
    t1 = time.time()
    t1 = time.time()
    t1 = time.time()
    t1 = time.time()
    t1 = time.time()
    t1 = time.time()
    t1 = time.time()
    t1 = time.time()
    t1 = time.time()
    t1 = time.time()
    t1 = time.time()
    t1 = time.time()
    t1 = time.time()
    t1 = time.time()
    t1 = time.time()
    t1 = time.time()
    t1 = time.time()
    t1 = time.time()
    t1 = time.time()
    t1 = time.time()
    t1 = time.time()
    t1 = time.time()
    t1 = time.time()
    t1 = time.time()
    t1 = time.time()
    t1 = time.time()
    t1 = time.time()
    t1 = time.time()
    stats = {
    stats = {
    stats = {
    stats = {
    stats = {
    stats = {
    stats = {
    stats = {
    stats = {
    stats = {
    stats = {
    stats = {
    stats = {
    stats = {
    stats = {
    stats = {
    stats = {
    stats = {
    stats = {
    stats = {
    stats = {
    stats = {
    stats = {
    stats = {
    stats = {
    stats = {
    stats = {
    stats = {
    stats = {
    stats = {
    stats = {
    stats = {
    stats = {
    stats = {
    stats = {
    stats = {
    stats = {
        'n_input': n0,
        'n_input': n0,
        'n_input': n0,
        'n_input': n0,
        'n_input': n0,
        'n_input': n0,
        'n_input': n0,
        'n_input': n0,
        'n_input': n0,
        'n_input': n0,
        'n_input': n0,
        'n_input': n0,
        'n_input': n0,
        'n_input': n0,
        'n_input': n0,
        'n_input': n0,
        'n_input': n0,
        'n_input': n0,
        'n_input': n0,
        'n_input': n0,
        'n_input': n0,
        'n_input': n0,
        'n_input': n0,
        'n_input': n0,
        'n_input': n0,
        'n_input': n0,
        'n_input': n0,
        'n_input': n0,
        'n_input': n0,
        'n_input': n0,
        'n_input': n0,
        'n_input': n0,
        'n_input': n0,
        'n_input': n0,
        'n_input': n0,
        'n_input': n0,
        'n_input': n0,
        'n_after_slice_decision': int(len(kept_indices_initial)),
        'n_after_slice_decision': int(len(kept_indices_initial)),
        'n_after_slice_decision': int(len(kept_indices_initial)),
        'n_after_slice_decision': int(len(kept_indices_initial)),
        'n_after_slice_decision': int(len(kept_indices_initial)),
        'n_after_slice_decision': int(len(kept_indices_initial)),
        'n_after_slice_decision': int(len(kept_indices_initial)),
        'n_after_slice_decision': int(len(kept_indices_initial)),
        'n_after_slice_decision': int(len(kept_indices_initial)),
        'n_after_slice_decision': int(len(kept_indices_initial)),
        'n_after_slice_decision': int(len(kept_indices_initial)),
        'n_after_slice_decision': int(len(kept_indices_initial)),
        'n_after_slice_decision': int(len(kept_indices_initial)),
        'n_after_slice_decision': int(len(kept_indices_initial)),
        'n_after_slice_decision': int(len(kept_indices_initial)),
        'n_after_slice_decision': int(len(kept_indices_initial)),
        'n_after_slice_decision': int(len(kept_indices_initial)),
        'n_after_slice_decision': int(len(kept_indices_initial)),
        'n_after_slice_decision': int(len(kept_indices_initial)),
        'n_after_slice_decision': int(len(kept_indices_initial)),
        'n_after_slice_decision': int(len(kept_indices_initial)),
        'n_after_slice_decision': int(len(kept_indices_initial)),
        'n_after_slice_decision': int(len(kept_indices_initial)),
        'n_after_slice_decision': int(len(kept_indices_initial)),
        'n_after_slice_decision': int(len(kept_indices_initial)),
        'n_after_slice_decision': int(len(kept_indices_initial)),
        'n_after_slice_decision': int(len(kept_indices_initial)),
        'n_after_slice_decision': int(len(kept_indices_initial)),
        'n_after_slice_decision': int(len(kept_indices_initial)),
        'n_after_slice_decision': int(len(kept_indices_initial)),
        'n_after_slice_decision': int(len(kept_indices_initial)),
        'n_after_slice_decision': int(len(kept_indices_initial)),
        'n_after_slice_decision': int(len(kept_indices_initial)),
        'n_after_slice_decision': int(len(kept_indices_initial)),
        'n_after_slice_decision': int(len(kept_indices_initial)),
        'n_after_slice_decision': int(len(kept_indices_initial)),
        'n_after_slice_decision': int(len(kept_indices_initial)),
        'n_final': int(n_final),
        'n_final': int(n_final),
        'n_final': int(n_final),
        'n_final': int(n_final),
        'n_final': int(n_final),
        'n_final': int(n_final),
        'n_final': int(n_final),
        'n_final': int(n_final),
        'n_final': int(n_final),
        'n_final': int(n_final),
        'n_final': int(n_final),
        'n_final': int(n_final),
        'n_final': int(n_final),
        'n_final': int(n_final),
        'n_final': int(n_final),
        'n_final': int(n_final),
        'n_final': int(n_final),
        'n_final': int(n_final),
        'n_final': int(n_final),
        'n_final': int(n_final),
        'n_final': int(n_final),
        'n_final': int(n_final),
        'n_final': int(n_final),
        'n_final': int(n_final),
        'n_final': int(n_final),
        'n_final': int(n_final),
        'n_final': int(n_final),
        'n_final': int(n_final),
        'n_final': int(n_final),
        'n_final': int(n_final),
        'n_final': int(n_final),
        'n_final': int(n_final),
        'n_final': int(n_final),
        'n_final': int(n_final),
        'n_final': int(n_final),
        'n_final': int(n_final),
        'n_final': int(n_final),
        'n_removed': int(n_removed),
        'n_removed': int(n_removed),
        'n_removed': int(n_removed),
        'n_removed': int(n_removed),
        'n_removed': int(n_removed),
        'n_removed': int(n_removed),
        'n_removed': int(n_removed),
        'n_removed': int(n_removed),
        'n_removed': int(n_removed),
        'n_removed': int(n_removed),
        'n_removed': int(n_removed),
        'n_removed': int(n_removed),
        'n_removed': int(n_removed),
        'n_removed': int(n_removed),
        'n_removed': int(n_removed),
        'n_removed': int(n_removed),
        'n_removed': int(n_removed),
        'n_removed': int(n_removed),
        'n_removed': int(n_removed),
        'n_removed': int(n_removed),
        'n_removed': int(n_removed),
        'n_removed': int(n_removed),
        'n_removed': int(n_removed),
        'n_removed': int(n_removed),
        'n_removed': int(n_removed),
        'n_removed': int(n_removed),
        'n_removed': int(n_removed),
        'n_removed': int(n_removed),
        'n_removed': int(n_removed),
        'n_removed': int(n_removed),
        'n_removed': int(n_removed),
        'n_removed': int(n_removed),
        'n_removed': int(n_removed),
        'n_removed': int(n_removed),
        'n_removed': int(n_removed),
        'n_removed': int(n_removed),
        'n_removed': int(n_removed),
        'time_s': t1 - t0,
        'time_s': t1 - t0,
        'time_s': t1 - t0,
        'time_s': t1 - t0,
        'time_s': t1 - t0,
        'time_s': t1 - t0,
        'time_s': t1 - t0,
        'time_s': t1 - t0,
        'time_s': t1 - t0,
        'time_s': t1 - t0,
        'time_s': t1 - t0,
        'time_s': t1 - t0,
        'time_s': t1 - t0,
        'time_s': t1 - t0,
        'time_s': t1 - t0,
        'time_s': t1 - t0,
        'time_s': t1 - t0,
        'time_s': t1 - t0,
        'time_s': t1 - t0,
        'time_s': t1 - t0,
        'time_s': t1 - t0,
        'time_s': t1 - t0,
        'time_s': t1 - t0,
        'time_s': t1 - t0,
        'time_s': t1 - t0,
        'time_s': t1 - t0,
        'time_s': t1 - t0,
        'time_s': t1 - t0,
        'time_s': t1 - t0,
        'time_s': t1 - t0,
        'time_s': t1 - t0,
        'time_s': t1 - t0,
        'time_s': t1 - t0,
        'time_s': t1 - t0,
        'time_s': t1 - t0,
        'time_s': t1 - t0,
        'time_s': t1 - t0,
        'per_slice': per_slice,
        'per_slice': per_slice,
        'per_slice': per_slice,
        'per_slice': per_slice,
        'per_slice': per_slice,
        'per_slice': per_slice,
        'per_slice': per_slice,
        'per_slice': per_slice,
        'per_slice': per_slice,
        'per_slice': per_slice,
        'per_slice': per_slice,
        'per_slice': per_slice,
        'per_slice': per_slice,
        'per_slice': per_slice,
        'per_slice': per_slice,
        'per_slice': per_slice,
        'per_slice': per_slice,
        'per_slice': per_slice,
        'per_slice': per_slice,
        'per_slice': per_slice,
        'per_slice': per_slice,
        'per_slice': per_slice,
        'per_slice': per_slice,
        'per_slice': per_slice,
        'per_slice': per_slice,
        'per_slice': per_slice,
        'per_slice': per_slice,
        'per_slice': per_slice,
        'per_slice': per_slice,
        'per_slice': per_slice,
        'per_slice': per_slice,
        'per_slice': per_slice,
        'per_slice': per_slice,
        'per_slice': per_slice,
        'per_slice': per_slice,
        'per_slice': per_slice,
        'per_slice': per_slice,
        'cluster_info': cluster_info
        'cluster_info': cluster_info
        'cluster_info': cluster_info
        'cluster_info': cluster_info
        'cluster_info': cluster_info
        'cluster_info': cluster_info
        'cluster_info': cluster_info
        'cluster_info': cluster_info
        'cluster_info': cluster_info
        'cluster_info': cluster_info
        'cluster_info': cluster_info
        'cluster_info': cluster_info
        'cluster_info': cluster_info
        'cluster_info': cluster_info
        'cluster_info': cluster_info
        'cluster_info': cluster_info
        'cluster_info': cluster_info
        'cluster_info': cluster_info
        'cluster_info': cluster_info
        'cluster_info': cluster_info
        'cluster_info': cluster_info
        'cluster_info': cluster_info
        'cluster_info': cluster_info
        'cluster_info': cluster_info
        'cluster_info': cluster_info
        'cluster_info': cluster_info
        'cluster_info': cluster_info
        'cluster_info': cluster_info
        'cluster_info': cluster_info
        'cluster_info': cluster_info
        'cluster_info': cluster_info
        'cluster_info': cluster_info
        'cluster_info': cluster_info
        'cluster_info': cluster_info
        'cluster_info': cluster_info
        'cluster_info': cluster_info
        'cluster_info': cluster_info
    }
    }
    }
    }
    }
    }
    }
    }
    }
    }
    }
    }
    }
    }
    }
    }
    }
    }
    }
    }
    }
    }
    }
    }
    }
    }
    }
    }
    }
    }
    }
    }
    }
    }
    }
    }
    }
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    # record statistics
    # record statistics
    # record statistics
    # record statistics
    # record statistics
    # record statistics
    # record statistics
    # record statistics
    # record statistics
    # record statistics
    # record statistics
    # record statistics
    # record statistics
    # record statistics
    # record statistics
    # record statistics
    # record statistics
    # record statistics
    # record statistics
    # record statistics
    # record statistics
    # record statistics
    # record statistics
    # record statistics
    # record statistics
    # record statistics
    # record statistics
    # record statistics
    # record statistics
    # record statistics
    # record statistics
    # record statistics
    # record statistics
    # record statistics
    # record statistics
    # record statistics
    # record statistics
    with open(os.path.join(outdir, SUMMARY_JSON), 'w') as f:
    with open(os.path.join(outdir, SUMMARY_JSON), 'w') as f:
    with open(os.path.join(outdir, SUMMARY_JSON), 'w') as f:
    with open(os.path.join(outdir, SUMMARY_JSON), 'w') as f:
    with open(os.path.join(outdir, SUMMARY_JSON), 'w') as f:
    with open(os.path.join(outdir, SUMMARY_JSON), 'w') as f:
    with open(os.path.join(outdir, SUMMARY_JSON), 'w') as f:
    with open(os.path.join(outdir, SUMMARY_JSON), 'w') as f:
    with open(os.path.join(outdir, SUMMARY_JSON), 'w') as f:
    with open(os.path.join(outdir, SUMMARY_JSON), 'w') as f:
    with open(os.path.join(outdir, SUMMARY_JSON), 'w') as f:
    with open(os.path.join(outdir, SUMMARY_JSON), 'w') as f:
    with open(os.path.join(outdir, SUMMARY_JSON), 'w') as f:
    with open(os.path.join(outdir, SUMMARY_JSON), 'w') as f:
    with open(os.path.join(outdir, SUMMARY_JSON), 'w') as f:
    with open(os.path.join(outdir, SUMMARY_JSON), 'w') as f:
    with open(os.path.join(outdir, SUMMARY_JSON), 'w') as f:
    with open(os.path.join(outdir, SUMMARY_JSON), 'w') as f:
    with open(os.path.join(outdir, SUMMARY_JSON), 'w') as f:
    with open(os.path.join(outdir, SUMMARY_JSON), 'w') as f:
    with open(os.path.join(outdir, SUMMARY_JSON), 'w') as f:
    with open(os.path.join(outdir, SUMMARY_JSON), 'w') as f:
    with open(os.path.join(outdir, SUMMARY_JSON), 'w') as f:
    with open(os.path.join(outdir, SUMMARY_JSON), 'w') as f:
    with open(os.path.join(outdir, SUMMARY_JSON), 'w') as f:
    with open(os.path.join(outdir, SUMMARY_JSON), 'w') as f:
    with open(os.path.join(outdir, SUMMARY_JSON), 'w') as f:
    with open(os.path.join(outdir, SUMMARY_JSON), 'w') as f:
    with open(os.path.join(outdir, SUMMARY_JSON), 'w') as f:
    with open(os.path.join(outdir, SUMMARY_JSON), 'w') as f:
    with open(os.path.join(outdir, SUMMARY_JSON), 'w') as f:
    with open(os.path.join(outdir, SUMMARY_JSON), 'w') as f:
    with open(os.path.join(outdir, SUMMARY_JSON), 'w') as f:
    with open(os.path.join(outdir, SUMMARY_JSON), 'w') as f:
    with open(os.path.join(outdir, SUMMARY_JSON), 'w') as f:
    with open(os.path.join(outdir, SUMMARY_JSON), 'w') as f:
    with open(os.path.join(outdir, SUMMARY_JSON), 'w') as f:
        json.dump(stats, f, indent=2, default=lambda x: (x.tolist() if hasattr(x,'tolist') else str(x)))
        json.dump(stats, f, indent=2, default=lambda x: (x.tolist() if hasattr(x,'tolist') else str(x)))
        json.dump(stats, f, indent=2, default=lambda x: (x.tolist() if hasattr(x,'tolist') else str(x)))
        json.dump(stats, f, indent=2, default=lambda x: (x.tolist() if hasattr(x,'tolist') else str(x)))
        json.dump(stats, f, indent=2, default=lambda x: (x.tolist() if hasattr(x,'tolist') else str(x)))
        json.dump(stats, f, indent=2, default=lambda x: (x.tolist() if hasattr(x,'tolist') else str(x)))
        json.dump(stats, f, indent=2, default=lambda x: (x.tolist() if hasattr(x,'tolist') else str(x)))
        json.dump(stats, f, indent=2, default=lambda x: (x.tolist() if hasattr(x,'tolist') else str(x)))
        json.dump(stats, f, indent=2, default=lambda x: (x.tolist() if hasattr(x,'tolist') else str(x)))
        json.dump(stats, f, indent=2, default=lambda x: (x.tolist() if hasattr(x,'tolist') else str(x)))
        json.dump(stats, f, indent=2, default=lambda x: (x.tolist() if hasattr(x,'tolist') else str(x)))
        json.dump(stats, f, indent=2, default=lambda x: (x.tolist() if hasattr(x,'tolist') else str(x)))
        json.dump(stats, f, indent=2, default=lambda x: (x.tolist() if hasattr(x,'tolist') else str(x)))
        json.dump(stats, f, indent=2, default=lambda x: (x.tolist() if hasattr(x,'tolist') else str(x)))
        json.dump(stats, f, indent=2, default=lambda x: (x.tolist() if hasattr(x,'tolist') else str(x)))
        json.dump(stats, f, indent=2, default=lambda x: (x.tolist() if hasattr(x,'tolist') else str(x)))
        json.dump(stats, f, indent=2, default=lambda x: (x.tolist() if hasattr(x,'tolist') else str(x)))
        json.dump(stats, f, indent=2, default=lambda x: (x.tolist() if hasattr(x,'tolist') else str(x)))
        json.dump(stats, f, indent=2, default=lambda x: (x.tolist() if hasattr(x,'tolist') else str(x)))
        json.dump(stats, f, indent=2, default=lambda x: (x.tolist() if hasattr(x,'tolist') else str(x)))
        json.dump(stats, f, indent=2, default=lambda x: (x.tolist() if hasattr(x,'tolist') else str(x)))
        json.dump(stats, f, indent=2, default=lambda x: (x.tolist() if hasattr(x,'tolist') else str(x)))
        json.dump(stats, f, indent=2, default=lambda x: (x.tolist() if hasattr(x,'tolist') else str(x)))
        json.dump(stats, f, indent=2, default=lambda x: (x.tolist() if hasattr(x,'tolist') else str(x)))
        json.dump(stats, f, indent=2, default=lambda x: (x.tolist() if hasattr(x,'tolist') else str(x)))
        json.dump(stats, f, indent=2, default=lambda x: (x.tolist() if hasattr(x,'tolist') else str(x)))
        json.dump(stats, f, indent=2, default=lambda x: (x.tolist() if hasattr(x,'tolist') else str(x)))
        json.dump(stats, f, indent=2, default=lambda x: (x.tolist() if hasattr(x,'tolist') else str(x)))
        json.dump(stats, f, indent=2, default=lambda x: (x.tolist() if hasattr(x,'tolist') else str(x)))
        json.dump(stats, f, indent=2, default=lambda x: (x.tolist() if hasattr(x,'tolist') else str(x)))
        json.dump(stats, f, indent=2, default=lambda x: (x.tolist() if hasattr(x,'tolist') else str(x)))
        json.dump(stats, f, indent=2, default=lambda x: (x.tolist() if hasattr(x,'tolist') else str(x)))
        json.dump(stats, f, indent=2, default=lambda x: (x.tolist() if hasattr(x,'tolist') else str(x)))
        json.dump(stats, f, indent=2, default=lambda x: (x.tolist() if hasattr(x,'tolist') else str(x)))
        json.dump(stats, f, indent=2, default=lambda x: (x.tolist() if hasattr(x,'tolist') else str(x)))
        json.dump(stats, f, indent=2, default=lambda x: (x.tolist() if hasattr(x,'tolist') else str(x)))
        json.dump(stats, f, indent=2, default=lambda x: (x.tolist() if hasattr(x,'tolist') else str(x)))
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    # print summary
    # print summary
    # print summary
    # print summary
    # print summary
    # print summary
    # print summary
    # print summary
    # print summary
    # print summary
    # print summary
    # print summary
    # print summary
    # print summary
    # print summary
    # print summary
    # print summary
    # print summary
    # print summary
    # print summary
    # print summary
    # print summary
    # print summary
    # print summary
    # print summary
    # print summary
    # print summary
    # print summary
    # print summary
    # print summary
    # print summary
    # print summary
    # print summary
    # print summary
    # print summary
    # print summary
    # print summary
    print("=== SUMMARY ===")
    print("=== SUMMARY ===")
    print("=== SUMMARY ===")
    print("=== SUMMARY ===")
    print("=== SUMMARY ===")
    print("=== SUMMARY ===")
    print("=== SUMMARY ===")
    print("=== SUMMARY ===")
    print("=== SUMMARY ===")
    print("=== SUMMARY ===")
    print("=== SUMMARY ===")
    print("=== SUMMARY ===")
    print("=== SUMMARY ===")
    print("=== SUMMARY ===")
    print("=== SUMMARY ===")
    print("=== SUMMARY ===")
    print("=== SUMMARY ===")
    print("=== SUMMARY ===")
    print("=== SUMMARY ===")
    print("=== SUMMARY ===")
    print("=== SUMMARY ===")
    print("=== SUMMARY ===")
    print("=== SUMMARY ===")
    print("=== SUMMARY ===")
    print("=== SUMMARY ===")
    print("=== SUMMARY ===")
    print("=== SUMMARY ===")
    print("=== SUMMARY ===")
    print("=== SUMMARY ===")
    print("=== SUMMARY ===")
    print("=== SUMMARY ===")
    print("=== SUMMARY ===")
    print("=== SUMMARY ===")
    print("=== SUMMARY ===")
    print("=== SUMMARY ===")
    print("=== SUMMARY ===")
    print("=== SUMMARY ===")
    print(f"initial_count: {n0}")
    print(f"initial_count: {n0}")
    print(f"initial_count: {n0}")
    print(f"initial_count: {n0}")
    print(f"initial_count: {n0}")
    print(f"initial_count: {n0}")
    print(f"initial_count: {n0}")
    print(f"initial_count: {n0}")
    print(f"initial_count: {n0}")
    print(f"initial_count: {n0}")
    print(f"initial_count: {n0}")
    print(f"initial_count: {n0}")
    print(f"initial_count: {n0}")
    print(f"initial_count: {n0}")
    print(f"initial_count: {n0}")
    print(f"initial_count: {n0}")
    print(f"initial_count: {n0}")
    print(f"initial_count: {n0}")
    print(f"initial_count: {n0}")
    print(f"initial_count: {n0}")
    print(f"initial_count: {n0}")
    print(f"initial_count: {n0}")
    print(f"initial_count: {n0}")
    print(f"initial_count: {n0}")
    print(f"initial_count: {n0}")
    print(f"initial_count: {n0}")
    print(f"initial_count: {n0}")
    print(f"initial_count: {n0}")
    print(f"initial_count: {n0}")
    print(f"initial_count: {n0}")
    print(f"initial_count: {n0}")
    print(f"initial_count: {n0}")
    print(f"initial_count: {n0}")
    print(f"initial_count: {n0}")
    print(f"initial_count: {n0}")
    print(f"initial_count: {n0}")
    print(f"initial_count: {n0}")
    print(f"after_slice_decision: {len(kept_indices_initial)}")
    print(f"after_slice_decision: {len(kept_indices_initial)}")
    print(f"after_slice_decision: {len(kept_indices_initial)}")
    print(f"after_slice_decision: {len(kept_indices_initial)}")
    print(f"after_slice_decision: {len(kept_indices_initial)}")
    print(f"after_slice_decision: {len(kept_indices_initial)}")
    print(f"after_slice_decision: {len(kept_indices_initial)}")
    print(f"after_slice_decision: {len(kept_indices_initial)}")
    print(f"after_slice_decision: {len(kept_indices_initial)}")
    print(f"after_slice_decision: {len(kept_indices_initial)}")
    print(f"after_slice_decision: {len(kept_indices_initial)}")
    print(f"after_slice_decision: {len(kept_indices_initial)}")
    print(f"after_slice_decision: {len(kept_indices_initial)}")
    print(f"after_slice_decision: {len(kept_indices_initial)}")
    print(f"after_slice_decision: {len(kept_indices_initial)}")
    print(f"after_slice_decision: {len(kept_indices_initial)}")
    print(f"after_slice_decision: {len(kept_indices_initial)}")
    print(f"after_slice_decision: {len(kept_indices_initial)}")
    print(f"after_slice_decision: {len(kept_indices_initial)}")
    print(f"after_slice_decision: {len(kept_indices_initial)}")
    print(f"after_slice_decision: {len(kept_indices_initial)}")
    print(f"after_slice_decision: {len(kept_indices_initial)}")
    print(f"after_slice_decision: {len(kept_indices_initial)}")
    print(f"after_slice_decision: {len(kept_indices_initial)}")
    print(f"after_slice_decision: {len(kept_indices_initial)}")
    print(f"after_slice_decision: {len(kept_indices_initial)}")
    print(f"after_slice_decision: {len(kept_indices_initial)}")
    print(f"after_slice_decision: {len(kept_indices_initial)}")
    print(f"after_slice_decision: {len(kept_indices_initial)}")
    print(f"after_slice_decision: {len(kept_indices_initial)}")
    print(f"after_slice_decision: {len(kept_indices_initial)}")
    print(f"after_slice_decision: {len(kept_indices_initial)}")
    print(f"after_slice_decision: {len(kept_indices_initial)}")
    print(f"after_slice_decision: {len(kept_indices_initial)}")
    print(f"after_slice_decision: {len(kept_indices_initial)}")
    print(f"after_slice_decision: {len(kept_indices_initial)}")
    print(f"after_slice_decision: {len(kept_indices_initial)}")
    print(f"final_kept: {n_final}")
    print(f"final_kept: {n_final}")
    print(f"final_kept: {n_final}")
    print(f"final_kept: {n_final}")
    print(f"final_kept: {n_final}")
    print(f"final_kept: {n_final}")
    print(f"final_kept: {n_final}")
    print(f"final_kept: {n_final}")
    print(f"final_kept: {n_final}")
    print(f"final_kept: {n_final}")
    print(f"final_kept: {n_final}")
    print(f"final_kept: {n_final}")
    print(f"final_kept: {n_final}")
    print(f"final_kept: {n_final}")
    print(f"final_kept: {n_final}")
    print(f"final_kept: {n_final}")
    print(f"final_kept: {n_final}")
    print(f"final_kept: {n_final}")
    print(f"final_kept: {n_final}")
    print(f"final_kept: {n_final}")
    print(f"final_kept: {n_final}")
    print(f"final_kept: {n_final}")
    print(f"final_kept: {n_final}")
    print(f"final_kept: {n_final}")
    print(f"final_kept: {n_final}")
    print(f"final_kept: {n_final}")
    print(f"final_kept: {n_final}")
    print(f"final_kept: {n_final}")
    print(f"final_kept: {n_final}")
    print(f"final_kept: {n_final}")
    print(f"final_kept: {n_final}")
    print(f"final_kept: {n_final}")
    print(f"final_kept: {n_final}")
    print(f"final_kept: {n_final}")
    print(f"final_kept: {n_final}")
    print(f"final_kept: {n_final}")
    print(f"final_kept: {n_final}")
    print(f"total_removed: {n_removed}")
    print(f"total_removed: {n_removed}")
    print(f"total_removed: {n_removed}")
    print(f"total_removed: {n_removed}")
    print(f"total_removed: {n_removed}")
    print(f"total_removed: {n_removed}")
    print(f"total_removed: {n_removed}")
    print(f"total_removed: {n_removed}")
    print(f"total_removed: {n_removed}")
    print(f"total_removed: {n_removed}")
    print(f"total_removed: {n_removed}")
    print(f"total_removed: {n_removed}")
    print(f"total_removed: {n_removed}")
    print(f"total_removed: {n_removed}")
    print(f"total_removed: {n_removed}")
    print(f"total_removed: {n_removed}")
    print(f"total_removed: {n_removed}")
    print(f"total_removed: {n_removed}")
    print(f"total_removed: {n_removed}")
    print(f"total_removed: {n_removed}")
    print(f"total_removed: {n_removed}")
    print(f"total_removed: {n_removed}")
    print(f"total_removed: {n_removed}")
    print(f"total_removed: {n_removed}")
    print(f"total_removed: {n_removed}")
    print(f"total_removed: {n_removed}")
    print(f"total_removed: {n_removed}")
    print(f"total_removed: {n_removed}")
    print(f"total_removed: {n_removed}")
    print(f"total_removed: {n_removed}")
    print(f"total_removed: {n_removed}")
    print(f"total_removed: {n_removed}")
    print(f"total_removed: {n_removed}")
    print(f"total_removed: {n_removed}")
    print(f"total_removed: {n_removed}")
    print(f"total_removed: {n_removed}")
    print(f"total_removed: {n_removed}")
    print(f"removal_rate: {n_removed/n0*100:.1f}%")
    print(f"removal_rate: {n_removed/n0*100:.1f}%")
    print(f"removal_rate: {n_removed/n0*100:.1f}%")
    print(f"removal_rate: {n_removed/n0*100:.1f}%")
    print(f"removal_rate: {n_removed/n0*100:.1f}%")
    print(f"removal_rate: {n_removed/n0*100:.1f}%")
    print(f"removal_rate: {n_removed/n0*100:.1f}%")
    print(f"removal_rate: {n_removed/n0*100:.1f}%")
    print(f"removal_rate: {n_removed/n0*100:.1f}%")
    print(f"removal_rate: {n_removed/n0*100:.1f}%")
    print(f"removal_rate: {n_removed/n0*100:.1f}%")
    print(f"removal_rate: {n_removed/n0*100:.1f}%")
    print(f"removal_rate: {n_removed/n0*100:.1f}%")
    print(f"removal_rate: {n_removed/n0*100:.1f}%")
    print(f"removal_rate: {n_removed/n0*100:.1f}%")
    print(f"removal_rate: {n_removed/n0*100:.1f}%")
    print(f"removal_rate: {n_removed/n0*100:.1f}%")
    print(f"removal_rate: {n_removed/n0*100:.1f}%")
    print(f"removal_rate: {n_removed/n0*100:.1f}%")
    print(f"removal_rate: {n_removed/n0*100:.1f}%")
    print(f"removal_rate: {n_removed/n0*100:.1f}%")
    print(f"removal_rate: {n_removed/n0*100:.1f}%")
    print(f"removal_rate: {n_removed/n0*100:.1f}%")
    print(f"removal_rate: {n_removed/n0*100:.1f}%")
    print(f"removal_rate: {n_removed/n0*100:.1f}%")
    print(f"removal_rate: {n_removed/n0*100:.1f}%")
    print(f"removal_rate: {n_removed/n0*100:.1f}%")
    print(f"removal_rate: {n_removed/n0*100:.1f}%")
    print(f"removal_rate: {n_removed/n0*100:.1f}%")
    print(f"removal_rate: {n_removed/n0*100:.1f}%")
    print(f"removal_rate: {n_removed/n0*100:.1f}%")
    print(f"removal_rate: {n_removed/n0*100:.1f}%")
    print(f"removal_rate: {n_removed/n0*100:.1f}%")
    print(f"removal_rate: {n_removed/n0*100:.1f}%")
    print(f"removal_rate: {n_removed/n0*100:.1f}%")
    print(f"removal_rate: {n_removed/n0*100:.1f}%")
    print(f"removal_rate: {n_removed/n0*100:.1f}%")
    print(f"processing_time: {t1-t0:.2f}s")
    print(f"processing_time: {t1-t0:.2f}s")
    print(f"processing_time: {t1-t0:.2f}s")
    print(f"processing_time: {t1-t0:.2f}s")
    print(f"processing_time: {t1-t0:.2f}s")
    print(f"processing_time: {t1-t0:.2f}s")
    print(f"processing_time: {t1-t0:.2f}s")
    print(f"processing_time: {t1-t0:.2f}s")
    print(f"processing_time: {t1-t0:.2f}s")
    print(f"processing_time: {t1-t0:.2f}s")
    print(f"processing_time: {t1-t0:.2f}s")
    print(f"processing_time: {t1-t0:.2f}s")
    print(f"processing_time: {t1-t0:.2f}s")
    print(f"processing_time: {t1-t0:.2f}s")
    print(f"processing_time: {t1-t0:.2f}s")
    print(f"processing_time: {t1-t0:.2f}s")
    print(f"processing_time: {t1-t0:.2f}s")
    print(f"processing_time: {t1-t0:.2f}s")
    print(f"processing_time: {t1-t0:.2f}s")
    print(f"processing_time: {t1-t0:.2f}s")
    print(f"processing_time: {t1-t0:.2f}s")
    print(f"processing_time: {t1-t0:.2f}s")
    print(f"processing_time: {t1-t0:.2f}s")
    print(f"processing_time: {t1-t0:.2f}s")
    print(f"processing_time: {t1-t0:.2f}s")
    print(f"processing_time: {t1-t0:.2f}s")
    print(f"processing_time: {t1-t0:.2f}s")
    print(f"processing_time: {t1-t0:.2f}s")
    print(f"processing_time: {t1-t0:.2f}s")
    print(f"processing_time: {t1-t0:.2f}s")
    print(f"processing_time: {t1-t0:.2f}s")
    print(f"processing_time: {t1-t0:.2f}s")
    print(f"processing_time: {t1-t0:.2f}s")
    print(f"processing_time: {t1-t0:.2f}s")
    print(f"processing_time: {t1-t0:.2f}s")
    print(f"processing_time: {t1-t0:.2f}s")
    print(f"processing_time: {t1-t0:.2f}s")
    print(f"saved -> {outpath}")
    print(f"saved -> {outpath}")
    print(f"saved -> {outpath}")
    print(f"saved -> {outpath}")
    print(f"saved -> {outpath}")
    print(f"saved -> {outpath}")
    print(f"saved -> {outpath}")
    print(f"saved -> {outpath}")
    print(f"saved -> {outpath}")
    print(f"saved -> {outpath}")
    print(f"saved -> {outpath}")
    print(f"saved -> {outpath}")
    print(f"saved -> {outpath}")
    print(f"saved -> {outpath}")
    print(f"saved -> {outpath}")
    print(f"saved -> {outpath}")
    print(f"saved -> {outpath}")
    print(f"saved -> {outpath}")
    print(f"saved -> {outpath}")
    print(f"saved -> {outpath}")
    print(f"saved -> {outpath}")
    print(f"saved -> {outpath}")
    print(f"saved -> {outpath}")
    print(f"saved -> {outpath}")
    print(f"saved -> {outpath}")
    print(f"saved -> {outpath}")
    print(f"saved -> {outpath}")
    print(f"saved -> {outpath}")
    print(f"saved -> {outpath}")
    print(f"saved -> {outpath}")
    print(f"saved -> {outpath}")
    print(f"saved -> {outpath}")
    print(f"saved -> {outpath}")
    print(f"saved -> {outpath}")
    print(f"saved -> {outpath}")
    print(f"saved -> {outpath}")
    print(f"saved -> {outpath}")
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    # show plots
    # show plots
    # show plots
    # show plots
    # show plots
    # show plots
    # show plots
    # show plots
    # show plots
    # show plots
    # show plots
    # show plots
    # show plots
    # show plots
    # show plots
    # show plots
    # show plots
    # show plots
    # show plots
    # show plots
    # show plots
    # show plots
    # show plots
    # show plots
    # show plots
    # show plots
    # show plots
    # show plots
    # show plots
    # show plots
    # show plots
    # show plots
    # show plots
    # show plots
    # show plots
    # show plots
    # show plots
    plot_results(original_points, pts_final, stats, outdir)
    plot_results(original_points, pts_final, stats, outdir)
    plot_results(original_points, pts_final, stats, outdir)
    plot_results(original_points, pts_final, stats, outdir)
    plot_results(original_points, pts_final, stats, outdir)
    plot_results(original_points, pts_final, stats, outdir)
    plot_results(original_points, pts_final, stats, outdir)
    plot_results(original_points, pts_final, stats, outdir)
    plot_results(original_points, pts_final, stats, outdir)
    plot_results(original_points, pts_final, stats, outdir)
    plot_results(original_points, pts_final, stats, outdir)
    plot_results(original_points, pts_final, stats, outdir)
    plot_results(original_points, pts_final, stats, outdir)
    plot_results(original_points, pts_final, stats, outdir)
    plot_results(original_points, pts_final, stats, outdir)
    plot_results(original_points, pts_final, stats, outdir)
    plot_results(original_points, pts_final, stats, outdir)
    plot_results(original_points, pts_final, stats, outdir)
    plot_results(original_points, pts_final, stats, outdir)
    plot_results(original_points, pts_final, stats, outdir)
    plot_results(original_points, pts_final, stats, outdir)
    plot_results(original_points, pts_final, stats, outdir)
    plot_results(original_points, pts_final, stats, outdir)
    plot_results(original_points, pts_final, stats, outdir)
    plot_results(original_points, pts_final, stats, outdir)
    plot_results(original_points, pts_final, stats, outdir)
    plot_results(original_points, pts_final, stats, outdir)
    plot_results(original_points, pts_final, stats, outdir)
    plot_results(original_points, pts_final, stats, outdir)
    plot_results(original_points, pts_final, stats, outdir)
    plot_results(original_points, pts_final, stats, outdir)
    plot_results(original_points, pts_final, stats, outdir)
    plot_results(original_points, pts_final, stats, outdir)
    plot_results(original_points, pts_final, stats, outdir)
    plot_results(original_points, pts_final, stats, outdir)
    plot_results(original_points, pts_final, stats, outdir)
    plot_results(original_points, pts_final, stats, outdir)
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    return outpath, pts_final, stats
    return outpath, pts_final, stats
    return outpath, pts_final, stats
    return outpath, pts_final, stats
    return outpath, pts_final, stats
    return outpath, pts_final, stats
    return outpath, pts_final, stats
    return outpath, pts_final, stats
    return outpath, pts_final, stats
    return outpath, pts_final, stats
    return outpath, pts_final, stats
    return outpath, pts_final, stats
    return outpath, pts_final, stats
    return outpath, pts_final, stats
    return outpath, pts_final, stats
    return outpath, pts_final, stats
    return outpath, pts_final, stats
    return outpath, pts_final, stats
    return outpath, pts_final, stats
    return outpath, pts_final, stats
    return outpath, pts_final, stats
    return outpath, pts_final, stats
    return outpath, pts_final, stats
    return outpath, pts_final, stats
    return outpath, pts_final, stats
    return outpath, pts_final, stats
    return outpath, pts_final, stats
    return outpath, pts_final, stats
    return outpath, pts_final, stats
    return outpath, pts_final, stats
    return outpath, pts_final, stats
    return outpath, pts_final, stats
    return outpath, pts_final, stats
    return outpath, pts_final, stats
    return outpath, pts_final, stats
    return outpath, pts_final, stats
    return outpath, pts_final, stats





































# ---------- run ----------
# ---------- run ----------
# ---------- run ----------
# ---------- run ----------
# ---------- run ----------
# ---------- run ----------
# ---------- run ----------
# ---------- run ----------
# ---------- run ----------
# ---------- run ----------
# ---------- run ----------
# ---------- run ----------
# ---------- run ----------
# ---------- run ----------
# ---------- run ----------
# ---------- run ----------
# ---------- run ----------
# ---------- run ----------
# ---------- run ----------
# ---------- run ----------
# ---------- run ----------
# ---------- run ----------
# ---------- run ----------
# ---------- run ----------
# ---------- run ----------
# ---------- run ----------
# ---------- run ----------
# ---------- run ----------
# ---------- run ----------
# ---------- run ----------
# ---------- run ----------
# ---------- run ----------
# ---------- run ----------
# ---------- run ----------
# ---------- run ----------
# ---------- run ----------
# ---------- run ----------
if __name__ == "__main__":
if __name__ == "__main__":
if __name__ == "__main__":
if __name__ == "__main__":
if __name__ == "__main__":
if __name__ == "__main__":
if __name__ == "__main__":
if __name__ == "__main__":
if __name__ == "__main__":
if __name__ == "__main__":
if __name__ == "__main__":
if __name__ == "__main__":
if __name__ == "__main__":
if __name__ == "__main__":
if __name__ == "__main__":
if __name__ == "__main__":
if __name__ == "__main__":
if __name__ == "__main__":
if __name__ == "__main__":
if __name__ == "__main__":
if __name__ == "__main__":
if __name__ == "__main__":
if __name__ == "__main__":
if __name__ == "__main__":
if __name__ == "__main__":
if __name__ == "__main__":
if __name__ == "__main__":
if __name__ == "__main__":
if __name__ == "__main__":
if __name__ == "__main__":
if __name__ == "__main__":
if __name__ == "__main__":
if __name__ == "__main__":
if __name__ == "__main__":
if __name__ == "__main__":
if __name__ == "__main__":
if __name__ == "__main__":
    outpath, pts_final, stats = run_remove_outliers()    outpath, pts_final, stats = run_remove_outliers()    outpath, pts_final, stats = run_remove_outliers()    outpath, pts_final, stats = run_remove_outliers()    outpath, pts_final, stats = run_remove_outliers()    outpath, pts_final, stats = run_remove_outliers()    outpath, pts_final, stats = run_remove_outliers()    outpath, pts_final, stats = run_remove_outliers()    outpath, pts_final, stats = run_remove_outliers()    outpath, pts_final, stats = run_remove_outliers()    outpath, pts_final, stats = run_remove_outliers()    outpath, pts_final, stats = run_remove_outliers()    outpath, pts_final, stats = run_remove_outliers()    outpath, pts_final, stats = run_remove_outliers()    outpath, pts_final, stats = run_remove_outliers()    outpath, pts_final, stats = run_remove_outliers()    outpath, pts_final, stats = run_remove_outliers()    outpath, pts_final, stats = run_remove_outliers()    outpath, pts_final, stats = run_remove_outliers()    outpath, pts_final, stats = run_remove_outliers()    outpath, pts_final, stats = run_remove_outliers()    outpath, pts_final, stats = run_remove_outliers()    outpath, pts_final, stats = run_remove_outliers()    outpath, pts_final, stats = run_remove_outliers()    outpath, pts_final, stats = run_remove_outliers()    outpath, pts_final, stats = run_remove_outliers()    outpath, pts_final, stats = run_remove_outliers()    outpath, pts_final, stats = run_remove_outliers()    outpath, pts_final, stats = run_remove_outliers()    outpath, pts_final, stats = run_remove_outliers()    outpath, pts_final, stats = run_remove_outliers()    outpath, pts_final, stats = run_remove_outliers()    outpath, pts_final, stats = run_remove_outliers()    outpath, pts_final, stats = run_remove_outliers()    outpath, pts_final, stats = run_remove_outliers()    outpath, pts_final, stats = run_remove_outliers()    outpath, pts_final, stats = run_remove_outliers()
